# %% [markdown]
# ## 스타벅스 이디야 데이터 분석

# %% [markdown]
# ---

# %% [markdown]
# 현업에서는 파일의 양이 방대하기 때문에 파일들을 데이터베이스(DBMS)에 저장하고, 데이터베이스에서 쿼리를 통해 필요한 부분의 테이블만 가져와서 데이터를 전처리 및 시각화함

# %% [markdown]
# AWS RDS (MySQL) 에 프로젝트 관련 Database 를 생성하고, 접근 가능한 사용자 계정을 생성함
#
# - Database Name : oneday
# - User Name / Password : oneday / 1234

# %% [markdown]
# 자체 운영 데이터베이스 시스템보다 AWS RDS에서 데이터베이스를 사용해서 얻는 이점
# - 관리의 편리성 : 백업, 패치 관리, 복구 등을 AWS가 처리하여 사용자가 걱정할 필요가 없음
# - 확장성 : 클라우드 데이터베이스는 사용자의 요구에 따라 자원을 쉽게 확장하거나 축소 가능함
# - 보안 : AWS는 데이터를 암호화하여 저장하고 전송하여 기업의 데이터 유출을 예방함
# - 비용 효율성 : 클라우드 서비스는 '사용한 만큼만 지불'하는 모델을 제공하고, 이로 인해 사전에 큰 투자 없이 필요한 리소스를 사용할 수 있고, 비용을 예측하기 쉬움

# %%
# python에서 AWS RDS(mysql)에 연결
import mysql.connector
remote = mysql.connector.connect(
    host = "database-1.cx8zt2bohelq.us-east-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "vkfks134"
)

# %%
# 결과를 모두 소진해야 다음 쿼리를 실행하도록 커서 객체 생성
cursor = remote.cursor(buffered=True)

# 모든 데이터베이스 조회
cursor.execute('SHOW databases;')
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('oneday',),
#  ('performance_schema',),
#  ('sys',),
#  ('zerobase',),
#  ('zerodb',)]

# %% [markdown]
# 데이터베이스 생성 및 생성문 확인

# %%
# oneday 데이터베이스 생성
cursor.execute("CREATE DATABASE oneday DEFAULT CHARACTER SET utf8mb4;")  # utf8mb4는 이모지 등 유니코드 문자의 전체 범위 지원
cursor.execute('SHOW databases;')
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('oneday',),
#  ('performance_schema',),
#  ('sys',),
#  ('zerobase',),
#  ('zerodb',)]

# %%
# 데이터베이스 생성문 확인
cursor.execute("SHOW CREATE DATABASE oneday;")
cursor.fetchall()
# Out:
# [('oneday',
#   "CREATE DATABASE `oneday` /*!40100 DEFAULT CHARACTER SET utf8mb4 COLLATE utf8mb4_0900_ai_ci */ /*!80016 DEFAULT ENCRYPTION='N' */")]

# %% [markdown]
# user 조회, 삭제 및 생성

# %%
# user 조회
cursor.execute('USE mysql;')
cursor.execute('SELECT host, user FROM user;')
cursor.fetchall()
# Out:
# [('%', 'admin'),
#  ('%', 'oneday'),
#  ('%', 'zero'),
#  ('localhost', 'mysql.infoschema'),
#  ('localhost', 'mysql.session'),
#  ('localhost', 'mysql.sys'),
#  ('localhost', 'rdsadmin')]

# %%
# 기존 oneday 외부 유저 삭제
cursor.execute("DROP user 'oneday'@'%';")

# %%
# oneday 외부 유저 다시 생성
cursor.execute("CREATE user 'oneday'@'%' identified by '1234';")
cursor.execute("SELECT host, user FROM user;")
cursor.fetchall()
# Out:
# [('%', 'admin'),
#  ('%', 'oneday'),
#  ('%', 'zero'),
#  ('localhost', 'mysql.infoschema'),
#  ('localhost', 'mysql.session'),
#  ('localhost', 'mysql.sys'),
#  ('localhost', 'rdsadmin')]

# %% [markdown]
# user 권한 조회, 삭제 및 생성

# %%
# user 권한 조회
cursor.execute("SHOW GRANTS FOR 'oneday'@'%';")
cursor.fetchall()
# Out:
# [('GRANT USAGE ON *.* TO `oneday`@`%`',),
#  ('GRANT ALL PRIVILEGES ON `oneday`.* TO `oneday`@`%`',)]

# %%
# user 권한 제거
cursor.execute("REVOKE ALL ON oneday.* FROM 'oneday'@'%';")

# %%
# oneday 유저에게  다시 oneday 데이터베이스 권한 할당
cursor.execute("GRANT ALL ON oneday.* TO 'oneday'@'%';")
cursor.execute("SHOW GRANTS FOR 'oneday'@'%';")
cursor.fetchall()
# Out:
# [('GRANT USAGE ON *.* TO `oneday`@`%`',),
#  ('GRANT ALL PRIVILEGES ON `oneday`.* TO `oneday`@`%`',)]

# %% [markdown]
# 스타벅스 이디야 데이터를 저장할 테이블 구조 생성

# %%
# 커피 브랜드 테이블 구조 생성
cursor.execute("use oneday;")
# 기본키는 null 값이 있으면 안됨
cursor.execute("CREATE TABLE COFFEE_BRAND (id int not null primary key auto_increment, name varchar(255));")

# %% [markdown]
# - VARCHAR 필드의 크기는 설정할 수 있는 최대 길이를 의미하며, 실제 데이터의 길이에 따라 필요한 저장 공간이 달라짐

# %%
# 커피 스토어 테이블 구조 생성
cursor.execute("use oneday;")
cursor.execute(
    "CREATE TABLE COFFEE_STORE (id int NOT NULL PRIMARY KEY auto_increment, brand int NOT NULL, name varchar(32) NOT NULL, gu_name varchar(5) NOT NULL, address varchar(128) NOT NULL, lat decimal(16,14) NOT NULL, lng decimal(17,14) NOT NULL, FOREIGN KEY (brand) REFERENCES COFFEE_BRAND(id));"
)

# %%
cursor.execute("DESC COFFEE_BRAND;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('name', b'varchar(255)', 'YES', '', None, '')]

# %%
cursor.execute("DESC COFFEE_STORE;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('brand', b'int', 'NO', 'MUL', None, ''),
#  ('name', b'varchar(32)', 'NO', '', None, ''),
#  ('gu_name', b'varchar(5)', 'NO', '', None, ''),
#  ('address', b'varchar(128)', 'NO', '', None, ''),
#  ('lat', b'decimal(16,14)', 'NO', '', None, ''),
#  ('lng', b'decimal(17,14)', 'NO', '', None, '')]

# %% [markdown]
# COFFEE_BRAND 데이터를  입력하고 확인

# %%
# ID 값은 auto_increment로 자동으로 올라감
cursor.execute("insert into COFFEE_BRAND (name) values ('STARBUCKS'), ('EDIYA')")

# %%
remote.close()

# %%
cursor.close()
# Out:
# True

# %% [markdown]
# AWS RDS에 연결하여 oneday 계정을 만들고 해당 계정에 데이터베이스 권한을 주고 나서 다시 oneday 계정으로 로그인하여 작업을 계속하는 이유

# %% [markdown]
# - 보안 강화 및 작업 환경 분리  : admin 계정은 모든 권한을 가지고 있어서 강력하지만, 그만큼 위험도 큽니다. 실수로 데이터를 삭제하거나 변경할 수 있으며, 보안 위협에 더 노출될 수 있기 때문에 oneday 같은 특정 데이터베이스만 사용할 수 있는 계정을 사용하면 필요한 권한만 부여하여 리스크를 최소화할 수 있음

# %%
# python에서 AWS RDS(mysql)에 연결
import mysql.connector
remote = mysql.connector.connect(
    host = "database-1.cx8zt2bohelq.us-east-2.rds.amazonaws.com",
    port = 3306,
    user = "oneday",
    password = "1234"
)

# %%
cursor = remote.cursor(buffered=True)
cursor.execute("SHOW databases;")
cursor.fetchall()
# Out:
# [('information_schema',), ('oneday',), ('performance_schema',)]

# %%
cursor.execute("USE oneday;")
cursor.execute("DESC COFFEE_BRAND;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('name', b'varchar(255)', 'YES', '', None, '')]

# %%
cursor.execute("Desc COFFEE_STORE;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('brand', b'int', 'NO', 'MUL', None, ''),
#  ('name', b'varchar(32)', 'NO', '', None, ''),
#  ('gu_name', b'varchar(5)', 'NO', '', None, ''),
#  ('address', b'varchar(128)', 'NO', '', None, ''),
#  ('lat', b'decimal(16,14)', 'NO', '', None, ''),
#  ('lng', b'decimal(17,14)', 'NO', '', None, '')]

# %%
cursor.execute("INSERT INTO COFFEE_BRAND (name) VALUES ('STARBUCKS'), ('EDIYA')")

# %%
cursor.execute("SELECT * FROM COFFEE_BRAND;")
cursor.fetchall()
# Out:
# [(1, 'STARBUCKS'), (2, 'EDIYA')]

# %% [markdown]
# - 스타벅스 페이지에 접근하는 코드에서 팝업창이 없을 때 팝업창을 닫는 코드에서 에러가 발생하는데 이 때 예외처리 해서 에러 메시지 출력 및 실행이 중단되지 않도록 수정하기

# %%
# 스타벅스 페이지 크롤링
import warnings
from tqdm import tqdm
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException
warnings.simplefilter(action='ignore')

driver = webdriver.Chrome("./driver/chromedriver-win64/chromedriver.exe")
driver.get("https://www.starbucks.co.kr/store/store_map.do?disp=locale")

# 팝업창 닫기를 시도
try:
    driver.find_element_by_css_selector('.holiday_notice_close a').click()
except NoSuchElementException as e:
    print(e)
# Out:
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".holiday_notice_close a"}
#   (Session info: chrome=119.0.6045.106)

# %% [markdown]
# 스타벅스 페이지에서 데이터를 가져올때, COFFEE_STORE 테이블에 바로 입력하도록 수정하자
#
# - 데이터 세트: 매장 이름, 매장이 위치한 구 이름, 매장 주소, 위도, 경도
# - 필요한 데이터를 한세트씩 가져와서 COFFEE_STORE 테이블에 각각INSERT

# %%
# 서울 버튼 클릭
driver.find_element_by_css_selector(".sido_arae_box > li > a").click()

# %%
# 전체 선택
driver.find_element_by_css_selector(".gugun_arae_box > li > a").click()

# %%
# 서울시 전체 리스트 가져오기
seoul_list = driver.find_elements_by_css_selector("#mCSB_3_container ul li")
len(seoul_list)
# Out:
# 607

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# %%
seoul_list = soup.select("#mCSB_3_container ul li")
seoul_list
# Out:
# [<li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3672" data-hlytag="null" data-index="1" data-lat="37.510178" data-long="127.022223" data-name="논현역사거리" data-storecd="1434" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="논현역사거리" data-store="1434" data-yn="N">논현역사거리  </strong> <p class="result_details">서울특별시 강남구 강남대로 538 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3858" data-hlytag="null" data-index="2" data-lat="37.5139309" data-long="127.0206057" data-name="신사역성일빌딩" data-storecd="1595" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="신사역성일빌딩" data-store="1595" data-yn="N">신사역성일빌딩  </strong> <p class="result_details">서울특별시 강남구 강남대로 584 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3669" data-hlytag="null" data-index="3" data-lat="37.499517" data-long="127.031495" data-name="국기원사거리" data-storecd="1527" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="국기원사거리" data-store="1527" data-yn="N">국기원사거리  </strong> <p class="result_details">서울특별시 강남구 테헤란로 125 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3703" data-hlytag="null" data-index="4" data-lat="37.494668" data-long="127.062583" data-name="대치재경빌딩R" data-storecd="1468" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치재경빌딩R" data-store="1468" data-yn="N">대치재경빌딩R  </strong> <p class="result_details">서울특별시 강남구 남부순환로 2947 (대치동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3912" data-hlytag="null" data-index="5" data-lat="37.515000" data-long="127.063196" data-name="봉은사역" data-storecd="1640" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="봉은사역" data-store="1640" data-yn="N">봉은사역  </strong> <p class="result_details">서울특별시 강남구 봉은사로 619 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3893" data-hlytag="null" data-index="6" data-lat="37.5227934" data-long="127.0286009" data-name="압구정윤성빌딩" data-storecd="1650" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정윤성빌딩" data-store="1650" data-yn="N">압구정윤성빌딩  </strong> <p class="result_details">서울특별시 강남구 논현로 834 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3897" data-hlytag="null" data-index="7" data-lat="37.510150" data-long="127.060275" data-name="코엑스별마당" data-storecd="1626" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="코엑스별마당" data-store="1626" data-yn="N">코엑스별마당  </strong> <p class="result_details">서울특별시 강남구 영동대로 513 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3648" data-hlytag="null" data-index="8" data-lat="37.507750" data-long="127.060651" data-name="삼성역섬유센터R" data-storecd="1438" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성역섬유센터R" data-store="1438" data-yn="N">삼성역섬유센터R  </strong> <p class="result_details">서울특별시 강남구 테헤란로 518 (대치동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3623" data-hlytag="null" data-index="9" data-lat="37.5273669" data-long="127.033061" data-name="압구정R" data-storecd="1411" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정R" data-store="1411" data-yn="N">압구정R  </strong> <p class="result_details">서울특별시 강남구 언주로 861 (신사동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3588" data-hlytag="null" data-index="10" data-lat="37.488008" data-long="127.102650" data-name="수서역R" data-storecd="1389" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="수서역R" data-store="1389" data-yn="N">수서역R  </strong> <p class="result_details">서울특별시 강남구 광평로 281 (수서동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3604" data-hlytag="null" data-index="11" data-lat="37.485192" data-long="127.036685" data-name="양재강남빌딩R" data-storecd="1404" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="양재강남빌딩R" data-store="1404" data-yn="N">양재강남빌딩R  </strong> <p class="result_details">서울특별시 강남구 남부순환로 2621 (도곡동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3562" data-hlytag="null" data-index="12" data-lat="37.505321" data-long="127.050409" data-name="선릉동신빌딩R" data-storecd="1355" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="선릉동신빌딩R" data-store="1355" data-yn="N">선릉동신빌딩R  </strong> <p class="result_details">서울특별시 강남구 테헤란로 409 (삼성동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3564" data-hlytag="null" data-index="13" data-lat="37.511293" data-long="127.048409" data-name="봉은사로선정릉" data-storecd="1348" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="봉은사로선정릉" data-store="1348" data-yn="N">봉은사로선정릉  </strong> <p class="result_details">서울특별시 강남구 봉은사로 446 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3483" data-hlytag="null" data-index="14" data-lat="37.502117" data-long="127.026672" data-name="강남오거리" data-storecd="1255" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남오거리" data-store="1255" data-yn="N">강남오거리  </strong> <p class="result_details">서울특별시 강남구 봉은사로2길 39 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3467" data-hlytag="null" data-index="15" data-lat="37.50999" data-long="127.061455" data-name="스타필드코엑스몰R" data-storecd="1211" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="스타필드코엑스몰R" data-store="1211" data-yn="N">스타필드코엑스몰R  </strong> <p class="result_details">서울특별시 강남구 영동대로 513 (삼성동) 코엑스 A106호<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3397" data-hlytag="null" data-index="16" data-lat="37.518181" data-long="127.045995" data-name="강남구청정문" data-storecd="1188" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남구청정문" data-store="1188" data-yn="N">강남구청정문  </strong> <p class="result_details">서울특별시 강남구 학동로 419 (청담동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3496" data-hlytag="null" data-index="17" data-lat="37.492805" data-long="127.041309" data-name="도곡공원" data-storecd="1263" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="도곡공원" data-store="1263" data-yn="N">도곡공원  </strong> <p class="result_details">서울특별시 강남구 도곡로 205 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3478" data-hlytag="null" data-index="18" data-lat="37.497711" data-long="127.028439" data-name="강남R" data-storecd="1258" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남R" data-store="1258" data-yn="N">강남R  </strong> <p class="result_details">서울특별시 강남구 강남대로 390 (역삼동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3315" data-hlytag="null" data-index="19" data-lat="37.498973" data-long="127.060172" data-name="대치은마사거리" data-storecd="1099" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치은마사거리" data-store="1099" data-yn="N">대치은마사거리  </strong> <p class="result_details">서울특별시 강남구 도곡로 457 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3370" data-hlytag="null" data-index="20" data-lat="37.522156" data-long="127.056449" data-name="청담영동대로" data-storecd="1154" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="청담영동대로" data-store="1154" data-yn="N">청담영동대로  </strong> <p class="result_details">서울특별시 강남구 영동대로 720 (청담동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3303" data-hlytag="null" data-index="21" data-lat="37.526283" data-long="127.02956" data-name="압구정" data-storecd="1084" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정" data-store="1084" data-yn="N">압구정  </strong> <p class="result_details">서울특별시 강남구 압구정로30길 17 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3355" data-hlytag="null" data-index="22" data-lat="37.521933" data-long="127.022521" data-name="신사가로수" data-storecd="1159" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="신사가로수" data-store="1159" data-yn="N">신사가로수  </strong> <p class="result_details">서울특별시 강남구 가로수길 59 <br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3366" data-hlytag="null" data-index="23" data-lat="37.525216" data-long="127.041827" data-name="청담스타R" data-storecd="1146" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="청담스타R" data-store="1146" data-yn="N">청담스타R  </strong> <p class="result_details">서울특별시 강남구 도산대로57길 24 (청담동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3346" data-hlytag="null" data-index="24" data-lat="37.492396" data-long="127.03091" data-name="강남우성" data-storecd="1129" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남우성" data-store="1129" data-yn="N">강남우성  </strong> <p class="result_details">서울특별시 강남구 강남대로 328 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3171" data-hlytag="null" data-index="25" data-lat="37.52236449999999" data-long="127.03795430000002" data-name="학동사거리" data-storecd="991" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="학동사거리" data-store="991" data-yn="N">학동사거리  </strong> <p class="result_details">서울특별시 강남구 도산대로 328 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3287" data-hlytag="null" data-index="26" data-lat="37.503331" data-long="127.058817" data-name="대치사거리" data-storecd="1062" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치사거리" data-store="1062" data-yn="N">대치사거리  </strong> <p class="result_details">서울특별시 강남구 삼성로 402 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3235" data-hlytag="null" data-index="27" data-lat="37.5075307" data-long="127.05742710000004" data-name="포스코사거리" data-storecd="1038" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="포스코사거리" data-store="1038" data-yn="N">포스코사거리  </strong> <p class="result_details">서울특별시 강남구 테헤란로 505 (삼성동) 화진빌딩<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3096" data-hlytag="null" data-index="28" data-lat="37.5191632" data-long="127.0286446" data-name="을지병원사거리" data-storecd="914" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="을지병원사거리" data-store="914" data-yn="N">을지병원사거리  </strong> <p class="result_details">서울특별시 강남구 논현로 752 (논현동,구산빌딩)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3048" data-hlytag="null" data-index="29" data-lat="37.5162021" data-long="127.0207428" data-name="신사역" data-storecd="863" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="신사역" data-store="863" data-yn="N">신사역  </strong> <p class="result_details">서울특별시 강남구 도산대로 108 (논현동) 렉스타워<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3009" data-hlytag="null" data-index="30" data-lat="37.492167" data-long="127.057398" data-name="도곡역" data-storecd="825" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="도곡역" data-store="825" data-yn="N">도곡역  </strong> <p class="result_details">서울특별시 강남구 남부순환로 2909 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9998" data-hlytag="null" data-index="31" data-lat="37.514887" data-long="127.035653" data-name="서울세관사거리" data-storecd="815" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서울세관사거리" data-store="815" data-yn="N">서울세관사거리  </strong> <p class="result_details">서울특별시 강남구 언주로 650 (논현동) 한국건설기술인협회<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9926" data-hlytag="null" data-index="32" data-lat="37.5236351" data-long="127.04686509999999" data-name="청담사거리" data-storecd="734" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="청담사거리" data-store="734" data-yn="N">청담사거리  </strong> <p class="result_details">서울특별시 강남구 도산대로 458 (청담동) 리츠타워<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9883" data-hlytag="null" data-index="33" data-lat="37.496801" data-long="127.055055" data-name="한티역" data-storecd="687" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="한티역" data-store="687" data-yn="N">한티역  </strong> <p class="result_details">서울특별시 강남구 도곡로 408, 디마크빌딩 101호 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9939" data-hlytag="null" data-index="34" data-lat="37.4941059" data-long="127.03299730000003" data-name="역삼초교사거리" data-storecd="752" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼초교사거리" data-store="752" data-yn="N">역삼초교사거리  </strong> <p class="result_details">서울특별시 강남구 역삼로 123 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9933" data-hlytag="null" data-index="35" data-lat="37.513715" data-long="127.059245" data-name="코엑스몰" data-storecd="744" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="코엑스몰" data-store="744" data-yn="N">코엑스몰  </strong> <p class="result_details">서울특별시 강남구 영동대로 513 (삼성동) O103호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9861" data-hlytag="null" data-index="36" data-lat="37.5231593" data-long="127.02162499999997" data-name="가로수길" data-storecd="672" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="가로수길" data-store="672" data-yn="N">가로수길  </strong> <p class="result_details">서울특별시 강남구 논현로175길 94, 1~2층 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9826" data-hlytag="null" data-index="37" data-lat="37.501623" data-long="127.039375" data-name="역삼대로" data-storecd="632" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼대로" data-store="632" data-yn="N">역삼대로  </strong> <p class="result_details">서울특별시 강남구 테헤란로 211, 한국고등교육재단빌딩 1층 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9831" data-hlytag="null" data-index="38" data-lat="37.499721" data-long="127.033582" data-name="역삼포스코" data-storecd="636" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼포스코" data-store="636" data-yn="N">역삼포스코  </strong> <p class="result_details">서울특별시 강남구 테헤란로 134, P&amp;S TOWER (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9824" data-hlytag="null" data-index="39" data-lat="37.50314" data-long="127.025546" data-name="강남대로" data-storecd="630" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남대로" data-store="630" data-yn="N">강남대로  </strong> <p class="result_details">서울특별시 강남구 강남대로 456, 한석타워 2층 1-2호 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9859" data-hlytag="null" data-index="40" data-lat="37.5243631" data-long="127.05155990000003" data-name="청담" data-storecd="667" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="청담" data-store="667" data-yn="N">청담  </strong> <p class="result_details">서울특별시 강남구 도산대로 532, 인희빌딩 1층 (청담동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9835" data-hlytag="null" data-index="41" data-lat="37.5097863" data-long="127.05791339999996" data-name="삼성도심공항" data-storecd="643" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성도심공항" data-store="643" data-yn="N">삼성도심공항  </strong> <p class="result_details">서울특별시 강남구 테헤란로87길 33 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9792" data-hlytag="null" data-index="42" data-lat="37.507794" data-long="127.06517" data-name="삼성교" data-storecd="607" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성교" data-store="607" data-yn="N">삼성교  </strong> <p class="result_details">서울특별시 강남구 영동대로86길 12, 동남유화빌딩 1층<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9301" data-hlytag="null" data-index="43" data-lat="37.51464884" data-long="127.0307302" data-name="학동역" data-storecd="251" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="학동역" data-store="251" data-yn="N">학동역  </strong> <p class="result_details">서울특별시 강남구 논현로 704 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9263" data-hlytag="null" data-index="44" data-lat="37.49966175" data-long="127.0622171" data-name="대치" data-storecd="200" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치" data-store="200" data-yn="N">대치  </strong> <p class="result_details">서울특별시 강남구 도곡로 511 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9260" data-hlytag="null" data-index="45" data-lat="37.490298" data-long="127.054895" data-name="SSG마켓도곡R" data-storecd="198" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="SSG마켓도곡R" data-store="198" data-yn="N">SSG마켓도곡R  </strong> <p class="result_details">서울특별시 강남구 언주로30길 57, 타워팰리스Ⅱ F 지하1층 (도곡동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9238" data-hlytag="null" data-index="46" data-lat="37.50703529" data-long="127.0555503" data-name="삼성" data-storecd="180" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성" data-store="180" data-yn="N">삼성  </strong> <p class="result_details">서울특별시 강남구 테헤란로 443, 애플트리타워 1층 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9228" data-hlytag="null" data-index="47" data-lat="37.50377562" data-long="127.051196" data-name="선릉세화빌딩" data-storecd="170" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="선릉세화빌딩" data-store="170" data-yn="N">선릉세화빌딩  </strong> <p class="result_details">서울특별시 강남구 테헤란로64길 18 (대치동) 1층<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9213" data-hlytag="null" data-index="48" data-lat="37.52674095" data-long="127.0281105" data-name="압구정역" data-storecd="158" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정역" data-store="158" data-yn="N">압구정역  </strong> <p class="result_details">서울특별시 강남구 압구정로 170, 관영빌딩 1층 지하1층 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9431" data-hlytag="null" data-index="49" data-lat="37.52680046" data-long="127.0347174" data-name="압구정로" data-storecd="283" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정로" data-store="283" data-yn="N">압구정로  </strong> <p class="result_details">서울특별시 강남구 압구정로42길 32 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9447" data-hlytag="null" data-index="50" data-lat="37.49592355" data-long="127.0388645" data-name="구역삼사거리" data-storecd="279" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="구역삼사거리" data-store="279" data-yn="N">구역삼사거리  </strong> <p class="result_details">서울특별시 강남구 논현로 401 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9316" data-hlytag="null" data-index="51" data-lat="37.50236693" data-long="127.0407" data-name="큰길타워" data-storecd="278" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="큰길타워" data-store="278" data-yn="N">큰길타워  </strong> <p class="result_details">서울특별시 강남구 테헤란로 223, 큰길타워빌딩 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9319" data-hlytag="null" data-index="52" data-lat="37.5165849" data-long="127.04124330000002" data-name="강남구청역" data-storecd="275" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남구청역" data-store="275" data-yn="N">강남구청역  </strong> <p class="result_details">서울특별시 강남구 선릉로 669, 웰빙센터 1층 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9320" data-hlytag="null" data-index="53" data-lat="37.493554" data-long="127.061874" data-name="대치역" data-storecd="274" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치역" data-store="274" data-yn="N">대치역  </strong> <p class="result_details">서울특별시 강남구 남부순환로 2936 (대치동) 107호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9322" data-hlytag="null" data-index="54" data-lat="37.47781106" data-long="127.0451411" data-name="포이" data-storecd="272" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="포이" data-store="272" data-yn="N">포이  </strong> <p class="result_details">서울특별시 강남구 논현로 88 (개포동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9358" data-hlytag="null" data-index="55" data-lat="37.49971982" data-long="127.0349084" data-name="아크플레이스" data-storecd="19" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="아크플레이스" data-store="19" data-yn="N">아크플레이스  </strong> <p class="result_details">서울특별시 강남구 테헤란로 142 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9351" data-hlytag="null" data-index="56" data-lat="37.49803646" data-long="127.0684943" data-name="학여울역" data-storecd="3" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="학여울역" data-store="3" data-yn="N">학여울역  </strong> <p class="result_details">서울특별시 강남구 영동대로 215 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3170" data-hlytag="null" data-index="57" data-lat="37.51075489999999" data-long="127.04455970000003" data-name="선정릉역" data-storecd="989" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="선정릉역" data-store="989" data-yn="N">선정릉역  </strong> <p class="result_details">서울특별시 강남구 봉은사로 407 (삼성동) 에프오빌딩<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9478" data-hlytag="null" data-index="58" data-lat="37.51354184" data-long="127.0527183" data-name="삼성현대힐" data-storecd="58" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성현대힐" data-store="58" data-yn="N">삼성현대힐  </strong> <p class="result_details">서울특별시 강남구 삼성로 605 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9329" data-hlytag="null" data-index="59" data-lat="37.5018592" data-long="127.03727759999992" data-name="GS타워" data-storecd="266" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="GS타워" data-store="266" data-yn="N">GS타워  </strong> <p class="result_details">서울특별시 강남구 논현로 508 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9309" data-hlytag="null" data-index="60" data-lat="37.52405601" data-long="127.027915" data-name="압구정미소" data-storecd="259" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정미소" data-store="259" data-yn="N">압구정미소  </strong> <p class="result_details">서울특별시 강남구 논현로 841 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9308" data-hlytag="null" data-index="61" data-lat="37.50393894" data-long="127.0485135" data-name="선릉역" data-storecd="258" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="선릉역" data-store="258" data-yn="N">선릉역  </strong> <p class="result_details">서울특별시 강남구 테헤란로 334, LG화재 빌딩 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9678" data-hlytag="null" data-index="62" data-lat="37.515351" data-long="127.060109" data-name="코엑스사거리" data-storecd="484" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="코엑스사거리" data-store="484" data-yn="N">코엑스사거리  </strong> <p class="result_details">서울특별시 강남구 영동대로 616 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9663" data-hlytag="null" data-index="63" data-lat="37.492209" data-long="127.039389" data-name="역삼럭키" data-storecd="471" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼럭키" data-store="471" data-yn="N">역삼럭키  </strong> <p class="result_details">서울특별시 강남구 도곡로 183 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9598" data-hlytag="null" data-index="64" data-lat="37.528115" data-long="127.036441" data-name="신압구정" data-storecd="394" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="신압구정" data-store="394" data-yn="N">신압구정  </strong> <p class="result_details">서울특별시 강남구 언주로174길 29 (신사동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9517" data-hlytag="null" data-index="65" data-lat="37.50898041" data-long="127.0403869" data-name="아크로힐스논현" data-storecd="306" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="아크로힐스논현" data-store="306" data-yn="N">아크로힐스논현  </strong> <p class="result_details">서울특별시 강남구 봉은사로 304, 금강빌딩 1-2층 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9692" data-hlytag="null" data-index="66" data-lat="37.4964557" data-long="127.02968850000002" data-name="강남비젼타워" data-storecd="497" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남비젼타워" data-store="497" data-yn="N">강남비젼타워  </strong> <p class="result_details">서울특별시 강남구 테헤란로2길 27, 1층 101호 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9545" data-hlytag="null" data-index="67" data-lat="37.526549" data-long="127.040437" data-name="압구정로데오역" data-storecd="338" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="압구정로데오역" data-store="338" data-yn="N">압구정로데오역  </strong> <p class="result_details">서울특별시 강남구 선릉로 836, 삼원빌딩 1,2층 (청담동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9521" data-hlytag="null" data-index="68" data-lat="37.502721" data-long="127.044308" data-name="르네상스사거리" data-storecd="316" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="르네상스사거리" data-store="316" data-yn="N">르네상스사거리  </strong> <p class="result_details">서울특별시 강남구 테헤란로 306 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9531" data-hlytag="null" data-index="69" data-lat="37.50576" data-long="127.057966" data-name="포스코" data-storecd="325" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="포스코" data-store="325" data-yn="N">포스코  </strong> <p class="result_details">서울특별시 강남구 삼성로86길 7, 1층 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9752" data-hlytag="null" data-index="70" data-lat="37.505053" data-long="127.046577" data-name="선릉로" data-storecd="565" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="선릉로" data-store="565" data-yn="N">선릉로  </strong> <p class="result_details">서울특별시 강남구 선릉로93길 22, 대흥빌딩 1층 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9626" data-hlytag="null" data-index="71" data-lat="37.5115577" data-long="127.03226199999994" data-name="논현힐탑" data-storecd="430" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="논현힐탑" data-store="430" data-yn="N">논현힐탑  </strong> <p class="result_details">서울특별시 강남구 논현로 648 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9629" data-hlytag="null" data-index="72" data-lat="37.51736229999999" data-long="127.02329570000006" data-name="도산가로수길" data-storecd="433" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="도산가로수길" data-store="433" data-yn="N">도산가로수길  </strong> <p class="result_details">서울특별시 강남구 도산대로 134, 2층 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4024" data-hlytag="null" data-index="73" data-lat="37.4984818" data-long="127.052066" data-name="대치한티" data-storecd="1760" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치한티" data-store="1760" data-yn="N">대치한티  </strong> <p class="result_details">서울특별시 강남구 선릉로 324 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4409" data-hlytag="null" data-index="74" data-lat="37.4828551359882" data-long="127.0607152444621" data-name="개포동" data-storecd="2125" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="개포동" data-store="2125" data-yn="N">개포동  </strong> <p class="result_details">서울특별시 강남구 선릉로 34 (개포동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4153" data-hlytag="null" data-index="75" data-lat="37.4873267937748" data-long="127.103140081887" data-name="수서역사거리" data-storecd="1873" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="수서역사거리" data-store="1873" data-yn="N">수서역사거리  </strong> <p class="result_details">서울특별시 강남구 광평로 280 (수서동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3980" data-hlytag="null" data-index="76" data-lat="37.513019" data-long="127.059838" data-name="코엑스아셈타워" data-storecd="1710" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="코엑스아셈타워" data-store="1710" data-yn="N">코엑스아셈타워  </strong> <p class="result_details">서울특별시 강남구 영동대로 517 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4152" data-hlytag="null" data-index="77" data-lat="37.50369465391196" data-long="127.04172081609172" data-name="센터필드R" data-storecd="1831" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="센터필드R" data-store="1831" data-yn="N">센터필드R  </strong> <p class="result_details">서울특별시 강남구 테헤란로 231 (역삼동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4032" data-hlytag="null" data-index="78" data-lat="37.51966" data-long="127.0341" data-name="도산사거리" data-storecd="1813" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="도산사거리" data-store="1813" data-yn="N">도산사거리  </strong> <p class="result_details">서울특별시 강남구 언주로 727 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4079" data-hlytag="null" data-index="79" data-lat="37.467274319644" data-long="127.099929726" data-name="강남세곡" data-storecd="1800" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남세곡" data-store="1800" data-yn="N">강남세곡  </strong> <p class="result_details">서울특별시 강남구 헌릉로569길 18 (세곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3968" data-hlytag="null" data-index="80" data-lat="37.500313" data-long="127.066961" data-name="대치삼성프라자" data-storecd="1716" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="대치삼성프라자" data-store="1716" data-yn="N">대치삼성프라자  </strong> <p class="result_details">서울특별시 강남구 영동대로 237 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3820" data-hlytag="null" data-index="81" data-lat="37.507775" data-long="127.036472" data-name="언주역" data-storecd="2057" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="언주역" data-store="2057" data-yn="N">언주역  </strong> <p class="result_details">서울특별시 강남구 봉은사로 222 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4293" data-hlytag="null" data-index="82" data-lat="37.4970572543978" data-long="127.028180714381" data-name="강남역신분당역사" data-storecd="1975" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남역신분당역사" data-store="1975" data-yn="N">강남역신분당역사  </strong> <p class="result_details">서울특별시 강남구 강남대로 396 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4319" data-hlytag="null" data-index="83" data-lat="37.509206962541256" data-long="127.06560851480327" data-name="삼성역" data-storecd="2000" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성역" data-store="2000" data-yn="N">삼성역  </strong> <p class="result_details">서울특별시 강남구 테헤란로 620 (대치동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3990" data-hlytag="null" data-index="84" data-lat="37.50383" data-long="127.04487" data-name="테헤란로아남타워" data-storecd="1752" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="테헤란로아남타워" data-store="1752" data-yn="N">테헤란로아남타워  </strong> <p class="result_details">서울특별시 강남구 테헤란로 311 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4244" data-hlytag="null" data-index="85" data-lat="37.5078978596254" data-long="127.023338614644" data-name="강남논현" data-storecd="1902" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강남논현" data-store="1902" data-yn="N">강남논현  </strong> <p class="result_details">서울특별시 강남구 강남대로 512 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4104" data-hlytag="null" data-index="86" data-lat="37.510843366121534" data-long="127.06363342044263" data-name="삼성동" data-storecd="1846" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="삼성동" data-store="1846" data-yn="N">삼성동  </strong> <p class="result_details">서울특별시 강남구 영동대로96길 12 (삼성동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4486" data-hlytag="null" data-index="87" data-lat="37.5194407323478" data-long="127.049552661542" data-name="청담역" data-storecd="2204" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="청담역" data-store="2204" data-yn="N">청담역  <img alt="" class="mCS_img_loaded" src="//image.istarbucks.co.kr/common/img/store/icon_nstore.png"/></strong> <p class="result_details">서울특별시 강남구 삼성로 709 (청담동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4043" data-hlytag="null" data-index="88" data-lat="37.499367" data-long="127.048425" data-name="역삼이마트" data-storecd="1727" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼이마트" data-store="1727" data-yn="N">역삼이마트  </strong> <p class="result_details">서울특별시 강남구 역삼로 310 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3333" data-hlytag="null" data-index="89" data-lat="37.618319" data-long="127.021072" data-name="미아뉴타운" data-storecd="1120" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="미아뉴타운" data-store="1120" data-yn="N">미아뉴타운  </strong> <p class="result_details">서울특별시 강북구 삼양로 161 (미아동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3144" data-hlytag="null" data-index="90" data-lat="37.6400354" data-long="127.0273766" data-name="강북구청사거리" data-storecd="971" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강북구청사거리" data-store="971" data-yn="N">강북구청사거리  </strong> <p class="result_details">서울특별시 강북구 도봉로 365 (수유동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3059" data-hlytag="null" data-index="91" data-lat="37.611809" data-long="127.0306971" data-name="미아사거리역" data-storecd="872" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="미아사거리역" data-store="872" data-yn="N">미아사거리역  </strong> <p class="result_details">서울특별시 강북구 도봉로 32 (미아동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9304" data-hlytag="null" data-index="92" data-lat="37.6380167" data-long="127.02613500000007" data-name="수유역" data-storecd="254" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="수유역" data-store="254" data-yn="N">수유역  </strong> <p class="result_details">서울특별시 강북구 도봉로 342 (번동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9700" data-hlytag="null" data-index="93" data-lat="37.626148" data-long="127.026578" data-name="미아역" data-storecd="509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="미아역" data-store="509" data-yn="N">미아역  </strong> <p class="result_details">서울특별시 강북구 도봉로 196 (미아동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4192" data-hlytag="null" data-index="94" data-lat="37.664380074618" data-long="127.008566467101" data-name="파라스파라서울" data-storecd="1858" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="파라스파라서울" data-store="1858" data-yn="N">파라스파라서울  </strong> <p class="result_details">서울특별시 강북구 삼양로 689 (우이동) 파라스파라서울 지하1층<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3702" data-hlytag="null" data-index="95" data-lat="37.558509" data-long="126.835096" data-name="발산역사거리" data-storecd="1547" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="발산역사거리" data-store="1547" data-yn="N">발산역사거리  </strong> <p class="result_details">서울특별시 강서구 공항대로 248 (마곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3881" data-hlytag="null" data-index="96" data-lat="37.559611" data-long="126.826298" data-name="마곡역" data-storecd="1625" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="마곡역" data-store="1625" data-yn="N">마곡역  </strong> <p class="result_details">서울특별시 강서구 공항대로 168 (마곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3624" data-hlytag="null" data-index="97" data-lat="37.549501" data-long="126.835984" data-name="우장산역" data-storecd="1383" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="우장산역" data-store="1383" data-yn="N">우장산역  </strong> <p class="result_details">서울특별시 강서구 강서로 267 (내발산동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3585" data-hlytag="null" data-index="98" data-lat="37.5605261" data-long="126.833887" data-name="마곡사이언스타워R" data-storecd="1396" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="마곡사이언스타워R" data-store="1396" data-yn="N">마곡사이언스타워R  </strong> <p class="result_details">서울특별시 강서구 마곡동로 62 (마곡동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3480" data-hlytag="null" data-index="99" data-lat="37.574339" data-long="126.816415" data-name="방화DT" data-storecd="1311" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="방화DT" data-store="1311" data-yn="N">방화DT  </strong> <p class="result_details">서울특별시 강서구 방화대로 375 (방화동)<br/>1522-3232</p> <i class="pin_generalDT">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3504" data-hlytag="null" data-index="100" data-lat="37.56813" data-long="126.82614" data-name="마곡나루역" data-storecd="1267" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="마곡나루역" data-store="1267" data-yn="N">마곡나루역  </strong> <p class="result_details">서울특별시 강서구 마곡중앙로 161-17 (마곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3404" data-hlytag="null" data-index="101" data-lat="37.560487" data-long="126.829667" data-name="마곡GMG" data-storecd="1217" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="마곡GMG" data-store="1217" data-yn="N">마곡GMG  </strong> <p class="result_details">서울특별시 강서구 마곡중앙6로 16 (마곡동) 117,118,119,120호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3418" data-hlytag="null" data-index="102" data-lat="37.561640" data-long="126.853327" data-name="가양역" data-storecd="1196" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="가양역" data-store="1196" data-yn="N">가양역  </strong> <p class="result_details">서울특별시 강서구 양천로 476 (등촌동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3257" data-hlytag="null" data-index="103" data-lat="37.535149" data-long="126.863232" data-name="화곡DT" data-storecd="1114" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="화곡DT" data-store="1114" data-yn="N">화곡DT  </strong> <p class="result_details">서울특별시 강서구 등촌로 57 (화곡동)<br/>1522-3232</p> <i class="pin_generalDT">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3312" data-hlytag="null" data-index="104" data-lat="37.566964" data-long="126.840731" data-name="양천향교역" data-storecd="1119" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="양천향교역" data-store="1119" data-yn="N">양천향교역  </strong> <p class="result_details">서울특별시 강서구 강서로 463 (마곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3081" data-hlytag="null" data-index="105" data-lat="37.5405115" data-long="126.8372413" data-name="화곡동" data-storecd="909" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="화곡동" data-store="909" data-yn="N">화곡동  </strong> <p class="result_details">서울특별시 강서구 화곡로 142(화곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3083" data-hlytag="null" data-index="106" data-lat="37.5582043" data-long="126.84433919999992" data-name="등촌" data-storecd="898" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="등촌" data-store="898" data-yn="N">등촌  </strong> <p class="result_details">서울특별시 강서구 공항대로 329 (등촌동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9894" data-hlytag="null" data-index="107" data-lat="37.547359" data-long="126.874436" data-name="염창역" data-storecd="703" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="염창역" data-store="703" data-yn="N">염창역  </strong> <p class="result_details">서울특별시 강서구 공항대로 627 (염창동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9920" data-hlytag="null" data-index="108" data-lat="37.56033" data-long="126.839279" data-name="발산역" data-storecd="731" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="발산역" data-store="731" data-yn="N">발산역  </strong> <p class="result_details">서울특별시 강서구 강서로 388 (등촌동) 그랜드마트<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9738" data-hlytag="null" data-index="109" data-lat="37.532303" data-long="126.846077" data-name="까치산역" data-storecd="549" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="까치산역" data-store="549" data-yn="N">까치산역  </strong> <p class="result_details">서울특별시 강서구 강서로13길 3 (화곡동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4479" data-hlytag="null" data-index="110" data-lat="37.5579224739977" data-long="126.84054030692" data-name="발산역5번출구" data-storecd="2196" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="발산역5번출구" data-store="2196" data-yn="N">발산역5번출구  </strong> <p class="result_details">서울특별시 강서구 강서로52길 43 (내발산동, DH647), 1층 일부<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4328" data-hlytag="null" data-index="111" data-lat="37.542514" data-long="126.839062" data-name="화곡역8번출구" data-storecd="2013" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="화곡역8번출구" data-store="2013" data-yn="N">화곡역8번출구  </strong> <p class="result_details">서울특별시 강서구 강서로 179 (화곡동), 1층 일부<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4315" data-hlytag="null" data-index="112" data-lat="37.546305" data-long="126.835923" data-name="강서우장산" data-storecd="2003" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="강서우장산" data-store="2003" data-yn="N">강서우장산  </strong> <p class="result_details">서울특별시 강서구 강서로 231 (화곡동, 우장산역 해링턴 타워), 116/117/118/119/120호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4004" data-hlytag="null" data-index="113" data-lat="37.55101" data-long="126.86638" data-name="등촌대로" data-storecd="1771" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="등촌대로" data-store="1771" data-yn="N">등촌대로  </strong> <p class="result_details">서울특별시 강서구 공항대로 543 (염창동, 센터스퀘어)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3983" data-hlytag="null" data-index="114" data-lat="37.56007" data-long="126.855372" data-name="가양역사거리" data-storecd="1839" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="가양역사거리" data-store="1839" data-yn="N">가양역사거리  </strong> <p class="result_details">서울특별시 강서구 화곡로 416 (등촌동) 가양더스카이벨리5차 지식산업센터 101, 102, 114,~117호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
# ...
#  <li class="quickResultLstCon" data-code="4190" data-hlytag="null" data-index="569" data-lat="37.5549672" data-long="127.0201447" data-name="신금호역" data-storecd="2062" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="신금호역" data-store="2062" data-yn="N">신금호역  </strong> <p class="result_details">서울특별시 성동구 금호로 158-1 (금호동1가) 1~5층 전체<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4361" data-hlytag="null" data-index="570" data-lat="37.5605427226347" data-long="127.035267332652" data-name="왕십리역9번출구" data-storecd="2055" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="왕십리역9번출구" data-store="2055" data-yn="N">왕십리역9번출구  </strong> <p class="result_details">서울특별시 성동구 고산자로 234 (행당동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4237" data-hlytag="null" data-index="571" data-lat="37.5444620830457" data-long="127.055413311106" data-name="성수" data-storecd="1928" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="성수" data-store="1928" data-yn="N">성수  </strong> <p class="result_details">서울특별시 성동구 아차산로 104 (성수동2가)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4136" data-hlytag="null" data-index="572" data-lat="37.5430298" data-long="127.0133661" data-name="옥수" data-storecd="1862" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="옥수" data-store="1862" data-yn="N">옥수  </strong> <p class="result_details">서울특별시 성동구 독서당로 202 (옥수동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3959" data-hlytag="null" data-index="573" data-lat="37.547326" data-long="127.066367" data-name="성수낙낙" data-storecd="1712" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="성수낙낙" data-store="1712" data-yn="N">성수낙낙  </strong> <p class="result_details">서울특별시 성동구 광나루로8길 31 (성수동2가) 성수낙낙 1층 101~107호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3837" data-hlytag="null" data-index="574" data-lat="37.539305" data-long="126.963060" data-name="효창공원앞역" data-storecd="1572" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="효창공원앞역" data-store="1572" data-yn="N">효창공원앞역  </strong> <p class="result_details">서울특별시 용산구 백범로 313 (효창동, 용산 롯데캐슬 센터포레)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3918" data-hlytag="null" data-index="575" data-lat="37.555165" data-long="126.968446" data-name="서울역서부" data-storecd="1655" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서울역서부" data-store="1655" data-yn="N">서울역서부  </strong> <p class="result_details">서울특별시 용산구 만리재로 202 (서계동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3584" data-hlytag="null" data-index="576" data-lat="37.534273" data-long="126.994789" data-name="이태원역" data-storecd="1415" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="이태원역" data-store="1415" data-yn="N">이태원역  </strong> <p class="result_details">서울특별시 용산구 이태원로 188 (이태원동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3556" data-hlytag="null" data-index="577" data-lat="37.537131" data-long="127.00098" data-name="한강진역R" data-storecd="1339" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="한강진역R" data-store="1339" data-yn="N">한강진역R  </strong> <p class="result_details">서울특별시 용산구 이태원로 252 (한남동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3550" data-hlytag="null" data-index="578" data-lat="37.527586" data-long="126.965401" data-name="용산역써밋R" data-storecd="1340" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="용산역써밋R" data-store="1340" data-yn="N">용산역써밋R  </strong> <p class="result_details">서울특별시 용산구 한강대로 69 (한강로2가, 용산푸르지오써밋)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3518" data-hlytag="null" data-index="579" data-lat="37.518605" data-long="126.977271" data-name="이촌" data-storecd="1268" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="이촌" data-store="1268" data-yn="N">이촌  </strong> <p class="result_details">서울특별시 용산구 이촌로 276 (이촌동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3487" data-hlytag="null" data-index="580" data-lat="37.528702" data-long="126.966757" data-name="신용산역" data-storecd="1253" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="신용산역" data-store="1253" data-yn="N">신용산역  </strong> <p class="result_details">서울특별시 용산구 한강대로 95 (한강로2가, 래미안용산)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3386" data-hlytag="null" data-index="581" data-lat="37.523818" data-long="126.970389" data-name="용산파크타워" data-storecd="1170" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="용산파크타워" data-store="1170" data-yn="N">용산파크타워  </strong> <p class="result_details">서울특별시 용산구 서빙고로 67 (용산동5가, 파크타워)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3321" data-hlytag="null" data-index="582" data-lat="37.542831" data-long="126.972242" data-name="남영동" data-storecd="1115" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="남영동" data-store="1115" data-yn="N">남영동  </strong> <p class="result_details">서울특별시 용산구 한강대로 275 (갈월동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3288" data-hlytag="null" data-index="583" data-lat="37.53485" data-long="127.010919" data-name="한남동R" data-storecd="1093" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="한남동R" data-store="1093" data-yn="N">한남동R  </strong> <p class="result_details">서울특별시 용산구 독서당로 94 (한남동)<br/>1522-3232</p> <i class="pin_reserve">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3246" data-hlytag="null" data-index="584" data-lat="37.551102" data-long="126.988317" data-name="서울타워" data-storecd="1040" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서울타워" data-store="1040" data-yn="N">서울타워  </strong> <p class="result_details">서울특별시 용산구 남산공원길 105 (용산동2가) YTN서울타워 1층<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9934" data-hlytag="null" data-index="585" data-lat="37.551752" data-long="126.972694" data-name="서울역동자동" data-storecd="746" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서울역동자동" data-store="746" data-yn="N">서울역동자동  </strong> <p class="result_details">서울특별시 용산구 한강대로 372 (동자동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9800" data-hlytag="null" data-index="586" data-lat="37.533394" data-long="127.00563" data-name="순천향입구" data-storecd="612" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="순천향입구" data-store="612" data-yn="N">순천향입구  </strong> <p class="result_details">서울특별시 용산구 대사관로 67 (한남동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9391" data-hlytag="null" data-index="587" data-lat="37.54460479" data-long="126.9672252" data-name="숙대" data-storecd="135" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="숙대" data-store="135" data-yn="N">숙대  </strong> <p class="result_details">서울특별시 용산구 청파로47길 57 (청파동3가)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9462" data-hlytag="null" data-index="588" data-lat="37.5289857" data-long="126.991782" data-name="동빙고" data-storecd="94" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="동빙고" data-store="94" data-yn="N">동빙고  </strong> <p class="result_details">서울특별시 용산구 장문로 12 (동빙고동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9577" data-hlytag="null" data-index="589" data-lat="37.544118" data-long="126.971891" data-name="숙대입구역" data-storecd="370" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="숙대입구역" data-store="370" data-yn="N">숙대입구역  </strong> <p class="result_details">서울특별시 용산구 한강대로 291 (갈월동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9307" data-hlytag="null" data-index="590" data-lat="37.5288539" data-long="126.96404469999993" data-name="용산아이파크몰" data-storecd="257" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="용산아이파크몰" data-store="257" data-yn="N">용산아이파크몰  </strong> <p class="result_details">서울특별시 용산구 한강대로23길 55<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9568" data-hlytag="null" data-index="591" data-lat="37.52111" data-long="126.96905" data-name="동부이촌동" data-storecd="522" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="동부이촌동" data-store="522" data-yn="N">동부이촌동  </strong> <p class="result_details">서울특별시 용산구 이촌로 198 (이촌동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4341" data-hlytag="null" data-index="592" data-lat="37.54474797" data-long="126.96484196" data-name="숙명여대정문" data-storecd="2031" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="숙명여대정문" data-store="2031" data-yn="N">숙명여대정문  </strong> <p class="result_details">서울특별시 용산구 청파로47길 100 (청파동2가) 프라임관B1F(로비층)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4002" data-hlytag="null" data-index="593" data-lat="37.5258562" data-long="126.9676442" data-name="용산해링턴스퀘어" data-storecd="1740" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="용산해링턴스퀘어" data-store="1740" data-yn="N">용산해링턴스퀘어  </strong> <p class="result_details">서울특별시 용산구 서빙고로 17 (한강로3가)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4232" data-hlytag="null" data-index="594" data-lat="37.53854" data-long="126.98737" data-name="경리단길" data-storecd="1990" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="경리단길" data-store="1990" data-yn="N">경리단길  </strong> <p class="result_details">서울특별시 용산구 회나무로 3 (이태원동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4080" data-hlytag="null" data-index="595" data-lat="37.55415699928705" data-long="126.97179361292846" data-name="서울역사" data-storecd="1798" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서울역사" data-store="1798" data-yn="N">서울역사  </strong> <p class="result_details">서울특별시 용산구 한강대로 405 (동자동) 신-101호<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3891" data-hlytag="null" data-index="596" data-lat="37.538571" data-long="126.967409" data-name="용산리첸시아" data-storecd="1673" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="용산리첸시아" data-store="1673" data-yn="N">용산리첸시아  </strong> <p class="result_details">서울특별시 용산구 백범로 341 (원효로1가, 리첸시아 용산)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4160" data-hlytag="null" data-index="597" data-lat="37.55126" data-long="126.97273" data-name="포포인츠서울역" data-storecd="1889" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="포포인츠서울역" data-store="1889" data-yn="N">포포인츠서울역  </strong> <p class="result_details">서울특별시 용산구 한강대로 366 (동자동)<br/>1522-3232</p> <i class="pin_generalWT">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4185" data-hlytag="null" data-index="598" data-lat="37.53286105987034" data-long="126.96100091132484" data-name="용산전자랜드" data-storecd="1886" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="용산전자랜드" data-store="1886" data-yn="N">용산전자랜드  </strong> <p class="result_details">서울특별시 용산구 청파로 74 (한강로3가)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3223" data-hlytag="null" data-index="599" data-lat="37.597842" data-long="127.092509" data-name="상봉" data-storecd="1055" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="상봉" data-store="1055" data-yn="N">상봉  </strong> <p class="result_details">서울특별시 중랑구 상봉로 131 (상봉동, 상봉 듀오트리스 주상복합)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3135" data-hlytag="null" data-index="600" data-lat="37.5930326" data-long="127.07473579999998" data-name="중랑역" data-storecd="964" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="중랑역" data-store="964" data-yn="N">중랑역  </strong> <p class="result_details">서울특별시 중랑구 망우로30길 3 (상봉동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3087" data-hlytag="null" data-index="601" data-lat="37.60538908" data-long="127.0957558" data-name="중랑구청" data-storecd="903" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="중랑구청" data-store="903" data-yn="N">중랑구청  </strong> <p class="result_details">서울특별시 중랑구 신내로 72<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3023" data-hlytag="null" data-index="602" data-lat="37.579594" data-long="127.087966" data-name="사가정역" data-storecd="838" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="사가정역" data-store="838" data-yn="N">사가정역  </strong> <p class="result_details">서울특별시 중랑구 면목로 310<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="9686" data-hlytag="null" data-index="603" data-lat="37.59689" data-long="127.08647" data-name="상봉역" data-storecd="493" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="상봉역" data-store="493" data-yn="N">상봉역  </strong> <p class="result_details">서울특별시 중랑구 망우로 307 (상봉동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3936" data-hlytag="null" data-index="604" data-lat="37.615368" data-long="127.076633" data-name="묵동" data-storecd="1668" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="묵동" data-store="1668" data-yn="N">묵동  </strong> <p class="result_details">서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="4307" data-hlytag="null" data-index="605" data-lat="37.6066536267232" data-long="127.106359790053" data-name="양원역" data-storecd="2002" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="양원역" data-store="2002" data-yn="N">양원역  </strong> <p class="result_details">서울특별시 중랑구 양원역로10길 3 (망우동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
#  <li class="quickResultLstCon" data-code="3801" data-hlytag="null" data-index="606" data-lat="37.60170912407773" data-long="127.07841136432036" data-name="중화역" data-storecd="1749" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="중화역" data-store="1749" data-yn="N">중화역  </strong> <p class="result_details">서울특별시 중랑구 봉화산로 35 <br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>]

# %% [markdown]
# #### 하나만 테스트 해보자

# %%
# 매장 이름
title = seoul_list[0]["data-name"]
title
# Out:
# '역삼아레나빌딩'

# %%
# 주소
address = seoul_list[0].select_one("p").text[:-9]
address
# Out:
# '서울특별시 강남구 언주로 425 (역삼동)'

# %%
# 구 이름
gu_name = address.split(' ')[1]
gu_name
# Out:
# '강남구'

# %%
# 위도 및 경도
lat = seoul_list[0]["data-lat"]
lng = seoul_list[0]["data-long"]
lat, lng
# Out:
# ('37.501087', '127.043069')

# %%
# 서울시 스타벅스 전체매장
for content in tqdm(seoul_list):

    # 매장 이름
    title = content["data-name"]
    

    # 주소
    address = content.select_one("p").text[:-9]
    

    # 구 이름
    gu_name = address.split(' ')[1]

    # 위도, 경도
    lat = content["data-lat"]
    lng = content["data-long"]

    # 테이블에 insert
    sql = "INSERT INTO COFFEE_STORE (brand, name, gu_name, address, lat, lng) VALUES (1, %s, %s, %s, %s, %s)"
    cursor.execute(sql, (title, gu_name, address, lat, lng))
    conn.commit()
# Out:
# 100%|██████████| 607/607 [04:03<00:00,  2.49it/s]

# %%
driver.close()

# %%
# 총 개수 확인
cursor.execute("SELECT COUNT(*) FROM COFFEE_STORE")
result = cursor.fetchall()
result
# Out:
# [(607,)]

# %%
# 10개만 보기
cursor.execute("SELECT * FROM COFFEE_STORE LIMIT 10;")
result = cursor.fetchall()
result
# Out:
# [(1,
#   1,
#   '역삼아레나빌딩',
#   '강남구',
#   '서울특별시 강남구 언주로 425 (역삼동)',
#   Decimal('37.50108700000000'),
#   Decimal('127.04306900000000')),
#  (2,
#   1,
#   '논현역사거리',
#   '강남구',
#   '서울특별시 강남구 강남대로 538 (논현동)',
#   Decimal('37.51017800000000'),
#   Decimal('127.02222300000000')),
#  (3,
#   1,
#   '신사역성일빌딩',
#   '강남구',
#   '서울특별시 강남구 강남대로 584 (논현동)',
#   Decimal('37.51393090000000'),
#   Decimal('127.02060570000000')),
#  (4,
#   1,
#   '국기원사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 125 (역삼동)',
#   Decimal('37.49951700000000'),
#   Decimal('127.03149500000000')),
#  (5,
#   1,
#   '대치재경빌딩R',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2947 (대치동)',
#   Decimal('37.49466800000000'),
#   Decimal('127.06258300000000')),
#  (6,
#   1,
#   '봉은사역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 619 (삼성동)',
#   Decimal('37.51500000000000'),
#   Decimal('127.06319600000000')),
#  (7,
#   1,
#   '압구정윤성빌딩',
#   '강남구',
#   '서울특별시 강남구 논현로 834 (신사동)',
#   Decimal('37.52279340000000'),
#   Decimal('127.02860090000000')),
#  (8,
#   1,
#   '코엑스별마당',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동)',
#   Decimal('37.51015000000000'),
#   Decimal('127.06027500000000')),
#  (9,
#   1,
#   '삼성역섬유센터R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 518 (대치동)',
#   Decimal('37.50775000000000'),
#   Decimal('127.06065100000000')),
#  (10,
#   1,
#   '압구정R',
#   '강남구',
#   '서울특별시 강남구 언주로 861 (신사동)',
#   Decimal('37.52736690000000'),
#   Decimal('127.03306100000000'))]

# %%
cursor.close()
# Out:
# True

# %% [markdown]
# 이디야 페이지에서 데이터를 가져올때, COFFEE_STORE 테이블에 바로 입력하도록 수정하자
#
# - 데이터 세트 : 매장 이름, 매장이 위치한 구 이름, 매장 주소, 위도, 경도
# - 이디야 페이지에서 검색에 사용할 구 이름은 COFFEE_STORE 에서 중복을 제거하는 쿼리(distinct)를 사용하여 가져와서 {서울  + 구이름} 형식으로 변환하여 사용하자
# - 필요한 데이터를 한 세트씩 가져와서 COFFEE_STORE 테이블에 각각 INSERT
# - COFFEE_STORE 테이블에 입력할 구 이름은 {'서울 '} 이 제거된 구 이름!

# %% [markdown]
# 제출 6.
# - 이디야 데이터 관련 코드 & 실행 결과 (ipynb)

# %%
# 이디야 페이지 크롤링
import warnings
from tqdm import tqdm_notebook
from selenium import webdriver
from bs4 import BeautifulSoup
warnings.simplefilter(action='ignore')

driver = webdriver.Chrome("./driver/chromedriver-win64/chromedriver.exe")
driver.get("https://ediya.com/contents/find_store.html")

# %%
# 주소 탭 클릭
driver.find_element_by_css_selector("#contentWrap > div.contents > div > div.store_search_pop > ul > li:nth-child(2) > a").click()

# %%
import mysql.connector

conn = mysql.connector.connect(
    host = "database-1.cx8zt2bohelq.us-east-2.rds.amazonaws.com",
    port = 3306,
    user = "oneday",
    password = "1234"
)

cursor = conn.cursor(buffered=True)

# %%
conn.close()
cursor.close()
# Out:
# True

# %%
cursor.execute("USE oneday;")

# %%
# 검색어는 COFFEE_STORE에서 중복 없는 gu_name을 가져와 "서울 "과 합침
cursor.execute("SELECT DISTINCT (gu_name) FROM COFFEE_STORE;")
result = cursor.fetchall()
gu_list = ['서울 ' + name[0] for name in result]

len(gu_list), gu_list[:3]
# Out:
# (25, ['서울 강남구', '서울 강북구', '서울 강서구'])

# %%
# 구별 검색어 검색창에 입력 (하나만 테스트)
search_keyword = driver.find_element_by_css_selector("#keyword")
search_keyword.clear()
search_keyword.send_keys(gu_list[0])

# %%
# 검색 버튼 클릭
search_button = driver.find_element_by_css_selector("#keyword_div > form > button")
search_button.click()

# %%
# 검색 결과 리스트 가져오기
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
contents = soup.select("#placesList li")
len(contents)
# Out:
# 39

# %%
# 매장 이름, 주소 데이터 수집
title = contents[0].select_one('dt').text
address = contents[0].select_one('dd').text
title, address
# Out:
# ('강남YMCA점', '서울 강남구 논현동')

# %%
driver.close()

# %%
# 구 이름
gu_name = address.split(' ')[1]
gu_name
# Out:
# '강남구'

# %%
# 구글맵 이용
import googlemaps
gmaps_key = "AIzaSyDrXFafxS1zYn77x1jEXHGoJ43_LZGudtc"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
# 위도, 경도

tmp = gmaps.geocode(address, language='ko')
tmp
# Out:
# [{'address_components': [{'long_name': '논현동',
#     'short_name': '논현동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 강남구 논현동',
#   'geometry': {'bounds': {'northeast': {'lat': 37.5231802, 'lng': 127.0438519},
#     'southwest': {'lat': 37.5044773, 'lng': 127.0195255}},
#    'location': {'lat': 37.5136787, 'lng': 127.0317124},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 37.5231802, 'lng': 127.0438519},
#     'southwest': {'lat': 37.5044773, 'lng': 127.0195255}}},
#   'place_id': 'ChIJh8vInfGjfDUR2f7GJmldEIY',
#   'types': ['political', 'sublocality', 'sublocality_level_2']}]

# %%
#  API 응답의 완전성을 위해 필요한 것
tmp[0].get("formatted_address")
# Out:
# '대한민국 서울특별시 중랑구 묵동 2 묵동 2번지 중랑구 서울특별시 KR 02021'

# %%
lat = tmp[0]["geometry"]["location"]["lat"]
lng = tmp[0]["geometry"]["location"]["lng"]
lat, lng
# Out:
# (37.5136787, 127.0317124)

# %%
import mysql.connector

conn = mysql.connector.connect(
    host = "database-1.cx8zt2bohelq.us-east-2.rds.amazonaws.com",
    port = 3306,
    user = "oneday",
    password = "1234"
)

cursor = conn.cursor(buffered=True)

# %%
# 이디야 매장 전체 데이터 구하기
import time
import googlemaps

driver = webdriver.Chrome("./driver/chromedriver-win64/chromedriver.exe")
driver.get("https://ediya.com/contents/find_store.html")

# 주소 탭 클릭
driver.find_element_by_css_selector("#contentWrap > div.contents > div > div.store_search_pop > ul > li:nth-child(2) > a").click()

search_keyword = driver.find_element_by_css_selector("#keyword")
search_button = driver.find_element_by_css_selector("#keyword_div button")

cursor.execute("USE oneday;")
# 테이블에 insert
sql = "INSERT INTO COFFEE_STORE (brand, name, gu_name, address, lat, lng) VALUES (2, %s, %s, %s, %s, %s)"
time.sleep(1)


for gu in gu_list:
    # 구별 검색어 검색창에 입력
    search_keyword.clear()
    search_keyword.send_keys(gu)
    
    # 검색 버튼 클릭
    search_button.click()
    time.sleep(1)

    # 검색 결과 리스트 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    contents = soup.select("#placesList li")

    for content in contents:
        # 매장 이름, 주소, 구 이름 데이터 수집
        title = content.select_one('dt').text
        address = content.select_one('dd').text
        gu_name = address.split(' ')[1]


        try:
            tmp = gmaps.geocode(address, language='ko')
            if tmp:
                tmp[0].get("formatted_address")
                lat = tmp[0]["geometry"]["location"]["lat"]
                lng = tmp[0]["geometry"]["location"]["lng"]
                cursor.execute(sql, (title, gu_name, address, lat, lng))
                conn.commit()
            else:
                print("주소를 찾을 수 없습니다: ", address)
        except IndexError as e:
            print("주소 처리 중 오류 발생: ", address)
            print(str(e))
# Out:
# 주소를 찾을 수 없습니다:  서울 관악구 남부순환로 1369 (신림동, 관악농협농산물백화점)
# 주소를 찾을 수 없습니다:  서울 마포구 신촌로 66 (노고산동, 농협중앙회)
# 주소를 찾을 수 없습니다:  서울 서대문구 수색로 100 (북가좌동, DMC래미안e편한세상)
# 주소를 찾을 수 없습니다:  서울 서초구 서초대로 108 (방배동, 삼보빌딩)
# 주소를 찾을 수 없습니다:  서울 송파구 충민로 66 (문정동, 가든파이브라이프)
# 주소를 찾을 수 없습니다:  서울 송파구 송파대로 567 (잠실동, 잠실주공아파트)
# 주소를 찾을 수 없습니다:  서울 영등포구 63로 40 (여의도동, 라이프오피스텔)

# %% [markdown]
# 위와 같이 구글맵 api 를 통해서 얻어올 수 없을 경우 예외처리를 하여 해당 주소들의 위도, 경도 값을 http://map.esran.com/  가져와야 함
# 또한 찾은 위도, 경도 값은 손수 넣어줘야 함

# %%
driver.close()

# %%
cursor.execute("USE oneday;")
cursor.execute("DELETE FROM COFFEE_STORE WHERE brand=2;")

# %%
cursor.execute("SELECT * FROM COFFEE_STORE order by id desc;")
cursor.fetchall()
# Out:
# [(607,
#   1,
#   '중화역',
#   '중랑구',
#   '서울특별시 중랑구 봉화산로 35 ',
#   Decimal('37.60170912407773'),
#   Decimal('127.07841136432036')),
#  (606,
#   1,
#   '양원역',
#   '중랑구',
#   '서울특별시 중랑구 양원역로10길 3 (망우동)',
#   Decimal('37.60665362672320'),
#   Decimal('127.10635979005300')),
#  (605,
#   1,
#   '묵동',
#   '중랑구',
#   '서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층',
#   Decimal('37.61536800000000'),
#   Decimal('127.07663300000000')),
#  (604,
#   1,
#   '상봉역',
#   '중랑구',
#   '서울특별시 중랑구 망우로 307 (상봉동)',
#   Decimal('37.59689000000000'),
#   Decimal('127.08647000000000')),
#  (603,
#   1,
#   '사가정역',
#   '중랑구',
#   '서울특별시 중랑구 면목로 310',
#   Decimal('37.57959400000000'),
#   Decimal('127.08796600000000')),
#  (602,
#   1,
#   '중랑구청',
#   '중랑구',
#   '서울특별시 중랑구 신내로 72',
#   Decimal('37.60538908000000'),
#   Decimal('127.09575580000000')),
#  (601,
#   1,
#   '중랑역',
#   '중랑구',
#   '서울특별시 중랑구 망우로30길 3 (상봉동)',
#   Decimal('37.59303260000000'),
#   Decimal('127.07473579999998')),
#  (600,
#   1,
#   '상봉',
#   '중랑구',
#   '서울특별시 중랑구 상봉로 131 (상봉동, 상봉 듀오트리스 주상복합)',
#   Decimal('37.59784200000000'),
#   Decimal('127.09250900000000')),
#  (599,
#   1,
#   '용산전자랜드',
#   '용산구',
#   '서울특별시 용산구 청파로 74 (한강로3가)',
#   Decimal('37.53286105987034'),
#   Decimal('126.96100091132484')),
#  (598,
#   1,
#   '포포인츠서울역',
#   '용산구',
#   '서울특별시 용산구 한강대로 366 (동자동)',
#   Decimal('37.55126000000000'),
#   Decimal('126.97273000000000')),
#  (597,
#   1,
#   '용산리첸시아',
#   '용산구',
#   '서울특별시 용산구 백범로 341 (원효로1가, 리첸시아 용산)',
#   Decimal('37.53857100000000'),
#   Decimal('126.96740900000000')),
#  (596,
#   1,
#   '서울역사',
#   '용산구',
#   '서울특별시 용산구 한강대로 405 (동자동) 신-101호',
#   Decimal('37.55415699928705'),
#   Decimal('126.97179361292846')),
#  (595,
#   1,
#   '경리단길',
#   '용산구',
#   '서울특별시 용산구 회나무로 3 (이태원동)',
#   Decimal('37.53854000000000'),
#   Decimal('126.98737000000000')),
#  (594,
#   1,
#   '용산해링턴스퀘어',
#   '용산구',
#   '서울특별시 용산구 서빙고로 17 (한강로3가)',
#   Decimal('37.52585620000000'),
#   Decimal('126.96764420000000')),
#  (593,
#   1,
#   '숙명여대정문',
#   '용산구',
#   '서울특별시 용산구 청파로47길 100 (청파동2가) 프라임관B1F(로비층)',
#   Decimal('37.54474797000000'),
#   Decimal('126.96484196000000')),
#  (592,
#   1,
#   '동부이촌동',
#   '용산구',
#   '서울특별시 용산구 이촌로 198 (이촌동)',
#   Decimal('37.52111000000000'),
#   Decimal('126.96905000000000')),
#  (591,
#   1,
#   '용산아이파크몰',
#   '용산구',
#   '서울특별시 용산구 한강대로23길 55',
#   Decimal('37.52885390000000'),
#   Decimal('126.96404469999993')),
#  (590,
#   1,
#   '숙대입구역',
#   '용산구',
#   '서울특별시 용산구 한강대로 291 (갈월동)',
#   Decimal('37.54411800000000'),
#   Decimal('126.97189100000000')),
#  (589,
#   1,
#   '동빙고',
#   '용산구',
#   '서울특별시 용산구 장문로 12 (동빙고동)',
#   Decimal('37.52898570000000'),
#   Decimal('126.99178200000000')),
#  (588,
#   1,
#   '숙대',
#   '용산구',
#   '서울특별시 용산구 청파로47길 57 (청파동3가)',
#   Decimal('37.54460479000000'),
#   Decimal('126.96722520000000')),
#  (587,
#   1,
#   '순천향입구',
#   '용산구',
#   '서울특별시 용산구 대사관로 67 (한남동)',
#   Decimal('37.53339400000000'),
#   Decimal('127.00563000000000')),
#  (586,
#   1,
#   '서울역동자동',
#   '용산구',
#   '서울특별시 용산구 한강대로 372 (동자동)',
#   Decimal('37.55175200000000'),
#   Decimal('126.97269400000000')),
#  (585,
#   1,
#   '서울타워',
#   '용산구',
#   '서울특별시 용산구 남산공원길 105 (용산동2가) YTN서울타워 1층',
#   Decimal('37.55110200000000'),
#   Decimal('126.98831700000000')),
#  (584,
#   1,
#   '한남동R',
#   '용산구',
#   '서울특별시 용산구 독서당로 94 (한남동)',
#   Decimal('37.53485000000000'),
#   Decimal('127.01091900000000')),
#  (583,
#   1,
#   '남영동',
#   '용산구',
#   '서울특별시 용산구 한강대로 275 (갈월동)',
#   Decimal('37.54283100000000'),
#   Decimal('126.97224200000000')),
#  (582,
#   1,
#   '용산파크타워',
#   '용산구',
#   '서울특별시 용산구 서빙고로 67 (용산동5가, 파크타워)',
#   Decimal('37.52381800000000'),
#   Decimal('126.97038900000000')),
#  (581,
#   1,
#   '신용산역',
#   '용산구',
#   '서울특별시 용산구 한강대로 95 (한강로2가, 래미안용산)',
#   Decimal('37.52870200000000'),
#   Decimal('126.96675700000000')),
#  (580,
#   1,
#   '이촌',
#   '용산구',
#   '서울특별시 용산구 이촌로 276 (이촌동)',
#   Decimal('37.51860500000000'),
#   Decimal('126.97727100000000')),
#  (579,
#   1,
#   '용산역써밋R',
#   '용산구',
#   '서울특별시 용산구 한강대로 69 (한강로2가, 용산푸르지오써밋)',
#   Decimal('37.52758600000000'),
#   Decimal('126.96540100000000')),
#  (578,
#   1,
#   '한강진역R',
#   '용산구',
#   '서울특별시 용산구 이태원로 252 (한남동)',
#   Decimal('37.53713100000000'),
#   Decimal('127.00098000000000')),
#  (577,
#   1,
#   '이태원역',
#   '용산구',
#   '서울특별시 용산구 이태원로 188 (이태원동)',
#   Decimal('37.53427300000000'),
#   Decimal('126.99478900000000')),
#  (576,
#   1,
#   '서울역서부',
#   '용산구',
#   '서울특별시 용산구 만리재로 202 (서계동)',
#   Decimal('37.55516500000000'),
#   Decimal('126.96844600000000')),
#  (575,
#   1,
#   '효창공원앞역',
#   '용산구',
#   '서울특별시 용산구 백범로 313 (효창동, 용산 롯데캐슬 센터포레)',
#   Decimal('37.53930500000000'),
#   Decimal('126.96306000000000')),
#  (574,
#   1,
#   '성수낙낙',
#   '성동구',
#   '서울특별시 성동구 광나루로8길 31 (성수동2가) 성수낙낙 1층 101~107호',
#   Decimal('37.54732600000000'),
#   Decimal('127.06636700000000')),
#  (573,
#   1,
#   '옥수',
#   '성동구',
#   '서울특별시 성동구 독서당로 202 (옥수동)',
#   Decimal('37.54302980000000'),
#   Decimal('127.01336610000000')),
#  (572,
#   1,
#   '성수',
#   '성동구',
#   '서울특별시 성동구 아차산로 104 (성수동2가)',
#   Decimal('37.54446208304570'),
#   Decimal('127.05541331110600')),
#  (571,
#   1,
#   '왕십리역9번출구',
#   '성동구',
#   '서울특별시 성동구 고산자로 234 (행당동)',
#   Decimal('37.56054272263470'),
#   Decimal('127.03526733265200')),
#  (570,
#   1,
#   '신금호역',
#   '성동구',
#   '서울특별시 성동구 금호로 158-1 (금호동1가) 1~5층 전체',
#   Decimal('37.55496720000000'),
#   Decimal('127.02014470000000')),
#  (569,
#   1,
#   '엔터식스',
#   '성동구',
#   '서울특별시 성동구 왕십리광장로 17 (행당동)',
#   Decimal('37.56175811000000'),
#   Decimal('127.03833280000000')),
#  (568,
#   1,
#   '한양대',
#   '성동구',
#   '서울특별시 성동구 왕십리로 225 (행당동) 1,2층',
#   Decimal('37.55726984000000'),
#   Decimal('127.04216490000000')),
#  (567,
#   1,
#   '왕십리역',
#   '성동구',
#   '서울특별시 성동구 왕십리로 326 (도선동)',
#   Decimal('37.56275410000000'),
#   Decimal('127.03390720000000')),
#  (566,
#   1,
#   '상왕십리역',
#   '성동구',
#   '서울특별시 성동구 왕십리로 382 (하왕십리동)',
#   Decimal('37.56516900000000'),
#   Decimal('127.02790700000000')),
#  (565,
#   1,
#   '성수역',
#   '성동구',
#   '서울특별시 성동구 성수이로 94 (성수동2가)',
#   Decimal('37.54319300000000'),
#   Decimal('127.05694300000000')),
#  (564,
#   1,
#   '황학사거리',
#   '성동구',
#   '서울특별시 성동구 왕십리로 410 (하왕십리동, 센트라스)',
#   Decimal('37.56764400000000'),
#   Decimal('127.02369700000000')),
#  (563,
#   1,
#   '뚝섬역',
#   '성동구',
#   '서울특별시 성동구 아차산로 42 (성수동1가)',
#   Decimal('37.54643200000000'),
#   Decimal('127.04904200000000')),
#  (562,
#   1,
#   '금호역',
#   '성동구',
#   '서울특별시 성동구 동호로 99 (금호동4가)',
#   Decimal('37.54799390000000'),
#   Decimal('127.01533430000000')),
#  (561,
#   1,
#   '서울숲역',
#   '성동구',
#   '서울특별시 성동구 왕십리로 50 (성수동1가) 1층',
#   Decimal('37.54207500000000'),
#   Decimal('127.04496100000000')),
#  (560,
#   1,
#   '청량리역사',
#   '동대문구',
#   '서울특별시 동대문구 왕산로 214 (전농동)',
#   Decimal('37.57945000000000'),
#   Decimal('127.04785000000000')),
#  (559,
#   1,
#   '경동1960',
#   '동대문구',
#   '서울특별시 동대문구 고산자로36길 3 (제기동)',
#   Decimal('37.57961410214940'),
#   Decimal('127.03868496377300')),
#  (558,
#   1,
#   '경희대',
#   '동대문구',
#   '서울특별시 동대문구 경희대로 16-1 (회기동)',
#   Decimal('37.59288120000000'),
#   Decimal('127.05280849999997')),
#  (557,
#   1,
#   '장한평역',
#   '동대문구',
#   '서울특별시 동대문구 장한로 10 (장안동)',
#   Decimal('37.56233700000000'),
#   Decimal('127.06551100000000')),
#  (556,
#   1,
#   '외대',
#   '동대문구',
#   '서울특별시 동대문구 휘경로 12-1 (이문동)',
#   Decimal('37.59575188000000'),
#   Decimal('127.06140020000000')),
#  (555,
#   1,
#   '회기역사거리',
#   '동대문구',
#   '서울특별시 동대문구 이문로 37 (회기동)',
#   Decimal('37.59078400000000'),
#   Decimal('127.05609800000000')),
#  (554,
#   1,
#   '신설동역',
#   '동대문구',
#   '서울특별시 동대문구 왕산로 19 (신설동)',
#   Decimal('37.57672280000000'),
#   Decimal('127.02554460000000')),
#  (553,
#   1,
#   '외대정문',
#   '동대문구',
#   '서울특별시 동대문구 이문로 93 (이문동)',
#   Decimal('37.59534640000000'),
#   Decimal('127.05903020000000')),
#  (552,
#   1,
#   '경희대삼거리',
#   '동대문구',
#   '서울특별시 동대문구 회기로 141 (회기동)',
#   Decimal('37.59153100000000'),
#   Decimal('127.05201700000000')),
#  (551,
#   1,
#   '답십리역',
#   '동대문구',
#   '서울특별시 동대문구 천호대로 263 (답십리동)',
#   Decimal('37.56846600000000'),
#   Decimal('127.05110600000000')),
#  (550,
#   1,
#   '고척아이파크',
#   '구로구',
#   '서울특별시 구로구 경인로43길 49 (고척동, 고척아이파크), 1층 D-101호',
#   Decimal('37.49930562934076'),
#   Decimal('126.85822089235810')),
#  (549,
#   1,
#   '구로구청',
#   '구로구',
#   '서울특별시 구로구 가마산로 232 (구로동, 스페스큐브), B101호',
#   Decimal('37.49395067031256'),
#   Decimal('126.88676120707717')),
#  (548,
#   1,
#   '구로오류DT',
#   '구로구',
#   '서울특별시 구로구 서해안로 2233 (오류동)',
#   Decimal('37.48812923188320'),
#   Decimal('126.83449188984100')),
#  (547,
#   1,
#   '구로NC',
#   '구로구',
#   '서울특별시 구로구 구로중앙로 152 (구로동) 구로NC',
#   Decimal('37.50121900000000'),
#   Decimal('126.88279800000000')),
#  (546,
#   1,
#   '구로고척',
#   '구로구',
#   '서울특별시 구로구 경인로 387 (고척동)',
#   Decimal('37.49706000000000'),
#   Decimal('126.86315000000000')),
#  (545,
#   1,
#   '현대디큐브B2',
#   '구로구',
#   '서울특별시 구로구 경인로 662 (신도림동)',
#   Decimal('37.50882800000000'),
#   Decimal('126.88948800000000')),
#  (544,
#   1,
#   '구로호텔',
#   '구로구',
#   '서울특별시 구로구 디지털로32길 72, 구로호텔 1층 (구로동)',
#   Decimal('37.48312930000000'),
#   Decimal('126.89885909999998')),
#  (543,
#   1,
#   '현대디큐브2F',
#   '구로구',
#   '서울특별시 구로구 경인로 662 (신도림동)',
#   Decimal('37.50863600000000'),
#   Decimal('126.88922500000000')),
#  (542,
#   1,
#   '구로하이엔드',
#   '구로구',
#   '서울특별시 구로구 디지털로26길 5, 에이스하이엔드타워1차 103호 (구로동)',
#   Decimal('37.48161800000000'),
#   Decimal('126.89313600000000')),
#  (541,
#   1,
#   '구로에이스',
#   '구로구',
#   '서울특별시 구로구 디지털로 285, 에이스트윈타워1차 103호 (구로동)',
#   Decimal('37.48448329000000'),
#   Decimal('126.89449570000000')),
#  (540,
#   1,
#   '구로디지털로',
#   '구로구',
#   '서울특별시 구로구 디지털로33길 11, 에이스테크노8차 1층 (구로동)',
#   Decimal('37.48591100000000'),
#   Decimal('126.89558700000000')),
#  (539,
#   1,
#   '오류동역',
#   '구로구',
#   '서울특별시 구로구 경인로 216 (오류동)',
#   Decimal('37.49621550000000'),
#   Decimal('126.84486140000000')),
#  (538,
#   1,
#   '구로디지털타워',
#   '구로구',
#   '서울특별시 구로구 디지털로32길 30 (구로동)',
#   Decimal('37.48343200000000'),
#   Decimal('126.89648000000000')),
#  (537,
#   1,
#   '신도림',
#   '구로구',
#   '서울특별시 구로구 경인로 610 (신도림동)',
#   Decimal('37.50551700000000'),
#   Decimal('126.88395300000000')),
#  (536,
#   1,
#   '천호대로길동',
#   '강동구',
#   '서울특별시 강동구 천호대로 1131 거산 유팰리스',
#   Decimal('37.53465100000000'),
#   Decimal('127.13721000000000')),
#  (535,
#   1,
#   '올림픽공원북2문',
#   '강동구',
#   '서울특별시 강동구 강동대로 199 (성내동)',
#   Decimal('37.52418320000000'),
#   Decimal('127.12867750000000')),
#  (534,
#   1,
#   '강일역',
#   '강동구',
#   '서울특별시 강동구 고덕로 429 (강일동), 1층',
#   Decimal('37.55747468801038'),
#   Decimal('127.17351070838722')),
#  (533,
#   1,
#   '천호사거리',
#   '강동구',
#   '서울특별시 강동구 올림픽로 651 (천호동)',
#   Decimal('37.53970200000000'),
#   Decimal('127.12354200000000')),
#  (532,
#   1,
#   '상일동역',
#   '강동구',
#   '서울특별시 강동구 고덕로 399 (고덕동, 고덕센트럴푸르지오)',
#   Decimal('37.55754181615496'),
#   Decimal('127.17072672474717')),
#  (531,
#   1,
#   '명일이마트',
#   '강동구',
#   '서울특별시 강동구 동남로75길 5 (명일동) 명일이마트별관주차장',
#   Decimal('37.55399100000000'),
#   Decimal('127.15598400000000')),
#  (530,
#   1,
#   '천호역',
#   '강동구',
#   '서울특별시 강동구 천호대로 1012, 태승빌딩 (성내동)',
#   Decimal('37.53795191000000'),
#   Decimal('127.12457930000000')),
#  (529,
#   1,
#   '상일동',
#   '강동구',
#   '서울특별시 강동구 상일로10길 36, 1~2층 (상일동)',
#   Decimal('37.55079895986590'),
#   Decimal('127.17410429214200')),
#  (528,
#   1,
#   '길동역',
#   '강동구',
#   '서울특별시 강동구 양재대로 1487 (길동)',
#   Decimal('37.53874330000000'),
#   Decimal('127.13998790000000')),
#  (527,
#   1,
#   '천호이마트',
#   '강동구',
#   '서울특별시 강동구 천호대로 1015-14 (천호동) 이마트별관',
#   Decimal('37.53893300000000'),
#   Decimal('127.12521400000000')),
#  (526,
#   1,
#   '천호로데오',
#   '강동구',
#   '서울특별시 강동구 천호대로 1037 (천호동)',
#   Decimal('37.53780690000000'),
#   Decimal('127.12730940000006')),
#  (525,
#   1,
#   '둔촌동',
#   '강동구',
#   '서울특별시 강동구 양재대로 1303 (성내동) 평원빌딩',
#   Decimal('37.52272400000000'),
#   Decimal('127.13394300000000')),
#  (524,
#   1,
#   '강동역',
#   '강동구',
#   '서울특별시 강동구 천호대로 1089 (천호동, 강동 헤르셔)',
#   Decimal('37.53604700000000'),
#   Decimal('127.13308600000000')),
#  (523,
#   1,
#   '굽은다리역',
#   '강동구',
#   '서울특별시 강동구 양재대로 1568 (명일동, 원일타워)',
#   Decimal('37.54540300000000'),
#   Decimal('127.14310100000000')),
#  (522,
#   1,
#   '강동암사DT',
#   '강동구',
#   '서울특별시 강동구 고덕로 43 (암사동)',
#   Decimal('37.55505400000000'),
#   Decimal('127.13006500000000')),
#  (521,
#   1,
#   '강동구청DT',
#   '강동구',
#   '서울특별시 강동구 성내로 32 (성내동)',
#   Decimal('37.52943700000000'),
#   Decimal('127.12383500000000')),
#  (520,
#   1,
#   '명일역',
#   '강동구',
#   '서울특별시 강동구 양재대로 1647 (명일동)',
#   Decimal('37.55258000000000'),
#   Decimal('127.14379900000000')),
#  (519,
#   1,
#   '명동남산',
#   '중구',
#   '서울특별시 중구 퇴계로 132 (남산동3가)',
#   Decimal('37.56080900000000'),
#   Decimal('126.98639700000000')),
#  (518,
#   1,
#   '포포인츠명동',
#   '중구',
#   '서울특별시 중구 삼일대로10길 36 (저동2가)',
#   Decimal('37.56572110000000'),
#   Decimal('126.98934260000000')),
#  (517,
#   1,
#   '별다방',
#   '중구',
#   '서울특별시 중구 퇴계로 100 (회현동2가)',
#   Decimal('37.56020130000000'),
#   Decimal('126.98293270000000')),
#  (516,
#   1,
#   '레스케이프호텔R',
#   '중구',
#   '서울특별시 중구 퇴계로 67 (회현동1가)',
#   Decimal('37.55983460000000'),
#   Decimal('126.97949460000000')),
#  (515,
#   1,
#   '동대문디자인플라자',
#   '중구',
#   '서울특별시 중구 을지로 281 (을지로7가) 디자인장터',
#   Decimal('37.56743000000000'),
#   Decimal('127.00975800000000')),
#  (514,
#   1,
#   '세종대로',
#   '중구',
#   '서울특별시 중구 세종대로 135-5 (태평로1가)',
#   Decimal('37.56867800000000'),
#   Decimal('126.97649300000000')),
#  (513,
#   1,
#   '숭례문SG타워',
#   '중구',
#   '서울특별시 중구 세종대로 14 (남대문로5가)',
#   Decimal('37.55812930000000'),
#   Decimal('126.97426370000000')),
#  (512,
#   1,
#   '청계크리스탈스퀘어',
#   '중구',
#   '서울특별시 중구 청계천로 106 (수표동)',
#   Decimal('37.56790000000000'),
#   Decimal('126.98933000000000')),
#  (511,
#   1,
#   '무교로',
#   '중구',
#   '서울특별시 중구 무교로 15 (무교동)',
#   Decimal('37.56739900000000'),
#   Decimal('126.97890000000000')),
#  (510,
#   1,
#   '이마트타워',
#   '중구',
#   '서울특별시 중구 세종대로7길 37 (순화동) 1층',
#   Decimal('37.56074346369670'),
#   Decimal('126.97252839195800')),
#  (509,
#   1,
#   '충무로',
#   '중구',
#   '서울특별시 중구 충무로 3 (필동1가)',
#   Decimal('37.56149598081020'),
#   Decimal('126.99282309719600')),
#  (508,
#   1,
#   '명동입구',
#   '중구',
#   '서울특별시 중구 남대문로 68-1 (명동2가)',
#   Decimal('37.56331900000000'),
#   Decimal('126.98224200000000')),
#  (507,
#   1,
#   '명동역',
#   '중구',
#   '서울특별시 중구 퇴계로 101, 건물 전체 (충무로 1가)',
#   Decimal('37.56102000000000'),
#   Decimal('126.98312000000000')),
#  (506,
#   1,
#   '시청',
#   '중구',
#   '서울특별시 중구 을지로 19, 삼성화재삼성빌딩 1층 (을지로1가)',
#   Decimal('37.56629000000000'),
#   Decimal('126.97980800000000')),
#  (505,
#   1,
#   '을지로한국빌딩',
#   '중구',
#   '서울특별시 중구 을지로 50, 1층 (을지로 2가)',
#   Decimal('37.56572200000000'),
#   Decimal('126.98329000000000')),
#  (504,
#   1,
#   '소공로',
#   '중구',
#   '서울특별시 중구 남대문로7길 19, 삼영빌딩 1층 일부 (소공동)',
#   Decimal('37.56372730000000'),
#   Decimal('126.98076809999998')),
#  (503,
#   1,
#   '을지로삼화타워',
#   '중구',
#   '서울특별시 중구 을지로5길 16 (을지로2가) 1층',
#   Decimal('37.56690200000000'),
#   Decimal('126.98470700000000')),
#  (502,
#   1,
#   '황학캐슬',
#   '중구',
#   '서울특별시 중구 청계천로 400 (황학동) 롯데캐슬베네치아',
#   Decimal('37.57124000000000'),
#   Decimal('127.02290500000000')),
#  (501,
#   1,
#   '남산단암',
#   '중구',
#   '서울특별시 중구 소월로 10, 단암빌딩 (남대문로5가)',
#   Decimal('37.55853622000000'),
#   Decimal('126.97545850000000')),
#  (500,
#   1,
#   '퍼시픽타워',
#   '중구',
#   '서울특별시 중구 세종대로9길 41, 퍼시픽타워 1층 (서소문동)',
#   Decimal('37.56132157000000'),
#   Decimal('126.97302640000000')),
#  (499,
#   1,
#   '태평로',
#   '중구',
#   '서울특별시 중구 세종대로 72, 대영빌딩 1층 (태평로2가)',
#   Decimal('37.56248285000000'),
#   Decimal('126.97679280000000')),
#  (498,
#   1,
#   '문화일보',
#   '중구',
#   '서울특별시 중구 새문안로 22 (충정로1가) 문화일보',
#   Decimal('37.56712291000000'),
#   Decimal('126.96866420000000')),
#  (497,
#   1,
#   '무교동',
#   '중구',
#   '서울특별시 중구 무교로 21 (무교동) 코오롱빌딩 1층',
#   Decimal('37.56781712000000'),
#   Decimal('126.97873800000000')),
#  (496,
#   1,
#   '환구단',
#   '중구',
#   '서울특별시 중구 소공로 112 (소공동)',
#   Decimal('37.56444800000000'),
#   Decimal('126.97915700000000')),
#  (495,
#   1,
#   '대한극장',
#   '중구',
#   '서울특별시 중구 퇴계로 212 (필동2가) 1,2층',
#   Decimal('37.56105065000000'),
#   Decimal('126.99527350000000')),
#  (494,
#   1,
#   '순화동더샵',
#   '중구',
#   '서울특별시 중구 칠패로 27, 1층 (순화동)',
#   Decimal('37.56007200000000'),
#   Decimal('126.97193100000000')),
#  (493,
#   1,
#   '숭례문',
#   '중구',
#   '서울특별시 중구 세종대로 17, 와이즈타워 1층 (남대문로5가)',
#   Decimal('37.55874473000000'),
#   Decimal('126.97309520000000')),
#  (492,
#   1,
#   '명동메트로',
#   '중구',
#   '서울특별시 중구 명동9가길 14 (을지로1가) 메트로호텔',
#   Decimal('37.56511800000000'),
#   Decimal('126.98368100000000')),
#  (491,
#   1,
#   '신당역',
#   '중구',
#   '서울특별시 중구 퇴계로 385, 1층 (흥인동)',
#   Decimal('37.56552200000000'),
#   Decimal('127.01455400000000')),
#  (490,
#   1,
#   '서소문로',
#   '중구',
#   '서울특별시 중구 서소문로 120 (서소문동) 대한빌딩',
#   Decimal('37.56300600000000'),
#   Decimal('126.97454600000000')),
#  (489,
#   1,
#   '명동길',
#   '중구',
#   '서울특별시 중구 명동10길 41',
#   Decimal('37.56206950000000'),
#   Decimal('126.98586690000000')),
#  (488,
#   1,
#   '중구저동',
#   '중구',
#   '서울특별시 중구 수표로 34 (저동2가)',
#   Decimal('37.56436860000000'),
#   Decimal('126.99033820000000')),
#  (487,
#   1,
#   '약수역',
#   '중구',
#   '서울특별시 중구 다산로 129 (신당동)',
#   Decimal('37.55543700000000'),
#   Decimal('127.01072530000000')),
#  (486,
#   1,
#   '명동중앙로',
#   '중구',
#   '서울특별시 중구 명동길 60 (명동 2가)',
#   Decimal('37.56374850000000'),
#   Decimal('126.98577230000000')),
#  (485,
#   1,
#   '한국프레스센터',
#   '중구',
#   '서울특별시 중구 세종대로 124 (태평로1가)',
#   Decimal('37.56738100000000'),
#   Decimal('126.97785900000000')),
#  (484,
#   1,
#   '서울중앙우체국',
#   '중구',
#   '서울특별시 중구 소공로 70 (충무로 1가) 서울 중앙 우체국',
#   Decimal('37.56167800000000'),
#   Decimal('126.98211700000000')),
#  (483,
#   1,
#   '신세계본점6F',
#   '중구',
#   '서울특별시 중구 퇴계로 77 (충무로1가)',
#   Decimal('37.56038100000000'),
#   Decimal('126.98075800000000')),
#  (482,
#   1,
#   '을지로2가',
#   '중구',
#   '서울특별시 중구 삼일대로 358 (을지로2가)',
#   Decimal('37.56634700000000'),
#   Decimal('126.98806600000000')),
#  (481,
#   1,
#   '을지로경기빌딩',
#   '중구',
#   '서울특별시 중구 남대문로10길 9 (삼각동) 경기빌딩',
#   Decimal('37.56717200000000'),
#   Decimal('126.98315600000000')),
#  (480,
#   1,
#   '회현역',
#   '중구',
#   '서울특별시 중구 퇴계로 72 (회현동) 리더스뷰남산',
#   Decimal('37.55898090000000'),
#   Decimal('126.98074670000005')),
#  (479,
#   1,
#   '연세세브란스',
#   '중구',
#   '서울특별시 중구 통일로 10 (남대문로5가)',
#   Decimal('37.55720700000000'),
#   Decimal('126.97354000000000')),
#  (478,
#   1,
#   '신당역사거리',
#   '중구',
#   '서울특별시 중구 다산로 258 (흥인동)',
#   Decimal('37.56580700000000'),
#   Decimal('127.01643000000000')),
#  (477,
#   1,
#   '동대입구역',
#   '중구',
#   '서울특별시 중구 장충단로 166 (장충동1가)',
#   Decimal('37.55959300000000'),
#   Decimal('127.00614200000000')),
#  (476,
#   1,
#   '을지로국제빌딩',
#   '중구',
#   '서울특별시 중구 남대문로 109 (다동)',
#   Decimal('37.56695200000000'),
#   Decimal('126.98221900000000')),
#  (475,
#   1,
#   '동대문공원',
#   '중구',
#   '서울특별시 중구 장충단로 229 (광희동1가)',
#   Decimal('37.56513300000000'),
#   Decimal('127.00719100000000')),
#  (474,
#   1,
#   '대우재단빌딩',
#   '중구',
#   '서울특별시 중구 퇴계로 18 (남대문로5가)',
#   Decimal('37.55678100000000'),
#   Decimal('126.97508100000000')),
#  (473,
#   1,
#   '을지로내외빌딩R',
#   '중구',
#   '서울특별시 중구 을지로 51 (을지로2가)',
#   Decimal('37.56647900000000'),
#   Decimal('126.98366300000000')),
#  (472,
#   1,
#   '신세계본점5F',
#   '중구',
#   '서울특별시 중구 소공로 63 (충무로1가)',
#   Decimal('37.56095100000000'),
#   Decimal('126.98113400000000')),
#  (471,
#   1,
#   '동국대',
#   '중구',
#   '서울특별시 중구 서애로 1길 11',
#   Decimal('37.56154200000000'),
#   Decimal('126.99843700000000')),
#  (470,
#   1,
#   '국립중앙의료원',
#   '중구',
#   '서울특별시 중구 을지로 251 (을지로6가)',
#   Decimal('37.56651600000000'),
#   Decimal('127.00623760000000')),
#  (469,
#   1,
#   '대한상공회의소R',
#   '중구',
#   '서울특별시 중구 세종대로 39 (남대문로4가) 1층',
#   Decimal('37.56093800000000'),
#   Decimal('126.97370200000000')),
#  (468,
#   1,
#   '동대문두타',
#   '중구',
#   '서울특별시 중구 장충단로 275 (을지로6가)',
#   Decimal('37.56892512604548'),
#   Decimal('127.00878383484597')),
#  (467,
#   1,
#   '을지로4가역',
#   '중구',
#   '서울특별시 중구 을지로 170 (을지로4가)',
#   Decimal('37.56668200000000'),
#   Decimal('126.99728500000000')),
#  (466,
#   1,
#   '숭례문북창',
#   '중구',
#   '서울특별시 중구 세종대로12길 12 (남대문로4가)',
#   Decimal('37.56172500000000'),
#   Decimal('126.97683800000000')),
#  (465,
#   1,
#   '서대문역',
#   '종로구',
#   '서울특별시 종로구 통일로 134 (평동)',
#   Decimal('37.56670000000000'),
#   Decimal('126.96629000000000')),
#  (464,
#   1,
#   '서울대치과병원',
#   '종로구',
#   '서울특별시 종로구 대학로 101 서울대학교 치과병원 신관1층',
#   Decimal('37.57790000000000'),
#   Decimal('126.99965000000000')),
#  (463,
#   1,
#   '동숭길입구',
#   '종로구',
#   '서울특별시 종로구 대학로 146 (혜화동)',
#   Decimal('37.58423600000000'),
#   Decimal('127.00201400000000')),
#  (462,
#   1,
#   '강북삼성병원1층',
#   '종로구',
#   '서울특별시 종로구 새문안로 29 (평동)',
#   Decimal('37.56854600000000'),
#   Decimal('126.96756000000000')),
#  (461,
#   1,
#   '종로플레이스',
#   '종로구',
#   '서울특별시 종로구 창경궁로 120 (인의동)',
#   Decimal('37.57319000000000'),
#   Decimal('126.99830900000000')),
#  (460,
#   1,
#   '정동',
#   '종로구',
#   '서울특별시 종로구 새문안로 42 (신문로2가)',
#   Decimal('37.56857800000000'),
#   Decimal('126.97006700000000')),
#  (459,
#   1,
#   '광화문교보문고',
#   '종로구',
#   '서울특별시 종로구 종로 1 (종로1가)',
#   Decimal('37.57101700000000'),
#   Decimal('126.97793700000000')),
#  (458,
#   1,
#   '종로관수',
#   '종로구',
#   '서울특별시 종로구 삼일대로20길 13 (관수동)',
#   Decimal('37.56938500000000'),
#   Decimal('126.98866500000000')),
#  (457,
#   1,
#   '경복궁사거리',
#   '종로구',
#   '서울특별시 종로구 율곡로 6, B동 101호(중학동, 트윈트리타워)',
#   Decimal('37.57557800000000'),
#   Decimal('126.98058100000000')),
#  (456,
#   1,
#   '대학로',
#   '종로구',
#   '서울특별시 종로구 대학로 57, 홍익대학교 대학로캠퍼스 內 (연건동)',
#   Decimal('37.57650900000000'),
#   Decimal('127.00144900000000')),
#  (455,
#   1,
#   '종로3가',
#   '종로구',
#   '서울특별시 종로구 종로 113-1, 1-4층 (종로3가)',
#   Decimal('37.57055270000000'),
#   Decimal('126.99020550000000')),
#  (454,
#   1,
#   '마로니에공원',
#   '종로구',
#   '서울특별시 종로구 대학로 116, 1-2층 (동숭동)',
#   Decimal('37.58154296000000'),
#   Decimal('127.00234120000000')),
#  (453,
#   1,
#   '이마빌딩',
#   '종로구',
#   '서울특별시 종로구 종로1길 42 (수송동)',
#   Decimal('37.57386370000000'),
#   Decimal('126.97897149999994')),
#  (452,
#   1,
#   '경복궁역',
#   '종로구',
#   '서울특별시 종로구 자하문로4길 6, 1층 (통의동)',
#   Decimal('37.57715080000000'),
#   Decimal('126.97274530000004')),
#  (451,
#   1,
#   '종로관철',
#   '종로구',
#   '서울특별시 종로구 종로12길 21, 2층 (관철동)',
#   Decimal('37.56905800000000'),
#   Decimal('126.98601300000000')),
#  (450,
#   1,
#   '동숭로아트',
#   '종로구',
#   '서울특별시 종로구 동숭길 110 (동숭동)',
#   Decimal('37.58296900000000'),
#   Decimal('127.00387600000000')),
#  (449,
#   1,
#   '종각',
#   '종로구',
#   '서울특별시 종로구 종로 64 (종로2가)',
#   Decimal('37.56991830000000'),
#   Decimal('126.98452810000003')),
#  (448,
#   1,
#   '주얼리시티',
#   '종로구',
#   '서울특별시 종로구 종로 183 (인의동) 효성주얼리시티',
#   Decimal('37.57154914000000'),
#   Decimal('126.99870500000000')),
#  (447,
#   1,
#   '스페이스본',
#   '종로구',
#   '서울특별시 종로구 사직로8길 4 (사직동) 광화문 풍림스페이스본',
#   Decimal('37.57532212000000'),
#   Decimal('126.96924940000000')),
#  (446,
#   1,
#   '성대입구',
#   '종로구',
#   '서울특별시 종로구 창경궁로 235 (명륜3가)',
#   Decimal('37.58289200000000'),
#   Decimal('126.99839200000000')),
#  (445,
#   1,
#   '광화문',
#   '종로구',
#   '서울특별시 종로구 세종대로 167 (세종로)',
#   Decimal('37.57122930000000'),
#   Decimal('126.97628720000000')),
#  (444,
#   1,
#   '인사',
#   '종로구',
#   '서울특별시 종로구 인사동길 14 (인사동)',
#   Decimal('37.57212930000000'),
#   Decimal('126.98703490000002')),
#  (443,
#   1,
#   '적선',
#   '종로구',
#   '서울특별시 종로구 새문안로5길 55, 노스게이트빌딩 1층 (적선동)',
#   Decimal('37.57520431000000'),
#   Decimal('126.97393610000000')),
#  (442,
#   1,
#   '광화문D타워',
#   '종로구',
#   '서울특별시 종로구 종로3길 17 (청진동) D타워',
#   Decimal('37.57140000000000'),
#   Decimal('126.97882970000000')),
#  (441,
#   1,
#   '삼청동',
#   '종로구',
#   '서울특별시 종로구 삼청로 111-1 (삼청동)',
#   Decimal('37.58538100000000'),
#   Decimal('126.98175120000000')),
#  (440,
#   1,
#   '안국',
#   '종로구',
#   '서울특별시 종로구 북촌로 5-1 (재동)',
#   Decimal('37.57733800000000'),
#   Decimal('126.98563500000000')),
#  (439,
#   1,
#   '새문안로',
#   '종로구',
#   '서울특별시 종로구 새문안로 92 (신문로1가) 광화문오피시아빌딩',
#   Decimal('37.56965970000000'),
#   Decimal('126.97489030000000')),
#  (438,
#   1,
#   '종로수송',
#   '종로구',
#   '서울특별시 종로구 종로5길 30 (청진동) 1~3층',
#   Decimal('37.57149310000000'),
#   Decimal('126.98078310000000')),
#  (437,
#   1,
#   '북촌로',
#   '종로구',
#   '서울특별시 종로구 북촌로4길 23 (계동)',
#   Decimal('37.57946200000000'),
#   Decimal('126.98643100000000')),
#  (436,
#   1,
#   '종로구청',
#   '종로구',
#   '서울특별시 종로구 삼봉로 71 (수송동)',
#   Decimal('37.57266200000000'),
#   Decimal('126.98113800000000')),
#  (435,
#   1,
#   '동묘앞역',
#   '종로구',
#   '서울특별시 종로구 종로 344 (숭인동, 대우디오빌) 101호 일부, 201호 일부',
#   Decimal('37.57270000000000'),
#   Decimal('127.01607200000000')),
#  (434,
#   1,
#   '정부서울청사R',
#   '종로구',
#   '서울특별시 종로구 새문안로5가길 28 (적선동)',
#   Decimal('37.57441100000000'),
#   Decimal('126.97357100000000')),
#  (433,
#   1,
#   '독립문역',
#   '종로구',
#   '서울특별시 종로구 송월길 155 경희궁자이 4단지 1층 팰리스애비뉴 4114~4119호',
#   Decimal('37.57143200000000'),
#   Decimal('126.96126900000000')),
#  (432,
#   1,
#   '종로R',
#   '종로구',
#   '서울특별시 종로구 종로 51 (종로2가)',
#   Decimal('37.57080400000000'),
#   Decimal('126.98349400000000')),
#  (431,
#   1,
#   '광화문우체국',
#   '종로구',
#   '서울특별시 종로구 종로 6 (서린동)',
#   Decimal('37.56985400000000'),
#   Decimal('126.97808300000000')),
#  (430,
#   1,
#   '종로평창동',
#   '종로구',
#   '서울특별시 종로구 평창12길 3 (평창동)',
#   Decimal('37.60614900000000'),
#   Decimal('126.96721300000000')),
#  (429,
#   1,
#   '강북삼성병원',
#   '종로구',
#   '서울특별시 종로구 새문안로 29 (평동)',
#   Decimal('37.56854600000000'),
#   Decimal('126.96756000000000')),
#  (428,
#   1,
#   '경희궁로',
#   '종로구',
#   '서울특별시 종로구 새문안로3길 15 (당주동)',
#   Decimal('37.57175900000000'),
#   Decimal('126.97234300000000')),
#  (427,
#   1,
#   '혜화역',
#   '종로구',
#   '서울특별시 종로구 대학로12길 4 (동숭동)1~2층',
#   Decimal('37.58247790000000'),
#   Decimal('127.00218500000000')),
#  (426,
#   1,
#   '연합뉴스',
#   '종로구',
#   '서울특별시 종로구 율곡로2길 25 (수송동)',
#   Decimal('37.57432890000000'),
#   Decimal('126.98045900000050')),
#  (425,
#   1,
#   '진관DT',
#   '은평구',
#   '서울특별시 은평구 연서로 645 (진관동)',
#   Decimal('37.65017870000000'),
#   Decimal('126.93619680000000')),
#  (424,
#   1,
#   '녹번역',
#   '은평구',
#   '서울특별시 은평구 통일로 636 (녹번동) 110,111,112,113,114,115호',
#   Decimal('37.60330762131233'),
#   Decimal('126.93528567756574')),
#  (423,
#   1,
#   '더북한산',
#   '은평구',
#   '서울특별시 은평구 대서문길 24-11 (진관동)',
#   Decimal('37.65545765932660'),
#   Decimal('126.94755637434500')),
#  (422,
#   1,
#   '새절역',
#   '은평구',
#   '서울특별시 은평구 증산로 371 (신사동)',
#   Decimal('37.58942667302070'),
#   Decimal('126.91286345652400')),
#  (421,
#   1,
#   '수색',
#   '은평구',
#   '서울특별시 은평구 수색로 216 (수색동)',
#   Decimal('37.58040000000000'),
#   Decimal('126.89906800000000')),
#  (420,
#   1,
#   '구산역',
#   '은평구',
#   '서울특별시 은평구 연서로 146 (대조동)',
#   Decimal('37.61174500000000'),
#   Decimal('126.91767800000000')),
#  (419,
#   1,
#   '은평이마트',
#   '은평구',
#   '서울특별시 은평구 은평로 111 (응암동)',
#   Decimal('37.60037923000000'),
#   Decimal('126.92027350000000')),
#  (418,
#   1,
#   '은평구청입구',
#   '은평구',
#   '서울특별시 은평구 은평로 170 (응암동)',
#   Decimal('37.60104200000000'),
#   Decimal('126.92678900000000')),
#  (417,
#   1,
#   '구파발역',
#   '은평구',
#   '서울특별시 은평구 진관2로 12',
#   Decimal('37.63446000000000'),
#   Decimal('126.91888100000000')),
#  (416,
#   1,
#   '연신내',
#   '은평구',
#   '서울특별시 은평구 통일로 867 (갈현동)',
#   Decimal('37.62041700000000'),
#   Decimal('126.91991300000000')),
#  (415,
#   1,
#   '연신내역사거리',
#   '은평구',
#   '서울특별시 은평구 통일로 842 (불광동)',
#   Decimal('37.61862000000000'),
#   Decimal('126.92206200000000')),
#  (414,
#   1,
#   '구파발사거리',
#   '은평구',
#   '서울특별시 은평구 진관3로 21 은평엘크루 101동 105-108호',
#   Decimal('37.63961700000000'),
#   Decimal('126.91881000000000')),
#  (413,
#   1,
#   '불광역',
#   '은평구',
#   '서울특별시 은평구 통일로 715 (대조동)',
#   Decimal('37.60938200000000'),
#   Decimal('126.93039710000000')),
#  (412,
#   1,
#   '신풍역',
#   '영등포구',
#   '서울특별시 영등포구 신풍로 23 (신길동)',
#   Decimal('37.50034696205280'),
#   Decimal('126.90843838400200')),
#  (411,
#   1,
#   '당산역사거리',
#   '영등포구',
#   '서울특별시 영등포구 양평로 47 (당산동5가)',
#   Decimal('37.53398400000000'),
#   Decimal('126.90115600000000')),
#  (410,
#   1,
#   '더현대서울(B2)R',
#   '영등포구',
#   '서울특별시 영등포구 여의대로 108 (여의도동)',
#   Decimal('37.52640000000000'),
#   Decimal('126.92877000000000')),
#  (409,
#   1,
#   '영등포시장교차로',
#   '영등포구',
#   '서울특별시 영등포구 영중로 45 (영등포동6가)',
#   Decimal('37.52042390000000'),
#   Decimal('126.90444600000000')),
#  (408,
#   1,
#   '서울양평역',
#   '영등포구',
#   '서울특별시 영등포구 선유서로24길 6 (양평동1가, 영등포 중흥 S-CLASS)',
#   Decimal('37.52312800000000'),
#   Decimal('126.88580900000000')),
#  (407,
#   1,
#   '영등포구청역',
#   '영등포구',
#   '서울특별시 영등포구 국회대로 558 ',
#   Decimal('37.52789000000000'),
#   Decimal('126.89608000000000')),
#  (406,
#   1,
#   '영등포시장역',
#   '영등포구',
#   '서울특별시 영등포구 영중로 79 (영등포동7가)',
#   Decimal('37.52347500000000'),
#   Decimal('126.90490700000000')),
#  (405,
#   1,
#   '선유도역 1번출구',
#   '영등포구',
#   '서울특별시 영등포구 양평로 128 (양평동5가)양평로 128',
#   Decimal('37.53833300000000'),
#   Decimal('126.89361200000000')),
#  (404,
#   1,
#   '여의도신한투자증권타워',
#   '영등포구',
#   '서울특별시 영등포구 여의대로 70 (여의도동)',
#   Decimal('37.52498000000000'),
#   Decimal('126.92414000000000')),
#  (403,
#   1,
#   '여의도IFC(1F)',
#   '영등포구',
#   '서울특별시 영등포구 국제금융로 10 (여의도동)',
#   Decimal('37.52527300000000'),
#   Decimal('126.92466800000000')),
#  (402,
#   1,
#   '여의도의사당',
#   '영등포구',
#   '서울특별시 영등포구 국회대로74길 12 (여의도동)',
#   Decimal('37.53002300000000'),
#   Decimal('126.92109000000000')),
#  (401,
#   1,
#   '타임스퀘어2F',
#   '영등포구',
#   '서울특별시 영등포구 영중로 15 지상2층 (영등포동4가)',
#   Decimal('37.51698500000000'),
#   Decimal('126.90338700000000')),
#  (400,
#   1,
#   '영등포본동',
#   '영등포구',
#   '서울특별시 영등포구 영등포로 254 (영등포동3가)',
#   Decimal('37.51871300000000'),
#   Decimal('126.90955900000000')),
#  (399,
#   1,
#   '타임스퀘어B2',
#   '영등포구',
#   '서울특별시 영등포구 영중로 15, 지하2층 (영등포동4가)',
#   Decimal('37.51698500000000'),
#   Decimal('126.90338700000000')),
#  (398,
#   1,
#   '여의도호성',
#   '영등포구',
#   '서울특별시 영등포구 여의대방로65길 24, 호성빌딩 1층 (여의도동)',
#   Decimal('37.52017600000000'),
#   Decimal('126.92942600000000')),
#  (397,
#   1,
#   '신세계타임스퀘어1F',
#   '영등포구',
#   '서울특별시 영등포구 영중로 9, 신세계백화점 리빙관 1층 (영등포동4가)',
#   Decimal('37.51716200000000'),
#   Decimal('126.90560800000000')),
#  (396,
#   1,
#   '문래동',
#   '영등포구',
#   '서울특별시 영등포구 선유로 64, 대창타운빌 1층 (문래동3가)',
#   Decimal('37.51960200000000'),
#   Decimal('126.88965200000000')),
#  (395,
#   1,
#   '롯데캐슬여의도',
#   '영등포구',
#   '서울특별시 영등포구 의사당대로 127 (여의도동, 롯데캐슬엠파이어) 1층 104호',
#   Decimal('37.52025214000000'),
#   Decimal('126.92636780000000')),
#  (394,
#   1,
#   '여의도',
#   '영등포구',
#   '서울특별시 영등포구 국제금융로2길 28 (여의도동)',
#   Decimal('37.52403519000000'),
#   Decimal('126.92451790000000')),
#  (393,
#   1,
#   '하이테크시티',
#   '영등포구',
#   '서울특별시 영등포구 경인로 775 (문래동3가) 에이스하이테크시티',
#   Decimal('37.51467062000000'),
#   Decimal('126.89864740000000')),
#  (392,
#   1,
#   '신세계타임스퀘어B2',
#   '영등포구',
#   '서울특별시 영등포구 영중로 9, 신세계타임스퀘어점 리빙관 지하2층 (영등포동4가)',
#   Decimal('37.51716200000000'),
#   Decimal('126.90560800000000')),
#  (391,
#   1,
#   '여의도일신',
#   '영등포구',
#   '서울특별시 영등포구 은행로 11 (여의도동) 1층 1부',
#   Decimal('37.52800000000000'),
#   Decimal('126.92010300000000')),
#  (390,
#   1,
#   '여의도한양증권',
#   '영등포구',
#   '서울특별시 영등포구 국제금융로6길 7 (여의도동) 한양증권',
#   Decimal('37.52241800000000'),
#   Decimal('126.92909300000000')),
#  (389,
#   1,
#   '당산',
#   '영등포구',
#   '서울특별시 영등포구 양평로 64 (당산동6가)',
#   Decimal('37.53516400000000'),
#   Decimal('126.89994200000000')),
#  (388,
#   1,
#   '문래역',
#   '영등포구',
#   '서울특별시 영등포구 당산로 34 (문래동3가)',
#   Decimal('37.51744600000000'),
#   Decimal('126.89525800000000')),
#  (387,
#   1,
#   '영등포신길',
#   '영등포구',
#   '서울특별시 영등포구 신길로 137 (신길동) 1,2층',
#   Decimal('37.50456600000000'),
#   Decimal('126.91007300000000')),
#  (386,
#   1,
#   '여의도ABL타워',
#   '영등포구',
#   '서울특별시 영등포구 의사당대로 147 (여의도동) 알리안츠타워',
#   Decimal('37.51874900000000'),
#   Decimal('126.92779000000000')),
#  (385,
#   1,
#   '동여의도',
#   '영등포구',
#   '서울특별시 영등포구 국제금융로 86 (여의도동) 롯데캐슬 아이비',
#   Decimal('37.51994940000000'),
#   Decimal('126.93179570000000')),
#  (384,
#   1,
#   '선유동이레빌딩',
#   '영등포구',
#   '서울특별시 영등포구 선유동2로 57 (양평제1동) 이레빌딩',
#   Decimal('37.53410900000000'),
#   Decimal('126.89691200000000')),
#  (383,
#   1,
#   '여의도역R',
#   '영등포구',
#   '서울특별시 영등포구 의사당대로 83 (여의도동) 1층',
#   Decimal('37.52332800000000'),
#   Decimal('126.92343900000000')),
#  (382,
#   1,
#   '선유도역',
#   '영등포구',
#   '서울특별시 영등포구 양평로 115 (양평동4가)',
#   Decimal('37.53726800000000'),
#   Decimal('126.89459400000000')),
#  (381,
#   1,
#   '국회의사당역',
#   '영등포구',
#   '서울특별시 영등포구 의사당대로 8 (여의도동)',
#   Decimal('37.52783100000000'),
#   Decimal('126.91688200000000')),
#  (380,
#   1,
#   '여의도공원R',
#   '영등포구',
#   '서울특별시 영등포구 여의공원로 101 (여의도동)',
#   Decimal('37.52923100000000'),
#   Decimal('126.92487200000000')),
#  (379,
#   1,
#   '영등포KT',
#   '영등포구',
#   '서울특별시 영등포구 영중로 119 (영등포동8가)',
#   Decimal('37.52641900000000'),
#   Decimal('126.90531400000000')),
#  (378,
#   1,
#   '국회대로',
#   '영등포구',
#   '서울특별시 영등포구 국회대로 786 (여의도동)',
#   Decimal('37.53026000000000'),
#   Decimal('126.91954900000000')),
#  (377,
#   1,
#   '여의도화재보험',
#   '영등포구',
#   '서울특별시 영등포구 국제금융로6길 38 (여의도동)',
#   Decimal('37.52134500000000'),
#   Decimal('126.92600400000000')),
#  (376,
#   1,
#   '여의도KBS R',
#   '영등포구',
#   '서울특별시 영등포구 의사당대로 26 (여의도동)',
#   Decimal('37.52659600000000'),
#   Decimal('126.91845600000000')),
#  (375,
#   1,
#   '여의도IFC몰(L1)R',
#   '영등포구',
#   '서울특별시 영등포구 국제금융로 10 (여의도동)  지하1층 178호',
#   Decimal('37.52512700000000'),
#   Decimal('126.92550800000000')),
#  (374,
#   1,
#   '당산대로',
#   '영등포구',
#   '서울특별시 영등포구 양평로 22 (당산동6가)',
#   Decimal('37.53312100000000'),
#   Decimal('126.90380400000000')),
#  (373,
#   1,
#   '영등포역',
#   '영등포구',
#   '서울특별시 영등포구 경인로 870 (영등포동1가)',
#   Decimal('37.51696140000000'),
#   Decimal('126.90913900000000')),
#  (372,
#   1,
#   '샛강역',
#   '영등포구',
#   '서울특별시 영등포구 여의대방로 376 (여의도동)',
#   Decimal('37.51835510000000'),
#   Decimal('126.93127160000000')),
#  (371,
#   1,
#   '타임스퀘어R',
#   '영등포구',
#   '서울특별시 영등포구 영중로 15 지하 1층 (영등포동4가)',
#   Decimal('37.51755000000000'),
#   Decimal('126.90516000000000')),
#  (370,
#   1,
#   '신월동DT',
#   '양천구',
#   '서울특별시 양천구 남부순환로 319 (신월동)',
#   Decimal('37.53829235305590'),
#   Decimal('126.82710140924300')),
#  (369,
#   1,
#   '목동10단지',
#   '양천구',
#   '서울특별시 양천구 목동서로 401 (신정동, 대림아크로빌), 상가A동 101,101-1호',
#   Decimal('37.51542561617700'),
#   Decimal('126.85960306799900')),
#  (368,
#   1,
#   '목동트라팰리스',
#   '양천구',
#   '서울특별시 양천구 오목로 299 (목동)',
#   Decimal('37.52550000000000'),
#   Decimal('126.87020000000000')),
#  (367,
#   1,
#   '목동SBS',
#   '양천구',
#   '서울특별시 양천구 목동서로 161 (목동), 1/2층 일부',
#   Decimal('37.52896162444895'),
#   Decimal('126.87363009594163')),
#  (366,
#   1,
#   '현대목동',
#   '양천구',
#   '서울특별시 양천구 목동동로 257 (목동, 현대하이페리온) 지하2층',
#   Decimal('37.52684800000000'),
#   Decimal('126.87502300000000')),
#  (365,
#   1,
#   '목동',
#   '양천구',
#   '서울특별시 양천구 목동서로 67 (목동) 우성에펠타운',
#   Decimal('37.53638383000000'),
#   Decimal('126.87855970000000')),
#  (364,
#   1,
#   '목동5단지',
#   '양천구',
#   '서울특별시 양천구 목동동로 411, 1동 116호(목동, 부영그린타운3차)',
#   Decimal('37.53670600000000'),
#   Decimal('126.88212000000000')),
#  (363,
#   1,
#   '목동7단지',
#   '양천구',
#   '서울특별시 양천구 목동서로 213 (목동) 세신비젼프라자',
#   Decimal('37.52801200000000'),
#   Decimal('126.87053000000000')),
#  (362,
#   1,
#   '신월IC DT',
#   '양천구',
#   '서울특별시 양천구 남부순환로 430 (신월동)',
#   Decimal('37.52949840000000'),
#   Decimal('126.83198300000000')),
#  (361,
#   1,
#   '오목교역',
#   '양천구',
#   '서울특별시 양천구 오목로 354 (목동)',
#   Decimal('37.52358820000000'),
#   Decimal('126.87652120000007')),
#  (360,
#   1,
#   '목동8단지',
#   '양천구',
#   '서울특별시 양천구 목동서로 299 (신정동)',
#   Decimal('37.52051800000000'),
#   Decimal('126.86884100000000')),
#  (359,
#   1,
#   '목동오목로',
#   '양천구',
#   '서울특별시 양천구 오목로 279 (목동) 102,103,104,105호',
#   Decimal('37.52592300000000'),
#   Decimal('126.86843800000000')),
#  (358,
#   1,
#   '목동역',
#   '양천구',
#   '서울특별시 양천구 목동로 203 (신정동) 1층일부',
#   Decimal('37.52668400000000'),
#   Decimal('126.86398600000000')),
#  (357,
#   1,
#   '신정DT',
#   '양천구',
#   '서울특별시 양천구 신월로 341 (신정동)',
#   Decimal('37.52199300000000'),
#   Decimal('126.85886500000000')),
#  (356,
#   1,
#   '목동행복한',
#   '양천구',
#   '서울특별시 양천구 목동동로 309 (목동)',
#   Decimal('37.52914700000000'),
#   Decimal('126.87609900000000')),
#  (355,
#   1,
#   '등촌역',
#   '양천구',
#   '서울특별시 양천구 공항대로 566 (목동) 1층 2층',
#   Decimal('37.54888400000000'),
#   Decimal('126.86807000000000')),
#  (354,
#   1,
#   '목동파리공원',
#   '양천구',
#   '서울특별시 양천구 목동동로 377 (목동)',
#   Decimal('37.53533600000000'),
#   Decimal('126.87885200000000')),
#  (353,
#   1,
#   '송파마천사거리DT',
#   '송파구',
#   '서울특별시 송파구 거마로 78 (마천동)',
#   Decimal('37.49982900000000'),
#   Decimal('127.14767200000000')),
#  (352,
#   1,
#   '문정법조타운 한양타워',
#   '송파구',
#   '서울특별시 송파구 법원로11길 12 (문정동)',
#   Decimal('37.48599091628540'),
#   Decimal('127.11792183157400')),
#  (351,
#   1,
#   '송파KT',
#   '송파구',
#   '서울특별시 송파구 잠실로 209 (신천동), 오피스빌딩 1층 2~4호',
#   Decimal('37.51399910000000'),
#   Decimal('127.10630260000000')),
#  (350,
#   1,
#   '몽촌토성역',
#   '송파구',
#   '서울특별시 송파구 위례성대로 6 (방이동)',
#   Decimal('37.51691300000000'),
#   Decimal('127.11312700000000')),
#  (349,
#   1,
#   '송파거여역',
#   '송파구',
#   '서울특별시 송파구 오금로 493 (거여동)',
#   Decimal('37.49364895715680'),
#   Decimal('127.14369868888800')),
#  (348,
#   1,
#   '송파NC',
#   '송파구',
#   '서울특별시 송파구 충민로 66 (문정동)  가든파이브라이프 패션관1층',
#   Decimal('37.47787610000000'),
#   Decimal('127.12567478000000')),
#  (347,
#   1,
#   '잠실본동',
#   '송파구',
#   '서울특별시 송파구 백제고분로 91 (잠실동), 1층',
#   Decimal('37.50864458854420'),
#   Decimal('127.07949103207000')),
#  (346,
#   1,
#   '가든파이브',
#   '송파구',
#   '서울특별시 송파구 충민로 10 (문정동) 가든파이브툴',
#   Decimal('37.47823160000000'),
#   Decimal('127.11937030000001')),
#  (345,
#   1,
#   '가락시장역',
#   '송파구',
#   '서울특별시 송파구 중대로 121, 롯데캐슬 파인힐 1층 (가락동)',
#   Decimal('37.49429900000000'),
#   Decimal('127.12135400000000')),
#  (344,
#   1,
#   '석촌역',
#   '송파구',
#   '서울특별시 송파구 백제고분로 358, 1층 (석촌동)',
#   Decimal('37.50426260000000'),
#   Decimal('127.10610769999994')),
#  (343,
#   1,
#   '가락본동',
#   '송파구',
#   '서울특별시 송파구 송파대로30길 13 (가락동)',
#   Decimal('37.49489500000000'),
#   Decimal('127.11878500000000')),
#  (342,
#   1,
#   '올림픽아파트',
#   '송파구',
#   '서울특별시 송파구 양재대로 1220 (방이동)',
#   Decimal('37.51531500000000'),
#   Decimal('127.13323700000000')),
#  (341,
#   1,
#   '아시아선수촌',
#   '송파구',
#   '서울특별시 송파구 백제고분로 69 (잠실동)',
#   Decimal('37.51059000000000'),
#   Decimal('127.07904700000000')),
#  (340,
#   1,
#   '갤러리아팰리스',
#   '송파구',
#   '서울특별시 송파구 올림픽로 212, 갤러리아 팰리스 (잠실동)',
#   Decimal('37.51108365000000'),
#   Decimal('127.09380590000000')),
#  (339,
#   1,
#   '잠실역',
#   '송파구',
#   '서울특별시 송파구 송파대로 562 (신천동, 웰리스타워,삼성웰리스아파트) 1층,2층',
#   Decimal('37.51527200000000'),
#   Decimal('127.09923100000000')),
#  (338,
#   1,
#   '잠실새내역',
#   '송파구',
#   '서울특별시 송파구 올림픽로 96 (잠실동)',
#   Decimal('37.51167900000000'),
#   Decimal('127.08106200000000')),
#  (337,
#   1,
#   '잠실푸르지오월드',
#   '송파구',
#   '서울특별시 송파구 올림픽로35가길 9, 잠실푸르지오월드마크 1층 (신천동)',
#   Decimal('37.51764900000000'),
#   Decimal('127.10342600000000')),
#  (336,
#   1,
#   '석촌호수',
#   '송파구',
#   '서울특별시 송파구 석촌호수로 262 (송파동)',
#   Decimal('37.50958100000000'),
#   Decimal('127.10499300000000')),
#  (335,
#   1,
#   '방이역',
#   '송파구',
#   '서울특별시 송파구 마천로 53, 1~2층 (오금동)',
#   Decimal('37.50866600000000'),
#   Decimal('127.12656900000000')),
#  (334,
#   1,
#   '올림픽공원남문',
#   '송파구',
#   '서울특별시 송파구 위례성대로 102 (방이동)',
#   Decimal('37.51330000000000'),
#   Decimal('127.12311300000000')),
#  (333,
#   1,
#   '올림픽훼미리',
#   '송파구',
#   '서울특별시 송파구 중대로 68 (문정동)',
#   Decimal('37.49162600000000'),
#   Decimal('127.11630800000000')),
#  (332,
#   1,
#   '문정로데오',
#   '송파구',
#   '서울특별시 송파구 동남로 141 (가락동)',
#   Decimal('37.49190500000000'),
#   Decimal('127.12626960000000')),
#  (331,
#   1,
#   '석촌서호',
#   '송파구',
#   '서울특별시 송파구 석촌호수로 176 (삼전동)',
#   Decimal('37.50639290000000'),
#   Decimal('127.09646840000000')),
#  (330,
#   1,
#   '송파사거리',
#   '송파구',
#   '서울특별시 송파구 송파대로 386 (송파동)',
#   Decimal('37.50227880000000'),
#   Decimal('127.11039040000000')),
#  (329,
#   1,
#   '송파아이파크',
#   '송파구',
#   '서울특별시 송파구 법원로 55 (문정동)',
#   Decimal('37.47989200000000'),
#   Decimal('127.12237900000000')),
#  (328,
#   1,
#   '올림픽평화의문',
#   '송파구',
#   '서울특별시 송파구 위례성대로 38 (방이동) 해태그린피아빌라트',
#   Decimal('37.51564260000000'),
#   Decimal('127.11648190000005')),
#  (327,
#   1,
#   '송파방이DT',
#   '송파구',
#   '서울특별시 송파구 오금로 241 (방이동)',
#   Decimal('37.50656400000000'),
#   Decimal('127.12049500000000')),
#  (326,
#   1,
#   '송파위례',
#   '송파구',
#   '서울특별시 송파구 위례광장로 230 (장지동, 위례2차아이파크)',
#   Decimal('37.47826400000000'),
#   Decimal('127.14406700000000')),
#  (325,
#   1,
#   '잠실대교남단R',
#   '송파구',
#   '서울특별시 송파구 송파대로 570 타워 730 1층',
#   Decimal('37.51551100000000'),
#   Decimal('127.09900600000000')),
#  (324,
#   1,
#   '문정역',
#   '송파구',
#   '서울특별시 송파구 송파대로 167 (문정동)테라타워 B동 137호~139호,204호',
#   Decimal('37.48481300000000'),
#   Decimal('127.12223700000000')),
#  (323,
#   1,
#   '문정하비오',
#   '송파구',
#   '서울특별시 송파구 송파대로 111 (문정동, 파크하비오) 204동 104호~107호',
#   Decimal('37.48192500000000'),
#   Decimal('127.12344600000000')),
#  (322,
#   1,
#   '송파개롱역',
#   '송파구',
#   '서울특별시 송파구 오금로 420 (가락동)',
#   Decimal('37.49695600000000'),
#   Decimal('127.13652000000000')),
#  (321,
#   1,
#   '문정법원로R',
#   '송파구',
#   '서울특별시 송파구 송파대로 201 (문정동)',
#   Decimal('37.48744700000000'),
#   Decimal('127.11916400000000')),
#  (320,
#   1,
#   '잠실시그마타워',
#   '송파구',
#   '서울특별시 송파구 올림픽로 289 (신천동)',
#   Decimal('37.51456700000000'),
#   Decimal('127.10249300000000')),
#  (319,
#   1,
#   '송파헬리오시티',
#   '송파구',
#   '서울특별시 송파구 송파대로 345 (가락동, 헬리오시티)',
#   Decimal('37.49785630000000'),
#   Decimal('127.10313250000000')),
#  (318,
#   1,
#   '송파나루역DT',
#   '송파구',
#   '서울특별시 송파구 오금로 142 (송파동)',
#   Decimal('37.51079300000000'),
#   Decimal('127.11026580000000')),
#  (317,
#   1,
#   '장위뉴타운',
#   '성북구',
#   '서울특별시 성북구 장월로38길 4 (장위동)',
#   Decimal('37.61795689659980'),
#   Decimal('127.05153570977800')),
#  (316,
#   1,
#   '고대안암병원',
#   '성북구',
#   '서울특별시 성북구 고려대로 73 (안암동5가)',
#   Decimal('37.58687889805418'),
#   Decimal('127.02820333331364')),
#  (315,
#   1,
#   '한성대입구역',
#   '성북구',
#   '서울특별시 성북구 성북로 11 (성북동1가)',
#   Decimal('37.58905400000000'),
#   Decimal('127.00483900000000')),
#  (314,
#   1,
#   '안암역',
#   '성북구',
#   '서울특별시 성북구 고려대로 102-2 (안암동5가)',
#   Decimal('37.58631900000000'),
#   Decimal('127.03055600000000')),
#  (313,
#   1,
#   '성신여대',
#   '성북구',
#   '서울특별시 성북구 동소문로24길 12 (동선동1가)',
#   Decimal('37.59313500000000'),
#   Decimal('127.01837900000000')),
#  (312,
#   1,
#   '현대미아',
#   '성북구',
#   '서울특별시 성북구 동소문로 315 (길음동) 지하1층',
#   Decimal('37.60837822000000'),
#   Decimal('127.02874830000000')),
#  (311,
#   1,
#   '고대',
#   '성북구',
#   '서울특별시 성북구 고려대로24길 51 (안암동5가)',
#   Decimal('37.58397192000000'),
#   Decimal('127.02973520000000')),
#  (310,
#   1,
#   '월곡역',
#   '성북구',
#   '서울특별시 성북구 화랑로 76, 101-1호 (하월곡동)',
#   Decimal('37.60171800000000'),
#   Decimal('127.04044600000000')),
#  (309,
#   1,
#   '삼선교',
#   '성북구',
#   '서울특별시 성북구 동소문로 10 (동소문동2가)',
#   Decimal('37.58869600000000'),
#   Decimal('127.00732070000003')),
#  (308,
#   1,
#   '종암',
#   '성북구',
#   '서울특별시 성북구 종암로 122 (종암동)',
#   Decimal('37.60109500000000'),
#   Decimal('127.03384700000000')),
#  (307,
#   1,
#   '성신여대정문',
#   '성북구',
#   '서울특별시 성북구 보문로34길 62 (동선동2가)',
#   Decimal('37.59091000000000'),
#   Decimal('127.01880000000000')),
#  (306,
#   1,
#   '미아',
#   '성북구',
#   '서울특별시 성북구 동소문로 314 (하월곡동)',
#   Decimal('37.60758100000000'),
#   Decimal('127.02930300000000')),
#  (305,
#   1,
#   '종암DT',
#   '성북구',
#   '서울특별시 성북구 종암로 17 (종암동)',
#   Decimal('37.59195250000000'),
#   Decimal('127.03604010000000')),
#  (304,
#   1,
#   '미아이마트',
#   '성북구',
#   '서울특별시 성북구 도봉로 17 (길음동)',
#   Decimal('37.61067800000000'),
#   Decimal('127.02992100000000')),
#  (303,
#   1,
#   '길음역',
#   '성북구',
#   '서울특별시 성북구 정릉로 376 (돈암동)',
#   Decimal('37.60213900000000'),
#   Decimal('127.02527100000000')),
#  (302,
#   1,
#   '서울웨이브아트센터',
#   '서초구',
#   '서울특별시 서초구 잠원로 145-35 (잠원동)',
#   Decimal('37.51880700000000'),
#   Decimal('127.00704000000000')),
#  (301,
#   1,
#   '서이초교사거리',
#   '서초구',
#   '서울특별시 서초구 사임당로 143 (서초동)',
#   Decimal('37.49181460000000'),
#   Decimal('127.02522520000000')),
#  (300,
#   1,
#   '강남역우송빌딩',
#   '서초구',
#   '서울특별시 서초구 서초대로73길 7 (서초동)',
#   Decimal('37.49813146014130'),
#   Decimal('127.02527908458000')),
#  (299,
#   1,
#   '반포자이',
#   '서초구',
#   '서울특별시 서초구 잠원로 24 (반포동)',
#   Decimal('37.50717047534941'),
#   Decimal('127.00991890834830')),
#  (298,
#   1,
#   '강남에비뉴',
#   '서초구',
#   '서울특별시 서초구 서초대로77길 62, 강남역아이파크 B102~B105 (서초동)',
#   Decimal('37.50270000000000'),
#   Decimal('127.02389400000000')),
#  (297,
#   1,
#   '서울교대',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 64, 1층 (서초동)',
#   Decimal('37.48739700000000'),
#   Decimal('127.01513400000000')),
#  (296,
#   1,
#   '서초동',
#   '서초구',
#   '서울특별시 서초구 남부순환로339길 64, 현우빌딩 1층 (서초동)',
#   Decimal('37.48594100000000'),
#   Decimal('127.02152500000000')),
#  (295,
#   1,
#   '강남GT타워',
#   '서초구',
#   '서울특별시 서초구 서초대로 411, GT타워 (서초동)',
#   Decimal('37.49805600000000'),
#   Decimal('127.02583300000003')),
#  (294,
#   1,
#   '교대법원',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 164 (서초동)',
#   Decimal('37.49632900000000'),
#   Decimal('127.01333600000000')),
#  (293,
#   1,
#   '서초역',
#   '서초구',
#   '서울특별시 서초구 반포대로 118 (서초동)',
#   Decimal('37.49067495000000'),
#   Decimal('127.00861180000000')),
#  (292,
#   1,
#   '몬테소리',
#   '서초구',
#   '서울특별시 서초구 강남대로 399 (서초동)',
#   Decimal('37.49826950000000'),
#   Decimal('127.02686500000000')),
#  (291,
#   1,
#   '서래마을입구',
#   '서초구',
#   '서울특별시 서초구 서래로 48 (반포동)',
#   Decimal('37.49925284000000'),
#   Decimal('126.99848010000000')),
#  (290,
#   1,
#   '남부터미널2',
#   '서초구',
#   '서울특별시 서초구 효령로 274 (서초동)',
#   Decimal('37.48436736000000'),
#   Decimal('127.01421920000000')),
#  (289,
#   1,
#   '영동2교',
#   '서초구',
#   '서울특별시 서초구 논현로 139, 대흥빌딩 (양재동)',
#   Decimal('37.48203954000000'),
#   Decimal('127.04257480000000')),
#  (288,
#   1,
#   '신논현역',
#   '서초구',
#   '서울특별시 서초구 강남대로 483 (반포동) 청호빌딩',
#   Decimal('37.50529000000000'),
#   Decimal('127.02363600000000')),
#  (287,
#   1,
#   '하이브랜드',
#   '서초구',
#   '서울특별시 서초구 매헌로 16, 리빙관 101호 (양재동)',
#   Decimal('37.46330766000000'),
#   Decimal('127.03684470000000')),
#  (286,
#   1,
#   '교대',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 118 (서초동)',
#   Decimal('37.49236110000000'),
#   Decimal('127.01422070000000')),
#  (285,
#   1,
#   '강남2',
#   '서초구',
#   '서울특별시 서초구 서초대로77길 27, 유빌딩 1,2층 (서초동)',
#   Decimal('37.50008750000000'),
#   Decimal('127.02549090000002')),
#  (284,
#   1,
#   '뉴코아강남',
#   '서초구',
#   '서울특별시 서초구 잠원로 69 (잠원동) 킴스클럽',
#   Decimal('37.51031339000000'),
#   Decimal('127.00695820000000')),
#  (283,
#   1,
#   '남부터미널',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 26, 래미안서초유니빌 1층 101호 (서초동)',
#   Decimal('37.48467334000000'),
#   Decimal('127.01694640000000')),
#  (282,
#   1,
#   '반포역',
#   '서초구',
#   '서울특별시 서초구 신반포로 257 (잠원동) 신반포11차상가',
#   Decimal('37.50858900000000'),
#   Decimal('127.01195900000000')),
#  (281,
#   1,
#   '방배역',
#   '서초구',
#   '서울특별시 서초구 방배로 84 (방배동)',
#   Decimal('37.48200755000000'),
#   Decimal('126.99764380000000')),
#  (280,
#   1,
#   '강남삼성타운',
#   '서초구',
#   '서울특별시 서초구 서초대로78길 24 (서초동)',
#   Decimal('37.49562035000000'),
#   Decimal('127.02771440000000')),
#  (279,
#   1,
#   '센트럴시티',
#   '서초구',
#   '서울특별시 서초구 신반포로 176 (반포동)',
#   Decimal('37.50470700000000'),
#   Decimal('127.00445900000000')),
#  (278,
#   1,
#   '서초중앙로',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 225',
#   Decimal('37.50169100000000'),
#   Decimal('127.01152000000000')),
#  (277,
#   1,
#   '서울아트센터',
#   '서초구',
#   '서울특별시 서초구 남부순환로 2395 (서초동) 호경빌딩',
#   Decimal('37.48086600000000'),
#   Decimal('127.01236800000000')),
#  (276,
#   1,
#   '서초파라곤',
#   '서초구',
#   '서울특별시 서초구 서초대로74길 29 (서초동) 서초파라곤',
#   Decimal('37.49494100000000'),
#   Decimal('127.02742200000000')),
#  (275,
#   1,
#   '내방역',
#   '서초구',
#   '서울특별시 서초구 방배로 184 (방배동) 대풍빌딩',
#   Decimal('37.49000400000000'),
#   Decimal('126.99245500000000')),
#  (274,
#   1,
#   '이수역',
#   '서초구',
#   '서울특별시 서초구 동작대로 112 (방배동)',
#   Decimal('37.48646640000000'),
#   Decimal('126.98274029999993')),
#  (273,
#   1,
#   '논현역',
#   '서초구',
#   '서울특별시 서초구 강남대로 557 (잠원동) 1~2층',
#   Decimal('37.51119830000000'),
#   Decimal('127.02058750000000')),
#  (272,
#   1,
#   '양재역',
#   '서초구',
#   '서울특별시 서초구 강남대로 202 (양재동) 모산빌딩',
#   Decimal('37.48204750000000'),
#   Decimal('127.03676820000000')),
#  (271,
#   1,
#   '파미에파크R',
#   '서초구',
#   '서울특별시 서초구 사평대로 205 (반포동) CENTRALCITY',
#   Decimal('37.50305210000000'),
#   Decimal('127.00436200000000')),
#  (270,
#   1,
#   '사당로데오',
#   '서초구',
#   '서울특별시 서초구 방배천로 5-4(방배동)',
#   Decimal('37.47727520000000'),
#   Decimal('126.98216049999996')),
#  (269,
#   1,
#   '청계산입구역',
#   '서초구',
#   '서울특별시 서초구 청계산로 203 (신원동)',
#   Decimal('37.44732300000000'),
#   Decimal('127.05625000000000')),
#  (268,
#   1,
#   '서초법원',
#   '서초구',
#   '서울특별시 서초구 서초대로 274 (서초동)',
#   Decimal('37.49297000000000'),
#   Decimal('127.01187500000000')),
#  (267,
#   1,
#   '방배카페거리',
#   '서초구',
#   '서울특별시 서초구 방배중앙로 162 (방배동)',
#   Decimal('37.49347670000000'),
#   Decimal('126.98652970000000')),
#  (266,
#   1,
#   '방배',
#   '서초구',
#   '서울특별시 서초구 방배로 211',
#   Decimal('37.49191400000000'),
#   Decimal('126.99049739999998')),
#  (265,
#   1,
#   '강남대로논현R',
#   '서초구',
#   '서울특별시 서초구 강남대로85길 5 (반포동)',
#   Decimal('37.50741300000000'),
#   Decimal('127.02256800000000')),
#  (264,
#   1,
#   '서울고속터미널',
#   '서초구',
#   '서울특별시 서초구 신반포로 194 (반포동)',
#   Decimal('37.50440600000000'),
#   Decimal('127.00564800000000')),
#  (263,
#   1,
#   '강남대로신사',
#   '서초구',
#   '서울특별시 서초구 강남대로 595 (잠원동)',
#   Decimal('37.51489000000000'),
#   Decimal('127.01946900000000')),
#  (262,
#   1,
#   '이수역사거리',
#   '서초구',
#   '서울특별시 서초구 서초대로 3-4 (방배동, 방배디오슈페리움1)',
#   Decimal('37.48585000000000'),
#   Decimal('126.98302700000000')),
#  (261,
#   1,
#   '서초우성사거리',
#   '서초구',
#   '서울특별시 서초구 강남대로 343 (서초동)',
#   Decimal('37.49354500000000'),
#   Decimal('127.02943000000000')),
#  (260,
#   1,
#   '서초구청',
#   '서초구',
#   '서울특별시 서초구 남부순환로 2557 (서초동)',
#   Decimal('37.48420600000000'),
#   Decimal('127.03010300000000')),
#  (259,
#   1,
#   '서초역이화빌딩',
#   '서초구',
#   '서울특별시 서초구 반포대로21길 3 (서초동)',
#   Decimal('37.48793100000000'),
#   Decimal('127.00912600000000')),
#  (258,
#   1,
#   '센트럴F1',
#   '서초구',
#   '서울특별시 서초구 신반포로 176 (반포동)',
#   Decimal('37.50514800000000'),
#   Decimal('127.00439500000000')),
#  (257,
#   1,
#   '방배다이치빌딩',
#   '서초구',
#   '서울특별시 서초구 방배로 114 (방배동)',
#   Decimal('37.48432900000000'),
#   Decimal('126.99587200000000')),
#  (256,
#   1,
#   '강남교보타워R',
#   '서초구',
#   '서울특별시 서초구 강남대로 465 (서초동)',
#   Decimal('37.50378900000000'),
#   Decimal('127.02407500000000')),
#  (255,
#   1,
#   '방배로',
#   '서초구',
#   '서울특별시 서초구 방배로 52 (방배동)',
#   Decimal('37.47934340000000'),
#   Decimal('126.99949680000000')),
#  (254,
#   1,
#   '현대신촌',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 83 (창천동)',
#   Decimal('37.55608305795150'),
#   Decimal('126.93584487650900')),
#  (253,
#   1,
#   '북가좌DT',
#   '서대문구',
#   '서울특별시 서대문구 응암로 85 (북가좌동)',
#   Decimal('37.58075800000000'),
#   Decimal('126.91147800000000')),
#  (252,
#   1,
#   '이대역',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 183 (대현동)',
#   Decimal('37.55708610000000'),
#   Decimal('126.94628020000000')),
#  (251,
#   1,
#   '충정타워',
#   '서대문구',
#   '서울특별시 서대문구 서소문로 21, 충정타워빌딩 1층 (충정로3가)',
#   Decimal('37.55986900000000'),
#   Decimal('126.96411000000000')),
#  (250,
#   1,
#   '신촌명물거리',
#   '서대문구',
#   '서울특별시 서대문구 명물길 24, 1-5층 (창천동)',
#   Decimal('37.55779600000000'),
#   Decimal('126.93809500000000')),
#  (249,
#   1,
#   '연대동문',
#   '서대문구',
#   '서울특별시 서대문구 성산로 565 (대신동)',
#   Decimal('37.56638500000000'),
#   Decimal('126.94627300000000')),
#  (248,
#   1,
#   '충정로역',
#   '서대문구',
#   '서울특별시 서대문구 충정로 23',
#   Decimal('37.56137000000000'),
#   Decimal('126.96321900000000')),
#  (247,
#   1,
#   '신촌아트레온',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 129 (창천동)',
#   Decimal('37.55650500000000'),
#   Decimal('126.94023800000000')),
#  (246,
#   1,
#   '연대',
#   '서대문구',
#   '서울특별시 서대문구 연세로 35 (창천동)',
#   Decimal('37.55870600000000'),
#   Decimal('126.93672700000000')),
#  (245,
#   1,
#   '이대ECC',
#   '서대문구',
#   '서울특별시 서대문구 이화여대길 52 (대현동) 이화여자대학교 B415호',
#   Decimal('37.56163100000000'),
#   Decimal('126.94735000000000')),
#  (244,
#   1,
#   '연세종합관',
#   '서대문구',
#   '서울특별시 서대문구 연세로 50, 연세세브란스 종합관 (신촌동)',
#   Decimal('37.56177145000000'),
#   Decimal('126.94147080000000')),
#  (243,
#   1,
#   '이대R',
#   '서대문구',
#   '서울특별시 서대문구 이화여대길 34 (대현동)',
#   Decimal('37.55848315000000'),
# ...
#   '서울특별시 관악구 남부순환로 1908 (봉천동)',
#   Decimal('37.47794600000000'),
#   Decimal('126.96119300000000')),
#  (122,
#   1,
#   '강서구청사거리',
#   '강서구',
#   '서울특별시 강서구 화곡로 350 (화곡동)',
#   Decimal('37.55492660000000'),
#   Decimal('126.85231330000000')),
#  (121,
#   1,
#   '송정역',
#   '강서구',
#   '서울특별시 강서구 공항대로 38 (공항동), 1층 일부',
#   Decimal('37.56097361346000'),
#   Decimal('126.81155773497200')),
#  (120,
#   1,
#   '마곡나루공원',
#   '강서구',
#   '서울특별시 강서구 마곡중앙5로 47 (마곡동)',
#   Decimal('37.56700700000000'),
#   Decimal('126.82224600000000')),
#  (119,
#   1,
#   '강서NC',
#   '강서구',
#   '서울특별시 강서구 강서로56길 17 (등촌동)',
#   Decimal('37.56008800000000'),
#   Decimal('126.84053400000000')),
#  (118,
#   1,
#   '김포공항DT',
#   '강서구',
#   '서울특별시 강서구 개화동로 517 (방화동)',
#   Decimal('37.56639600000000'),
#   Decimal('126.80608000000000')),
#  (117,
#   1,
#   '마곡웰튼',
#   '강서구',
#   '서울특별시 강서구 마곡중앙5로 22 (마곡동), 104/105/106호',
#   Decimal('37.56754000000000'),
#   Decimal('126.82553000000000')),
#  (116,
#   1,
#   '내발산',
#   '강서구',
#   '서울특별시 강서구 강서로 323 (내발산동), 101/102호',
#   Decimal('37.55467000000000'),
#   Decimal('126.83672000000000')),
#  (115,
#   1,
#   '가양역사거리',
#   '강서구',
#   '서울특별시 강서구 화곡로 416 (등촌동) 가양더스카이벨리5차 지식산업센터 101, 102, 114,~117호',
#   Decimal('37.56007000000000'),
#   Decimal('126.85537200000000')),
#  (114,
#   1,
#   '등촌대로',
#   '강서구',
#   '서울특별시 강서구 공항대로 543 (염창동, 센터스퀘어)',
#   Decimal('37.55101000000000'),
#   Decimal('126.86638000000000')),
#  (113,
#   1,
#   '강서우장산',
#   '강서구',
#   '서울특별시 강서구 강서로 231 (화곡동, 우장산역 해링턴 타워), 116/117/118/119/120호',
#   Decimal('37.54630500000000'),
#   Decimal('126.83592300000000')),
#  (112,
#   1,
#   '화곡역8번출구',
#   '강서구',
#   '서울특별시 강서구 강서로 179 (화곡동), 1층 일부',
#   Decimal('37.54251400000000'),
#   Decimal('126.83906200000000')),
#  (111,
#   1,
#   '발산역5번출구',
#   '강서구',
#   '서울특별시 강서구 강서로52길 43 (내발산동, DH647), 1층 일부',
#   Decimal('37.55792247399770'),
#   Decimal('126.84054030692000')),
#  (110,
#   1,
#   '까치산역',
#   '강서구',
#   '서울특별시 강서구 강서로13길 3 (화곡동)',
#   Decimal('37.53230300000000'),
#   Decimal('126.84607700000000')),
#  (109,
#   1,
#   '발산역',
#   '강서구',
#   '서울특별시 강서구 강서로 388 (등촌동) 그랜드마트',
#   Decimal('37.56033000000000'),
#   Decimal('126.83927900000000')),
#  (108,
#   1,
#   '염창역',
#   '강서구',
#   '서울특별시 강서구 공항대로 627 (염창동)',
#   Decimal('37.54735900000000'),
#   Decimal('126.87443600000000')),
#  (107,
#   1,
#   '등촌',
#   '강서구',
#   '서울특별시 강서구 공항대로 329 (등촌동)',
#   Decimal('37.55820430000000'),
#   Decimal('126.84433919999992')),
#  (106,
#   1,
#   '화곡동',
#   '강서구',
#   '서울특별시 강서구 화곡로 142(화곡동)',
#   Decimal('37.54051150000000'),
#   Decimal('126.83724130000000')),
#  (105,
#   1,
#   '양천향교역',
#   '강서구',
#   '서울특별시 강서구 강서로 463 (마곡동)',
#   Decimal('37.56696400000000'),
#   Decimal('126.84073100000000')),
#  (104,
#   1,
#   '화곡DT',
#   '강서구',
#   '서울특별시 강서구 등촌로 57 (화곡동)',
#   Decimal('37.53514900000000'),
#   Decimal('126.86323200000000')),
#  (103,
#   1,
#   '가양역',
#   '강서구',
#   '서울특별시 강서구 양천로 476 (등촌동)',
#   Decimal('37.56164000000000'),
#   Decimal('126.85332700000000')),
#  (102,
#   1,
#   '마곡GMG',
#   '강서구',
#   '서울특별시 강서구 마곡중앙6로 16 (마곡동) 117,118,119,120호',
#   Decimal('37.56048700000000'),
#   Decimal('126.82966700000000')),
#  (101,
#   1,
#   '마곡나루역',
#   '강서구',
#   '서울특별시 강서구 마곡중앙로 161-17 (마곡동)',
#   Decimal('37.56813000000000'),
#   Decimal('126.82614000000000')),
#  (100,
#   1,
#   '방화DT',
#   '강서구',
#   '서울특별시 강서구 방화대로 375 (방화동)',
#   Decimal('37.57433900000000'),
#   Decimal('126.81641500000000')),
#  (99,
#   1,
#   '마곡사이언스타워R',
#   '강서구',
#   '서울특별시 강서구 마곡동로 62 (마곡동)',
#   Decimal('37.56052610000000'),
#   Decimal('126.83388700000000')),
#  (98,
#   1,
#   '우장산역',
#   '강서구',
#   '서울특별시 강서구 강서로 267 (내발산동)',
#   Decimal('37.54950100000000'),
#   Decimal('126.83598400000000')),
#  (97,
#   1,
#   '마곡역',
#   '강서구',
#   '서울특별시 강서구 공항대로 168 (마곡동)',
#   Decimal('37.55961100000000'),
#   Decimal('126.82629800000000')),
#  (96,
#   1,
#   '발산역사거리',
#   '강서구',
#   '서울특별시 강서구 공항대로 248 (마곡동)',
#   Decimal('37.55850900000000'),
#   Decimal('126.83509600000000')),
#  (95,
#   1,
#   '파라스파라서울',
#   '강북구',
#   '서울특별시 강북구 삼양로 689 (우이동) 파라스파라서울 지하1층',
#   Decimal('37.66438007461800'),
#   Decimal('127.00856646710100')),
#  (94,
#   1,
#   '미아역',
#   '강북구',
#   '서울특별시 강북구 도봉로 196 (미아동)',
#   Decimal('37.62614800000000'),
#   Decimal('127.02657800000000')),
#  (93,
#   1,
#   '수유역',
#   '강북구',
#   '서울특별시 강북구 도봉로 342 (번동)',
#   Decimal('37.63801670000000'),
#   Decimal('127.02613500000007')),
#  (92,
#   1,
#   '미아사거리역',
#   '강북구',
#   '서울특별시 강북구 도봉로 32 (미아동)',
#   Decimal('37.61180900000000'),
#   Decimal('127.03069710000000')),
#  (91,
#   1,
#   '강북구청사거리',
#   '강북구',
#   '서울특별시 강북구 도봉로 365 (수유동)',
#   Decimal('37.64003540000000'),
#   Decimal('127.02737660000000')),
#  (90,
#   1,
#   '미아뉴타운',
#   '강북구',
#   '서울특별시 강북구 삼양로 161 (미아동)',
#   Decimal('37.61831900000000'),
#   Decimal('127.02107200000000')),
#  (89,
#   1,
#   '역삼이마트',
#   '강남구',
#   '서울특별시 강남구 역삼로 310 (역삼동)',
#   Decimal('37.49936700000000'),
#   Decimal('127.04842500000000')),
#  (88,
#   1,
#   '청담역',
#   '강남구',
#   '서울특별시 강남구 삼성로 709 (청담동)',
#   Decimal('37.51944073234780'),
#   Decimal('127.04955266154200')),
#  (87,
#   1,
#   '삼성동',
#   '강남구',
#   '서울특별시 강남구 영동대로96길 12 (삼성동)',
#   Decimal('37.51084336612153'),
#   Decimal('127.06363342044263')),
#  (86,
#   1,
#   '강남논현',
#   '강남구',
#   '서울특별시 강남구 강남대로 512 (논현동)',
#   Decimal('37.50789785962540'),
#   Decimal('127.02333861464400')),
#  (85,
#   1,
#   '테헤란로아남타워',
#   '강남구',
#   '서울특별시 강남구 테헤란로 311 (역삼동)',
#   Decimal('37.50383000000000'),
#   Decimal('127.04487000000000')),
#  (84,
#   1,
#   '삼성역',
#   '강남구',
#   '서울특별시 강남구 테헤란로 620 (대치동)',
#   Decimal('37.50920696254126'),
#   Decimal('127.06560851480327')),
#  (83,
#   1,
#   '강남역신분당역사',
#   '강남구',
#   '서울특별시 강남구 강남대로 396 (역삼동)',
#   Decimal('37.49705725439780'),
#   Decimal('127.02818071438100')),
#  (82,
#   1,
#   '언주역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 222 (역삼동)',
#   Decimal('37.50777500000000'),
#   Decimal('127.03647200000000')),
#  (81,
#   1,
#   '대치삼성프라자',
#   '강남구',
#   '서울특별시 강남구 영동대로 237 (대치동)',
#   Decimal('37.50031300000000'),
#   Decimal('127.06696100000000')),
#  (80,
#   1,
#   '강남세곡',
#   '강남구',
#   '서울특별시 강남구 헌릉로569길 18 (세곡동)',
#   Decimal('37.46727431964400'),
#   Decimal('127.09992972600000')),
#  (79,
#   1,
#   '도산사거리',
#   '강남구',
#   '서울특별시 강남구 언주로 727 (논현동)',
#   Decimal('37.51966000000000'),
#   Decimal('127.03410000000000')),
#  (78,
#   1,
#   '센터필드R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 231 (역삼동)',
#   Decimal('37.50369465391196'),
#   Decimal('127.04172081609172')),
#  (77,
#   1,
#   '코엑스아셈타워',
#   '강남구',
#   '서울특별시 강남구 영동대로 517 (삼성동)',
#   Decimal('37.51301900000000'),
#   Decimal('127.05983800000000')),
#  (76,
#   1,
#   '수서역사거리',
#   '강남구',
#   '서울특별시 강남구 광평로 280 (수서동)',
#   Decimal('37.48732679377480'),
#   Decimal('127.10314008188700')),
#  (75,
#   1,
#   '개포동',
#   '강남구',
#   '서울특별시 강남구 선릉로 34 (개포동)',
#   Decimal('37.48285513598820'),
#   Decimal('127.06071524446210')),
#  (74,
#   1,
#   '대치한티',
#   '강남구',
#   '서울특별시 강남구 선릉로 324 (대치동)',
#   Decimal('37.49848180000000'),
#   Decimal('127.05206600000000')),
#  (73,
#   1,
#   '도산가로수길',
#   '강남구',
#   '서울특별시 강남구 도산대로 134, 2층 (논현동)',
#   Decimal('37.51736229999999'),
#   Decimal('127.02329570000006')),
#  (72,
#   1,
#   '논현힐탑',
#   '강남구',
#   '서울특별시 강남구 논현로 648 (논현동)',
#   Decimal('37.51155770000000'),
#   Decimal('127.03226199999994')),
#  (71,
#   1,
#   '선릉로',
#   '강남구',
#   '서울특별시 강남구 선릉로93길 22, 대흥빌딩 1층 (역삼동)',
#   Decimal('37.50505300000000'),
#   Decimal('127.04657700000000')),
#  (70,
#   1,
#   '포스코',
#   '강남구',
#   '서울특별시 강남구 삼성로86길 7, 1층 (대치동)',
#   Decimal('37.50576000000000'),
#   Decimal('127.05796600000000')),
#  (69,
#   1,
#   '르네상스사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 306 (역삼동)',
#   Decimal('37.50272100000000'),
#   Decimal('127.04430800000000')),
#  (68,
#   1,
#   '압구정로데오역',
#   '강남구',
#   '서울특별시 강남구 선릉로 836, 삼원빌딩 1,2층 (청담동)',
#   Decimal('37.52654900000000'),
#   Decimal('127.04043700000000')),
#  (67,
#   1,
#   '강남비젼타워',
#   '강남구',
#   '서울특별시 강남구 테헤란로2길 27, 1층 101호 (역삼동)',
#   Decimal('37.49645570000000'),
#   Decimal('127.02968850000002')),
#  (66,
#   1,
#   '아크로힐스논현',
#   '강남구',
#   '서울특별시 강남구 봉은사로 304, 금강빌딩 1-2층 (역삼동)',
#   Decimal('37.50898041000000'),
#   Decimal('127.04038690000000')),
#  (65,
#   1,
#   '신압구정',
#   '강남구',
#   '서울특별시 강남구 언주로174길 29 (신사동)',
#   Decimal('37.52811500000000'),
#   Decimal('127.03644100000000')),
#  (64,
#   1,
#   '역삼럭키',
#   '강남구',
#   '서울특별시 강남구 도곡로 183 (역삼동)',
#   Decimal('37.49220900000000'),
#   Decimal('127.03938900000000')),
#  (63,
#   1,
#   '코엑스사거리',
#   '강남구',
#   '서울특별시 강남구 영동대로 616 (삼성동)',
#   Decimal('37.51535100000000'),
#   Decimal('127.06010900000000')),
#  (62,
#   1,
#   '선릉역',
#   '강남구',
#   '서울특별시 강남구 테헤란로 334, LG화재 빌딩 (역삼동)',
#   Decimal('37.50393894000000'),
#   Decimal('127.04851350000000')),
#  (61,
#   1,
#   '압구정미소',
#   '강남구',
#   '서울특별시 강남구 논현로 841 (신사동)',
#   Decimal('37.52405601000000'),
#   Decimal('127.02791500000000')),
#  (60,
#   1,
#   'GS타워',
#   '강남구',
#   '서울특별시 강남구 논현로 508 (역삼동)',
#   Decimal('37.50185920000000'),
#   Decimal('127.03727759999992')),
#  (59,
#   1,
#   '삼성현대힐',
#   '강남구',
#   '서울특별시 강남구 삼성로 605 (삼성동)',
#   Decimal('37.51354184000000'),
#   Decimal('127.05271830000000')),
#  (58,
#   1,
#   '선정릉역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 407 (삼성동) 에프오빌딩',
#   Decimal('37.51075489999999'),
#   Decimal('127.04455970000003')),
#  (57,
#   1,
#   '학여울역',
#   '강남구',
#   '서울특별시 강남구 영동대로 215 (대치동)',
#   Decimal('37.49803646000000'),
#   Decimal('127.06849430000000')),
#  (56,
#   1,
#   '아크플레이스',
#   '강남구',
#   '서울특별시 강남구 테헤란로 142 (역삼동)',
#   Decimal('37.49971982000000'),
#   Decimal('127.03490840000000')),
#  (55,
#   1,
#   '포이',
#   '강남구',
#   '서울특별시 강남구 논현로 88 (개포동)',
#   Decimal('37.47781106000000'),
#   Decimal('127.04514110000000')),
#  (54,
#   1,
#   '대치역',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2936 (대치동) 107호',
#   Decimal('37.49355400000000'),
#   Decimal('127.06187400000000')),
#  (53,
#   1,
#   '강남구청역',
#   '강남구',
#   '서울특별시 강남구 선릉로 669, 웰빙센터 1층 (논현동)',
#   Decimal('37.51658490000000'),
#   Decimal('127.04124330000002')),
#  (52,
#   1,
#   '큰길타워',
#   '강남구',
#   '서울특별시 강남구 테헤란로 223, 큰길타워빌딩 (역삼동)',
#   Decimal('37.50236693000000'),
#   Decimal('127.04070000000000')),
#  (51,
#   1,
#   '구역삼사거리',
#   '강남구',
#   '서울특별시 강남구 논현로 401 (역삼동)',
#   Decimal('37.49592355000000'),
#   Decimal('127.03886450000000')),
#  (50,
#   1,
#   '압구정로',
#   '강남구',
#   '서울특별시 강남구 압구정로42길 32 (신사동)',
#   Decimal('37.52680046000000'),
#   Decimal('127.03471740000000')),
#  (49,
#   1,
#   '압구정역',
#   '강남구',
#   '서울특별시 강남구 압구정로 170, 관영빌딩 1층 지하1층 (신사동)',
#   Decimal('37.52674095000000'),
#   Decimal('127.02811050000000')),
#  (48,
#   1,
#   '선릉세화빌딩',
#   '강남구',
#   '서울특별시 강남구 테헤란로64길 18 (대치동) 1층',
#   Decimal('37.50377562000000'),
#   Decimal('127.05119600000000')),
#  (47,
#   1,
#   '삼성',
#   '강남구',
#   '서울특별시 강남구 테헤란로 443, 애플트리타워 1층 (삼성동)',
#   Decimal('37.50703529000000'),
#   Decimal('127.05555030000000')),
#  (46,
#   1,
#   'SSG마켓도곡R',
#   '강남구',
#   '서울특별시 강남구 언주로30길 57, 타워팰리스Ⅱ F 지하1층 (도곡동)',
#   Decimal('37.49029800000000'),
#   Decimal('127.05489500000000')),
#  (45,
#   1,
#   '대치',
#   '강남구',
#   '서울특별시 강남구 도곡로 511 (대치동)',
#   Decimal('37.49966175000000'),
#   Decimal('127.06221710000000')),
#  (44,
#   1,
#   '학동역',
#   '강남구',
#   '서울특별시 강남구 논현로 704 (논현동)',
#   Decimal('37.51464884000000'),
#   Decimal('127.03073020000000')),
#  (43,
#   1,
#   '삼성교',
#   '강남구',
#   '서울특별시 강남구 영동대로86길 12, 동남유화빌딩 1층',
#   Decimal('37.50779400000000'),
#   Decimal('127.06517000000000')),
#  (42,
#   1,
#   '삼성도심공항',
#   '강남구',
#   '서울특별시 강남구 테헤란로87길 33 (삼성동)',
#   Decimal('37.50978630000000'),
#   Decimal('127.05791339999996')),
#  (41,
#   1,
#   '청담',
#   '강남구',
#   '서울특별시 강남구 도산대로 532, 인희빌딩 1층 (청담동)',
#   Decimal('37.52436310000000'),
#   Decimal('127.05155990000003')),
#  (40,
#   1,
#   '강남대로',
#   '강남구',
#   '서울특별시 강남구 강남대로 456, 한석타워 2층 1-2호 (역삼동)',
#   Decimal('37.50314000000000'),
#   Decimal('127.02554600000000')),
#  (39,
#   1,
#   '역삼포스코',
#   '강남구',
#   '서울특별시 강남구 테헤란로 134, P&S TOWER (역삼동)',
#   Decimal('37.49972100000000'),
#   Decimal('127.03358200000000')),
#  (38,
#   1,
#   '역삼대로',
#   '강남구',
#   '서울특별시 강남구 테헤란로 211, 한국고등교육재단빌딩 1층 (역삼동)',
#   Decimal('37.50162300000000'),
#   Decimal('127.03937500000000')),
#  (37,
#   1,
#   '가로수길',
#   '강남구',
#   '서울특별시 강남구 논현로175길 94, 1~2층 (신사동)',
#   Decimal('37.52315930000000'),
#   Decimal('127.02162499999997')),
#  (36,
#   1,
#   '코엑스몰',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동) O103호',
#   Decimal('37.51371500000000'),
#   Decimal('127.05924500000000')),
#  (35,
#   1,
#   '역삼초교사거리',
#   '강남구',
#   '서울특별시 강남구 역삼로 123 (역삼동)',
#   Decimal('37.49410590000000'),
#   Decimal('127.03299730000003')),
#  (34,
#   1,
#   '한티역',
#   '강남구',
#   '서울특별시 강남구 도곡로 408, 디마크빌딩 101호 (대치동)',
#   Decimal('37.49680100000000'),
#   Decimal('127.05505500000000')),
#  (33,
#   1,
#   '청담사거리',
#   '강남구',
#   '서울특별시 강남구 도산대로 458 (청담동) 리츠타워',
#   Decimal('37.52363510000000'),
#   Decimal('127.04686509999999')),
#  (32,
#   1,
#   '서울세관사거리',
#   '강남구',
#   '서울특별시 강남구 언주로 650 (논현동) 한국건설기술인협회',
#   Decimal('37.51488700000000'),
#   Decimal('127.03565300000000')),
#  (31,
#   1,
#   '도곡역',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2909 (대치동)',
#   Decimal('37.49216700000000'),
#   Decimal('127.05739800000000')),
#  (30,
#   1,
#   '신사역',
#   '강남구',
#   '서울특별시 강남구 도산대로 108 (논현동) 렉스타워',
#   Decimal('37.51620210000000'),
#   Decimal('127.02074280000000')),
#  (29,
#   1,
#   '을지병원사거리',
#   '강남구',
#   '서울특별시 강남구 논현로 752 (논현동,구산빌딩)',
#   Decimal('37.51916320000000'),
#   Decimal('127.02864460000000')),
#  (28,
#   1,
#   '포스코사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 505 (삼성동) 화진빌딩',
#   Decimal('37.50753070000000'),
#   Decimal('127.05742710000004')),
#  (27,
#   1,
#   '대치사거리',
#   '강남구',
#   '서울특별시 강남구 삼성로 402 (대치동)',
#   Decimal('37.50333100000000'),
#   Decimal('127.05881700000000')),
#  (26,
#   1,
#   '학동사거리',
#   '강남구',
#   '서울특별시 강남구 도산대로 328 (논현동)',
#   Decimal('37.52236449999999'),
#   Decimal('127.03795430000002')),
#  (25,
#   1,
#   '강남우성',
#   '강남구',
#   '서울특별시 강남구 강남대로 328 (역삼동)',
#   Decimal('37.49239600000000'),
#   Decimal('127.03091000000000')),
#  (24,
#   1,
#   '청담스타R',
#   '강남구',
#   '서울특별시 강남구 도산대로57길 24 (청담동)',
#   Decimal('37.52521600000000'),
#   Decimal('127.04182700000000')),
#  (23,
#   1,
#   '신사가로수',
#   '강남구',
#   '서울특별시 강남구 가로수길 59 ',
#   Decimal('37.52193300000000'),
#   Decimal('127.02252100000000')),
#  (22,
#   1,
#   '압구정',
#   '강남구',
#   '서울특별시 강남구 압구정로30길 17 (신사동)',
#   Decimal('37.52628300000000'),
#   Decimal('127.02956000000000')),
#  (21,
#   1,
#   '청담영동대로',
#   '강남구',
#   '서울특별시 강남구 영동대로 720 (청담동)',
#   Decimal('37.52215600000000'),
#   Decimal('127.05644900000000')),
#  (20,
#   1,
#   '대치은마사거리',
#   '강남구',
#   '서울특별시 강남구 도곡로 457 (대치동)',
#   Decimal('37.49897300000000'),
#   Decimal('127.06017200000000')),
#  (19,
#   1,
#   '강남R',
#   '강남구',
#   '서울특별시 강남구 강남대로 390 (역삼동)',
#   Decimal('37.49771100000000'),
#   Decimal('127.02843900000000')),
#  (18,
#   1,
#   '도곡공원',
#   '강남구',
#   '서울특별시 강남구 도곡로 205 (역삼동)',
#   Decimal('37.49280500000000'),
#   Decimal('127.04130900000000')),
#  (17,
#   1,
#   '강남구청정문',
#   '강남구',
#   '서울특별시 강남구 학동로 419 (청담동)',
#   Decimal('37.51818100000000'),
#   Decimal('127.04599500000000')),
#  (16,
#   1,
#   '스타필드코엑스몰R',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동) 코엑스 A106호',
#   Decimal('37.50999000000000'),
#   Decimal('127.06145500000000')),
#  (15,
#   1,
#   '강남오거리',
#   '강남구',
#   '서울특별시 강남구 봉은사로2길 39 (역삼동)',
#   Decimal('37.50211700000000'),
#   Decimal('127.02667200000000')),
#  (14,
#   1,
#   '봉은사로선정릉',
#   '강남구',
#   '서울특별시 강남구 봉은사로 446 (삼성동)',
#   Decimal('37.51129300000000'),
#   Decimal('127.04840900000000')),
#  (13,
#   1,
#   '선릉동신빌딩R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 409 (삼성동)',
#   Decimal('37.50532100000000'),
#   Decimal('127.05040900000000')),
#  (12,
#   1,
#   '양재강남빌딩R',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2621 (도곡동)',
#   Decimal('37.48519200000000'),
#   Decimal('127.03668500000000')),
#  (11,
#   1,
#   '수서역R',
#   '강남구',
#   '서울특별시 강남구 광평로 281 (수서동)',
#   Decimal('37.48800800000000'),
#   Decimal('127.10265000000000')),
#  (10,
#   1,
#   '압구정R',
#   '강남구',
#   '서울특별시 강남구 언주로 861 (신사동)',
#   Decimal('37.52736690000000'),
#   Decimal('127.03306100000000')),
#  (9,
#   1,
#   '삼성역섬유센터R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 518 (대치동)',
#   Decimal('37.50775000000000'),
#   Decimal('127.06065100000000')),
#  (8,
#   1,
#   '코엑스별마당',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동)',
#   Decimal('37.51015000000000'),
#   Decimal('127.06027500000000')),
#  (7,
#   1,
#   '압구정윤성빌딩',
#   '강남구',
#   '서울특별시 강남구 논현로 834 (신사동)',
#   Decimal('37.52279340000000'),
#   Decimal('127.02860090000000')),
#  (6,
#   1,
#   '봉은사역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 619 (삼성동)',
#   Decimal('37.51500000000000'),
#   Decimal('127.06319600000000')),
#  (5,
#   1,
#   '대치재경빌딩R',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2947 (대치동)',
#   Decimal('37.49466800000000'),
#   Decimal('127.06258300000000')),
#  (4,
#   1,
#   '국기원사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 125 (역삼동)',
#   Decimal('37.49951700000000'),
#   Decimal('127.03149500000000')),
#  (3,
#   1,
#   '신사역성일빌딩',
#   '강남구',
#   '서울특별시 강남구 강남대로 584 (논현동)',
#   Decimal('37.51393090000000'),
#   Decimal('127.02060570000000')),
#  (2,
#   1,
#   '논현역사거리',
#   '강남구',
#   '서울특별시 강남구 강남대로 538 (논현동)',
#   Decimal('37.51017800000000'),
#   Decimal('127.02222300000000')),
#  (1,
#   1,
#   '역삼아레나빌딩',
#   '강남구',
#   '서울특별시 강남구 언주로 425 (역삼동)',
#   Decimal('37.50108700000000'),
#   Decimal('127.04306900000000'))]

# %%
# 이디야 매장 전체 데이터 구하기
import time
import googlemaps

driver = webdriver.Chrome("./driver/chromedriver-win64/chromedriver.exe")
driver.get("https://ediya.com/contents/find_store.html")

# 주소 탭 클릭
driver.find_element_by_css_selector("#contentWrap > div.contents > div > div.store_search_pop > ul > li:nth-child(2) > a").click()

search_keyword = driver.find_element_by_css_selector("#keyword")
search_button = driver.find_element_by_css_selector("#keyword_div button")

cursor.execute("USE oneday;")
# 테이블에 insert
sql = "INSERT INTO COFFEE_STORE (brand, name, gu_name, address, lat, lng) VALUES (2, %s, %s, %s, %s, %s)"
time.sleep(1)

# 주소를 찾을 수 없을 때 수동으로 위도와 경도를 매핑하는 딕셔너리
address_to_coords = {
    "서울 관악구 남부순환로 1369 (신림동, 관악농협농산물백화점)": (37.480015243858205, 126.90297235228446),
    "서울 마포구 신촌로 66 (노고산동, 농협중앙회)": (37.55600645259885, 126.93304897393608),
    "서울 서대문구 수색로 100 (북가좌동, DMC래미안e편한세상)": (37.57495124473997, 126.90825191501912),
    "서울 서초구 서초대로 108 (방배동, 삼보빌딩)": (37.48750853475973, 126.99420794887064),
    "서울 송파구 충민로 66 (문정동, 가든파이브라이프)": (37.47748419041258, 127.12496889994861),
    "서울 송파구 송파대로 567 (잠실동, 잠실주공아파트)": (37.51432402116925, 127.09334786098638),
    "서울 영등포구 63로 40 (여의도동, 라이프오피스텔)": (37.51956203765937, 126.9391390787403),
}

for gu in gu_list:
    # 구별 검색어 검색창에 입력
    search_keyword.clear()
    search_keyword.send_keys(gu)
    
    # 검색 버튼 클릭
    search_button.click()
    time.sleep(1)

    # 검색 결과 리스트 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    contents = soup.select("#placesList li")

    for content in contents:
        # 매장 이름, 주소, 구 이름 데이터 수집
        title = content.select_one('dt').text
        address = content.select_one('dd').text
        gu_name = address.split(' ')[1]


        try:
            tmp = gmaps.geocode(address, language='ko')
            if tmp:
                tmp[0].get("formatted_address")
                lat = tmp[0]["geometry"]["location"]["lat"]
                lng = tmp[0]["geometry"]["location"]["lng"]
                cursor.execute(sql, (title, gu_name, address, lat, lng))
                conn.commit()
            else:
                print("주소를 찾을 수 없습니다: ", address)
                # 수동으로 입력된 위도와 경도 값을 가져옵니다.
                lat, lng = address_to_coords[address]
                cursor.execute(sql, (title, gu_name, address, lat, lng))
                conn.commit()
        except IndexError as e:
            print("주소 처리 중 오류 발생: ", address)
            print(str(e))
# Out:
# 주소를 찾을 수 없습니다:  서울 관악구 남부순환로 1369 (신림동, 관악농협농산물백화점)
# 주소를 찾을 수 없습니다:  서울 마포구 신촌로 66 (노고산동, 농협중앙회)
# 주소를 찾을 수 없습니다:  서울 서대문구 수색로 100 (북가좌동, DMC래미안e편한세상)
# 주소를 찾을 수 없습니다:  서울 서초구 서초대로 108 (방배동, 삼보빌딩)
# 주소를 찾을 수 없습니다:  서울 송파구 충민로 66 (문정동, 가든파이브라이프)
# 주소를 찾을 수 없습니다:  서울 송파구 송파대로 567 (잠실동, 잠실주공아파트)
# 주소를 찾을 수 없습니다:  서울 영등포구 63로 40 (여의도동, 라이프오피스텔)

# %%
cursor.execute("DESC COFFEE_STORE;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('brand', b'int', 'NO', 'MUL', None, ''),
#  ('name', b'varchar(32)', 'NO', '', None, ''),
#  ('gu_name', b'varchar(5)', 'NO', '', None, ''),
#  ('address', b'varchar(128)', 'NO', '', None, ''),
#  ('lat', b'decimal(16,14)', 'NO', '', None, ''),
#  ('lng', b'decimal(17,14)', 'NO', '', None, '')]

# %%
cursor.execute("SELECT * FROM COFFEE_STORE WHERE brand=2 ORDER BY id DESC;")
cursor.fetchall()
# Out:
# [(1221,
#   2,
#   '화랑대역점',
#   '중랑구',
#   '서울 중랑구 신내로25가길 2 (묵동, 현동학당)',
#   Decimal('37.61945060000000'),
#   Decimal('127.08416050000000')),
#  (1220,
#   2,
#   '중화동점',
#   '중랑구',
#   '서울 중랑구 동일로129길 1 (중화동)',
#   Decimal('37.60195730000000'),
#   Decimal('127.08662700000000')),
#  (1219,
#   2,
#   '중랑역점',
#   '중랑구',
#   '서울 중랑구 망우로 198 (상봉동)',
#   Decimal('37.59328500000000'),
#   Decimal('127.07488880000000')),
#  (1218,
#   2,
#   '중랑묵동점',
#   '중랑구',
#   '서울 중랑구 동일로 932 (묵동, 묵동자이아파트)',
#   Decimal('37.61377890000001'),
#   Decimal('127.07752370000000')),
#  (1217,
#   2,
#   '중랑교차로점',
#   '중랑구',
#   '서울 중랑구 동일로 683 (면목동)',
#   Decimal('37.59144780000000'),
#   Decimal('127.07988210000000')),
#  (1216,
#   2,
#   '우림시장점',
#   '중랑구',
#   '서울 중랑구 봉우재로 240 (망우동)',
#   Decimal('37.59526970000000'),
#   Decimal('127.09937670000000')),
#  (1215,
#   2,
#   '양원역점',
#   '중랑구',
#   '서울 중랑구 양원역로14가길 24 (망우동)',
#   Decimal('37.60748980000000'),
#   Decimal('127.10695150000000')),
#  (1214,
#   2,
#   '신내동점',
#   '중랑구',
#   '서울 중랑구 봉화산로 215 (신내동)',
#   Decimal('37.60767080000000'),
#   Decimal('127.09656530000000')),
#  (1213,
#   2,
#   '서일중앙점',
#   '중랑구',
#   '서울 중랑구 용마산로 394 (면목동, 해동검도)',
#   Decimal('37.58666669999999'),
#   Decimal('127.09554950000000')),
#  (1212,
#   2,
#   '서울중화초등학교점',
#   '중랑구',
#   '서울 중랑구 신내로7가길 7 (신내동, 제이리옴)',
#   Decimal('37.60234760000000'),
#   Decimal('127.09545850000000')),
#  (1211,
#   2,
#   '서울의료원점',
#   '중랑구',
#   '서울 중랑구 신내로 156 (신내동, 서울의료원)',
#   Decimal('37.61278100000000'),
#   Decimal('127.09817870000000')),
#  (1210,
#   2,
#   '서울상봉1동점',
#   '중랑구',
#   '서울 중랑구 상봉중앙로 36 (상봉동)',
#   Decimal('37.60028470000000'),
#   Decimal('127.08774320000000')),
#  (1209,
#   2,
#   '상봉중앙점',
#   '중랑구',
#   '서울 중랑구 망우로 316 (상봉동)',
#   Decimal('37.59648470000000'),
#   Decimal('127.08753540000000')),
#  (1208,
#   2,
#   '상봉역점',
#   '중랑구',
#   '서울 중랑구 망우로 277 (상봉동)',
#   Decimal('37.59606050000001'),
#   Decimal('127.08341730000000')),
#  (1207,
#   2,
#   '상봉엠코점',
#   '중랑구',
#   '서울 중랑구 망우로 353 (상봉동, 상봉 프레미어스 엠코)',
#   Decimal('37.59808100000000'),
#   Decimal('127.09059510000000')),
#  (1206,
#   2,
#   '사가정역점',
#   '중랑구',
#   '서울 중랑구 면목로 325 (면목동)',
#   Decimal('37.58114470000000'),
#   Decimal('127.08816790000000')),
#  (1205,
#   2,
#   '사가정아이파크점',
#   '중랑구',
#   '서울 중랑구 동일로92길 57 (면목동, 메디포레)',
#   Decimal('37.58351040000000'),
#   Decimal('127.08318860000000')),
#  (1204,
#   2,
#   '봉화산역점',
#   '중랑구',
#   '서울 중랑구 신내로 211 (신내동)',
#   Decimal('37.61632530000000'),
#   Decimal('127.09267760000000')),
#  (1203,
#   2,
#   '면목역점',
#   '중랑구',
#   '서울 중랑구 면목로 429 (면목동, 킴스아파트)',
#   Decimal('37.59172080000000'),
#   Decimal('127.08689310000000')),
#  (1202,
#   2,
#   '면목늘찬병원점',
#   '중랑구',
#   '서울 중랑구 동일로 643 (면목동, 늘찬병원)',
#   Decimal('37.58777300000000'),
#   Decimal('127.07973460000000')),
#  (1201,
#   2,
#   '면목경남아너스빌점',
#   '중랑구',
#   '서울 중랑구 면목로27길 92 (면목동)',
#   Decimal('37.57426580000000'),
#   Decimal('127.08053470000000')),
#  (1200,
#   2,
#   '먹골역점',
#   '중랑구',
#   '서울 중랑구 동일로157길 13 (묵동)',
#   Decimal('37.60972500000000'),
#   Decimal('127.07689840000000')),
#  (1199,
#   2,
#   '망우코레일점',
#   '중랑구',
#   '서울 중랑구 망우로55길 11-10 (상봉동, 망우역)',
#   Decimal('37.59860300000000'),
#   Decimal('127.09288200000000')),
#  (1198,
#   2,
#   '망우중앙점',
#   '중랑구',
#   '서울 중랑구 용마산로115길 109 (망우동, 한일써너스빌리젠시2단지)',
#   Decimal('37.59764420000000'),
#   Decimal('127.09434620000000')),
#  (1197,
#   2,
#   '망우동점',
#   '중랑구',
#   '서울 중랑구 망우로 416 (망우동)',
#   Decimal('37.59911950000000'),
#   Decimal('127.09836140000000')),
#  (1196,
#   2,
#   '동원사거리점',
#   '중랑구',
#   '서울 중랑구 겸재로 240 (면목동, 행복오피스텔)',
#   Decimal('37.58954760000000'),
#   Decimal('127.09392180000000')),
#  (1195,
#   2,
#   '금란망우점',
#   '중랑구',
#   '서울 중랑구 망우로 460 (망우동)',
#   Decimal('37.60008470000000'),
#   Decimal('127.10315650000000')),
#  (1194,
#   2,
#   '이태원역점',
#   '용산구',
#   '서울 용산구 이태원로 176 (이태원동)',
#   Decimal('37.53450380000000'),
#   Decimal('126.99069950000000')),
#  (1193,
#   2,
#   '원효로점',
#   '용산구',
#   '서울 용산구 원효로 257 (원효로1가)',
#   Decimal('37.53998010000000'),
#   Decimal('126.96744700000000')),
#  (1192,
#   2,
#   '용산효창점',
#   '용산구',
#   '서울 용산구 효창원로66길 2 (효창동)',
#   Decimal('37.54316270000000'),
#   Decimal('126.96366900000000')),
#  (1191,
#   2,
#   '용산청파점',
#   '용산구',
#   '서울 용산구 청파로71길 10 (청파동1가, 새마을금고)',
#   Decimal('37.55003870000000'),
#   Decimal('126.96760590000000')),
#  (1190,
#   2,
#   '용산중앙점',
#   '용산구',
#   '서울 용산구 한강대로 52-1 (한강로3가)',
#   Decimal('37.52560840000000'),
#   Decimal('126.96486170000000')),
#  (1189,
#   2,
#   '용산원효점',
#   '용산구',
#   '서울 용산구 원효로 70 (원효로4가, 신정빌딩)',
#   Decimal('37.53427760000000'),
#   Decimal('126.95264130000000')),
#  (1188,
#   2,
#   '용문점',
#   '용산구',
#   '서울 용산구 원효로41길 73 (원효로2가)',
#   Decimal('37.53631710000001'),
#   Decimal('126.96246250000000')),
#  (1187,
#   2,
#   '순천향병원점',
#   '용산구',
#   '서울 용산구 대사관로 72 ',
#   Decimal('37.53304790000000'),
#   Decimal('127.00593780000000')),
#  (1186,
#   2,
#   '숙대입구역점',
#   '용산구',
#   '서울 용산구 한강대로 289 (갈월동)',
#   Decimal('37.54406080000000'),
#   Decimal('126.97197220000000')),
#  (1185,
#   2,
#   '삼각지점',
#   '용산구',
#   '서울 용산구 한강대로 138 (한강로2가)',
#   Decimal('37.53048590000000'),
#   Decimal('126.96951070000000')),
#  (1184,
#   2,
#   '동자동점',
#   '용산구',
#   '서울 용산구 후암로 93 (동자동)',
#   Decimal('37.55334230000000'),
#   Decimal('126.97512130000000')),
#  (1183,
#   2,
#   '동부이촌동점',
#   '용산구',
#   '서울 용산구 이촌로77길 19 (이촌동)',
#   Decimal('37.52037139999999'),
#   Decimal('126.97502380000000')),
#  (1182,
#   2,
#   'IBK고객센터점',
#   '용산구',
#   '서울 용산구 한남대로 72 (한남동, IBK기업은행고객센터)',
#   Decimal('37.53507440000000'),
#   Decimal('127.00701240000000')),
#  (1181,
#   2,
#   '한양대점',
#   '성동구',
#   '서울 성동구 사근동길 4 (행당동)',
#   Decimal('37.55994480000000'),
#   Decimal('127.04154950000000')),
#  (1180,
#   2,
#   '텐즈힐점',
#   '성동구',
#   '서울 성동구 무학로 33 (하왕십리동, 텐즈힐)',
#   Decimal('37.56856530000000'),
#   Decimal('127.02796620000000')),
#  (1179,
#   2,
#   '장한평역점',
#   '성동구',
#   '서울 성동구 천호대로 426 (용답동)',
#   Decimal('37.56087100000000'),
#   Decimal('127.06619620000000')),
#  (1178,
#   2,
#   '응봉동점',
#   '성동구',
#   '서울 성동구 독서당로 381 (응봉동, 현대종합상가)',
#   Decimal('37.55098210000000'),
#   Decimal('127.03090930000000')),
#  (1177,
#   2,
#   '왕십리역점',
#   '성동구',
#   '서울 성동구 왕십리로 309 (행당동)',
#   Decimal('37.55942630000000'),
#   Decimal('127.03301790000000')),
#  (1176,
#   2,
#   '왕십리센트라스점',
#   '성동구',
#   '서울 성동구 무학로 22 (홍익동)',
#   Decimal('37.56607980000000'),
#   Decimal('127.03031290000000')),
#  (1175,
#   2,
#   '왕십리비트플렉스점',
#   '성동구',
#   '서울 성동구 왕십리광장로 17 (행당동)',
#   Decimal('37.56128860000000'),
#   Decimal('127.03838200000000')),
#  (1174,
#   2,
#   '옥수동점',
#   '성동구',
#   '서울 성동구 매봉길 12 (옥수동)',
#   Decimal('37.54527370000000'),
#   Decimal('127.01571820000000')),
#  (1173,
#   2,
#   '신금호역점',
#   '성동구',
#   '서울 성동구 금호산길 64 (금호동2가)',
#   Decimal('37.55389330000000'),
#   Decimal('127.01962840000000')),
#  (1172,
#   2,
#   '성수중앙점',
#   '성동구',
#   '서울 성동구 성수일로6길 47 (성수동2가, 현성빌딩)',
#   Decimal('37.54427460000000'),
#   Decimal('127.05532220000000')),
#  (1171,
#   2,
#   '성수우리W타워점',
#   '성동구',
#   '서울 성동구 아차산로15길 19 (성수동2가)',
#   Decimal('37.54477310000000'),
#   Decimal('127.06219630000000')),
#  (1170,
#   2,
#   '성수아카데미점',
#   '성동구',
#   '서울 성동구 성수이로 118 (성수동2가)',
#   Decimal('37.54519240000000'),
#   Decimal('127.05781830000000')),
#  (1169,
#   2,
#   '성동구청점',
#   '성동구',
#   '서울 성동구 고산자로 269 (도선동)',
#   Decimal('37.56328240000000'),
#   Decimal('127.03290860000000')),
#  (1168,
#   2,
#   '상왕십리역점',
#   '성동구',
#   '서울 성동구 무학봉15길 27 (하왕십리동)',
#   Decimal('37.56368040000000'),
#   Decimal('127.03019810000000')),
#  (1167,
#   2,
#   '마장역점',
#   '성동구',
#   '서울 성동구 마장로 293-1 (마장동)',
#   Decimal('37.56595950000000'),
#   Decimal('127.04215110000000')),
#  (1166,
#   2,
#   '마장동점',
#   '성동구',
#   '서울 성동구 고산자로 339-2 (마장동)',
#   Decimal('37.56341949999999'),
#   Decimal('127.04199970000000')),
#  (1165,
#   2,
#   '뚝섬역점',
#   '성동구',
#   '서울 성동구 상원길 38-1 (성수동1가)',
#   Decimal('37.54736860000000'),
#   Decimal('127.04879320000000')),
#  (1164,
#   2,
#   '답십리로데오점',
#   '성동구',
#   '서울 성동구 용답19길 17-1 (용답동)',
#   Decimal('37.56376550000000'),
#   Decimal('127.05258420000000')),
#  (1163,
#   2,
#   '논골사거리점',
#   '성동구',
#   '서울 성동구 난계로 35 (금호동1가)',
#   Decimal('37.55549740000000'),
#   Decimal('127.02457020000000')),
#  (1162,
#   2,
#   '회기역중앙점',
#   '동대문구',
#   '서울 동대문구 회기로 194-1 (휘경동)',
#   Decimal('37.58981570000000'),
#   Decimal('127.05748960000000')),
#  (1161,
#   2,
#   '회기역점',
#   '동대문구',
#   '서울 동대문구 망우로 67 (휘경동, 효자 워너빌)',
#   Decimal('41.96000520000000'),
#   Decimal('-97.44616230000000')),
#  (1160,
#   2,
#   '촬영소사거리점',
#   '동대문구',
#   '서울 동대문구 답십리로 264 (장안동)',
#   Decimal('37.57225990000000'),
#   Decimal('127.06947010000000')),
#  (1159,
#   2,
#   '청량리점',
#   '동대문구',
#   '서울 동대문구 왕산로 225 (청량리동)',
#   Decimal('37.58327230000000'),
#   Decimal('127.04474460000000')),
#  (1158,
#   2,
#   '전농사거리점',
#   '동대문구',
#   '서울 동대문구 사가정로 132 (전농동)',
#   Decimal('37.57760210000000'),
#   Decimal('127.05950870000000')),
#  (1157,
#   2,
#   '장한평군자초교점',
#   '동대문구',
#   '서울 동대문구 한천로2길 53 (장안동)',
#   Decimal('37.56286220000000'),
#   Decimal('127.06141190000000')),
#  (1156,
#   2,
#   '장안중앙점',
#   '동대문구',
#   '서울 동대문구 사가정로25길 42 (장안동)',
#   Decimal('37.58069840000000'),
#   Decimal('127.07095970000000')),
#  (1155,
#   2,
#   '장안중랑천점',
#   '동대문구',
#   '서울 동대문구 장한로18길 32 (장안동)',
#   Decimal('37.56752260000000'),
#   Decimal('127.07076400000000')),
#  (1154,
#   2,
#   '장안동점',
#   '동대문구',
#   '서울 동대문구 장한로 43 (장안동)',
#   Decimal('37.56509700000000'),
#   Decimal('127.06667980000000')),
#  (1153,
#   2,
#   '장안동사거리점',
#   '동대문구',
#   '서울 동대문구 답십리로 309 (장안동)',
#   Decimal('37.57238700000000'),
#   Decimal('127.07485530000000')),
#  (1152,
#   2,
#   '이문점 ',
#   '동대문구',
#   '서울 동대문구 신이문로 19 (이문동)',
#   Decimal('37.60312750000000'),
#   Decimal('127.06422490000000')),
#  (1151,
#   2,
#   '용두동점',
#   '동대문구',
#   '서울 동대문구 고산자로 413-1 (용두동)',
#   Decimal('37.57665690000000'),
#   Decimal('127.03793830000000')),
#  (1150,
#   2,
#   '용두동사거리점',
#   '동대문구',
#   '서울 동대문구 왕산로 68 (용두동)',
#   Decimal('37.57572570000000'),
#   Decimal('127.03428600000000')),
#  (1149,
#   2,
#   '외대점',
#   '동대문구',
#   '서울 동대문구 휘경로 12 (이문동)',
#   Decimal('37.59582130000000'),
#   Decimal('127.06127350000000')),
#  (1148,
#   2,
#   '신설동역점',
#   '동대문구',
#   '서울 동대문구 천호대로 11-3 (신설동)',
#   Decimal('37.57813150000000'),
#   Decimal('127.02739330000000')),
#  (1147,
#   2,
#   '서울시립대점',
#   '동대문구',
#   '서울 동대문구 서울시립대로 164 (전농동, 도석프라자)',
#   Decimal('37.58331270000000'),
#   Decimal('127.05481630000000')),
#  (1146,
#   2,
#   '배봉초교사거리점',
#   '동대문구',
#   '서울 동대문구 답십리로63길 131 (장안동)',
#   Decimal('37.57849590000000'),
#   Decimal('127.06932240000000')),
#  (1145,
#   2,
#   '동부병원사거리점',
#   '동대문구',
#   '서울 동대문구 무학로 104 (용두동)',
#   Decimal('37.57351260000000'),
#   Decimal('127.03091030000000')),
#  (1144,
#   2,
#   '동대문구청점',
#   '동대문구',
#   '서울 동대문구 천호대로 153-1 (용두동)',
#   Decimal('37.57960430000000'),
#   Decimal('127.02994090000000')),
#  (1143,
#   2,
#   '답십리파크자이점',
#   '동대문구',
#   '서울 동대문구 한천로 55 (답십리동, 영진빌딩)',
#   Decimal('37.56685700000000'),
#   Decimal('127.06183610000000')),
#  (1142,
#   2,
#   '답십리사거리점',
#   '동대문구',
#   '서울 동대문구 답십리로 145 (답십리동)',
#   Decimal('37.57308829999999'),
#   Decimal('127.05610540000000')),
#  (1141,
#   2,
#   '경희대캠퍼스점',
#   '동대문구',
#   '서울 동대문구 경희대로 26 (회기동, 경희대학교,경희초,중,고,여자중고등학교)',
#   Decimal('37.59489370000000'),
#   Decimal('127.04915620000000')),
#  (1140,
#   2,
#   '경희대점',
#   '동대문구',
#   '서울 동대문구 경희대로 4 (회기동)',
#   Decimal('37.59189370000000'),
#   Decimal('127.05252640000000')),
#  (1139,
#   2,
#   '천왕이펜하우스점',
#   '구로구',
#   '서울 구로구 천왕로 36 (천왕동)',
#   Decimal('37.48100830000000'),
#   Decimal('126.83927020000000')),
#  (1138,
#   2,
#   '오류북부역점',
#   '구로구',
#   '서울 구로구 경인로20길 6 (오류동)',
#   Decimal('37.49664040000000'),
#   Decimal('126.83852460000000')),
#  (1137,
#   2,
#   '오류남부점',
#   '구로구',
#   '서울 구로구 오류로8길 65 (오류동)',
#   Decimal('37.49269590000000'),
#   Decimal('126.84374390000000')),
#  (1136,
#   2,
#   '신도림테크노마트점',
#   '구로구',
#   '서울 구로구 새말로 97 (구로동)',
#   Decimal('37.50697350000000'),
#   Decimal('126.89031930000000')),
#  (1135,
#   2,
#   '신도림메르디앙점',
#   '구로구',
#   '서울 구로구 신도림로 65 (신도림동, 신도림월드메르디앙오피스텔)',
#   Decimal('37.50954010000000'),
#   Decimal('126.88203610000000')),
#  (1134,
#   2,
#   '성공회대점',
#   '구로구',
#   '서울 구로구 연동로 312 (항동)',
#   Decimal('37.48729730000000'),
#   Decimal('126.82423290000000')),
#  (1133,
#   2,
#   '메르디앙고척점',
#   '구로구',
#   '서울 구로구 중앙로8길 11 (고척동, 고척 월드메르디앙)',
#   Decimal('37.50294480000000'),
#   Decimal('126.86314740000000')),
#  (1132,
#   2,
#   '남구로역점',
#   '구로구',
#   '서울 구로구 디지털로27길 127 (가리봉동)',
#   Decimal('37.48467060000000'),
#   Decimal('126.88711900000000')),
#  (1131,
#   2,
#   '구일역점',
#   '구로구',
#   '서울 구로구 구일로 110 (구로동, 해원리버파크)',
#   Decimal('37.49505710000000'),
#   Decimal('126.87200690000000')),
#  (1130,
#   2,
#   '구로코레일점',
#   '구로구',
#   '서울 구로구 구로중앙로 174 (구로동, 구로역)',
#   Decimal('37.50257980000000'),
#   Decimal('126.88215450000000')),
#  (1129,
#   2,
#   '구로중앙점',
#   '구로구',
#   '서울 구로구 도림로 79 (구로동)',
#   Decimal('37.49008570000000'),
#   Decimal('126.89202840000000')),
#  (1128,
#   2,
#   '구로이마트점',
#   '구로구',
#   '서울 구로구 디지털로32길 43 (구로동)',
#   Decimal('37.48434850000000'),
#   Decimal('126.89792200000000')),
#  (1127,
#   2,
#   '구로역광장점',
#   '구로구',
#   '서울 구로구 경인로 572 (구로동, 스타팰리스)',
#   Decimal('37.49796680000000'),
#   Decimal('126.88436690000000')),
#  (1126,
#   2,
#   '구로에이스점',
#   '구로구',
#   '서울 구로구 디지털로33길 11 (구로동)',
#   Decimal('37.48571560000000'),
#   Decimal('126.89550920000000')),
#  (1125,
#   2,
#   '구로미성점',
#   '구로구',
#   '서울 구로구 구로중앙로 228 (신도림동, 기임빌딩)',
#   Decimal('37.50609590000000'),
#   Decimal('126.87662000000000')),
#  (1124,
#   2,
#   '구로궁동점',
#   '구로구',
#   '서울 구로구 오리로 1304 (궁동) 1층',
#   Decimal('37.50043890000000'),
#   Decimal('126.82852960000000')),
#  (1123,
#   2,
#   '구로구청점',
#   '구로구',
#   '서울 구로구 가마산로25길 9 (구로동, 네오팰리스)',
#   Decimal('37.49658830000001'),
#   Decimal('126.89030540000000')),
#  (1122,
#   2,
#   '구로거리공원점',
#   '구로구',
#   '서울 구로구 구로중앙로28길 73 (구로동)',
#   Decimal('37.50075910000000'),
#   Decimal('126.88940180000000')),
#  (1121,
#   2,
#   '구로NC점',
#   '구로구',
#   '서울 구로구 구로동로 240 (구로동)',
#   Decimal('37.50002360000000'),
#   Decimal('126.88268050000000')),
#  (1120,
#   2,
#   '고척스카이돔점',
#   '구로구',
#   '서울 구로구 경인로 397 (고척동, 골든타워빌딩)',
#   Decimal('37.50318840000000'),
#   Decimal('126.85885100000000')),
#  (1119,
#   2,
#   '고척사거리점',
#   '구로구',
#   '서울 구로구 고척로 228-6 (고척동, 종만빌딩)',
#   Decimal('37.50574720000000'),
#   Decimal('126.85823760000000')),
#  (1118,
#   2,
#   '개봉현대점',
#   '구로구',
#   '서울 구로구 개봉로 69 (개봉동)',
#   Decimal('37.49189860000000'),
#   Decimal('126.85565950000000')),
#  (1117,
#   2,
#   '개봉중앙점',
#   '구로구',
#   '서울 구로구 개봉로3길 26 (개봉동)',
#   Decimal('37.48647520000000'),
#   Decimal('126.85488820000000')),
#  (1116,
#   2,
#   '개봉역점',
#   '구로구',
#   '서울 구로구 남부순환로97길 11 (개봉동)',
#   Decimal('37.50300220000000'),
#   Decimal('126.84648510000000')),
#  (1115,
#   2,
#   '천호현대점',
#   '강동구',
#   '서울 강동구 올림픽로 665 (천호동)',
#   Decimal('37.54102890000000'),
#   Decimal('127.12371520000000')),
#  (1114,
#   2,
#   '천호초교사거리점',
#   '강동구',
#   '서울 강동구 구천면로 304 (천호동, 일주빌딩)',
#   Decimal('37.56961860000000'),
#   Decimal('127.02360390000000')),
#  (1113,
#   2,
#   '천호중앙점',
#   '강동구',
#   '서울 강동구 올림픽로 660 (천호동, 천호엘크루주상복합)',
#   Decimal('37.54016160000000'),
#   Decimal('127.12451750000000')),
#  (1112,
#   2,
#   '천호역점',
#   '강동구',
#   '서울 강동구 천호대로 1006 (성내동)',
#   Decimal('37.53049330000000'),
#   Decimal('127.12899200000000')),
#  (1111,
#   2,
#   '천호로데오점',
#   '강동구',
#   '서울 강동구 천호대로 1027 (천호동)',
#   Decimal('37.53824140000000'),
#   Decimal('127.12634640000000')),
#  (1110,
#   2,
#   '올림픽북문점',
#   '강동구',
#   '서울 강동구 성안로 7 (성내동)',
#   Decimal('37.52454190000000'),
#   Decimal('127.12889230000000')),
#  (1109,
#   2,
#   '암사중앙점',
#   '강동구',
#   '서울 강동구 암사길 50 (암사동, 제이빌더스)',
#   Decimal('37.55158690000000'),
#   Decimal('127.13486330000000')),
#  (1108,
#   2,
#   '상일리엔파크점',
#   '강동구',
#   '서울 강동구 상일로 74 (상일동, 고덕리엔파크3단지아파트)',
#   Decimal('37.55256120000000'),
#   Decimal('127.17525620000000')),
#  (1107,
#   2,
#   '보훈병원점',
#   '강동구',
#   '서울 강동구 명일로 110 (둔촌동, 둔촌동암펠로스타워)',
#   Decimal('37.52870910000000'),
#   Decimal('127.14317670000000')),
#  (1106,
#   2,
#   '명일중앙점',
#   '강동구',
#   '서울 강동구 상암로 210 (명일동, 명일현대종합상가)',
#   Decimal('37.54845670000000'),
#   Decimal('127.14878670000000')),
#  (1105,
#   2,
#   '명일역점',
#   '강동구',
#   '서울 강동구 구천면로 424 (명일동, 명일메가타운)',
#   Decimal('37.55031650000000'),
#   Decimal('127.14556920000000')),
#  (1104,
#   2,
#   '둔촌점',
#   '강동구',
#   '서울 강동구 양재대로 1377 (성내동)',
#   Decimal('37.53049330000000'),
#   Decimal('127.12899200000000')),
#  (1103,
#   2,
#   '길동중앙점',
#   '강동구',
#   '서울 강동구 명일로 200 (길동)',
#   Decimal('37.53653470000000'),
#   Decimal('127.14593820000000')),
#  (1102,
#   2,
#   '길동역점',
#   '강동구',
#   '서울 강동구 양재대로 1471 (길동)',
#   Decimal('37.53728220000000'),
#   Decimal('127.13940910000000')),
#  (1101,
#   2,
#   '길동사거리점',
#   '강동구',
#   '서울 강동구 천호대로 1132 (성내동)',
#   Decimal('37.53049330000000'),
#   Decimal('127.12899200000000')),
#  (1100,
#   2,
#   '고덕점',
#   '강동구',
#   '서울 강동구 동남로75길 19 (명일동, 명일빌딩)',
#   Decimal('37.55409510000000'),
#   Decimal('127.15514710000000')),
#  (1099,
#   2,
#   '고덕그라시움후문점',
#   '강동구',
#   '서울 강동구 동남로82길 121 (고덕동)',
#   Decimal('37.56426580000000'),
#   Decimal('127.16712440000000')),
#  (1098,
#   2,
#   '고덕강일2지구점',
#   '강동구',
#   '서울 강동구 아리수로93나길 76 (강일동)',
#   Decimal('37.57219860000000'),
#   Decimal('127.17422560000000')),
#  (1097,
#   2,
#   '강동역점',
#   '강동구',
#   '서울 강동구 천호대로 1065 (천호동, 강동상떼빌)',
#   Decimal('37.53594000000000'),
#   Decimal('127.13218700000000')),
#  (1096,
#   2,
#   '강동신명초교점',
#   '강동구',
#   '서울 강동구 명일로 260 (길동, 길동신동아아파트)',
#   Decimal('37.53961570000000'),
#   Decimal('127.14592930000000')),
#  (1095,
#   2,
#   '강동성내점',
#   '강동구',
#   '서울 강동구 풍성로 162 (성내동)',
#   Decimal('37.53048130000000'),
#   Decimal('127.12985840000000')),
#  (1094,
#   2,
#   '강동구청점',
#   '강동구',
#   '서울 강동구 성내로6길 20 (성내동, 청일 베르네)',
#   Decimal('37.52887530000000'),
#   Decimal('127.12228990000000')),
#  (1093,
#   2,
#   '강동고덕교차로점',
#   '강동구',
#   '서울 강동구 고덕로 421 (강일동, 대한연세요양원)',
#   Decimal('37.55737130000001'),
#   Decimal('127.17253990000000')),
#  (1092,
#   2,
#   '회현SK리더스점',
#   '중구',
#   '서울 중구 퇴계로 72 (회현동1가, 리더스뷰남산)',
#   Decimal('37.55375859999999'),
#   Decimal('126.98096960000000')),
#  (1091,
#   2,
#   '한국은행점',
#   '중구',
#   '서울 중구 남대문로 29-2 (남대문로3가)',
#   Decimal('37.56144320000000'),
#   Decimal('126.97896390000000')),
#  (1090,
#   2,
#   '퇴계로2길점',
#   '중구',
#   '서울 중구 퇴계로2길 1 (남창동)',
#   Decimal('37.56092920000000'),
#   Decimal('126.97876350000000')),
#  (1089,
#   2,
#   '태평로점',
#   '중구',
#   '서울 중구 세종대로11길 26 (서소문동)',
#   Decimal('37.56382820000000'),
#   Decimal('126.97520550000000')),
#  (1088,
#   2,
#   '충무필동점',
#   '중구',
#   '서울 중구 퇴계로 218-5 (필동2가)',
#   Decimal('37.55877340000000'),
#   Decimal('126.99472090000000')),
#  (1087,
#   2,
#   '충무아트홀점',
#   '중구',
#   '서울 중구 퇴계로 381-1 (신당동)',
#   Decimal('37.56527860000001'),
#   Decimal('127.01400120000000')),
#  (1086,
#   2,
#   '충무로점',
#   '중구',
#   '서울 중구 퇴계로 188 (필동1가)',
#   Decimal('37.56108620000000'),
#   Decimal('126.99246720000000')),
#  (1085,
#   2,
#   '충무로3가점',
#   '중구',
#   '서울 중구 퇴계로27길 31 (충무로3가)',
#   Decimal('37.56256740000000'),
#   Decimal('126.99124840000000')),
#  (1084,
#   2,
#   '청구역점',
#   '중구',
#   '서울 중구 다산로 181-2 (신당동)',
#   Decimal('37.55977499999999'),
#   Decimal('127.01323510000000')),
#  (1083,
#   2,
#   '정동점',
#   '중구',
#   '서울 중구 정동길 2-1 (정동)',
#   Decimal('37.56797830000000'),
#   Decimal('126.96935740000000')),
#  (1082,
#   2,
#   '을지로중앙점',
#   '중구',
#   '서울 중구 마른내로 49 (인현동1가)',
#   Decimal('37.56544250000000'),
#   Decimal('126.99399810000000')),
#  (1081,
#   2,
#   '을지로3가점',
#   '중구',
#   '서울 중구 수표로 45 (저동2가)',
#   Decimal('37.56353930000000'),
#   Decimal('126.99060860000000')),
#  (1080,
#   2,
#   '오장동점',
#   '중구',
#   '서울 중구 마른내로 109-1 (오장동)',
#   Decimal('37.56461010000000'),
#   Decimal('127.00013670000000')),
#  (1079,
#   2,
#   '약수역점',
#   '중구',
#   '서울 중구 동호로 186-13 (신당동)',
#   Decimal('37.55455830000000'),
#   Decimal('127.01163920000000')),
#  (1078,
#   2,
#   '신당중앙점',
#   '중구',
#   '서울 중구 퇴계로 455 (황학동)',
#   Decimal('37.56748190000000'),
#   Decimal('127.01990630000000')),
#  (1077,
#   2,
#   '신당점',
#   '중구',
#   '서울 중구 다산로35길 11 (신당동)',
#   Decimal('37.56355230000000'),
#   Decimal('127.01481740000000')),
#  (1076,
#   2,
#   '서울시청점',
#   '중구',
#   '서울 중구 세종대로20길 23 (무교동, 원창빌딩)',
#   Decimal('37.56715330000000'),
#   Decimal('126.97875660000000')),
#  (1075,
#   2,
#   '서소문점',
#   '중구',
#   '서울 중구 서소문로11길 8 (서소문동)',
#   Decimal('37.56332020000000'),
#   Decimal('126.97303750000000')),
#  (1074,
#   2,
#   '명동중앙점',
#   '중구',
#   '서울 중구 명동7길 21 (을지로2가, 명동아르누보센텀)',
#   Decimal('37.56469180000000'),
#   Decimal('126.98384290000000')),
#  (1073,
#   2,
#   '명동역점',
#   '중구',
#   '서울 중구 퇴계로 103 (충무로1가)',
#   Decimal('37.56116990000000'),
#   Decimal('126.98251620000000')),
#  (1072,
#   2,
#   '명동거리점',
#   '중구',
#   '서울 중구 명동8가길 7 (충무로2가, 프리엠상가)',
#   Decimal('37.56175730000000'),
#   Decimal('126.98540280000000')),
#  (1071,
#   2,
#   '만리동고개점',
#   '중구',
#   '서울 중구 만리재로 175 (만리동2가, 서울역센트럴자이),402동 102호',
#   Decimal('37.55453800000000'),
#   Decimal('126.96368140000000')),
#  (1070,
#   2,
#   '동평화점',
#   '중구',
#   '서울 중구 청계천로 318 (신당동)',
#   Decimal('37.56946110000000'),
#   Decimal('127.01394660000000')),
#  (1069,
#   2,
#   '동대문팀204점',
#   '중구',
#   '서울 중구 마장로 30 (신당동, Team204)',
#   Decimal('37.56767420000000'),
#   Decimal('127.01316050000000')),
#  (1068,
#   2,
#   '동대문점',
#   '중구',
#   '서울 중구 을지로43길 38 (을지로6가)',
#   Decimal('37.56770480000000'),
#   Decimal('127.00776410000000')),
#  (1067,
#   2,
#   '동국대후문점',
#   '중구',
#   '서울 중구 창경궁로 2 (충무로5가, 남경빌딩)',
#   Decimal('37.56255340000000'),
#   Decimal('126.99870280000000')),
#  (1066,
#   2,
#   '다동점',
#   '중구',
#   '서울 중구 다동길 46 (다동)',
#   Decimal('37.56792240000000'),
#   Decimal('126.98205510000000')),
#  (1065,
#   2,
#   '광희동점',
#   '중구',
#   '서울 중구 마른내로 165-1 (광희동1가)',
#   Decimal('37.56482570000000'),
#   Decimal('127.00615070000000')),
#  (1064,
#   2,
#   'IBK본점',
#   '중구',
#   '서울 중구 을지로 79 (을지로2가, 기업은행)',
#   Decimal('37.56645410000000'),
#   Decimal('126.98655260000000')),
#  (1063,
#   2,
#   '혜화역점',
#   '종로구',
#   '서울 종로구 창경궁로 258-15 (명륜2가)',
#   Decimal('37.58469970000000'),
#   Decimal('126.99904120000000')),
#  (1062,
#   2,
#   '혜화동로터리점',
#   '종로구',
#   '서울 종로구 혜화로 3-1 (혜화동)',
#   Decimal('37.58605780000000'),
#   Decimal('127.00054630000000')),
#  (1061,
#   2,
#   '탑골공원점',
#   '종로구',
#   '서울 종로구 낙원동 ',
#   Decimal('37.57257240000000'),
#   Decimal('126.98862310000000')),
#  (1060,
#   2,
#   '창신중앙점 ',
#   '종로구',
#   '서울 종로구 지봉로 64 (숭인동)',
#   Decimal('37.57573040000000'),
#   Decimal('127.01584220000000')),
#  (1059,
#   2,
#   '창덕궁점',
#   '종로구',
#   '서울 종로구 돈화문로 41-1 (묘동)',
#   Decimal('37.57227400000000'),
#   Decimal('126.99143490000000')),
#  (1058,
#   2,
#   '종로타워점',
#   '종로구',
#   '서울 종로구 종로 51 (종로2가, 종로타워)',
#   Decimal('37.57079000000000'),
#   Decimal('126.98356000000000')),
#  (1057,
#   2,
#   '종로삼일대로점',
#   '종로구',
#   '서울 종로구 삼일대로 390-1 (관철동)',
#   Decimal('37.56912450000000'),
#   Decimal('126.98600440000000')),
#  (1056,
#   2,
#   '종로구청점',
#   '종로구',
#   '서울 종로구 수송동',
#   Decimal('37.57369730000000'),
#   Decimal('126.98064530000000')),
#  (1055,
#   2,
#   '종로교차로점',
#   '종로구',
#   '서울 종로구 동호로 406-1 (종로5가)',
#   Decimal('37.57060000000000'),
#   Decimal('127.00225700000000')),
#  (1054,
#   2,
#   '종로5가점',
#   '종로구',
#   '서울 종로구 대학로 33 (효제동)',
#   Decimal('37.57304960000000'),
#   Decimal('127.00308820000000')),
#  (1053,
#   2,
#   '종로4가점',
#   '종로구',
#   '서울 종로구 김상옥로 1 (인의동)',
#   Decimal('37.57350770000000'),
#   Decimal('126.99790320000000')),
#  (1052,
#   2,
#   '종로3가점',
#   '종로구',
#   '서울 종로구 종로 126 (종로3가)',
#   Decimal('37.57006300000000'),
#   Decimal('126.99173260000000')),
#  (1051,
#   2,
#   '신설점',
#   '종로구',
#   '서울 종로구 난계로29길 30 (숭인동)',
#   Decimal('37.57423890000000'),
#   Decimal('127.02147330000000')),
#  (1050,
#   2,
#   '숭인점',
#   '종로구',
#   '서울 종로구 숭인동길 6 (숭인동)',
#   Decimal('37.57526170000000'),
#   Decimal('127.02159680000000')),
#  (1049,
#   2,
#   '성균관대점',
#   '종로구',
#   '서울 종로구 성균관로 8 (명륜2가)',
#   Decimal('37.58445200000000'),
#   Decimal('126.99948500000000')),
#  (1048,
#   2,
#   '상명대점',
#   '종로구',
#   '서울 종로구 홍지동',
#   Decimal('37.60079920000000'),
#   Decimal('126.95656880000000')),
#  (1047,
#   2,
#   '삼일빌딩점',
#   '종로구',
#   '서울 종로구 삼일대로15길 13 (관철동)',
#   Decimal('37.56938680000000'),
#   Decimal('126.98797200000000')),
#  (1046,
#   2,
#   '북촌마을점',
#   '종로구',
#   '서울 종로구 북촌로5길 39 (화동)',
#   Decimal('37.58222120000000'),
#   Decimal('126.98184900000000')),
#  (1045,
#   2,
#   '배화여대점',
#   '종로구',
#   '서울 종로구 필운대로1길 35 (필운동)',
#   Decimal('37.57782410000000'),
#   Decimal('126.96737170000000')),
#  (1044,
#   2,
#   '방통대점',
#   '종로구',
#   '서울 종로구 대학로 81-1 (연건동)',
#   Decimal('37.57834620000000'),
#   Decimal('127.00173750000000')),
#  (1043,
#   2,
#   '동묘역점',
#   '종로구',
#   '서울 종로구 종로 354 (숭인동)',
#   Decimal('37.57766310000000'),
#   Decimal('127.02240150000000')),
#  (1042,
#   2,
#   '동대문역점',
#   '종로구',
#   '서울 종로구 율곡로 286 (종로6가, 야드인빌딩)',
#   Decimal('37.57183250000000'),
#   Decimal('127.00814910000000')),
#  (1041,
#   2,
#   '독립문역점',
#   '종로구',
#   '서울 종로구 통일로 266 (무악동)',
#   Decimal('37.57719710000000'),
#   Decimal('126.95863970000000')),
#  (1040,
#   2,
#   '대학로점',
#   '종로구',
#   '서울 종로구 대학로10길 17 (동숭동)',
#   Decimal('37.58322000000000'),
#   Decimal('127.00439350000000')),
#  (1039,
#   2,
#   '낙원동점',
#   '종로구',
#   '서울 종로구 낙원동 ',
#   Decimal('37.57257240000000'),
#   Decimal('126.98862310000000')),
#  (1038,
#   2,
#   '광화문점',
#   '종로구',
#   '서울 종로구 세종대로23길 15 (도렴동)',
#   Decimal('37.57150270000000'),
#   Decimal('126.97566100000000')),
#  (1037,
#   2,
#   '경희궁점',
#   '종로구',
#   '서울 종로구 경희궁1길 16 (신문로2가)',
#   Decimal('37.57166700000000'),
#   Decimal('126.97070190000000')),
#  (1036,
#   2,
#   '경복궁역점',
#   '종로구',
#   '서울 종로구 자하문로 7 (체부동, 성명빌딩)',
#   Decimal('37.55914580000000'),
#   Decimal('126.92089200000000')),
#  (1035,
#   2,
#   '증산동점',
#   '은평구',
#   '서울 은평구 증산서길 78 (증산동)',
#   Decimal('37.58332990000000'),
#   Decimal('126.90652440000000')),
#  (1034,
#   2,
#   '응암중앙점',
#   '은평구',
#   '서울 은평구 응암로 183 (응암동)',
#   Decimal('37.58842700000000'),
#   Decimal('126.91664310000000')),
#  (1033,
#   2,
#   '응암오거리점',
#   '은평구',
#   '서울 은평구 응암로 211 (응암동)',
#   Decimal('37.59089570000000'),
#   Decimal('126.91712520000000')),
#  (1032,
#   2,
#   '응암역점',
#   '은평구',
#   '서울 은평구 연서로 9 (역촌동, 센타폴리스)',
#   Decimal('37.60647810000000'),
#   Decimal('126.91588070000000')),
#  (1031,
#   2,
#   '은평이마트점',
#   '은평구',
#   '서울 은평구 은평로 111 (응암동, 은평이마트)',
#   Decimal('37.60039460000000'),
#   Decimal('126.92021490000000')),
#  (1030,
#   2,
#   '은평구청점',
#   '은평구',
#   '서울 은평구 은평로 197 (녹번동)',
#   Decimal('37.60160970000000'),
#   Decimal('126.92964610000000')),
#  (1029,
#   2,
#   '연신내통일로점',
#   '은평구',
#   '서울 은평구 통일로 876 (불광동)',
#   Decimal('37.62119630000000'),
#   Decimal('126.92027730000000')),
#  (1028,
#   2,
#   '연신내역점',
#   '은평구',
#   '서울 은평구 통일로 855-9 (갈현동)',
#   Decimal('37.62154100000000'),
#   Decimal('126.91357800000000')),
#  (1027,
#   2,
#   '역촌진흥로점',
#   '은평구',
#   '서울 은평구 진흥로1길 3 (역촌동)',
#   Decimal('37.60801080000000'),
#   Decimal('126.91935460000000')),
#  (1026,
#   2,
#   '역촌역점',
#   '은평구',
#   '서울 은평구 진흥로 95 (역촌동)',
#   Decimal('37.60545130000000'),
#   Decimal('126.92212740000000')),
#  (1025,
#   2,
#   '역촌사거리점',
#   '은평구',
#   '서울 은평구 서오릉로 100 (대조동)',
#   Decimal('37.60893520000000'),
#   Decimal('126.92103760000000')),
#  (1024,
#   2,
#   '역촌동점',
#   '은평구',
#   '서울 은평구 갈현로 82 (역촌동)',
#   Decimal('37.60168150000000'),
#   Decimal('126.91437300000000')),
#  (1023,
#   2,
#   '수색역점',
#   '은평구',
#   '서울 은평구 수색로 250 (수색동)',
#   Decimal('37.58191540000001'),
#   Decimal('126.89633940000000')),
#  (1022,
#   2,
#   '서광교회점',
#   '은평구',
#   '서울 은평구 통일로 951 (갈현동, 서광교회)',
#   Decimal('37.62772860000000'),
#   Decimal('126.91918480000000')),
#  (1021,
#   2,
#   '새절역점',
#   '은평구',
#   '서울 은평구 가좌로 272 (신사동)',
#   Decimal('37.59561300000000'),
#   Decimal('126.90720330000000')),
#  (1020,
#   2,
#   '불광중앙점',
#   '은평구',
#   '서울 은평구 불광로 59 (불광동)',
#   Decimal('37.61235030000000'),
#   Decimal('126.93171180000000')),
#  (1019,
#   2,
#   '본서부병원점',
#   '은평구',
#   '서울 은평구 응암로 337 (응암동, 빛터룩스 빌딩)',
#   Decimal('37.60126920000000'),
#   Decimal('126.92215170000000')),
#  (1018,
#   2,
#   '백련산아이파크점',
#   '은평구',
#   '서울 은평구 응암로 264 (응암동, 서울빌딩)',
#   Decimal('37.58449690000000'),
#   Decimal('126.91426480000000')),
#  (1017,
#   2,
#   '녹번중앙점',
#   '은평구',
#   '서울 은평구 통일로 635 (녹번동, 녹번동메카오피스텔)',
#   Decimal('37.60328190000000'),
#   Decimal('126.93465150000000')),
#  (1016,
#   2,
#   '녹번동점',
#   '은평구',
#   '서울 은평구 진흥로 156 (녹번동, 신명빌딩)',
#   Decimal('37.60249050000000'),
#   Decimal('126.92480740000000')),
#  (1015,
#   2,
#   '구파발역점',
#   '은평구',
#   '서울 은평구 진관2로 29-21 (진관동, 드림스퀘어)',
#   Decimal('37.63569240000000'),
#   Decimal('126.91932690000000')),
#  (1014,
#   2,
#   '구산역점',
#   '은평구',
#   '서울 은평구 연서로 148 (대조동)',
#   Decimal('37.61198820000000'),
#   Decimal('126.91763340000000')),
#  (1013,
#   2,
#   '갈현점',
#   '은평구',
#   '서울 은평구 갈현로 268 (갈현동)',
#   Decimal('37.62069760000000'),
#   Decimal('126.91669210000000')),
#  (1012,
#   2,
#   '힐스테이트클래시안점',
#   '영등포구',
#   '서울 영등포구 신길로28길 9 (신길동, 힐스테이트 클래시안)',
#   Decimal('37.50368120000000'),
#   Decimal('126.91259140000000')),
#  (1011,
#   2,
#   '한국수출입은행점',
#   '영등포구',
#   '서울 영등포구 은행로 38 (여의도동, 한국수출입은행빌딩)',
#   Decimal('37.52860520000000'),
#   Decimal('126.92339630000000')),
#  (1010,
#   2,
#   '한강성심병원점',
#   '영등포구',
#   '서울 영등포구 버드나루로 51 (영등포동2가)',
#   Decimal('37.52060950000000'),
#   Decimal('126.91219460000000')),
#  (1009,
#   2,
#   '영등포홈플러스점',
#   '영등포구',
#   '서울 영등포구 당산로 42 (문래동3가, 홈플러스)',
#   Decimal('37.51898350000000'),
#   Decimal('126.89870590000000')),
#  (1008,
#   2,
#   '영등포코레일점',
#   '영등포구',
#   '서울 영등포구 경인로 846 (영등포동, 영등포 민자역사)',
#   Decimal('37.51592280000000'),
#   Decimal('126.90737270000000')),
#  (1007,
#   2,
#   '영등포중앙점',
#   '영등포구',
#   '서울 영등포구 영중로 37 (영등포동4가)',
#   Decimal('37.51947639999999'),
#   Decimal('126.90470540000000')),
#  (1006,
#   2,
#   '영등포점',
#   '영등포구',
#   '서울 영등포구 영중로 16-1 (영등포동3가)',
#   Decimal('37.51887260000000'),
#   Decimal('126.90716350000000')),
#  (1005,
#   2,
#   '영등포에이스점',
#   '영등포구',
#   '서울 영등포구 경인로 775 (문래동3가)',
#   Decimal('37.51726980000000'),
#   Decimal('126.89571520000000')),
#  (1004,
#   2,
#   '영등포아크로타워점',
#   '영등포구',
#   '서울 영등포구 국회대로54길 10 (영등포동7가, 아크로타워 스퀘어)',
#   Decimal('37.52310500000000'),
#   Decimal('126.90725220000000')),
#  (1003,
#   2,
#   '영등포시장점',
#   '영등포구',
#   '서울 영등포구 영등포로35길 19 (영등포동6가)',
#   Decimal('37.52268740000000'),
#   Decimal('126.90455360000000')),
#  (1002,
#   2,
#   '영등포본동점',
#   '영등포구',
#   '서울 영등포구 영신로19길 15 (영등포동)',
#   Decimal('37.51384750000000'),
#   Decimal('126.90599860000000')),
#  (1001,
#   2,
#   '영등포그랜드점',
#   '영등포구',
#   '서울 영등포구 양산로9길 15 (양평동3가, 그랜드타워)',
#   Decimal('37.52564790000000'),
#   Decimal('126.88888240000000')),
#  (1000,
#   2,
#   '영등포구청점',
#   '영등포구',
#   '서울 영등포구 당산로 110 (당산동3가)',
#   Decimal('37.52691890000000'),
#   Decimal('126.89838190000000')),
#  (999,
#   2,
#   '영등포knk점',
#   '영등포구',
#   '서울 영등포구 영신로 220 (영등포동8가, KnK디지털타워)',
#   Decimal('37.52655400000000'),
#   Decimal('126.90429900000000')),
#  (998,
#   2,
#   '여의도역점',
#   '영등포구',
#   '서울 영등포구 의사당대로 108 (여의도동, 아일렉스)',
#   Decimal('37.52102360000000'),
#   Decimal('126.92401160000000')),
#  (997,
#   2,
#   '여의도농협재단점',
#   '영등포구',
#   '서울 영등포구 국제금융로8길 2 (여의도동, 농협재단빌딩)',
#   Decimal('37.52198380000000'),
#   Decimal('126.93003100000000')),
#  (996,
#   2,
#   '여의나루역점',
#   '영등포구',
#   '서울 영등포구 여의나루로 113 (여의도동)',
#   Decimal('37.52602880000000'),
#   Decimal('126.93075110000000')),
#  (995,
#   2,
#   '양평동2가점',
#   '영등포구',
#   '서울 영등포구 선유서로25길 19 (양평동2가, 오목교투웨니퍼스트)',
#   Decimal('37.52432510000000'),
#   Decimal('126.88373130000000')),
#  (994,
#   2,
#   '신풍역점',
#   '영등포구',
#   '서울 영등포구 신풍로 52-1 (신길동)',
#   Decimal('37.49994590000000'),
#   Decimal('126.91179310000000')),
#  (993,
#   2,
#   '신길중앙점',
#   '영등포구',
#   '서울 영등포구 도신로 229 (신길동)',
#   Decimal('37.51219970000000'),
#   Decimal('126.91650530000000')),
#  (992,
#   2,
#   '신길역점',
#   '영등포구',
#   '서울 영등포구 영등포로 353 (신길동)',
#   Decimal('37.51507080000000'),
#   Decimal('126.91809500000000')),
#  (991,
#   2,
#   '신길아이파크점',
#   '영등포구',
#   '서울 영등포구 도림로 280 (신길동)',
#   Decimal('37.50294080000000'),
#   Decimal('126.90421560000000')),
#  (990,
#   2,
#   '신길썬프라자점',
#   '영등포구',
#   '서울 영등포구 신길로 42 (신길동)',
#   Decimal('37.49647690000000'),
#   Decimal('126.90862710000000')),
#  (989,
#   2,
#   '신길성애병원점',
#   '영등포구',
#   '서울 영등포구 여의대방로53길 27 (신길동)',
#   Decimal('37.51778300000000'),
#   Decimal('126.91728360000000')),
#  (988,
#   2,
#   '선유도역점',
#   '영등포구',
#   '서울 영등포구 양평로 126 (양평동5가)',
#   Decimal('37.54117230000000'),
#   Decimal('126.89443370000000')),
#  (987,
#   2,
#   '서여의도점',
#   '영등포구',
#   '서울 영등포구 국회대로72길 17 (여의도동, KCC파크타운)',
#   Decimal('37.52954760000000'),
#   Decimal('126.92122570000000')),
#  (986,
#   2,
#   '보라매역점',
#   '영등포구',
#   '서울 영등포구 여의대방로 141 (신길동)',
#   Decimal('37.50744760000000'),
#   Decimal('126.91679880000000')),
#  (985,
#   2,
#   '라이프점',
#   '영등포구',
#   '서울 영등포구 63로 40 (여의도동, 라이프오피스텔)',
#   Decimal('37.51956203765937'),
#   Decimal('126.93913907874030')),
#  (984,
#   2,
#   '도림점',
#   '영등포구',
#   '서울 영등포구 도신로15길 40 (도림동, 도림빌딩)',
#   Decimal('37.51059260000000'),
#   Decimal('126.90877370000000')),
#  (983,
#   2,
#   '도림사거리점',
#   '영등포구',
#   '서울 영등포구 도림로 326 (신길동)',
#   Decimal('37.50658150000000'),
#   Decimal('126.90180010000000')),
#  (982,
#   2,
#   '대림역점',
#   '영등포구',
#   '서울 영등포구 도림로31길 2 (대림동)',
#   Decimal('37.49254740000000'),
#   Decimal('126.89592550000000')),
#  (981,
#   2,
#   '대림3동점',
#   '영등포구',
#   '서울 영등포구 대림로 212 (대림동)',
#   Decimal('37.49958420000000'),
#   Decimal('126.89818720000000')),
#  (980,
#   2,
#   '대림1동점',
#   '영등포구',
#   '서울 영등포구 도림로 198 (대림동)',
#   Decimal('37.49643720000000'),
#   Decimal('126.90284230000000')),
#  (979,
#   2,
#   '당산중앙점',
#   '영등포구',
#   '서울 영등포구 당산로 159 (당산동4가)',
#   Decimal('37.52905960000000'),
#   Decimal('126.89908220000000')),
#  (978,
#   2,
#   '당산역점',
#   '영등포구',
#   '서울 영등포구 당산로 222 (당산동5가, 당산디오빌)',
#   Decimal('37.53329740000000'),
#   Decimal('126.90223970000000')),
#  (977,
#   2,
#   '당산버드나루점',
#   '영등포구',
#   '서울 영등포구 버드나루로 87 (영등포동7가)',
#   Decimal('37.52479540000000'),
#   Decimal('126.90731630000000')),
#  (976,
#   2,
#   '남부고용센터점',
#   '영등포구',
#   '서울 영등포구 양산로 71 (양평동3가)',
#   Decimal('37.52988780000000'),
#   Decimal('126.89251860000000')),
#  (975,
#   2,
#   '국회의사당역점',
#   '영등포구',
#   '서울 영등포구 의사당대로 22 (여의도동, 이룸센터)',
#   Decimal('37.52682930000000'),
#   Decimal('126.91783000000000')),
#  (974,
#   2,
#   '국회대로점',
#   '영등포구',
#   '서울 영등포구 국회대로72길 4 (여의도동, 아이비피아빌딩)',
#   Decimal('37.53030550000000'),
#   Decimal('126.91996340000000')),
#  (973,
#   2,
#   'KBS별관점',
#   '영등포구',
#   '서울 영등포구 국제금융로8길 27-9 (여의도동, 동북빌딩)',
#   Decimal('37.51961690000000'),
#   Decimal('126.92895370000000')),
#  (972,
#   2,
#   '오목교대학학원점',
#   '양천구',
#   '서울 양천구 오목로 319 (목동)',
#   Decimal('37.52508050000000'),
#   Decimal('126.87307520000000')),
#  (971,
#   2,
#   '양천구청점',
#   '양천구',
#   '서울 양천구 목동동로 63 (신정동)',
#   Decimal('37.51530850000000'),
#   Decimal('126.86231800000000')),
#  (970,
#   2,
#   '신정역점',
#   '양천구',
#   '서울 양천구 오목로 155 (신정동)',
#   Decimal('37.52498280000000'),
#   Decimal('126.85465240000000')),
#  (969,
#   2,
#   '신정서부점',
#   '양천구',
#   '서울 양천구 신정로11길 50-15 (신정동)',
#   Decimal('37.51221980000000'),
#   Decimal('126.83834770000000')),
#  (968,
#   2,
#   '신정네거리역점',
#   '양천구',
#   '서울 양천구 중앙로 282 (신정동)',
#   Decimal('37.52158150000000'),
#   Decimal('126.85264660000000')),
#  (967,
#   2,
#   '신정교점',
#   '양천구',
#   '서울 양천구 신목로 36 (신정동)',
#   Decimal('37.51886900000000'),
#   Decimal('126.87382360000000')),
#  (966,
#   2,
#   '신월사거리점',
#   '양천구',
#   '서울 양천구 남부순환로 353 (신월동)',
#   Decimal('37.53568110000000'),
#   Decimal('126.82895290000000')),
#  (965,
#   2,
#   '신월7동점',
#   '양천구',
#   '서울 양천구 지양로 79 (신월동)',
#   Decimal('37.52242370000000'),
#   Decimal('126.83296300000000')),
#  (964,
#   2,
#   '신월5동점',
#   '양천구',
#   '서울 양천구 화곡로 50 (신월동)',
#   Decimal('37.53917180000000'),
#   Decimal('126.82743180000000')),
#  (963,
#   2,
#   '목동파리공원점',
#   '양천구',
#   '서울 양천구 목동동로 379 (목동)',
#   Decimal('37.53560480000000'),
#   Decimal('126.87875980000000')),
#  (962,
#   2,
#   '목동파라곤점',
#   '양천구',
#   '서울 양천구 목동서로 155 (목동)',
#   Decimal('37.52950380000000'),
#   Decimal('126.87516350000000')),
#  (961,
#   2,
#   '목동역점',
#   '양천구',
#   '서울 양천구 오목로 227 (신정동)',
#   Decimal('37.52607580000000'),
#   Decimal('126.86273430000000')),
#  (960,
#   2,
#   '목동아델리체점',
#   '양천구',
#   '서울 양천구 중앙로43길 14 (신정동, 래미안 목동아델리체)',
#   Decimal('37.51812730000000'),
#   Decimal('126.85198070000000')),
#  (959,
#   2,
#   '목동신트리점',
#   '양천구',
#   '서울 양천구 신정로 312 (신정동, 뉴프라자)',
#   Decimal('37.51323720000000'),
#   Decimal('126.85553970000000')),
#  (958,
#   2,
#   '목동신목점',
#   '양천구',
#   '서울 양천구 목동중앙로 85 (목동, 강산아파트)',
#   Decimal('37.53702030000000'),
#   Decimal('126.87145880000000')),
#  (957,
#   2,
#   '목동센트럴아이파크위브점',
#   '양천구',
#   '서울 양천구 남부순환로 603 (신월동)',
#   Decimal('37.51521060000000'),
#   Decimal('126.84067040000000')),
#  (956,
#   2,
#   '목4동점',
#   '양천구',
#   '서울 양천구 목동중앙본로7길 46 (목동)',
#   Decimal('37.53949770000000'),
#   Decimal('126.86613100000000')),
#  (955,
#   2,
#   '목3동점',
#   '양천구',
#   '서울 양천구 목동중앙북로 38 (목동, 롯데캐슬위너아파트)',
#   Decimal('37.54688690000000'),
#   Decimal('126.86726110000000')),
#  (954,
#   2,
#   '남부지방법원점',
#   '양천구',
#   '서울 양천구 은행정로4길 25 (신정동, SM엘루이아파트)',
#   Decimal('37.52153830000000'),
#   Decimal('126.86253760000000')),
#  (953,
#   2,
#   '강서초교점',
#   '양천구',
#   '서울 양천구 오목로 48 (신월동)',
#   Decimal('37.52200520000000'),
#   Decimal('126.84294590000000')),
#  (952,
#   2,
#   '종합운동장역점',
#   '송파구',
#   '서울 송파구 올림픽로 76 (잠실동, J타워)',
#   Decimal('37.51156630000000'),
#   Decimal('127.07902140000000')),
#  (951,
#   2,
#   '잠실역점',
#   '송파구',
#   '서울 송파구 송파대로 567 (잠실동, 잠실주공아파트)',
#   Decimal('37.51432402116925'),
#   Decimal('127.09334786098638')),
#  (950,
#   2,
#   '잠실본동점',
#   '송파구',
#   '서울 송파구 백제고분로 172 (잠실동, 제이케이빌딩)',
#   Decimal('37.51194230000000'),
#   Decimal('127.08702540000000')),
#  (949,
#   2,
#   '위례포레샤인점',
#   '송파구',
#   '서울 송파구 위례순환로 477 (장지동, 위례포레샤인23단지)',
#   Decimal('37.47628080000000'),
#   Decimal('127.13565490000000')),
#  (948,
#   2,
#   '위례아이파크점',
#   '송파구',
#   '서울 송파구 위례광장로 136 (장지동, 위례아이파크)',
#   Decimal('37.47629600000000'),
#   Decimal('127.14213140000000')),
#  (947,
#   2,
#   '올림픽프라자점',
#   '송파구',
#   '서울 송파구 양재대로 1222 (방이동)',
#   Decimal('37.51582570000000'),
#   Decimal('127.13221820000000')),
#  (946,
#   2,
#   '올림픽공원점',
#   '송파구',
#   '서울 송파구 올림픽로 354 (방이동)',
#   Decimal('37.51567460000000'),
#   Decimal('127.12539150000000')),
#  (945,
#   2,
#   '오금중앙점 ',
#   '송파구',
#   '서울 송파구 위례성대로22길 18 (오금동, 이시돌빌딩)',
#   Decimal('37.50871130000000'),
#   Decimal('127.13040080000000')),
#  (944,
#   2,
#   '오금점',
#   '송파구',
#   '서울 송파구 오금로 306 (가락동, 가락스타클래스)',
#   Decimal('37.50287860000000'),
#   Decimal('127.12612360000000')),
#  (943,
#   2,
#   '송파한양점',
#   '송파구',
#   '서울 송파구 가락로 165 (송파동, 위례캐슬빌)',
#   Decimal('37.50320460000000'),
#   Decimal('127.11784920000000')),
#  (942,
#   2,
#   '송파하비오점',
#   '송파구',
#   '서울 송파구 송파대로 111 (문정동, 파크하비오)',
#   Decimal('37.48165560000000'),
#   Decimal('127.12345150000000')),
#  (941,
#   2,
#   '송파풍납점',
#   '송파구',
#   '서울 송파구 강동대로9길 17-1 (풍납동)',
#   Decimal('37.52810059999999'),
#   Decimal('127.11654430000000')),
#  (940,
#   2,
#   '송파파인타운점',
#   '송파구',
#   '서울 송파구 충민로2길 28 (장지동, 대진플라자2)',
#   Decimal('37.47729840000000'),
#   Decimal('127.12756860000000')),
#  (939,
#   2,
#   '송파위례점',
#   '송파구',
#   '서울 송파구 위례광장로 188 (장지동, 아이온스퀘어)',
#   Decimal('37.48116050000000'),
#   Decimal('127.14232920000000')),
#  (938,
#   2,
#   '송파올림픽훼미리타운점',
#   '송파구',
#   '서울 송파구 중대로 24 (문정동, 올림픽훼밀리타운 아카데미 상가)',
#   Decimal('37.48851950000000'),
#   Decimal('127.11437750000000')),
#  (937,
#   2,
#   '송파문정점',
#   '송파구',
#   '서울 송파구 송이로 159 (가락동)',
#   Decimal('37.49295690000000'),
#   Decimal('127.12535260000000')),
#  (936,
#   2,
#   '석촌역점',
#   '송파구',
#   '서울 송파구 송파대로 456 (송파동, 웅현빌딩)',
#   Decimal('37.50720400000000'),
#   Decimal('127.10584080000000')),
#  (935,
#   2,
#   '석촌사거리점',
#   '송파구',
#   '서울 송파구 송파대로 409 (석촌동, 범양빌딩)',
#   Decimal('37.50762770000000'),
#   Decimal('127.10815300000000')),
#  (934,
#   2,
#   '석촌백제점',
#   '송파구',
#   '서울 송파구 백제고분로39길 15 (석촌동, 삼경빌딩)',
#   Decimal('37.50287330000000'),
#   Decimal('127.09898680000000')),
#  (933,
#   2,
#   '서울삼성내과점',
#   '송파구',
#   '서울 송파구 백제고분로 126 (잠실동, 오룡빌딩)',
#   Decimal('37.50615510000000'),
#   Decimal('127.08076680000000')),
#  (932,
#   2,
#   '삼전중앙점',
#   '송파구',
#   '서울 송파구 백제고분로27길 5 (삼전동)',
#   Decimal('37.50584140000000'),
#   Decimal('127.08979770000000')),
#  (931,
#   2,
#   '삼전역점',
#   '송파구',
#   '서울 송파구 백제고분로 263 (삼전동)',
#   Decimal('37.50279120000000'),
#   Decimal('127.09580080000000')),
#  (930,
#   2,
#   '방이초교점',
#   '송파구',
#   '서울 송파구 가락로 280 (방이동)',
#   Decimal('37.51275620000000'),
#   Decimal('127.12004780000000')),
#  (929,
#   2,
#   '방이역점',
#   '송파구',
#   '서울 송파구 위례성대로18길 32 (방이동)',
#   Decimal('37.50957590000000'),
#   Decimal('127.12471890000000')),
#  (928,
#   2,
#   '방이시장점',
#   '송파구',
#   '서울 송파구 백제고분로48길 3 (방이동)',
#   Decimal('37.51186130000000'),
#   Decimal('127.11375760000000')),
#  (927,
#   2,
#   '문정테라타워점',
#   '송파구',
#   '서울 송파구 송파대로 167 (문정동, 문정역테라타워)',
#   Decimal('37.49186910000000'),
#   Decimal('127.11915170000000')),
#  (926,
#   2,
#   '문정중앙점',
#   '송파구',
#   '서울 송파구 문정로 31-1 (문정동)',
#   Decimal('37.48646620000000'),
#   Decimal('127.12633400000000')),
#  (925,
#   2,
#   '문정문현점',
#   '송파구',
#   '서울 송파구 새말로8길 30 (문정동)',
#   Decimal('37.48014720000000'),
#   Decimal('127.12665190000000')),
#  (924,
#   2,
#   '문정KDU타워점',
#   '송파구',
#   '서울 송파구 정의로 70 (문정동, 케이디유타워)',
#   Decimal('37.48234360000000'),
#   Decimal('127.11720560000000')),
#  (923,
#   2,
#   '거여점',
#   '송파구',
#   '서울 송파구 오금로 497 (거여동)',
#   Decimal('37.48220960000000'),
#   Decimal('127.14302510000000')),
#  (922,
#   2,
#   '개롱역점',
#   '송파구',
#   '서울 송파구 오금로 407 (오금동, 상아아파트)',
#   Decimal('37.49772800000000'),
#   Decimal('127.13583500000000')),
#  (921,
#   2,
#   '가락중앙점',
#   '송파구',
#   '서울 송파구 송이로 87 (가락동)',
#   Decimal('37.49534590000000'),
#   Decimal('127.12384820000000')),
#  (920,
#   2,
#   '가락몰점',
#   '송파구',
#   '서울 송파구 양재대로 932 (가락동, 가락몰 판매동)',
#   Decimal('37.49311600000000'),
#   Decimal('127.11645390000000')),
#  (919,
#   2,
#   '가든파이브테크노관점',
#   '송파구',
#   '서울 송파구 충민로 66 (문정동, 가든파이브라이프)',
#   Decimal('37.47748419041258'),
#   Decimal('127.12496889994861')),
#  (918,
#   2,
#   '가든파이브점',
#   '송파구',
#   '서울 송파구 충민로 10 (문정동, 가든파이브툴)',
#   Decimal('37.47841760000000'),
#   Decimal('127.11888770000000')),
#  (917,
#   2,
#   '한성대점',
#   '성북구',
#   '서울 성북구 삼선교로 10 (삼선동1가)',
#   Decimal('37.58773390000000'),
#   Decimal('127.00690930000000')),
#  (916,
#   2,
#   '한성대역점',
#   '성북구',
#   '서울 성북구 동소문로 19 (동소문동1가)',
#   Decimal('37.58899690000000'),
#   Decimal('127.00638970000000')),
#  (915,
#   2,
#   '하월곡동점',
#   '성북구',
#   '서울 성북구 오패산로 16 (하월곡동)',
#   Decimal('37.60363180000000'),
#   Decimal('127.03759470000000')),
#  (914,
#   2,
#   '종암동점',
#   '성북구',
#   '서울 성북구 종암로 105 (종암동)',
#   Decimal('37.59959670000000'),
#   Decimal('127.03391670000000')),
#  (913,
#   2,
#   '정릉중앙점',
#   '성북구',
#   '서울 성북구 정릉로 251 (정릉동)',
#   Decimal('37.60471920000000'),
#   Decimal('127.01196500000000')),
#  (912,
#   2,
#   '장위중앙점',
#   '성북구',
#   '서울 성북구 장위로 35 (장위동)',
#   Decimal('37.61446150000000'),
#   Decimal('127.04077820000000')),
#  (911,
#   2,
#   '장위북서울꿈의숲점',
#   '성북구',
#   '서울 성북구 돌곶이로41가길 2 (장위동)',
#   Decimal('37.61864440000000'),
#   Decimal('127.04561080000000')),
#  (910,
#   2,
#   '장위동점',
#   '성북구',
#   '서울 성북구 월계로40길 7 (장위동)',
#   Decimal('37.62293470000000'),
#   Decimal('127.04846060000000')),
#  (909,
#   2,
#   '장위뉴타운점',
#   '성북구',
#   '서울 성북구 장월로 144-1 (장위동)',
#   Decimal('37.61765910000000'),
#   Decimal('127.05102320000000')),
#  (908,
#   2,
#   '장위2동점',
#   '성북구',
#   '서울 성북구 화랑로25길 14 (장위동)',
#   Decimal('37.61474040000000'),
#   Decimal('127.06035510000000')),
#  (907,
#   2,
#   '월곡동아점',
#   '성북구',
#   '서울 성북구 장월로1길 47 (상월곡동)',
#   Decimal('37.60619730000000'),
#   Decimal('127.04578430000000')),
#  (906,
#   2,
#   '월곡1동점',
#   '성북구',
#   '서울 성북구 오패산로 99 (하월곡동)',
#   Decimal('37.61075770000000'),
#   Decimal('127.03513050000000')),
#  (905,
#   2,
#   '안암래미안점',
#   '성북구',
#   '서울 성북구 보문로30가길 42 (안암동1가)',
#   Decimal('37.58899940000000'),
#   Decimal('127.02202050000000')),
#  (904,
#   2,
#   '성신여대점',
#   '성북구',
#   '서울 성북구 보문로34길 100 (동선동2가)',
#   Decimal('37.59120290000000'),
#   Decimal('127.02079090000000')),
#  (903,
#   2,
#   '성신여대역점',
#   '성북구',
#   '서울 성북구 동소문로17길 40 (동소문동6가)',
#   Decimal('37.59394370000000'),
#   Decimal('127.01592840000000')),
#  (902,
#   2,
#   '석관동점',
#   '성북구',
#   '서울 성북구 돌곶이로8길 22 (석관동, 래미안아트리치)',
#   Decimal('37.60610300000000'),
#   Decimal('127.06342290000000')),
#  (901,
#   2,
#   '석계중앙점',
#   '성북구',
#   '서울 성북구 화랑로40길 61 (석관동)',
#   Decimal('37.60737240000000'),
#   Decimal('127.06311940000000')),
#  (900,
#   2,
#   '보문역점',
#   '성북구',
#   '서울 성북구 보문로 111 (보문동2가)',
#   Decimal('37.58488090000001'),
#   Decimal('127.01916830000000')),
#  (899,
#   2,
#   '동소문동점',
#   '성북구',
#   '서울 성북구 동소문로13길 5 (동소문동4가)',
#   Decimal('37.59204520000000'),
#   Decimal('127.01287510000000')),
#  (898,
#   2,
#   '동덕여대점',
#   '성북구',
#   '서울 성북구 화랑로 99 (하월곡동)',
#   Decimal('37.60561100000000'),
#   Decimal('127.03801820000000')),
#  (897,
#   2,
#   '돌곶이역점',
#   '성북구',
#   '서울 성북구 돌곶이로22길 3 (석관동)',
#   Decimal('37.61020710000000'),
#   Decimal('127.05810310000000')),
#  (896,
#   2,
#   '돈암아리랑점',
#   '성북구',
#   '서울 성북구 아리랑로 75 (돈암동, 돈암코오롱하늘채)',
#   Decimal('37.59910680000000'),
#   Decimal('127.01379480000000')),
#  (895,
#   2,
#   '돈암동점',
#   '성북구',
#   '서울 성북구 동소문로 119 (동선동4가)',
#   Decimal('37.59436330000000'),
#   Decimal('127.01853130000000')),
#  (894,
#   2,
#   '길음뉴타운점',
#   '성북구',
#   '서울 성북구 길음로 74 (길음동, 길음 에스에이치빌)',
#   Decimal('37.60968510000000'),
#   Decimal('127.02071040000000')),
#  (893,
#   2,
#   '고대점',
#   '성북구',
#   '서울 성북구 고려대로24길 35 (안암동5가)',
#   Decimal('37.58468380000000'),
#   Decimal('127.02955620000000')),
#  (892,
#   2,
#   '고대개운점',
#   '성북구',
#   '서울 성북구 개운사길 30 (안암동5가)',
#   Decimal('37.58769040000000'),
#   Decimal('127.02943560000000')),
#  (891,
#   2,
#   '함지박사거리점',
#   '서초구',
#   '서울 서초구 방배로 234 우신빌딩',
#   Decimal('37.47807380000000'),
#   Decimal('127.00071980000000')),
#  (890,
#   2,
#   '포이점',
#   '서초구',
#   '서울 서초구 마방로10길 42 (양재동)',
#   Decimal('37.47565220000000'),
#   Decimal('127.04455970000000')),
#  (889,
#   2,
#   '청계산입구역점',
#   '서초구',
#   '서울 서초구 신원동',
#   Decimal('37.44417420000000'),
#   Decimal('127.06214500000000')),
#  (888,
#   2,
#   '잠원논현점',
#   '서초구',
#   '서울 서초구 신반포로 333 (잠원동)',
#   Decimal('37.51091800000000'),
#   Decimal('127.02006920000000')),
#  (887,
#   2,
#   '우면동점',
#   '서초구',
#   '서울 서초구 바우뫼로 20 (우면동, 고호빌딩)',
#   Decimal('37.46996410000000'),
#   Decimal('127.02530100000000')),
#  (886,
#   2,
#   '예술의전당점',
#   '서초구',
#   '서울 서초구 반포대로 32 (서초동, 원일빌딩)',
#   Decimal('37.48337890000000'),
#   Decimal('127.01210740000000')),
#  (885,
#   2,
#   '양재하나로마트점',
#   '서초구',
#   '서울 서초구 청계산로 10 (양재동, 농협하나로클럽)',
#   Decimal('37.46279880000000'),
#   Decimal('127.04386750000000')),
#  (884,
#   2,
#   '양재중앙점',
#   '서초구',
#   '서울 서초구 강남대로 221 (양재동, 양재역 환승주차장)',
#   Decimal('37.47854670000000'),
#   Decimal('127.04132690000000')),
#  (883,
#   2,
#   '양재점',
#   '서초구',
#   '서울 서초구 남부순환로347길 38 (서초동)',
#   Decimal('37.48603920000000'),
#   Decimal('127.03149020000000')),
#  (882,
#   2,
#   '양재언남점',
#   '서초구',
#   '서울 서초구 동산로 60 (양재동, 화성빌딩)',
#   Decimal('37.46854769999999'),
#   Decimal('127.02780080000000')),
#  (881,
#   2,
#   '신사멀버리힐스점',
#   '서초구',
#   '서울 서초구 강남대로 589 (잠원동)',
#   Decimal('37.51438730000000'),
#   Decimal('127.01915000000000')),
#  (880,
#   2,
#   '서초점',
#   '서초구',
#   '서울 서초구 서초대로48길 16 (서초동)',
#   Decimal('37.49205460000000'),
#   Decimal('127.01133480000000')),
#  (879,
#   2,
#   '서초우면중앙점',
#   '서초구',
#   '서울 서초구 양재대로2길 100-11 (우면동, 서초 리슈빌S)',
#   Decimal('37.45620770000000'),
#   Decimal('127.01620330000000')),
#  (878,
#   2,
#   '서초역점',
#   '서초구',
#   '서울 서초구 서초동 ',
#   Decimal('37.48838690000000'),
#   Decimal('127.01679540000000')),
#  (877,
#   2,
#   '서초법조타운점',
#   '서초구',
#   '서울 서초구 서초중앙로24길 7 (서초동, 동천빌딩)',
#   Decimal('37.49478620000000'),
#   Decimal('127.01449960000000')),
#  (876,
#   2,
#   '서울교대점',
#   '서초구',
#   '서울 서초구 서초동 ',
#   Decimal('37.48838690000000'),
#   Decimal('127.01679540000000')),
#  (875,
#   2,
#   '서울고속버스터미널점',
#   '서초구',
#   '서울 서초구 신반포로 194 (반포동, 강남고속버스터미널)',
#   Decimal('37.50612300000000'),
#   Decimal('127.00384600000000')),
#  (874,
#   2,
#   '방배중앙점',
#   '서초구',
#   '서울 서초구 동광로 1 (방배동, 대양빌딩)',
#   Decimal('37.49107210000000'),
#   Decimal('126.98302540000000')),
#  (873,
#   2,
#   '방배역점',
#   '서초구',
#   '서울 서초구 방배로 87 (방배동)',
#   Decimal('37.48217910000000'),
#   Decimal('126.99688650000000')),
#  (872,
#   2,
#   '방배백석점',
#   '서초구',
#   '서울 서초구 방배로 42 (방배동)',
#   Decimal('37.47870610000000'),
#   Decimal('126.99980680000000')),
#  (871,
#   2,
#   '반포지하상가점',
#   '서초구',
#   '서울 서초구 신반포로 지하 200 (잠원동, 강남터미널지하쇼핑몰)',
#   Decimal('37.50549820000000'),
#   Decimal('127.00115120000000')),
#  (870,
#   2,
#   '내방역점',
#   '서초구',
#   '서울 서초구 서초대로 108 (방배동, 삼보빌딩)',
#   Decimal('37.48750853475973'),
#   Decimal('126.99420794887064')),
#  (869,
#   2,
#   '남부터미널점',
#   '서초구',
#   '서울 서초구 서초동 ',
#   Decimal('37.48838690000000'),
#   Decimal('127.01679540000000')),
#  (868,
#   2,
#   '국립중앙도서관본관점',
#   '서초구',
#   '서울 서초구 반포대로 201 (반포동, 국립중앙도서관)',
#   Decimal('37.49768900000000'),
#   Decimal('127.00283330000000')),
#  (867,
#   2,
#   '국립중앙도서관디지털관점',
#   '서초구',
#   '서울 서초구 반포대로 201 (반포동, 국립중앙도서관)',
#   Decimal('37.49768900000000'),
#   Decimal('127.00283330000000')),
#  (866,
#   2,
#   '국립국악원점',
#   '서초구',
#   '서울 서초구 남부순환로 2364 (서초동, 국립국악원)',
#   Decimal('37.47775920000000'),
#   Decimal('127.00830430000000')),
#  (865,
#   2,
#   '교육개발원사거리점',
#   '서초구',
#   '서울 서초구 바우뫼로 180 (양재동, 신송빌딩)',
#   Decimal('37.47826830000000'),
#   Decimal('127.03982470000000')),
#  (864,
#   2,
#   '교대역점',
#   '서초구',
#   '서울 서초구 서초대로56길 22 (서초동, 성운빌딩)',
#   Decimal('37.49771020000000'),
#   Decimal('126.99780290000000')),
#  (863,
#   2,
#   '강남센트럴시티점',
#   '서초구',
#   '서울 서초구 신반포로 176 (반포동, 센트럴시티)',
#   Decimal('37.50412990000000'),
#   Decimal('127.00306920000000')),
#  (862,
#   2,
#   '홍은사거리점',
#   '서대문구',
#   '서울 서대문구 통일로 510 (홍은동, 북한산 더샵)',
#   Decimal('37.59338230000000'),
#   Decimal('126.94161720000000')),
#  (861,
#   2,
#   '충정로3가점',
#   '서대문구',
#   '서울 서대문구 경기대로 26-26 (충정로3가, 더스타일하우스디센트럴)',
#   Decimal('37.56130010000000'),
#   Decimal('126.96225900000000')),
#  (860,
#   2,
#   '이화여대점',
#   '서대문구',
#   '서울 서대문구 이화여대길 26 (대현동, 이화빌딩)',
#   Decimal('37.55796610000000'),
#   Decimal('126.94609090000000')),
#  (859,
#   2,
#   '연희홍연길점',
#   '서대문구',
#   '서울 서대문구 홍제천로 146-9 (연희동)',
#   Decimal('37.57352190000000'),
#   Decimal('126.92643420000000')),
#  (858,
#   2,
#   '연세대점',
#   '서대문구',
#   '서울 서대문구 연세로12길 10 (창천동)',
#   Decimal('37.55886030000000'),
#   Decimal('126.93752580000000')),
#  (857,
#   2,
#   '연남동점',
#   '서대문구',
#   '서울 서대문구 연희로 42 (연희동)',
#   Decimal('37.56235990000000'),
#   Decimal('126.92789480000000')),
#  (856,
#   2,
#   '신촌역점',
#   '서대문구',
#   '서울 서대문구 신촌로 87-20 (창천동)',
#   Decimal('37.56063190000000'),
#   Decimal('126.93401320000000')),
#  (855,
#   2,
#   '신촌기차역점',
#   '서대문구',
#   '서울 서대문구 신촌역로 35 (창천동)',
#   Decimal('37.55895450000000'),
#   Decimal('126.94147100000000')),
#  (854,
#   2,
#   '서대문점',
#   '서대문구',
#   '서울 서대문구 냉천동',
#   Decimal('37.56681210000000'),
#   Decimal('126.96235260000000')),
#  (853,
#   2,
#   '서대문구청점',
#   '서대문구',
#   '서울 서대문구 연희로 237 (연희동)',
#   Decimal('37.57823010000000'),
#   Decimal('126.93569430000000')),
#  (852,
#   2,
#   '북가좌동점',
#   '서대문구',
#   '서울 서대문구 증가로 257 (북가좌동)',
#   Decimal('37.58345120000000'),
#   Decimal('126.91153320000000')),
#  (851,
#   2,
#   '무악재역점',
#   '서대문구',
#   '서울 서대문구 홍제동 ',
#   Decimal('37.58707370000000'),
#   Decimal('126.94895450000000')),
#  (850,
#   2,
#   '명지전문대점',
#   '서대문구',
# ...
#   Decimal('37.59803300000000'),
#   Decimal('127.09409620000000')),
#  (731,
#   2,
#   '중곡대원점',
#   '광진구',
#   '서울 광진구 용마산로 111 (중곡동)',
#   Decimal('37.56359350000000'),
#   Decimal('127.08667290000000')),
#  (730,
#   2,
#   '자양우성점',
#   '광진구',
#   '서울 광진구 자양번영로 34 (자양동, 제이원하이텔)',
#   Decimal('37.53270130000000'),
#   Decimal('127.07582530000000')),
#  (729,
#   2,
#   '자양동점',
#   '광진구',
#   '서울 광진구 자양로 46 (자양동)',
#   Decimal('37.53223810000000'),
#   Decimal('127.08597940000000')),
#  (728,
#   2,
#   '아차산역점',
#   '광진구',
#   '서울 광진구 천호대로 663 (구의동)',
#   Decimal('37.55179190000000'),
#   Decimal('127.09022480000000')),
#  (727,
#   2,
#   '세종대후문점',
#   '광진구',
#   '서울 광진구 군자로 109 (군자동)',
#   Decimal('37.55287180000000'),
#   Decimal('127.07199130000000')),
#  (726,
#   2,
#   '뚝섬유원지역점',
#   '광진구',
#   '서울 광진구 능동로 21 (자양동)',
#   Decimal('37.53350190000000'),
#   Decimal('127.06728350000000')),
#  (725,
#   2,
#   '동서울터미널점',
#   '광진구',
#   '서울 광진구 구의동 ',
#   Decimal('37.54440070000000'),
#   Decimal('127.09284400000000')),
#  (724,
#   2,
#   '군자역점',
#   '광진구',
#   '서울 광진구 능동로 290 (능동, 삼일빌딩)',
#   Decimal('37.55559030000000'),
#   Decimal('127.07905950000000')),
#  (723,
#   2,
#   '구의자양로점',
#   '광진구',
#   '서울 광진구 자양로 251 (구의동)',
#   Decimal('37.54901210000000'),
#   Decimal('127.08929210000000')),
#  (722,
#   2,
#   '구의역점',
#   '광진구',
#   '서울 광진구 구의로 4 (구의동)',
#   Decimal('37.53820910000000'),
#   Decimal('127.08929480000000')),
#  (721,
#   2,
#   '구의사거리점',
#   '광진구',
#   '서울 광진구 광나루로 508 (구의동)',
#   Decimal('37.54473780000000'),
#   Decimal('127.08593070000000')),
#  (720,
#   2,
#   '광진구청점',
#   '광진구',
#   '서울 광진구 자양로 136 (구의동)',
#   Decimal('37.53978439999999'),
#   Decimal('127.08342440000000')),
#  (719,
#   2,
#   '광나루점',
#   '광진구',
#   '서울 광진구 아차산로 624 (광장동)',
#   Decimal('37.54820330000000'),
#   Decimal('127.10756600000000')),
#  (718,
#   2,
#   '건대후문점',
#   '광진구',
#   '서울 광진구 광나루로 416 (화양동, 건회빌딩)',
#   Decimal('37.54649510000001'),
#   Decimal('127.07558740000000')),
#  (717,
#   2,
#   '건대역점',
#   '광진구',
#   '서울 광진구 아차산로 229 (화양동, 한림타워)',
#   Decimal('37.54073190000000'),
#   Decimal('127.06900800000000')),
#  (716,
#   2,
#   '건대스타시티점',
#   '광진구',
#   '서울 광진구 아차산로 272 (자양동, 더샵스타시티)',
#   Decimal('37.53780280000000'),
#   Decimal('127.07263220000000')),
#  (715,
#   2,
#   '건대스타시티2호점',
#   '광진구',
#   '서울 광진구 능동로 92 (자양동, 스타시티몰) 지하 2층 201호',
#   Decimal('37.53855700000000'),
#   Decimal('127.07296160000000')),
#  (714,
#   2,
#   '건대로데오점',
#   '광진구',
#   '서울 광진구 아차산로30길 8 (자양동)',
#   Decimal('37.54041640000000'),
#   Decimal('127.06760760000000')),
#  (713,
#   2,
#   '청룡중앙점',
#   '관악구',
#   '서울 관악구 쑥고개로 80 (봉천동, 제이빌딩)',
#   Decimal('37.47917650000000'),
#   Decimal('126.94526070000000')),
#  (712,
#   2,
#   '인헌점',
#   '관악구',
#   '서울 관악구 인헌길 17 (봉천동)',
#   Decimal('37.47472450000000'),
#   Decimal('126.96705410000000')),
#  (711,
#   2,
#   '신림패션문화점',
#   '관악구',
#   '서울 관악구 봉천로6길 24 (신림동)',
#   Decimal('37.48862990000000'),
#   Decimal('126.92543080000000')),
#  (710,
#   2,
#   '신림중앙점',
#   '관악구',
#   '서울 관악구 관천로 52 (신림동)',
#   Decimal('37.48434719999999'),
#   Decimal('126.92663670000000')),
#  (709,
#   2,
#   '신림역점',
#   '관악구',
#   '서울 관악구 신림로 312 (신림동)',
#   Decimal('37.48222880000000'),
#   Decimal('126.93018280000000')),
#  (708,
#   2,
#   '신림신화교점',
#   '관악구',
#   '서울 관악구 신림로 199 (신림동)',
#   Decimal('37.47554020000000'),
#   Decimal('126.93620150000000')),
#  (707,
#   2,
#   '신림신원점',
#   '관악구',
#   '서울 관악구 신원로 16 (신림동)',
#   Decimal('37.48080200000000'),
#   Decimal('126.92807900000000')),
#  (706,
#   2,
#   '신림미성점',
#   '관악구',
#   '서울 관악구 난곡로 250 (신림동)',
#   Decimal('37.47652820000000'),
#   Decimal('126.91597340000000')),
#  (705,
#   2,
#   '신림대학동점',
#   '관악구',
#   '서울 관악구 호암로26길 17 (신림동)',
#   Decimal('37.47076930000000'),
#   Decimal('126.93461160000000')),
#  (704,
#   2,
#   '신림남부초교점',
#   '관악구',
#   '서울 관악구 남부순환로 1541-1 (신림동)',
#   Decimal('37.48340719999999'),
#   Decimal('126.92188880000000')),
#  (703,
#   2,
#   '신림난곡점',
#   '관악구',
#   '서울 관악구 난곡로 197 (신림동)',
#   Decimal('37.47253780000000'),
#   Decimal('126.91893870000000')),
#  (702,
#   2,
#   '신대방역점',
#   '관악구',
#   '서울 관악구 난곡로 368 (신림동)',
#   Decimal('37.48691080000000'),
#   Decimal('126.91380090000000')),
#  (701,
#   2,
#   '서울대중앙점',
#   '관악구',
#   '서울 관악구 남부순환로216길 2 (봉천동)',
#   Decimal('37.48135310000000'),
#   Decimal('126.94898990000000')),
#  (700,
#   2,
#   '사당중앙점',
#   '관악구',
#   '서울 관악구 과천대로 951 (남현동)',
#   Decimal('37.47547400000000'),
#   Decimal('126.98128600000000')),
#  (699,
#   2,
#   '봉천역점',
#   '관악구',
#   '서울 관악구 남부순환로 1725 (봉천동)',
#   Decimal('37.48267770000000'),
#   Decimal('126.94189460000000')),
#  (698,
#   2,
#   '봉일시장점',
#   '관악구',
#   '서울 관악구 은천로 23 (봉천동)',
#   Decimal('37.48641670000000'),
#   Decimal('126.93792210000000')),
#  (697,
#   2,
#   '보라매중앙점',
#   '관악구',
#   '서울 관악구 보라매로 62 (봉천동, 보라매삼성아파트)',
#   Decimal('37.49409710000000'),
#   Decimal('126.92785450000000')),
#  (696,
#   2,
#   '녹두거리점',
#   '관악구',
#   '서울 관악구 신림로 91 (신림동)',
#   Decimal('37.47027810000000'),
#   Decimal('126.93912000000000')),
#  (695,
#   2,
#   '남현홈플러스점',
#   '관악구',
#   '서울 관악구 과천대로 909 (남현동, 남현프라자)',
#   Decimal('37.47147830000000'),
#   Decimal('126.98241310000000')),
#  (694,
#   2,
#   '난곡사거리점',
#   '관악구',
#   '서울 관악구 남부순환로 1444 (신림동)',
#   Decimal('37.48090380000000'),
#   Decimal('126.91127540000000')),
#  (693,
#   2,
#   '낙성대역점',
#   '관악구',
#   '서울 관악구 남부순환로 1915 (봉천동)',
#   Decimal('37.47792620000000'),
#   Decimal('126.96222190000000')),
#  (692,
#   2,
#   '관악하나로마트점',
#   '관악구',
#   '서울 관악구 남부순환로 1369 (신림동, 관악농협농산물백화점)',
#   Decimal('37.48001524385821'),
#   Decimal('126.90297235228446')),
#  (691,
#   2,
#   '관악우성점',
#   '관악구',
#   '서울 관악구 관악로 232 (봉천동)',
#   Decimal('37.48494770000000'),
#   Decimal('126.95602740000000')),
#  (690,
#   2,
#   '관악구청점',
#   '관악구',
#   '서울 관악구 관악로 164 (봉천동, 대우디오슈페리움1단지)',
#   Decimal('37.49215600000000'),
#   Decimal('127.03093870000000')),
#  (689,
#   2,
#   '화곡중앙시장점',
#   '강서구',
#   '서울 강서구 가로공원로76길 61 (화곡동)',
#   Decimal('37.53441130000000'),
#   Decimal('126.83839180000000')),
#  (688,
#   2,
#   '화곡사거리점',
#   '강서구',
#   '서울 강서구 곰달래로 135 (화곡동)',
#   Decimal('37.53078730000000'),
#   Decimal('126.84792750000000')),
#  (687,
#   2,
#   '화곡본동시장점',
#   '강서구',
#   '서울 강서구 까치산로4길 11 (화곡동)',
#   Decimal('37.54222250000000'),
#   Decimal('126.84430240000000')),
#  (686,
#   2,
#   '화곡로점',
#   '강서구',
#   '서울 강서구 화곡로 133 (화곡동)',
#   Decimal('37.54085930000000'),
#   Decimal('126.83647730000000')),
#  (685,
#   2,
#   '화곡남부시장점',
#   '강서구',
#   '서울 강서구 등촌로5길 80 (화곡동)',
#   Decimal('37.53305990000000'),
#   Decimal('126.85896240000000')),
#  (684,
#   2,
#   '우장산동점',
#   '강서구',
#   '서울 강서구 우현로 15 (화곡동)',
#   Decimal('37.54718360000000'),
#   Decimal('126.84360950000000')),
#  (683,
#   2,
#   '염창블루나인점',
#   '강서구',
#   '서울 강서구 양천로 583 (염창동)',
#   Decimal('37.55725180000000'),
#   Decimal('126.86444100000000')),
#  (682,
#   2,
#   '염창동점',
#   '강서구',
#   '서울 강서구 양천로 689 (염창동)',
#   Decimal('37.55052370000000'),
#   Decimal('126.87295360000000')),
#  (681,
#   2,
#   '신방화중앙점',
#   '강서구',
#   '서울 강서구 방화대로34길 92 (방화동, 불해빌딩)',
#   Decimal('37.57087660000000'),
#   Decimal('126.82134390000000')),
#  (680,
#   2,
#   '송정역점',
#   '강서구',
#   '서울 강서구 공항대로 24 (공항동)',
#   Decimal('37.56164649999999'),
#   Decimal('126.80946640000000')),
#  (679,
#   2,
#   '서울공진초교점',
#   '강서구',
#   '서울 강서구 마곡중앙1로 26 (마곡동, 마곡엠리체)',
#   Decimal('37.55865330000000'),
#   Decimal('126.82380950000000')),
#  (678,
#   2,
#   '방화사거리점',
#   '강서구',
#   '서울 강서구 양천로 72 (방화동, 해성빌딩)',
#   Decimal('37.57298620000000'),
#   Decimal('126.80761850000000')),
#  (677,
#   2,
#   '방화동로점',
#   '강서구',
#   '서울 강서구 방화동로 95 (방화동)',
#   Decimal('37.56904400000000'),
#   Decimal('126.81257800000000')),
#  (676,
#   2,
#   '마곡헤리움점',
#   '강서구',
#   '서울 강서구 마곡중앙5로1길 25 (마곡동, 마곡헤리움2차)',
#   Decimal('37.56926600000000'),
#   Decimal('126.82640300000000')),
#  (675,
#   2,
#   '마곡파인스퀘어점',
#   '강서구',
#   '서울 강서구 마곡중앙4로 22 (마곡동, 파인스퀘어)',
#   Decimal('37.55841560000000'),
#   Decimal('126.82942650000000')),
#  (674,
#   2,
#   '마곡퀸즈파크9점',
#   '강서구',
#   '서울 강서구 공항대로 247 (마곡동, 퀸즈파크나인)',
#   Decimal('37.55930230000000'),
#   Decimal('126.83522300000000')),
#  (673,
#   2,
#   '마곡수명산점',
#   '강서구',
#   '서울 강서구 수명로 68-27 (내발산동, 웨스트엔드문화센터)',
#   Decimal('37.55267710000000'),
#   Decimal('126.82668190000000')),
#  (672,
#   2,
#   '마곡나루역점',
#   '강서구',
#   '서울 강서구 마곡중앙5로 6 (마곡동, 마곡나루역보타닉푸르지오시티)',
#   Decimal('37.56693560000000'),
#   Decimal('126.82656110000000')),
#  (671,
#   2,
#   '렘넌트문화센터점',
#   '강서구',
#   '서울 강서구 화곡로63길 65 (등촌동, 예원교회)',
#   Decimal('37.55793260000000'),
#   Decimal('126.84917620000000')),
#  (670,
#   2,
#   '등촌중앙점',
#   '강서구',
#   '서울 강서구 등촌로 67 (등촌동, 컴스웨이빌딩)',
#   Decimal('37.53608260000000'),
#   Decimal('126.86316210000000')),
#  (669,
#   2,
#   '등촌역점',
#   '강서구',
#   '서울 강서구 등촌로 217 (등촌동)',
#   Decimal('37.54915850000000'),
#   Decimal('126.86330550000000')),
#  (668,
#   2,
#   '내발산점',
#   '강서구',
#   '서울 강서구 강서로 304 (내발산동, 영종빌딩)',
#   Decimal('37.55272840000000'),
#   Decimal('126.83656710000000')),
#  (667,
#   2,
#   '까치산역점',
#   '강서구',
#   '서울 강서구 강서로17길 6 (화곡동)',
#   Decimal('37.53340910000000'),
#   Decimal('126.84522440000000')),
#  (666,
#   2,
#   '까치산로점',
#   '강서구',
#   '서울 강서구 까치산로 182 (화곡동)',
#   Decimal('37.55331880000000'),
#   Decimal('126.85389530000000')),
#  (665,
#   2,
#   '공항시장역점',
#   '강서구',
#   '서울 강서구 방화동로 37 (방화동, 메디스타워)',
#   Decimal('37.56400440000000'),
#   Decimal('126.81079150000000')),
#  (664,
#   2,
#   '개화산점',
#   '강서구',
#   '서울 강서구 양천로 28 (방화동, 벽산에어트리움)',
#   Decimal('37.57225400000000'),
#   Decimal('126.80709620000000')),
#  (663,
#   2,
#   '강서한강자이점',
#   '강서구',
#   '서울 강서구 양천로 401 (가양동)',
#   Decimal('37.56788020000000'),
#   Decimal('126.85107870000000')),
#  (662,
#   2,
#   '강서구청점',
#   '강서구',
#   '서울 강서구 화곡로 292 (화곡동, 서광프리메라)',
#   Decimal('37.55014560000000'),
#   Decimal('126.84859370000000')),
#  (661,
#   2,
#   '강서교차로점',
#   '강서구',
#   '서울 강서구 공항대로 437 (등촌동, 주신기업(주))',
#   Decimal('37.55752230000000'),
#   Decimal('126.85596110000000')),
#  (660,
#   2,
#   '강서nc점',
#   '강서구',
#   '서울 강서구 강서로54길 11 (등촌동)',
#   Decimal('37.55933560000000'),
#   Decimal('126.83927800000000')),
#  (659,
#   2,
#   '가양역점',
#   '강서구',
#   '서울 강서구 양천로 500 (등촌동)',
#   Decimal('37.55752230000000'),
#   Decimal('126.85596110000000')),
#  (658,
#   2,
#   '한신대점',
#   '강북구',
#   '서울 강북구 덕릉로 31 (수유동)',
#   Decimal('37.63422210000000'),
#   Decimal('127.01693430000000')),
#  (657,
#   2,
#   '우이역도선사점',
#   '강북구',
#   '서울 강북구 삼양로173길 21 (우이동)',
#   Decimal('37.66250020000000'),
#   Decimal('127.01130470000000')),
#  (656,
#   2,
#   '수유역점',
#   '강북구',
#   '서울 강북구 도봉로 355 (수유동)',
#   Decimal('37.63939180000000'),
#   Decimal('127.02674900000000')),
#  (655,
#   2,
#   '수유사거리점',
#   '강북구',
#   '서울 강북구 덕릉로 82 (수유동, 제네스타워)',
#   Decimal('37.63440330000000'),
#   Decimal('127.02285010000000')),
#  (654,
#   2,
#   '삼각산점',
#   '강북구',
#   '서울 강북구 솔샘로40길 3 (미아동)',
#   Decimal('37.61992030000000'),
#   Decimal('127.01601070000000')),
#  (653,
#   2,
#   '북한산점',
#   '강북구',
#   '서울 강북구 4.19로 85 (수유동)',
#   Decimal('37.64474990000000'),
#   Decimal('127.00560310000000')),
#  (652,
#   2,
#   '번동점',
#   '강북구',
#   '서울 강북구 오현로 194 (번동, 덕수빌딩)',
#   Decimal('37.62883380000000'),
#   Decimal('127.03985060000000')),
#  (651,
#   2,
#   '미아중앙점',
#   '강북구',
#   '서울 강북구 도봉로 128 (미아동)',
#   Decimal('37.62046450000000'),
#   Decimal('127.02876310000000')),
#  (650,
#   2,
#   '미아역점',
#   '강북구',
#   '서울 강북구 도봉로 207 -3(미아동)',
#   Decimal('37.62711020000000'),
#   Decimal('127.02543950000000')),
#  (649,
#   2,
#   '미아꿈의숲해링턴점',
#   '강북구',
#   '서울 강북구 오현로 45 (미아동, 꿈의숲 해링턴 플레이스)',
#   Decimal('37.61855660000000'),
#   Decimal('127.03408500000000')),
#  (648,
#   2,
#   '광산사거리점',
#   '강북구',
#   '서울 강북구 노해로 91 (수유동, 진흥빌딩)',
#   Decimal('37.64389570000000'),
#   Decimal('127.02256970000000')),
#  (647,
#   2,
#   '가오리역점',
#   '강북구',
#   '서울 강북구 삼각산로 108 (수유동)',
#   Decimal('37.64053880000000'),
#   Decimal('127.01616920000000')),
#  (646,
#   2,
#   '한티역점',
#   '강남구',
#   '서울 강남구 도곡로69길 8 (대치동)',
#   Decimal('37.49795510000000'),
#   Decimal('127.05613040000000')),
#  (645,
#   2,
#   '학동제마점',
#   '강남구',
#   '서울 강남구 학동로34길 22 (논현동)',
#   Decimal('37.51313870000001'),
#   Decimal('127.03365000000000')),
#  (644,
#   2,
#   '학동역점',
#   '강남구',
#   '서울 강남구 학동로 219 (논현동, 국제빌딩)',
#   Decimal('37.50979250000000'),
#   Decimal('127.02157800000000')),
#  (643,
#   2,
#   '포이사거리점',
#   '강남구',
#   '서울 강남구 개포로 218 (개포동)',
#   Decimal('37.47846800000000'),
#   Decimal('127.04662500000000')),
#  (642,
#   2,
#   '청담역점',
#   '강남구',
#   '서울 강남구 삼성로 721 (청담동, 룩희 819)',
#   Decimal('37.52006810000000'),
#   Decimal('127.04916340000000')),
#  (641,
#   2,
#   '청담사거리점',
#   '강남구',
#   '서울 강남구 도산대로 521 (청담동)',
#   Decimal('37.52486600000000'),
#   Decimal('127.05037300000000')),
#  (640,
#   2,
#   '일원동점',
#   '강남구',
#   '서울 강남구 양재대로27길 20 (일원동)',
#   Decimal('37.49069850000000'),
#   Decimal('127.08839480000000')),
#  (639,
#   2,
#   '이디야커피랩',
#   '강남구',
#   '서울 강남구 논현로 636 (논현동, 이디야빌딩)',
#   Decimal('37.52029460000000'),
#   Decimal('127.03594570000000')),
#  (638,
#   2,
#   '을지병원사거리점',
#   '강남구',
#   '서울 강남구 도산대로30길 7 (논현동)',
#   Decimal('37.51940230000000'),
#   Decimal('127.02943050000000')),
#  (637,
#   2,
#   '역삼플래티넘점',
#   '강남구',
#   '서울 강남구 테헤란로4길 46 (역삼동, 쌍용플래티넘밸류)',
#   Decimal('37.49533230000000'),
#   Decimal('127.03037250000000')),
#  (636,
#   2,
#   '역삼충현점',
#   '강남구',
#   '서울 강남구 논현로98길 7 (역삼동)',
#   Decimal('37.50378790000000'),
#   Decimal('127.03632960000000')),
#  (635,
#   2,
#   '역삼중앙점',
#   '강남구',
#   '서울 강남구 언주로81길 8 (역삼동)',
#   Decimal('37.50036600000000'),
#   Decimal('127.04286900000000')),
#  (634,
#   2,
#   '역삼점',
#   '강남구',
#   '서울 강남구 논현로72길 13 (역삼동)',
#   Decimal('37.49584150000000'),
#   Decimal('127.04054440000000')),
#  (633,
#   2,
#   '역삼월드점',
#   '강남구',
#   '서울 강남구 역삼로52길 14 (역삼동, 도곡프라자)',
#   Decimal('37.49854440000000'),
#   Decimal('127.04793690000000')),
#  (632,
#   2,
#   '역삼역점',
#   '강남구',
#   '서울 강남구 테헤란로25길 17 (역삼동)',
#   Decimal('37.50181120000000'),
#   Decimal('127.03521110000000')),
#  (631,
#   2,
#   '역삼상록점',
#   '강남구',
#   '서울 강남구 테헤란로43길 18 (역삼동, SC빌딩)',
#   Decimal('37.50442250000000'),
#   Decimal('127.04402700000000')),
#  (630,
#   2,
#   '역삼더블루점',
#   '강남구',
#   '서울 강남구 논현로63길 16 (역삼동, 역삼종합시장 더블루)',
#   Decimal('37.49290900000000'),
#   Decimal('127.03907230000000')),
#  (629,
#   2,
#   '압구정로데오역점',
#   '강남구',
#   '서울 강남구 선릉로161길 20 (신사동)',
#   Decimal('37.52753400000000'),
#   Decimal('127.03882820000000')),
#  (628,
#   2,
#   '신사점',
#   '강남구',
#   '서울 강남구 도산대로 118 (논현동)',
#   Decimal('37.51666790000000'),
#   Decimal('127.02172790000000')),
#  (627,
#   2,
#   '신사역점',
#   '강남구',
#   '서울 강남구 압구정로2길 62 (신사동)',
#   Decimal('37.51779430000000'),
#   Decimal('127.02144060000000')),
#  (626,
#   2,
#   '수서역점',
#   '강남구',
#   '서울 강남구 광평로 280 (수서동, 로즈데일오피스텔)',
#   Decimal('37.48734250000000'),
#   Decimal('127.10300150000000')),
#  (625,
#   2,
#   '선릉역점',
#   '강남구',
#   '서울 강남구 테헤란로 332 (역삼동, HJ타워)',
#   Decimal('37.50381880000000'),
#   Decimal('127.04814970000000')),
#  (624,
#   2,
#   '선릉사거리점',
#   '강남구',
#   '서울 강남구 선릉로 519 (역삼동, 삼능빌딩)',
#   Decimal('37.50590500000000'),
#   Decimal('127.04793700000000')),
#  (623,
#   2,
#   '삼성한전점',
#   '강남구',
#   '서울 강남구 테헤란로107길 11 (삼성동)',
#   Decimal('37.51044080000000'),
#   Decimal('127.06504850000000')),
#  (622,
#   2,
#   '삼성중앙역점',
#   '강남구',
#   '서울 강남구 삼성로 608 (삼성동, 우창빌딩)',
#   Decimal('37.50796000000000'),
#   Decimal('127.05654690000000')),
#  (621,
#   2,
#   '삼성동점',
#   '강남구',
#   '서울 강남구 테헤란로88길 10 (대치동)',
#   Decimal('37.50688330000000'),
#   Decimal('127.05943700000000')),
#  (620,
#   2,
#   '삼성대치점',
#   '강남구',
#   '서울 강남구 삼성로64길 32 (대치동, 주성빌딩)',
#   Decimal('37.50041960000000'),
#   Decimal('127.06307160000000')),
#  (619,
#   2,
#   '도산사거리점',
#   '강남구',
#   '서울 강남구 논현동 ',
#   Decimal('37.51367870000000'),
#   Decimal('127.03171240000000')),
#  (618,
#   2,
#   '도곡2동점',
#   '강남구',
#   '서울 강남구 논현로 142 (도곡동, 동현빌딩)',
#   Decimal('37.48243510000000'),
#   Decimal('127.04299330000000')),
#  (617,
#   2,
#   '대청역점',
#   '강남구',
#   '서울 강남구 개포로109길 34 (개포동, 대청프라자)',
#   Decimal('37.49421560000000'),
#   Decimal('127.07761700000000')),
#  (616,
#   2,
#   '건설회관점',
#   '강남구',
#   '서울 강남구 언주로 711 (논현동)',
#   Decimal('37.51630030000000'),
#   Decimal('127.02991230000000')),
#  (615,
#   2,
#   '개포동역점',
#   '강남구',
#   '서울 강남구 개포로82길 11 (개포동, 삼우빌딩)',
#   Decimal('37.48893480000000'),
#   Decimal('127.06793520000000')),
#  (614,
#   2,
#   '강남자곡점',
#   '강남구',
#   '서울 강남구 자곡로 180 (자곡동, 강남유탑유블레스)',
#   Decimal('37.47348460000000'),
#   Decimal('127.10309790000000')),
#  (613,
#   2,
#   '강남율현점',
#   '강남구',
#   '서울 강남구 밤고개로21길 8 (율현동, 세곡프라자)',
#   Decimal('37.47358220000000'),
#   Decimal('127.10783110000000')),
#  (612,
#   2,
#   '강남도산점',
#   '강남구',
#   '서울 강남구 도산대로37길 20 (신사동)',
#   Decimal('37.52228210000000'),
#   Decimal('127.03147990000000')),
#  (611,
#   2,
#   '강남대치점',
#   '강남구',
#   '서울 강남구 역삼로 415 (대치동, 성진빌딩)',
#   Decimal('37.50143400000000'),
#   Decimal('127.05232800000000')),
#  (610,
#   2,
#   '강남논현학동점',
#   '강남구',
#   '서울 강남구 논현로131길 28 (논현동)',
#   Decimal('37.51518990000000'),
#   Decimal('127.02755390000000')),
#  (609,
#   2,
#   '강남구청역아이티웨딩점',
#   '강남구',
#   '서울 강남구 학동로 338 (논현동, 강남파라곤)',
#   Decimal('37.51655130000000'),
#   Decimal('127.04013910000000')),
#  (608,
#   2,
#   '강남YMCA점',
#   '강남구',
#   '서울 강남구 논현동',
#   Decimal('37.51367870000000'),
#   Decimal('127.03171240000000'))]

# %% [markdown]
# auto_increment로 인해 오류가 뜬 것이 누적되어 id값을 초기화해야함
# 어쩔 수 없이 COFFEE_STORE 테이블을 삭제 후 다시 생성하고
# 스타벅스 값을 넣고, 이디야 값을 넣자

# %%
cursor.execute("DROP TABLE COFFEE_STORE;")

# %%
cursor.execute("SELECT COUNT(*) FROM COFFEE_STORE WHERE brand=2;")
result = cursor.fetchall()
result
# Out:
# [(614,)]

# %%
cursor.execute("SELECT s.* FROM COFFEE_BRAND b, COFFEE_STORE s WHERE b.id = s.brand AND b.name LIKE 'EDIYA' limit 10;")
result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# (608, 2, '강남YMCA점', '강남구', '서울 강남구 논현동', Decimal('37.51367870000000'), Decimal('127.03171240000000'))
# (609, 2, '강남구청역아이티웨딩점', '강남구', '서울 강남구 학동로 338 (논현동, 강남파라곤)', Decimal('37.51655130000000'), Decimal('127.04013910000000'))
# (610, 2, '강남논현학동점', '강남구', '서울 강남구 논현로131길 28 (논현동)', Decimal('37.51518990000000'), Decimal('127.02755390000000'))
# (611, 2, '강남대치점', '강남구', '서울 강남구 역삼로 415 (대치동, 성진빌딩)', Decimal('37.50143400000000'), Decimal('127.05232800000000'))
# (612, 2, '강남도산점', '강남구', '서울 강남구 도산대로37길 20 (신사동)', Decimal('37.52228210000000'), Decimal('127.03147990000000'))
# (613, 2, '강남율현점', '강남구', '서울 강남구 밤고개로21길 8 (율현동, 세곡프라자)', Decimal('37.47358220000000'), Decimal('127.10783110000000'))
# (614, 2, '강남자곡점', '강남구', '서울 강남구 자곡로 180 (자곡동, 강남유탑유블레스)', Decimal('37.47348460000000'), Decimal('127.10309790000000'))
# (615, 2, '개포동역점', '강남구', '서울 강남구 개포로82길 11 (개포동, 삼우빌딩)', Decimal('37.48893480000000'), Decimal('127.06793520000000'))
# (616, 2, '건설회관점', '강남구', '서울 강남구 언주로 711 (논현동)', Decimal('37.51630030000000'), Decimal('127.02991230000000'))
# (617, 2, '대청역점', '강남구', '서울 강남구 개포로109길 34 (개포동, 대청프라자)', Decimal('37.49421560000000'), Decimal('127.07761700000000'))

# %%
driver.close()

# %% [markdown]
# ---

# %%
cursor.execute("DESC COFFEE_STORE;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('brand', b'int', 'NO', 'MUL', None, ''),
#  ('name', b'varchar(32)', 'NO', '', None, ''),
#  ('gu_name', b'varchar(5)', 'NO', '', None, ''),
#  ('address', b'varchar(128)', 'NO', '', None, ''),
#  ('lat', b'decimal(16,14)', 'NO', '', None, ''),
#  ('lng', b'decimal(17,14)', 'NO', '', None, '')]

# %%
cursor.execute("SELECT * FROM COFFEE_STORE;")
cursor.fetchall()
# Out:
# [(1,
#   1,
#   '역삼아레나빌딩',
#   '강남구',
#   '서울특별시 강남구 언주로 425 (역삼동)',
#   Decimal('37.50108700000000'),
#   Decimal('127.04306900000000')),
#  (2,
#   1,
#   '논현역사거리',
#   '강남구',
#   '서울특별시 강남구 강남대로 538 (논현동)',
#   Decimal('37.51017800000000'),
#   Decimal('127.02222300000000')),
#  (3,
#   1,
#   '신사역성일빌딩',
#   '강남구',
#   '서울특별시 강남구 강남대로 584 (논현동)',
#   Decimal('37.51393090000000'),
#   Decimal('127.02060570000000')),
#  (4,
#   1,
#   '국기원사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 125 (역삼동)',
#   Decimal('37.49951700000000'),
#   Decimal('127.03149500000000')),
#  (5,
#   1,
#   '대치재경빌딩R',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2947 (대치동)',
#   Decimal('37.49466800000000'),
#   Decimal('127.06258300000000')),
#  (6,
#   1,
#   '봉은사역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 619 (삼성동)',
#   Decimal('37.51500000000000'),
#   Decimal('127.06319600000000')),
#  (7,
#   1,
#   '압구정윤성빌딩',
#   '강남구',
#   '서울특별시 강남구 논현로 834 (신사동)',
#   Decimal('37.52279340000000'),
#   Decimal('127.02860090000000')),
#  (8,
#   1,
#   '코엑스별마당',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동)',
#   Decimal('37.51015000000000'),
#   Decimal('127.06027500000000')),
#  (9,
#   1,
#   '삼성역섬유센터R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 518 (대치동)',
#   Decimal('37.50775000000000'),
#   Decimal('127.06065100000000')),
#  (10,
#   1,
#   '압구정R',
#   '강남구',
#   '서울특별시 강남구 언주로 861 (신사동)',
#   Decimal('37.52736690000000'),
#   Decimal('127.03306100000000')),
#  (11,
#   1,
#   '수서역R',
#   '강남구',
#   '서울특별시 강남구 광평로 281 (수서동)',
#   Decimal('37.48800800000000'),
#   Decimal('127.10265000000000')),
#  (12,
#   1,
#   '양재강남빌딩R',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2621 (도곡동)',
#   Decimal('37.48519200000000'),
#   Decimal('127.03668500000000')),
#  (13,
#   1,
#   '선릉동신빌딩R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 409 (삼성동)',
#   Decimal('37.50532100000000'),
#   Decimal('127.05040900000000')),
#  (14,
#   1,
#   '봉은사로선정릉',
#   '강남구',
#   '서울특별시 강남구 봉은사로 446 (삼성동)',
#   Decimal('37.51129300000000'),
#   Decimal('127.04840900000000')),
#  (15,
#   1,
#   '강남오거리',
#   '강남구',
#   '서울특별시 강남구 봉은사로2길 39 (역삼동)',
#   Decimal('37.50211700000000'),
#   Decimal('127.02667200000000')),
#  (16,
#   1,
#   '스타필드코엑스몰R',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동) 코엑스 A106호',
#   Decimal('37.50999000000000'),
#   Decimal('127.06145500000000')),
#  (17,
#   1,
#   '강남구청정문',
#   '강남구',
#   '서울특별시 강남구 학동로 419 (청담동)',
#   Decimal('37.51818100000000'),
#   Decimal('127.04599500000000')),
#  (18,
#   1,
#   '도곡공원',
#   '강남구',
#   '서울특별시 강남구 도곡로 205 (역삼동)',
#   Decimal('37.49280500000000'),
#   Decimal('127.04130900000000')),
#  (19,
#   1,
#   '강남R',
#   '강남구',
#   '서울특별시 강남구 강남대로 390 (역삼동)',
#   Decimal('37.49771100000000'),
#   Decimal('127.02843900000000')),
#  (20,
#   1,
#   '대치은마사거리',
#   '강남구',
#   '서울특별시 강남구 도곡로 457 (대치동)',
#   Decimal('37.49897300000000'),
#   Decimal('127.06017200000000')),
#  (21,
#   1,
#   '청담영동대로',
#   '강남구',
#   '서울특별시 강남구 영동대로 720 (청담동)',
#   Decimal('37.52215600000000'),
#   Decimal('127.05644900000000')),
#  (22,
#   1,
#   '압구정',
#   '강남구',
#   '서울특별시 강남구 압구정로30길 17 (신사동)',
#   Decimal('37.52628300000000'),
#   Decimal('127.02956000000000')),
#  (23,
#   1,
#   '신사가로수',
#   '강남구',
#   '서울특별시 강남구 가로수길 59 ',
#   Decimal('37.52193300000000'),
#   Decimal('127.02252100000000')),
#  (24,
#   1,
#   '청담스타R',
#   '강남구',
#   '서울특별시 강남구 도산대로57길 24 (청담동)',
#   Decimal('37.52521600000000'),
#   Decimal('127.04182700000000')),
#  (25,
#   1,
#   '강남우성',
#   '강남구',
#   '서울특별시 강남구 강남대로 328 (역삼동)',
#   Decimal('37.49239600000000'),
#   Decimal('127.03091000000000')),
#  (26,
#   1,
#   '학동사거리',
#   '강남구',
#   '서울특별시 강남구 도산대로 328 (논현동)',
#   Decimal('37.52236449999999'),
#   Decimal('127.03795430000002')),
#  (27,
#   1,
#   '대치사거리',
#   '강남구',
#   '서울특별시 강남구 삼성로 402 (대치동)',
#   Decimal('37.50333100000000'),
#   Decimal('127.05881700000000')),
#  (28,
#   1,
#   '포스코사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 505 (삼성동) 화진빌딩',
#   Decimal('37.50753070000000'),
#   Decimal('127.05742710000004')),
#  (29,
#   1,
#   '을지병원사거리',
#   '강남구',
#   '서울특별시 강남구 논현로 752 (논현동,구산빌딩)',
#   Decimal('37.51916320000000'),
#   Decimal('127.02864460000000')),
#  (30,
#   1,
#   '신사역',
#   '강남구',
#   '서울특별시 강남구 도산대로 108 (논현동) 렉스타워',
#   Decimal('37.51620210000000'),
#   Decimal('127.02074280000000')),
#  (31,
#   1,
#   '도곡역',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2909 (대치동)',
#   Decimal('37.49216700000000'),
#   Decimal('127.05739800000000')),
#  (32,
#   1,
#   '서울세관사거리',
#   '강남구',
#   '서울특별시 강남구 언주로 650 (논현동) 한국건설기술인협회',
#   Decimal('37.51488700000000'),
#   Decimal('127.03565300000000')),
#  (33,
#   1,
#   '청담사거리',
#   '강남구',
#   '서울특별시 강남구 도산대로 458 (청담동) 리츠타워',
#   Decimal('37.52363510000000'),
#   Decimal('127.04686509999999')),
#  (34,
#   1,
#   '한티역',
#   '강남구',
#   '서울특별시 강남구 도곡로 408, 디마크빌딩 101호 (대치동)',
#   Decimal('37.49680100000000'),
#   Decimal('127.05505500000000')),
#  (35,
#   1,
#   '역삼초교사거리',
#   '강남구',
#   '서울특별시 강남구 역삼로 123 (역삼동)',
#   Decimal('37.49410590000000'),
#   Decimal('127.03299730000003')),
#  (36,
#   1,
#   '코엑스몰',
#   '강남구',
#   '서울특별시 강남구 영동대로 513 (삼성동) O103호',
#   Decimal('37.51371500000000'),
#   Decimal('127.05924500000000')),
#  (37,
#   1,
#   '가로수길',
#   '강남구',
#   '서울특별시 강남구 논현로175길 94, 1~2층 (신사동)',
#   Decimal('37.52315930000000'),
#   Decimal('127.02162499999997')),
#  (38,
#   1,
#   '역삼대로',
#   '강남구',
#   '서울특별시 강남구 테헤란로 211, 한국고등교육재단빌딩 1층 (역삼동)',
#   Decimal('37.50162300000000'),
#   Decimal('127.03937500000000')),
#  (39,
#   1,
#   '역삼포스코',
#   '강남구',
#   '서울특별시 강남구 테헤란로 134, P&S TOWER (역삼동)',
#   Decimal('37.49972100000000'),
#   Decimal('127.03358200000000')),
#  (40,
#   1,
#   '강남대로',
#   '강남구',
#   '서울특별시 강남구 강남대로 456, 한석타워 2층 1-2호 (역삼동)',
#   Decimal('37.50314000000000'),
#   Decimal('127.02554600000000')),
#  (41,
#   1,
#   '청담',
#   '강남구',
#   '서울특별시 강남구 도산대로 532, 인희빌딩 1층 (청담동)',
#   Decimal('37.52436310000000'),
#   Decimal('127.05155990000003')),
#  (42,
#   1,
#   '삼성도심공항',
#   '강남구',
#   '서울특별시 강남구 테헤란로87길 33 (삼성동)',
#   Decimal('37.50978630000000'),
#   Decimal('127.05791339999996')),
#  (43,
#   1,
#   '삼성교',
#   '강남구',
#   '서울특별시 강남구 영동대로86길 12, 동남유화빌딩 1층',
#   Decimal('37.50779400000000'),
#   Decimal('127.06517000000000')),
#  (44,
#   1,
#   '학동역',
#   '강남구',
#   '서울특별시 강남구 논현로 704 (논현동)',
#   Decimal('37.51464884000000'),
#   Decimal('127.03073020000000')),
#  (45,
#   1,
#   '대치',
#   '강남구',
#   '서울특별시 강남구 도곡로 511 (대치동)',
#   Decimal('37.49966175000000'),
#   Decimal('127.06221710000000')),
#  (46,
#   1,
#   'SSG마켓도곡R',
#   '강남구',
#   '서울특별시 강남구 언주로30길 57, 타워팰리스Ⅱ F 지하1층 (도곡동)',
#   Decimal('37.49029800000000'),
#   Decimal('127.05489500000000')),
#  (47,
#   1,
#   '삼성',
#   '강남구',
#   '서울특별시 강남구 테헤란로 443, 애플트리타워 1층 (삼성동)',
#   Decimal('37.50703529000000'),
#   Decimal('127.05555030000000')),
#  (48,
#   1,
#   '선릉세화빌딩',
#   '강남구',
#   '서울특별시 강남구 테헤란로64길 18 (대치동) 1층',
#   Decimal('37.50377562000000'),
#   Decimal('127.05119600000000')),
#  (49,
#   1,
#   '압구정역',
#   '강남구',
#   '서울특별시 강남구 압구정로 170, 관영빌딩 1층 지하1층 (신사동)',
#   Decimal('37.52674095000000'),
#   Decimal('127.02811050000000')),
#  (50,
#   1,
#   '압구정로',
#   '강남구',
#   '서울특별시 강남구 압구정로42길 32 (신사동)',
#   Decimal('37.52680046000000'),
#   Decimal('127.03471740000000')),
#  (51,
#   1,
#   '구역삼사거리',
#   '강남구',
#   '서울특별시 강남구 논현로 401 (역삼동)',
#   Decimal('37.49592355000000'),
#   Decimal('127.03886450000000')),
#  (52,
#   1,
#   '큰길타워',
#   '강남구',
#   '서울특별시 강남구 테헤란로 223, 큰길타워빌딩 (역삼동)',
#   Decimal('37.50236693000000'),
#   Decimal('127.04070000000000')),
#  (53,
#   1,
#   '강남구청역',
#   '강남구',
#   '서울특별시 강남구 선릉로 669, 웰빙센터 1층 (논현동)',
#   Decimal('37.51658490000000'),
#   Decimal('127.04124330000002')),
#  (54,
#   1,
#   '대치역',
#   '강남구',
#   '서울특별시 강남구 남부순환로 2936 (대치동) 107호',
#   Decimal('37.49355400000000'),
#   Decimal('127.06187400000000')),
#  (55,
#   1,
#   '포이',
#   '강남구',
#   '서울특별시 강남구 논현로 88 (개포동)',
#   Decimal('37.47781106000000'),
#   Decimal('127.04514110000000')),
#  (56,
#   1,
#   '아크플레이스',
#   '강남구',
#   '서울특별시 강남구 테헤란로 142 (역삼동)',
#   Decimal('37.49971982000000'),
#   Decimal('127.03490840000000')),
#  (57,
#   1,
#   '학여울역',
#   '강남구',
#   '서울특별시 강남구 영동대로 215 (대치동)',
#   Decimal('37.49803646000000'),
#   Decimal('127.06849430000000')),
#  (58,
#   1,
#   '선정릉역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 407 (삼성동) 에프오빌딩',
#   Decimal('37.51075489999999'),
#   Decimal('127.04455970000003')),
#  (59,
#   1,
#   '삼성현대힐',
#   '강남구',
#   '서울특별시 강남구 삼성로 605 (삼성동)',
#   Decimal('37.51354184000000'),
#   Decimal('127.05271830000000')),
#  (60,
#   1,
#   'GS타워',
#   '강남구',
#   '서울특별시 강남구 논현로 508 (역삼동)',
#   Decimal('37.50185920000000'),
#   Decimal('127.03727759999992')),
#  (61,
#   1,
#   '압구정미소',
#   '강남구',
#   '서울특별시 강남구 논현로 841 (신사동)',
#   Decimal('37.52405601000000'),
#   Decimal('127.02791500000000')),
#  (62,
#   1,
#   '선릉역',
#   '강남구',
#   '서울특별시 강남구 테헤란로 334, LG화재 빌딩 (역삼동)',
#   Decimal('37.50393894000000'),
#   Decimal('127.04851350000000')),
#  (63,
#   1,
#   '코엑스사거리',
#   '강남구',
#   '서울특별시 강남구 영동대로 616 (삼성동)',
#   Decimal('37.51535100000000'),
#   Decimal('127.06010900000000')),
#  (64,
#   1,
#   '역삼럭키',
#   '강남구',
#   '서울특별시 강남구 도곡로 183 (역삼동)',
#   Decimal('37.49220900000000'),
#   Decimal('127.03938900000000')),
#  (65,
#   1,
#   '신압구정',
#   '강남구',
#   '서울특별시 강남구 언주로174길 29 (신사동)',
#   Decimal('37.52811500000000'),
#   Decimal('127.03644100000000')),
#  (66,
#   1,
#   '아크로힐스논현',
#   '강남구',
#   '서울특별시 강남구 봉은사로 304, 금강빌딩 1-2층 (역삼동)',
#   Decimal('37.50898041000000'),
#   Decimal('127.04038690000000')),
#  (67,
#   1,
#   '강남비젼타워',
#   '강남구',
#   '서울특별시 강남구 테헤란로2길 27, 1층 101호 (역삼동)',
#   Decimal('37.49645570000000'),
#   Decimal('127.02968850000002')),
#  (68,
#   1,
#   '압구정로데오역',
#   '강남구',
#   '서울특별시 강남구 선릉로 836, 삼원빌딩 1,2층 (청담동)',
#   Decimal('37.52654900000000'),
#   Decimal('127.04043700000000')),
#  (69,
#   1,
#   '르네상스사거리',
#   '강남구',
#   '서울특별시 강남구 테헤란로 306 (역삼동)',
#   Decimal('37.50272100000000'),
#   Decimal('127.04430800000000')),
#  (70,
#   1,
#   '포스코',
#   '강남구',
#   '서울특별시 강남구 삼성로86길 7, 1층 (대치동)',
#   Decimal('37.50576000000000'),
#   Decimal('127.05796600000000')),
#  (71,
#   1,
#   '선릉로',
#   '강남구',
#   '서울특별시 강남구 선릉로93길 22, 대흥빌딩 1층 (역삼동)',
#   Decimal('37.50505300000000'),
#   Decimal('127.04657700000000')),
#  (72,
#   1,
#   '논현힐탑',
#   '강남구',
#   '서울특별시 강남구 논현로 648 (논현동)',
#   Decimal('37.51155770000000'),
#   Decimal('127.03226199999994')),
#  (73,
#   1,
#   '도산가로수길',
#   '강남구',
#   '서울특별시 강남구 도산대로 134, 2층 (논현동)',
#   Decimal('37.51736229999999'),
#   Decimal('127.02329570000006')),
#  (74,
#   1,
#   '대치한티',
#   '강남구',
#   '서울특별시 강남구 선릉로 324 (대치동)',
#   Decimal('37.49848180000000'),
#   Decimal('127.05206600000000')),
#  (75,
#   1,
#   '개포동',
#   '강남구',
#   '서울특별시 강남구 선릉로 34 (개포동)',
#   Decimal('37.48285513598820'),
#   Decimal('127.06071524446210')),
#  (76,
#   1,
#   '수서역사거리',
#   '강남구',
#   '서울특별시 강남구 광평로 280 (수서동)',
#   Decimal('37.48732679377480'),
#   Decimal('127.10314008188700')),
#  (77,
#   1,
#   '코엑스아셈타워',
#   '강남구',
#   '서울특별시 강남구 영동대로 517 (삼성동)',
#   Decimal('37.51301900000000'),
#   Decimal('127.05983800000000')),
#  (78,
#   1,
#   '센터필드R',
#   '강남구',
#   '서울특별시 강남구 테헤란로 231 (역삼동)',
#   Decimal('37.50369465391196'),
#   Decimal('127.04172081609172')),
#  (79,
#   1,
#   '도산사거리',
#   '강남구',
#   '서울특별시 강남구 언주로 727 (논현동)',
#   Decimal('37.51966000000000'),
#   Decimal('127.03410000000000')),
#  (80,
#   1,
#   '강남세곡',
#   '강남구',
#   '서울특별시 강남구 헌릉로569길 18 (세곡동)',
#   Decimal('37.46727431964400'),
#   Decimal('127.09992972600000')),
#  (81,
#   1,
#   '대치삼성프라자',
#   '강남구',
#   '서울특별시 강남구 영동대로 237 (대치동)',
#   Decimal('37.50031300000000'),
#   Decimal('127.06696100000000')),
#  (82,
#   1,
#   '언주역',
#   '강남구',
#   '서울특별시 강남구 봉은사로 222 (역삼동)',
#   Decimal('37.50777500000000'),
#   Decimal('127.03647200000000')),
#  (83,
#   1,
#   '강남역신분당역사',
#   '강남구',
#   '서울특별시 강남구 강남대로 396 (역삼동)',
#   Decimal('37.49705725439780'),
#   Decimal('127.02818071438100')),
#  (84,
#   1,
#   '삼성역',
#   '강남구',
#   '서울특별시 강남구 테헤란로 620 (대치동)',
#   Decimal('37.50920696254126'),
#   Decimal('127.06560851480327')),
#  (85,
#   1,
#   '테헤란로아남타워',
#   '강남구',
#   '서울특별시 강남구 테헤란로 311 (역삼동)',
#   Decimal('37.50383000000000'),
#   Decimal('127.04487000000000')),
#  (86,
#   1,
#   '강남논현',
#   '강남구',
#   '서울특별시 강남구 강남대로 512 (논현동)',
#   Decimal('37.50789785962540'),
#   Decimal('127.02333861464400')),
#  (87,
#   1,
#   '삼성동',
#   '강남구',
#   '서울특별시 강남구 영동대로96길 12 (삼성동)',
#   Decimal('37.51084336612153'),
#   Decimal('127.06363342044263')),
#  (88,
#   1,
#   '청담역',
#   '강남구',
#   '서울특별시 강남구 삼성로 709 (청담동)',
#   Decimal('37.51944073234780'),
#   Decimal('127.04955266154200')),
#  (89,
#   1,
#   '역삼이마트',
#   '강남구',
#   '서울특별시 강남구 역삼로 310 (역삼동)',
#   Decimal('37.49936700000000'),
#   Decimal('127.04842500000000')),
#  (90,
#   1,
#   '미아뉴타운',
#   '강북구',
#   '서울특별시 강북구 삼양로 161 (미아동)',
#   Decimal('37.61831900000000'),
#   Decimal('127.02107200000000')),
#  (91,
#   1,
#   '강북구청사거리',
#   '강북구',
#   '서울특별시 강북구 도봉로 365 (수유동)',
#   Decimal('37.64003540000000'),
#   Decimal('127.02737660000000')),
#  (92,
#   1,
#   '미아사거리역',
#   '강북구',
#   '서울특별시 강북구 도봉로 32 (미아동)',
#   Decimal('37.61180900000000'),
#   Decimal('127.03069710000000')),
#  (93,
#   1,
#   '수유역',
#   '강북구',
#   '서울특별시 강북구 도봉로 342 (번동)',
#   Decimal('37.63801670000000'),
#   Decimal('127.02613500000007')),
#  (94,
#   1,
#   '미아역',
#   '강북구',
#   '서울특별시 강북구 도봉로 196 (미아동)',
#   Decimal('37.62614800000000'),
#   Decimal('127.02657800000000')),
#  (95,
#   1,
#   '파라스파라서울',
#   '강북구',
#   '서울특별시 강북구 삼양로 689 (우이동) 파라스파라서울 지하1층',
#   Decimal('37.66438007461800'),
#   Decimal('127.00856646710100')),
#  (96,
#   1,
#   '발산역사거리',
#   '강서구',
#   '서울특별시 강서구 공항대로 248 (마곡동)',
#   Decimal('37.55850900000000'),
#   Decimal('126.83509600000000')),
#  (97,
#   1,
#   '마곡역',
#   '강서구',
#   '서울특별시 강서구 공항대로 168 (마곡동)',
#   Decimal('37.55961100000000'),
#   Decimal('126.82629800000000')),
#  (98,
#   1,
#   '우장산역',
#   '강서구',
#   '서울특별시 강서구 강서로 267 (내발산동)',
#   Decimal('37.54950100000000'),
#   Decimal('126.83598400000000')),
#  (99,
#   1,
#   '마곡사이언스타워R',
#   '강서구',
#   '서울특별시 강서구 마곡동로 62 (마곡동)',
#   Decimal('37.56052610000000'),
#   Decimal('126.83388700000000')),
#  (100,
#   1,
#   '방화DT',
#   '강서구',
#   '서울특별시 강서구 방화대로 375 (방화동)',
#   Decimal('37.57433900000000'),
#   Decimal('126.81641500000000')),
#  (101,
#   1,
#   '마곡나루역',
#   '강서구',
#   '서울특별시 강서구 마곡중앙로 161-17 (마곡동)',
#   Decimal('37.56813000000000'),
#   Decimal('126.82614000000000')),
#  (102,
#   1,
#   '마곡GMG',
#   '강서구',
#   '서울특별시 강서구 마곡중앙6로 16 (마곡동) 117,118,119,120호',
#   Decimal('37.56048700000000'),
#   Decimal('126.82966700000000')),
#  (103,
#   1,
#   '가양역',
#   '강서구',
#   '서울특별시 강서구 양천로 476 (등촌동)',
#   Decimal('37.56164000000000'),
#   Decimal('126.85332700000000')),
#  (104,
#   1,
#   '화곡DT',
#   '강서구',
#   '서울특별시 강서구 등촌로 57 (화곡동)',
#   Decimal('37.53514900000000'),
#   Decimal('126.86323200000000')),
#  (105,
#   1,
#   '양천향교역',
#   '강서구',
#   '서울특별시 강서구 강서로 463 (마곡동)',
#   Decimal('37.56696400000000'),
#   Decimal('126.84073100000000')),
#  (106,
#   1,
#   '화곡동',
#   '강서구',
#   '서울특별시 강서구 화곡로 142(화곡동)',
#   Decimal('37.54051150000000'),
#   Decimal('126.83724130000000')),
#  (107,
#   1,
#   '등촌',
#   '강서구',
#   '서울특별시 강서구 공항대로 329 (등촌동)',
#   Decimal('37.55820430000000'),
#   Decimal('126.84433919999992')),
#  (108,
#   1,
#   '염창역',
#   '강서구',
#   '서울특별시 강서구 공항대로 627 (염창동)',
#   Decimal('37.54735900000000'),
#   Decimal('126.87443600000000')),
#  (109,
#   1,
#   '발산역',
#   '강서구',
#   '서울특별시 강서구 강서로 388 (등촌동) 그랜드마트',
#   Decimal('37.56033000000000'),
#   Decimal('126.83927900000000')),
#  (110,
#   1,
#   '까치산역',
#   '강서구',
#   '서울특별시 강서구 강서로13길 3 (화곡동)',
#   Decimal('37.53230300000000'),
#   Decimal('126.84607700000000')),
#  (111,
#   1,
#   '발산역5번출구',
#   '강서구',
#   '서울특별시 강서구 강서로52길 43 (내발산동, DH647), 1층 일부',
#   Decimal('37.55792247399770'),
#   Decimal('126.84054030692000')),
#  (112,
#   1,
#   '화곡역8번출구',
#   '강서구',
#   '서울특별시 강서구 강서로 179 (화곡동), 1층 일부',
#   Decimal('37.54251400000000'),
#   Decimal('126.83906200000000')),
#  (113,
#   1,
#   '강서우장산',
#   '강서구',
#   '서울특별시 강서구 강서로 231 (화곡동, 우장산역 해링턴 타워), 116/117/118/119/120호',
#   Decimal('37.54630500000000'),
#   Decimal('126.83592300000000')),
#  (114,
#   1,
#   '등촌대로',
#   '강서구',
#   '서울특별시 강서구 공항대로 543 (염창동, 센터스퀘어)',
#   Decimal('37.55101000000000'),
#   Decimal('126.86638000000000')),
#  (115,
#   1,
#   '가양역사거리',
#   '강서구',
#   '서울특별시 강서구 화곡로 416 (등촌동) 가양더스카이벨리5차 지식산업센터 101, 102, 114,~117호',
#   Decimal('37.56007000000000'),
#   Decimal('126.85537200000000')),
#  (116,
#   1,
#   '내발산',
#   '강서구',
#   '서울특별시 강서구 강서로 323 (내발산동), 101/102호',
#   Decimal('37.55467000000000'),
#   Decimal('126.83672000000000')),
#  (117,
#   1,
#   '마곡웰튼',
#   '강서구',
#   '서울특별시 강서구 마곡중앙5로 22 (마곡동), 104/105/106호',
#   Decimal('37.56754000000000'),
#   Decimal('126.82553000000000')),
#  (118,
#   1,
#   '김포공항DT',
#   '강서구',
#   '서울특별시 강서구 개화동로 517 (방화동)',
#   Decimal('37.56639600000000'),
#   Decimal('126.80608000000000')),
#  (119,
#   1,
#   '강서NC',
#   '강서구',
#   '서울특별시 강서구 강서로56길 17 (등촌동)',
#   Decimal('37.56008800000000'),
#   Decimal('126.84053400000000')),
#  (120,
#   1,
#   '마곡나루공원',
#   '강서구',
#   '서울특별시 강서구 마곡중앙5로 47 (마곡동)',
#   Decimal('37.56700700000000'),
#   Decimal('126.82224600000000')),
#  (121,
#   1,
#   '송정역',
#   '강서구',
#   '서울특별시 강서구 공항대로 38 (공항동), 1층 일부',
#   Decimal('37.56097361346000'),
#   Decimal('126.81155773497200')),
#  (122,
#   1,
#   '강서구청사거리',
#   '강서구',
#   '서울특별시 강서구 화곡로 350 (화곡동)',
#   Decimal('37.55492660000000'),
#   Decimal('126.85231330000000')),
#  (123,
#   1,
#   '낙성대역',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1908 (봉천동)',
#   Decimal('37.47794600000000'),
#   Decimal('126.96119300000000')),
#  (124,
#   1,
#   '관악서울대입구R',
#   '관악구',
#   '서울특별시 관악구 관악로 158 (봉천동)',
#   Decimal('37.47934300000000'),
#   Decimal('126.95278000000000')),
#  (125,
#   1,
#   '신림DT',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1419 (신림동)',
#   Decimal('37.48093500000000'),
#   Decimal('126.90840700000000')),
#  (126,
#   1,
#   '서울대역',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1817 (봉천동)',
#   Decimal('37.48159900000000'),
#   Decimal('126.95220000000000')),
#  (127,
#   1,
#   '낙성대DT',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1948 (봉천동)',
#   Decimal('37.47616900000000'),
#   Decimal('126.96500500000000')),
#  (128,
#   1,
#   '사당',
#   '관악구',
#   '서울특별시 관악구 남부순환로 2082-25',
#   Decimal('37.47601000000000'),
#   Decimal('126.98099700000000')),
#  (129,
#   1,
#   '보라매대교',
#   '관악구',
#   '서울특별시 관악구 보라매로3길 23 (봉천동) 1층',
#   Decimal('37.49144900000000'),
#   Decimal('126.92543200000000')),
#  (130,
#   1,
#   '신림',
#   '관악구',
#   '서울특별시 관악구 신림로 355-1 (신림동)',
#   Decimal('37.48609493000000'),
#   Decimal('126.92916020000000')),
#  (131,
#   1,
#   '신림타임스트림',
#   '관악구',
#   '서울특별시 관악구 신림로 330 타임스트림 1층',
#   Decimal('37.48385383000000'),
#   Decimal('126.93017990000000')),
#  (132,
#   1,
#   '서울대입구역',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1812 (봉천동)',
#   Decimal('37.48118000000000'),
#   Decimal('126.95132400000000')),
#  (133,
#   1,
#   '서울대입구역8번출구',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1831 (봉천동)',
#   Decimal('37.48120610000000'),
#   Decimal('126.95369420000000')),
#  (134,
#   1,
#   '봉천역',
#   '관악구',
#   '서울특별시 관악구 남부순환로 1730 (봉천동)',
#   Decimal('37.48203753400640'),
#   Decimal('126.94228779253800')),
#  (135,
#   1,
#   '건국대',
#   '광진구',
#   '서울특별시 광진구 능동로 117 (화양동)',
#   Decimal('37.54155920000000'),
#   Decimal('127.07112440000000')),
#  (136,
#   1,
#   '어린이대공원역',
#   '광진구',
#   '서울특별시 광진구 능동로 243 (군자동)',
#   Decimal('37.55194600000000'),
#   Decimal('127.07640400000000')),
#  (137,
#   1,
#   '아차산역',
#   '광진구',
#   '서울특별시 광진구 천호대로 676 (구의동)',
#   Decimal('37.55053880000000'),
#   Decimal('127.08987570000000')),
#  (138,
#   1,
#   '올림픽대교북단',
#   '광진구',
#   '서울특별시 광진구 광나루로 608 (구의동)',
#   Decimal('37.54112900000000'),
#   Decimal('127.09524000000000')),
#  (139,
#   1,
#   '구의DT',
#   '광진구',
#   '서울특별시 광진구 광나루로 519 (구의동)',
#   Decimal('37.54519840000000'),
#   Decimal('127.08715870000000')),
#  (140,
#   1,
#   '자양사거리',
#   '광진구',
#   '서울특별시 광진구 아차산로 355',
#   Decimal('37.53711580000000'),
#   Decimal('127.08258210000000')),
#  (141,
#   1,
#   '군자역',
#   '광진구',
#   '서울특별시 광진구 천호대로 548 (군자동) 중앙빌딩',
#   Decimal('37.55696500000000'),
#   Decimal('127.07903200000000')),
#  (142,
#   1,
#   '광나루',
#   '광진구',
#   '서울특별시 광진구 아차산로 607, 1,2층 (광장동)',
#   Decimal('37.54744200000000'),
#   Decimal('127.10593400000000')),
#  (143,
#   1,
#   '건대스타시티',
#   '광진구',
#   '서울특별시 광진구 아차산로 262 (자양동)',
#   Decimal('37.53854400000000'),
#   Decimal('127.07300900000000')),
#  (144,
#   1,
#   '건대입구',
#   '광진구',
#   '서울특별시 광진구 능동로 107 (화양동)',
#   Decimal('37.54066040000000'),
#   Decimal('127.07072249999999')),
#  (145,
#   1,
#   '구의역',
#   '광진구',
#   '서울특별시 광진구 아차산로 373 (구의동)',
#   Decimal('37.53698000000000'),
#   Decimal('127.08401500000000')),
#  (146,
#   1,
#   '광장',
#   '광진구',
#   '서울특별시 광진구 아차산로 537-17 (광장동)',
#   Decimal('37.54251800000000'),
#   Decimal('127.09965100000000')),
#  (147,
#   1,
#   '건국클래식',
#   '광진구',
#   '서울특별시 광진구 능동로 90 (자양동) 더 클래식500',
#   Decimal('37.53846600000000'),
#   Decimal('127.07127100000000')),
#  (148,
#   1,
#   '건대후문',
#   '광진구',
#   '서울특별시 광진구 능동로 172 (화양동)',
#   Decimal('37.54601801384760'),
#   Decimal('127.07400118174400')),
#  (149,
#   1,
#   '중곡역',
#   '광진구',
#   '서울특별시 광진구 능동로 400 (중곡동) 1층 108,109,110,111,112,118 6개호실',
#   Decimal('37.56501095087320'),
#   Decimal('127.08459679908000')),
#  (150,
#   1,
#   '자양이마트',
#   '광진구',
#   '서울특별시 광진구 아차산로 272 (자양동) 지하1층',
#   Decimal('37.53781700000000'),
#   Decimal('127.07259700000000')),
#  (151,
#   1,
#   '뚝섬유원지역',
#   '광진구',
#   '서울특별시 광진구 능동로 18 (자양동, 이튼타워리버3차)',
#   Decimal('37.53268464047900'),
#   Decimal('127.06787850355700')),
#  (152,
#   1,
#   '군자사거리',
#   '광진구',
#   '서울특별시 광진구 천호대로 549 (중곡동) 1층',
#   Decimal('37.55756660000000'),
#   Decimal('127.07933400000000')),
#  (153,
#   1,
#   '금천구청역',
#   '금천구',
#   '서울특별시 금천구 시흥대로73길 67 (시흥동), 엠메디컬타워 1층',
#   Decimal('37.45598300000000'),
#   Decimal('126.89572700000000')),
#  (154,
#   1,
#   '가산에스케이',
#   '금천구',
#   '서울특별시 금천구 가산디지털1로 171 (가산동), SK V1센터 1층',
#   Decimal('37.48061318000000'),
#   Decimal('126.88057020000000')),
#  (155,
#   1,
#   '독산사거리',
#   '금천구',
#   '서울특별시 금천구 시흥대로 426 (독산동)',
#   Decimal('37.47152832874549'),
#   Decimal('126.89856062315228')),
#  (156,
#   1,
#   '금천시흥',
#   '금천구',
#   '서울특별시 금천구 시흥대로 164 (시흥동)',
#   Decimal('37.44862400000000'),
#   Decimal('126.90318300000000')),
#  (157,
#   1,
#   '가산디지털단지역',
#   '금천구',
#   '서울특별시 금천구 벚꽃로 298 (가산동), 대륭포스트타워 6차 1층',
#   Decimal('37.48132400000000'),
#   Decimal('126.88377900000000')),
#  (158,
#   1,
#   '금천독산',
#   '금천구',
#   '서울특별시 금천구 두산로 70 (독산동)',
#   Decimal('37.46914000000000'),
#   Decimal('126.89524600000000')),
#  (159,
#   1,
#   '가산디지털',
#   '금천구',
#   '서울특별시 금천구 가산디지털1로 168 (가산동), 우림라이온스밸리 B동 1층',
#   Decimal('37.47983460000000'),
#   Decimal('126.88249969999992')),
#  (160,
#   1,
#   '마리오아울렛',
#   '금천구',
#   '서울특별시 금천구 벚꽃로 266 마리오아울렛3관',
#   Decimal('37.47870100000000'),
#   Decimal('126.88507600000000')),
#  (161,
#   1,
#   '가산브이타워',
#   '금천구',
#   '서울특별시 금천구 가산디지털1로 128 (가산동), V-TOWER 1층',
#   Decimal('37.47722100000000'),
#   Decimal('126.88368300000000')),
#  (162,
#   1,
#   '가산그레이트',
#   '금천구',
#   '서울특별시 금천구 디지털로9길 32, 갑을그레이트밸리 1층 (가산동)',
#   Decimal('37.47944910000000'),
#   Decimal('126.88747680000006')),
#  (163,
#   1,
#   '독산역',
#   '금천구',
#   '서울특별시 금천구 가산디지털1로 16 (가산동), 107-2, 108, 109호',
#   Decimal('37.46764460000000'),
#   Decimal('126.88766980000000')),
#  (164,
#   1,
#   '가산현대아울렛',
#   '금천구',
#   '서울특별시 금천구 디지털로10길 9 (가산동), 1층 일부',
#   Decimal('37.47758100000000'),
#   Decimal('126.88860300000000')),
#  (165,
#   1,
#   '가산케이에스',
#   '금천구',
#   '서울특별시 금천구 벚꽃로36길 30 (가산동), 가산KS타워 1층',
#   Decimal('37.48070713776140'),
#   Decimal('126.88509976016700')),
#  (166,
#   1,
#   '월계역',
#   '노원구',
#   '서울특별시 노원구 초안산로2라길26 월계동(104,105,106호)',
#   Decimal('37.62950000000000'),
#   Decimal('127.05740000000000')),
#  (167,
#   1,
#   '월계트레이더스',
#   '노원구',
#   '서울특별시 노원구 마들로3길 15 (월계동)',
#   Decimal('37.62770530000000'),
#   Decimal('127.06149779999998')),
#  (168,
#   1,
#   '상계초교사거리',
#   '노원구',
#   '서울특별시 노원구 노원로 449 (상계동)',
#   Decimal('37.65677600000000'),
#   Decimal('127.06644200000000')),
#  (169,
#   1,
#   '공릉DT',
#   '노원구',
#   '서울특별시 노원구 동일로 1015 (공릉동)',
#   Decimal('37.62068840000000'),
#   Decimal('127.07431160000000')),
#  (170,
#   1,
#   '노원마들역',
#   '노원구',
#   '서울특별시 노원구 노원로 569 (상계동, 임광아파트)',
#   Decimal('37.66094100000000'),
#   Decimal('127.05800800000000')),
#  (171,
#   1,
#   '공릉역',
#   '노원구',
#   '서울특별시 노원구 동일로 1081 (공릉동)',
#   Decimal('37.62633700000000'),
#   Decimal('127.07225200000000')),
#  (172,
#   1,
#   '은행사거리',
#   '노원구',
#   '서울특별시 노원구 중계로 217, 중흥빌딩 103,203호 (중계동)',
#   Decimal('37.65048737000000'),
#   Decimal('127.07598610000000')),
#  (173,
#   1,
#   '노원KT',
#   '노원구',
#   '서울특별시 노원구 노해로 502, (주)KT 노원사옥 (상계동)',
#   Decimal('37.65456200000000'),
#   Decimal('127.06361700000000')),
#  (174,
#   1,
#   '광운대',
#   '노원구',
#   '서울특별시 노원구 석계로 104 (월계동)',
#   Decimal('37.62314790000000'),
#   Decimal('127.06070090000003')),
#  (175,
#   1,
#   '중계역',
#   '노원구',
#   '서울특별시 노원구 동일로 1339, 대한빌딩 (상계동)',
#   Decimal('37.64817000000000'),
#   Decimal('127.06224400000000')),
#  (176,
#   1,
#   '노원역',
#   '노원구',
#   '서울특별시 노원구 동일로 1413 (상계동) 1층',
#   Decimal('37.65475100000000'),
#   Decimal('127.06003400000000')),
#  (177,
#   1,
#   '월계이마트',
#   '노원구',
#   '서울특별시 노원구 마들로3길 15 (월계동)',
#   Decimal('37.62715500000000'),
#   Decimal('127.06209400000000')),
#  (178,
#   1,
#   '태릉입구역DT',
#   '노원구',
#   '서울특별시 노원구 화랑로 469 (공릉동)',
#   Decimal('37.61942000000000'),
#   Decimal('127.07932000000000')),
#  (179,
#   1,
#   '노원상계',
#   '노원구',
#   '서울특별시 노원구 동일로215길 2 (상계동)',
#   Decimal('37.65153500000000'),
#   Decimal('127.06102600000000')),
#  (180,
#   1,
#   '창동이마트',
#   '도봉구',
#   '서울특별시 도봉구 노해로65길 4 (창동)',
#   Decimal('37.65164500000000'),
#   Decimal('127.04686900000000')),
#  (181,
#   1,
#   '쌍문역',
#   '도봉구',
#   '서울특별시 도봉구 도봉로 480 (창동)',
#   Decimal('37.64845600000000'),
#   Decimal('127.03478300000000')),
#  (182,
#   1,
#   '쌍문도봉로',
#   '도봉구',
#   '서울특별시 도봉구 도봉로 444 (창동)',
#   Decimal('37.64535160000000'),
#   Decimal('127.03310110000000')),
#  (183,
#   1,
#   '도봉로DT',
#   '도봉구',
#   '서울특별시 도봉구 도봉로 635 (쌍문동)',
#   Decimal('37.66118059290410'),
#   Decimal('127.04163006595700')),
#  (184,
#   1,
#   '방학역',
#   '도봉구',
#   '서울특별시 도봉구 도봉로 684 (방학동)101,102,113,114,115호',
#   Decimal('37.66531250000000'),
#   Decimal('127.04331250000000')),
#  (185,
#   1,
#   '창동역',
#   '도봉구',
#   '서울특별시 도봉구 마들로13길 61 (창동)',
#   Decimal('37.65450210559090'),
#   Decimal('127.04967253360700')),
#  (186,
#   1,
#   '노량진동',
#   '동작구',
#   '서울특별시 동작구 노량진로 190 (노량진동, 고려교육타워-어바니엘한강) 101호~105호',
#   Decimal('37.51306800000000'),
#   Decimal('126.94653700000000')),
#  (187,
#   1,
#   '남성역',
#   '동작구',
#   '서울특별시 동작구 사당로 219 (사당동)',
#   Decimal('37.48411980000000'),
#   Decimal('126.97257390000000')),
#  (188,
#   1,
#   '상도역',
#   '동작구',
#   '서울특별시 동작구 상도로37길 1 (상도1동)',
#   Decimal('37.50319360000000'),
#   Decimal('126.94845810000000')),
#  (189,
#   1,
#   '보라매공원R',
#   '동작구',
#   '서울특별시 동작구 보라매로5길 35 (신대방동, 파크스퀘어,보라매현대APT)',
#   Decimal('37.49226212712864'),
#   Decimal('126.92334570798292')),
#  (190,
#   1,
#   '이수자이',
#   '동작구',
#   '서울특별시 동작구 사당로 300 (사당동 이수자이)',
#   Decimal('37.48441400000000'),
#   Decimal('126.98004700000000')),
#  (191,
#   1,
#   '노량진역',
#   '동작구',
#   '서울특별시 동작구 노량진로 134 (노량진동)',
#   Decimal('37.51339000000000'),
#   Decimal('126.94087900000000')),
#  (192,
#   1,
#   '신대방삼거리역',
#   '동작구',
#   '서울특별시 동작구 상도로 102 (상도동)',
#   Decimal('37.49991400000000'),
#   Decimal('126.93176600000000')),
#  (193,
#   1,
#   '중앙대',
#   '동작구',
#   '서울특별시 동작구 흑석로 75-1 (흑석동)',
#   Decimal('37.50693300000000'),
#   Decimal('126.95812500000000')),
#  (194,
#   1,
#   '숭실대입구역',
#   '동작구',
#   '서울특별시 동작구 상도로 354 (상도동)',
#   Decimal('37.49683460000000'),
#   Decimal('126.95271230000003')),
#  (195,
#   1,
#   '숭실대',
#   '동작구',
#   '서울특별시 동작구 사당로 4 (상도동)',
#   Decimal('37.49538073000000'),
#   Decimal('126.95488910000000')),
#  (196,
#   1,
#   '사당역',
#   '동작구',
#   '서울특별시 동작구 동작대로 21, 양지빌딩 1-3층 (사당동)',
#   Decimal('37.47849216000000'),
#   Decimal('126.98134560000000')),
#  (197,
#   1,
#   '서강대프라자',
#   '마포구',
#   '서울특별시 마포구 백범로 35 (신수동)',
#   Decimal('37.55107300000000'),
#   Decimal('126.94309600000000')),
#  (198,
#   1,
#   '상암YTN',
#   '마포구',
#   '서울특별시 마포구 상암산로 76 (상암동)',
#   Decimal('37.57918300000000'),
#   Decimal('126.89231500000000')),
#  (199,
#   1,
#   '마포용강동',
#   '마포구',
#   '서울특별시 마포구 토정로 295 (용강동)',
#   Decimal('37.54118600000000'),
#   Decimal('126.94220900000000')),
#  (200,
#   1,
#   '홍대입구역사거리R',
#   '마포구',
#   '서울특별시 마포구 양화로 125 (서교동)',
#   Decimal('37.55463600000000'),
#   Decimal('126.92036000000000')),
#  (201,
#   1,
#   '마포경찰서후문',
#   '마포구',
#   '서울특별시 마포구 마포대로 173-14 (아현동)',
#   Decimal('37.55080000000000'),
#   Decimal('126.95343200000000')),
#  (202,
#   1,
#   '공덕',
#   '마포구',
#   '서울특별시 마포구 마포대로 130 (공덕동)',
#   Decimal('37.54591300000000'),
#   Decimal('126.95295600000000')),
#  (203,
#   1,
#   '합정폴리스R',
#   '마포구',
#   '서울특별시 마포구 양화로 45 (서교동, 메세나폴리스)',
#   Decimal('37.55090000000000'),
#   Decimal('126.91340000000000')),
#  (204,
#   1,
#   '홍대공항철도역',
#   '마포구',
#   '서울특별시 마포구 양화로 178 (동교동)',
#   Decimal('37.55749100000000'),
#   Decimal('126.92514600000000')),
#  (205,
#   1,
#   '마포염리',
#   '마포구',
#   '서울특별시 마포구 독막로 311 (염리동)',
#   Decimal('37.54387600000000'),
#   Decimal('126.94768000000000')),
#  (206,
#   1,
#   '서강광흥창역',
#   '마포구',
#   '서울특별시 마포구 서강로 69 (창전동)',
#   Decimal('37.54937700000000'),
#   Decimal('126.93166100000000')),
#  (207,
#   1,
#   '합정',
#   '마포구',
#   '서울특별시 마포구 월드컵로1길 14 (합정동) 마포한강푸르지오 110, 111, 112-2',
#   Decimal('37.54963000000000'),
#   Decimal('126.91299900000000')),
#  (208,
#   1,
#   '서강대흥역',
#   '마포구',
#   '서울특별시 마포구 백범로 89-5 (대흥동)',
#   Decimal('37.54817800000000'),
#   Decimal('126.94157600000000')),
#  (209,
#   1,
#   '서교동사거리',
#   '마포구',
#   '서울특별시 마포구 양화로 105 (서교동)',
#   Decimal('37.55337600000000'),
#   Decimal('126.91856400000000')),
#  (210,
#   1,
#   '상암사보이시티',
#   '마포구',
#   '서울특별시 마포구 월드컵북로54길 17 (상암동)',
#   Decimal('37.58147000000000'),
#   Decimal('126.88898300000000')),
#  (211,
#   1,
#   '신촌오거리',
#   '마포구',
#   '서울특별시 마포구 신촌로16길 10 (노고산동)',
#   Decimal('37.55513700000000'),
#   Decimal('126.93469400000000')),
#  (212,
#   1,
#   '상암디지털큐브',
#   '마포구',
#   '서울특별시 마포구 상암산로 34',
#   Decimal('37.57631320000000'),
#   Decimal('126.88924770000000')),
#  (213,
#   1,
#   '상수역',
#   '마포구',
#   '서울특별시 마포구 독막로 88 (상수동)',
#   Decimal('37.54748170000000'),
#   Decimal('126.92321579999998')),
#  (214,
#   1,
#   '공덕오거리',
#   '마포구',
#   '서울특별시 마포구 마포대로 86 (도화동) 창강빌딩',
#   Decimal('37.54246410000000'),
#   Decimal('126.95057730000008')),
#  (215,
#   1,
#   '서강대',
#   '마포구',
#   '서울특별시 마포구 백범로 23 (신수동)',
#   Decimal('37.55245840000000'),
#   Decimal('126.93782620000000')),
#  (216,
#   1,
#   '상암MBC',
#   '마포구',
#   '서울특별시 마포구 성암로 267 (상암동)',
#   Decimal('37.58129700000000'),
#   Decimal('126.89090800000000')),
#  (217,
#   1,
#   '홍대역',
#   '마포구',
#   '서울특별시 마포구 양화로 165, 상진빌딩 1층 (동교동)',
#   Decimal('37.55717500000000'),
#   Decimal('126.92365400000000')),
#  (218,
#   1,
#   '동교',
#   '마포구',
#   '서울특별시 마포구 월드컵북로 22, 영준빌딩 1층 (동교동)',
#   Decimal('37.55692800000000'),
#   Decimal('126.91981900000000')),
#  (219,
#   1,
#   '애오개역',
#   '마포구',
#   '서울특별시 마포구 마포대로 201, 마포트라팰리스II (아현동)',
#   Decimal('37.55218737000000'),
#   Decimal('126.95552030000000')),
#  (220,
#   1,
#   '상암DMC',
#   '마포구',
#   '서울특별시 마포구 월드컵북로 375, DMC이안오피스텔1단지 102호,202호 (상암동)',
#   Decimal('37.57762300000000'),
#   Decimal('126.89068400000000')),
#  (221,
#   1,
#   '마포일진빌딩',
#   '마포구',
#   '서울특별시 마포구 마포대로 45, 일진빌딩 1층 (도화동)',
#   Decimal('37.54043451000000'),
#   Decimal('126.94631680000000')),
#  (222,
#   1,
#   '마포아크로',
#   '마포구',
#   '서울특별시 마포구 마포대로 68 (도화동) 마포아크로타워',
#   Decimal('37.54145556000000'),
#   Decimal('126.94881900000000')),
#  (223,
#   1,
#   '홍대삼거리',
#   '마포구',
#   '서울특별시 마포구 와우산로 64 (상수동)',
#   Decimal('37.55026600000000'),
#   Decimal('126.92317900000000')),
#  (224,
#   1,
#   '망원역',
#   '마포구',
#   '서울특별시 마포구 월드컵로 74 (서교동)',
#   Decimal('37.55582900000000'),
#   Decimal('126.91063700000000')),
#  (225,
#   1,
#   '마포이마트',
#   '마포구',
#   '서울특별시 마포구 백범로 212 (신공덕동) 마포이마트',
#   Decimal('37.54242100000000'),
#   Decimal('126.95334100000000')),
#  (226,
#   1,
#   '합정메세나몰',
#   '마포구',
#   '서울특별시 마포구 양화로 45 (서교동, 메세나폴리스)',
#   Decimal('37.55100400000000'),
#   Decimal('126.91384800000000')),
#  (227,
#   1,
#   '아현역대로',
#   '마포구',
#   '서울특별시 마포구 신촌로 262 (아현동)',
#   Decimal('37.55709700000000'),
#   Decimal('126.95483400000000')),
#  (228,
#   1,
#   '디지털미디어시티역',
#   '마포구',
#   '서울특별시 마포구 성암로 179 (상암동)',
#   Decimal('37.57609000000000'),
#   Decimal('126.89897000000000')),
#  (229,
#   1,
#   '홍대역8번출구',
#   '마포구',
#   '서울특별시 마포구 양화로 166 (동교동)',
#   Decimal('37.55674350359900'),
#   Decimal('126.92416654360800')),
#  (230,
#   1,
#   '합정푸르지오',
#   '마포구',
#   '서울특별시 마포구 월드컵로3길 14 (합정동, 마포 한강 2차 푸르지오)',
#   Decimal('37.55109819950203'),
#   Decimal('126.91230706916590')),
#  (231,
#   1,
#   '홍대동교',
#   '마포구',
#   '서울특별시 마포구 양화로 192 (동교동)',
#   Decimal('37.55832805333290'),
#   Decimal('126.92624650187600')),
#  (232,
#   1,
#   '망원한강공원',
#   '마포구',
#   '서울특별시 마포구 마포나루길 435 (망원동)',
#   Decimal('37.55456250000000'),
#   Decimal('126.89568750000000')),
#  (233,
#   1,
#   '가재울뉴타운',
#   '서대문구',
#   '서울특별시 서대문구 가재울미래로 2 (남가좌동, DMC파크뷰자이)',
#   Decimal('37.57498410000000'),
#   Decimal('126.91644410000000')),
#  (234,
#   1,
#   '남가좌사거리',
#   '서대문구',
#   '서울특별시 서대문구 거북골로 84 (남가좌동, DMC에코자이104동)',
#   Decimal('37.57738600000000'),
#   Decimal('126.92081500000000')),
#  (235,
#   1,
#   '신촌역',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 73 (창천동)',
#   Decimal('37.55616700000000'),
#   Decimal('126.93467300000000')),
#  (236,
#   1,
#   '연희동',
#   '서대문구',
#   '서울특별시 서대문구 연희로 97 (연희동)',
#   Decimal('37.56670200000000'),
#   Decimal('126.93047500000000')),
#  (237,
#   1,
#   '아현역',
#   '서대문구',
#   '서울특별시 서대문구 신촌로35길 10 (북아현동, e편한세상신촌 4단지)',
#   Decimal('37.55842100000000'),
#   Decimal('126.95634900000000')),
#  (238,
#   1,
#   '홍제역',
#   '서대문구',
#   '서울특별시 서대문구 통일로 451 (홍제동)',
#   Decimal('37.58865800000000'),
#   Decimal('126.94386400000000')),
#  (239,
#   1,
#   '연세백양로',
#   '서대문구',
#   '서울특별시 서대문구 연세로 50 (신촌동) 연세대학교',
#   Decimal('37.56264400000000'),
#   Decimal('126.93752900000000')),
#  (240,
#   1,
#   '연희DT',
#   '서대문구',
#   '서울특별시 서대문구 연희로 144 (연희동)',
#   Decimal('37.57021430000000'),
#   Decimal('126.93397770000000')),
#  (241,
#   1,
#   '경기대',
#   '서대문구',
#   '서울특별시 서대문구 충정로 53 (충정로2가)',
#   Decimal('37.56367995000000'),
#   Decimal('126.96460450000000')),
#  (242,
#   1,
#   '신촌',
#   '서대문구',
#   '서울특별시 서대문구 연세로 10-1 (창천동)',
#   Decimal('37.55648577000000'),
#   Decimal('126.93711550000000')),
#  (243,
#   1,
#   '이대R',
#   '서대문구',
#   '서울특별시 서대문구 이화여대길 34 (대현동)',
#   Decimal('37.55848315000000'),
#   Decimal('126.94596430000000')),
#  (244,
#   1,
#   '연세종합관',
#   '서대문구',
#   '서울특별시 서대문구 연세로 50, 연세세브란스 종합관 (신촌동)',
#   Decimal('37.56177145000000'),
#   Decimal('126.94147080000000')),
#  (245,
#   1,
#   '이대ECC',
#   '서대문구',
#   '서울특별시 서대문구 이화여대길 52 (대현동) 이화여자대학교 B415호',
#   Decimal('37.56163100000000'),
#   Decimal('126.94735000000000')),
#  (246,
#   1,
#   '연대',
#   '서대문구',
#   '서울특별시 서대문구 연세로 35 (창천동)',
#   Decimal('37.55870600000000'),
#   Decimal('126.93672700000000')),
#  (247,
#   1,
#   '신촌아트레온',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 129 (창천동)',
#   Decimal('37.55650500000000'),
#   Decimal('126.94023800000000')),
#  (248,
#   1,
#   '충정로역',
#   '서대문구',
#   '서울특별시 서대문구 충정로 23',
#   Decimal('37.56137000000000'),
#   Decimal('126.96321900000000')),
#  (249,
#   1,
#   '연대동문',
#   '서대문구',
#   '서울특별시 서대문구 성산로 565 (대신동)',
#   Decimal('37.56638500000000'),
#   Decimal('126.94627300000000')),
#  (250,
#   1,
#   '신촌명물거리',
#   '서대문구',
#   '서울특별시 서대문구 명물길 24, 1-5층 (창천동)',
#   Decimal('37.55779600000000'),
#   Decimal('126.93809500000000')),
#  (251,
#   1,
#   '충정타워',
#   '서대문구',
#   '서울특별시 서대문구 서소문로 21, 충정타워빌딩 1층 (충정로3가)',
#   Decimal('37.55986900000000'),
#   Decimal('126.96411000000000')),
#  (252,
#   1,
#   '이대역',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 183 (대현동)',
#   Decimal('37.55708610000000'),
#   Decimal('126.94628020000000')),
#  (253,
#   1,
#   '북가좌DT',
#   '서대문구',
#   '서울특별시 서대문구 응암로 85 (북가좌동)',
#   Decimal('37.58075800000000'),
#   Decimal('126.91147800000000')),
#  (254,
#   1,
#   '현대신촌',
#   '서대문구',
#   '서울특별시 서대문구 신촌로 83 (창천동)',
#   Decimal('37.55608305795150'),
#   Decimal('126.93584487650900')),
#  (255,
#   1,
#   '방배로',
#   '서초구',
#   '서울특별시 서초구 방배로 52 (방배동)',
#   Decimal('37.47934340000000'),
#   Decimal('126.99949680000000')),
#  (256,
#   1,
#   '강남교보타워R',
#   '서초구',
#   '서울특별시 서초구 강남대로 465 (서초동)',
#   Decimal('37.50378900000000'),
#   Decimal('127.02407500000000')),
#  (257,
#   1,
#   '방배다이치빌딩',
#   '서초구',
#   '서울특별시 서초구 방배로 114 (방배동)',
#   Decimal('37.48432900000000'),
#   Decimal('126.99587200000000')),
#  (258,
#   1,
#   '센트럴F1',
#   '서초구',
#   '서울특별시 서초구 신반포로 176 (반포동)',
#   Decimal('37.50514800000000'),
#   Decimal('127.00439500000000')),
#  (259,
#   1,
#   '서초역이화빌딩',
#   '서초구',
#   '서울특별시 서초구 반포대로21길 3 (서초동)',
#   Decimal('37.48793100000000'),
#   Decimal('127.00912600000000')),
#  (260,
#   1,
#   '서초구청',
#   '서초구',
#   '서울특별시 서초구 남부순환로 2557 (서초동)',
#   Decimal('37.48420600000000'),
#   Decimal('127.03010300000000')),
#  (261,
#   1,
#   '서초우성사거리',
#   '서초구',
#   '서울특별시 서초구 강남대로 343 (서초동)',
#   Decimal('37.49354500000000'),
#   Decimal('127.02943000000000')),
#  (262,
#   1,
#   '이수역사거리',
#   '서초구',
#   '서울특별시 서초구 서초대로 3-4 (방배동, 방배디오슈페리움1)',
#   Decimal('37.48585000000000'),
#   Decimal('126.98302700000000')),
#  (263,
#   1,
#   '강남대로신사',
#   '서초구',
#   '서울특별시 서초구 강남대로 595 (잠원동)',
#   Decimal('37.51489000000000'),
#   Decimal('127.01946900000000')),
#  (264,
#   1,
#   '서울고속터미널',
#   '서초구',
#   '서울특별시 서초구 신반포로 194 (반포동)',
#   Decimal('37.50440600000000'),
#   Decimal('127.00564800000000')),
#  (265,
#   1,
#   '강남대로논현R',
#   '서초구',
#   '서울특별시 서초구 강남대로85길 5 (반포동)',
#   Decimal('37.50741300000000'),
#   Decimal('127.02256800000000')),
#  (266,
#   1,
#   '방배',
#   '서초구',
#   '서울특별시 서초구 방배로 211',
#   Decimal('37.49191400000000'),
#   Decimal('126.99049739999998')),
#  (267,
#   1,
#   '방배카페거리',
#   '서초구',
#   '서울특별시 서초구 방배중앙로 162 (방배동)',
#   Decimal('37.49347670000000'),
#   Decimal('126.98652970000000')),
#  (268,
#   1,
#   '서초법원',
#   '서초구',
#   '서울특별시 서초구 서초대로 274 (서초동)',
#   Decimal('37.49297000000000'),
#   Decimal('127.01187500000000')),
#  (269,
#   1,
#   '청계산입구역',
#   '서초구',
#   '서울특별시 서초구 청계산로 203 (신원동)',
#   Decimal('37.44732300000000'),
#   Decimal('127.05625000000000')),
#  (270,
#   1,
#   '사당로데오',
#   '서초구',
#   '서울특별시 서초구 방배천로 5-4(방배동)',
#   Decimal('37.47727520000000'),
#   Decimal('126.98216049999996')),
#  (271,
#   1,
#   '파미에파크R',
#   '서초구',
#   '서울특별시 서초구 사평대로 205 (반포동) CENTRALCITY',
#   Decimal('37.50305210000000'),
#   Decimal('127.00436200000000')),
#  (272,
#   1,
#   '양재역',
#   '서초구',
#   '서울특별시 서초구 강남대로 202 (양재동) 모산빌딩',
#   Decimal('37.48204750000000'),
#   Decimal('127.03676820000000')),
#  (273,
#   1,
#   '논현역',
#   '서초구',
#   '서울특별시 서초구 강남대로 557 (잠원동) 1~2층',
#   Decimal('37.51119830000000'),
#   Decimal('127.02058750000000')),
#  (274,
#   1,
#   '이수역',
#   '서초구',
#   '서울특별시 서초구 동작대로 112 (방배동)',
#   Decimal('37.48646640000000'),
#   Decimal('126.98274029999993')),
#  (275,
#   1,
#   '내방역',
#   '서초구',
#   '서울특별시 서초구 방배로 184 (방배동) 대풍빌딩',
#   Decimal('37.49000400000000'),
#   Decimal('126.99245500000000')),
#  (276,
#   1,
#   '서초파라곤',
#   '서초구',
#   '서울특별시 서초구 서초대로74길 29 (서초동) 서초파라곤',
#   Decimal('37.49494100000000'),
#   Decimal('127.02742200000000')),
#  (277,
#   1,
#   '서울아트센터',
#   '서초구',
#   '서울특별시 서초구 남부순환로 2395 (서초동) 호경빌딩',
#   Decimal('37.48086600000000'),
#   Decimal('127.01236800000000')),
#  (278,
#   1,
#   '서초중앙로',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 225',
#   Decimal('37.50169100000000'),
#   Decimal('127.01152000000000')),
#  (279,
#   1,
#   '센트럴시티',
#   '서초구',
#   '서울특별시 서초구 신반포로 176 (반포동)',
#   Decimal('37.50470700000000'),
#   Decimal('127.00445900000000')),
#  (280,
#   1,
#   '강남삼성타운',
#   '서초구',
#   '서울특별시 서초구 서초대로78길 24 (서초동)',
#   Decimal('37.49562035000000'),
#   Decimal('127.02771440000000')),
#  (281,
#   1,
#   '방배역',
#   '서초구',
#   '서울특별시 서초구 방배로 84 (방배동)',
#   Decimal('37.48200755000000'),
#   Decimal('126.99764380000000')),
#  (282,
#   1,
#   '반포역',
#   '서초구',
#   '서울특별시 서초구 신반포로 257 (잠원동) 신반포11차상가',
#   Decimal('37.50858900000000'),
#   Decimal('127.01195900000000')),
#  (283,
#   1,
#   '남부터미널',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 26, 래미안서초유니빌 1층 101호 (서초동)',
#   Decimal('37.48467334000000'),
#   Decimal('127.01694640000000')),
#  (284,
#   1,
#   '뉴코아강남',
#   '서초구',
#   '서울특별시 서초구 잠원로 69 (잠원동) 킴스클럽',
#   Decimal('37.51031339000000'),
#   Decimal('127.00695820000000')),
#  (285,
#   1,
#   '강남2',
#   '서초구',
#   '서울특별시 서초구 서초대로77길 27, 유빌딩 1,2층 (서초동)',
#   Decimal('37.50008750000000'),
#   Decimal('127.02549090000002')),
#  (286,
#   1,
#   '교대',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 118 (서초동)',
#   Decimal('37.49236110000000'),
#   Decimal('127.01422070000000')),
#  (287,
#   1,
#   '하이브랜드',
#   '서초구',
#   '서울특별시 서초구 매헌로 16, 리빙관 101호 (양재동)',
#   Decimal('37.46330766000000'),
#   Decimal('127.03684470000000')),
#  (288,
#   1,
#   '신논현역',
#   '서초구',
#   '서울특별시 서초구 강남대로 483 (반포동) 청호빌딩',
#   Decimal('37.50529000000000'),
#   Decimal('127.02363600000000')),
#  (289,
#   1,
#   '영동2교',
#   '서초구',
#   '서울특별시 서초구 논현로 139, 대흥빌딩 (양재동)',
#   Decimal('37.48203954000000'),
#   Decimal('127.04257480000000')),
#  (290,
#   1,
#   '남부터미널2',
#   '서초구',
#   '서울특별시 서초구 효령로 274 (서초동)',
#   Decimal('37.48436736000000'),
#   Decimal('127.01421920000000')),
#  (291,
#   1,
#   '서래마을입구',
#   '서초구',
#   '서울특별시 서초구 서래로 48 (반포동)',
#   Decimal('37.49925284000000'),
#   Decimal('126.99848010000000')),
#  (292,
#   1,
#   '몬테소리',
#   '서초구',
#   '서울특별시 서초구 강남대로 399 (서초동)',
#   Decimal('37.49826950000000'),
#   Decimal('127.02686500000000')),
#  (293,
#   1,
#   '서초역',
#   '서초구',
#   '서울특별시 서초구 반포대로 118 (서초동)',
#   Decimal('37.49067495000000'),
#   Decimal('127.00861180000000')),
#  (294,
#   1,
#   '교대법원',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 164 (서초동)',
#   Decimal('37.49632900000000'),
#   Decimal('127.01333600000000')),
#  (295,
#   1,
#   '강남GT타워',
#   '서초구',
#   '서울특별시 서초구 서초대로 411, GT타워 (서초동)',
#   Decimal('37.49805600000000'),
#   Decimal('127.02583300000003')),
#  (296,
#   1,
#   '서초동',
#   '서초구',
#   '서울특별시 서초구 남부순환로339길 64, 현우빌딩 1층 (서초동)',
#   Decimal('37.48594100000000'),
#   Decimal('127.02152500000000')),
#  (297,
#   1,
#   '서울교대',
#   '서초구',
#   '서울특별시 서초구 서초중앙로 64, 1층 (서초동)',
#   Decimal('37.48739700000000'),
#   Decimal('127.01513400000000')),
#  (298,
#   1,
#   '강남에비뉴',
#   '서초구',
#   '서울특별시 서초구 서초대로77길 62, 강남역아이파크 B102~B105 (서초동)',
#   Decimal('37.50270000000000'),
#   Decimal('127.02389400000000')),
#  (299,
#   1,
#   '반포자이',
#   '서초구',
#   '서울특별시 서초구 잠원로 24 (반포동)',
#   Decimal('37.50717047534941'),
#   Decimal('127.00991890834830')),
#  (300,
#   1,
#   '강남역우송빌딩',
#   '서초구',
#   '서울특별시 서초구 서초대로73길 7 (서초동)',
#   Decimal('37.49813146014130'),
#   Decimal('127.02527908458000')),
#  (301,
#   1,
#   '서이초교사거리',
#   '서초구',
#   '서울특별시 서초구 사임당로 143 (서초동)',
#   Decimal('37.49181460000000'),
#   Decimal('127.02522520000000')),
#  (302,
#   1,
#   '서울웨이브아트센터',
#   '서초구',
#   '서울특별시 서초구 잠원로 145-35 (잠원동)',
#   Decimal('37.51880700000000'),
#   Decimal('127.00704000000000')),
#  (303,
#   1,
#   '길음역',
#   '성북구',
#   '서울특별시 성북구 정릉로 376 (돈암동)',
#   Decimal('37.60213900000000'),
#   Decimal('127.02527100000000')),
#  (304,
#   1,
#   '미아이마트',
#   '성북구',
#   '서울특별시 성북구 도봉로 17 (길음동)',
#   Decimal('37.61067800000000'),
#   Decimal('127.02992100000000')),
#  (305,
#   1,
#   '종암DT',
#   '성북구',
#   '서울특별시 성북구 종암로 17 (종암동)',
#   Decimal('37.59195250000000'),
#   Decimal('127.03604010000000')),
#  (306,
#   1,
#   '미아',
#   '성북구',
#   '서울특별시 성북구 동소문로 314 (하월곡동)',
#   Decimal('37.60758100000000'),
#   Decimal('127.02930300000000')),
#  (307,
#   1,
#   '성신여대정문',
#   '성북구',
#   '서울특별시 성북구 보문로34길 62 (동선동2가)',
#   Decimal('37.59091000000000'),
#   Decimal('127.01880000000000')),
#  (308,
#   1,
#   '종암',
#   '성북구',
#   '서울특별시 성북구 종암로 122 (종암동)',
#   Decimal('37.60109500000000'),
#   Decimal('127.03384700000000')),
#  (309,
#   1,
#   '삼선교',
#   '성북구',
#   '서울특별시 성북구 동소문로 10 (동소문동2가)',
#   Decimal('37.58869600000000'),
#   Decimal('127.00732070000003')),
#  (310,
#   1,
#   '월곡역',
#   '성북구',
#   '서울특별시 성북구 화랑로 76, 101-1호 (하월곡동)',
#   Decimal('37.60171800000000'),
#   Decimal('127.04044600000000')),
#  (311,
#   1,
#   '고대',
#   '성북구',
#   '서울특별시 성북구 고려대로24길 51 (안암동5가)',
#   Decimal('37.58397192000000'),
#   Decimal('127.02973520000000')),
#  (312,
#   1,
#   '현대미아',
#   '성북구',
#   '서울특별시 성북구 동소문로 315 (길음동) 지하1층',
#   Decimal('37.60837822000000'),
#   Decimal('127.02874830000000')),
#  (313,
#   1,
#   '성신여대',
#   '성북구',
#   '서울특별시 성북구 동소문로24길 12 (동선동1가)',
#   Decimal('37.59313500000000'),
#   Decimal('127.01837900000000')),
#  (314,
#   1,
#   '안암역',
#   '성북구',
#   '서울특별시 성북구 고려대로 102-2 (안암동5가)',
#   Decimal('37.58631900000000'),
#   Decimal('127.03055600000000')),
#  (315,
#   1,
#   '한성대입구역',
#   '성북구',
#   '서울특별시 성북구 성북로 11 (성북동1가)',
#   Decimal('37.58905400000000'),
#   Decimal('127.00483900000000')),
#  (316,
#   1,
#   '고대안암병원',
#   '성북구',
#   '서울특별시 성북구 고려대로 73 (안암동5가)',
#   Decimal('37.58687889805418'),
#   Decimal('127.02820333331364')),
#  (317,
#   1,
#   '장위뉴타운',
#   '성북구',
#   '서울특별시 성북구 장월로38길 4 (장위동)',
#   Decimal('37.61795689659980'),
#   Decimal('127.05153570977800')),
#  (318,
#   1,
#   '송파나루역DT',
#   '송파구',
#   '서울특별시 송파구 오금로 142 (송파동)',
#   Decimal('37.51079300000000'),
#   Decimal('127.11026580000000')),
#  (319,
#   1,
#   '송파헬리오시티',
#   '송파구',
#   '서울특별시 송파구 송파대로 345 (가락동, 헬리오시티)',
#   Decimal('37.49785630000000'),
#   Decimal('127.10313250000000')),
#  (320,
#   1,
#   '잠실시그마타워',
#   '송파구',
#   '서울특별시 송파구 올림픽로 289 (신천동)',
#   Decimal('37.51456700000000'),
#   Decimal('127.10249300000000')),
#  (321,
#   1,
#   '문정법원로R',
#   '송파구',
#   '서울특별시 송파구 송파대로 201 (문정동)',
#   Decimal('37.48744700000000'),
#   Decimal('127.11916400000000')),
#  (322,
#   1,
#   '송파개롱역',
#   '송파구',
#   '서울특별시 송파구 오금로 420 (가락동)',
#   Decimal('37.49695600000000'),
#   Decimal('127.13652000000000')),
#  (323,
#   1,
#   '문정하비오',
#   '송파구',
#   '서울특별시 송파구 송파대로 111 (문정동, 파크하비오) 204동 104호~107호',
#   Decimal('37.48192500000000'),
#   Decimal('127.12344600000000')),
#  (324,
#   1,
#   '문정역',
#   '송파구',
#   '서울특별시 송파구 송파대로 167 (문정동)테라타워 B동 137호~139호,204호',
#   Decimal('37.48481300000000'),
#   Decimal('127.12223700000000')),
#  (325,
#   1,
#   '잠실대교남단R',
#   '송파구',
#   '서울특별시 송파구 송파대로 570 타워 730 1층',
#   Decimal('37.51551100000000'),
#   Decimal('127.09900600000000')),
#  (326,
#   1,
#   '송파위례',
#   '송파구',
#   '서울특별시 송파구 위례광장로 230 (장지동, 위례2차아이파크)',
#   Decimal('37.47826400000000'),
#   Decimal('127.14406700000000')),
#  (327,
#   1,
#   '송파방이DT',
#   '송파구',
#   '서울특별시 송파구 오금로 241 (방이동)',
#   Decimal('37.50656400000000'),
#   Decimal('127.12049500000000')),
#  (328,
#   1,
#   '올림픽평화의문',
#   '송파구',
#   '서울특별시 송파구 위례성대로 38 (방이동) 해태그린피아빌라트',
#   Decimal('37.51564260000000'),
#   Decimal('127.11648190000005')),
#  (329,
#   1,
#   '송파아이파크',
#   '송파구',
#   '서울특별시 송파구 법원로 55 (문정동)',
#   Decimal('37.47989200000000'),
#   Decimal('127.12237900000000')),
#  (330,
#   1,
#   '송파사거리',
#   '송파구',
#   '서울특별시 송파구 송파대로 386 (송파동)',
#   Decimal('37.50227880000000'),
#   Decimal('127.11039040000000')),
#  (331,
#   1,
#   '석촌서호',
#   '송파구',
#   '서울특별시 송파구 석촌호수로 176 (삼전동)',
#   Decimal('37.50639290000000'),
#   Decimal('127.09646840000000')),
#  (332,
#   1,
#   '문정로데오',
#   '송파구',
#   '서울특별시 송파구 동남로 141 (가락동)',
#   Decimal('37.49190500000000'),
#   Decimal('127.12626960000000')),
#  (333,
#   1,
#   '올림픽훼미리',
#   '송파구',
#   '서울특별시 송파구 중대로 68 (문정동)',
#   Decimal('37.49162600000000'),
#   Decimal('127.11630800000000')),
#  (334,
#   1,
#   '올림픽공원남문',
#   '송파구',
#   '서울특별시 송파구 위례성대로 102 (방이동)',
#   Decimal('37.51330000000000'),
#   Decimal('127.12311300000000')),
#  (335,
#   1,
#   '방이역',
#   '송파구',
#   '서울특별시 송파구 마천로 53, 1~2층 (오금동)',
#   Decimal('37.50866600000000'),
#   Decimal('127.12656900000000')),
#  (336,
#   1,
#   '석촌호수',
#   '송파구',
#   '서울특별시 송파구 석촌호수로 262 (송파동)',
#   Decimal('37.50958100000000'),
#   Decimal('127.10499300000000')),
#  (337,
#   1,
#   '잠실푸르지오월드',
#   '송파구',
#   '서울특별시 송파구 올림픽로35가길 9, 잠실푸르지오월드마크 1층 (신천동)',
#   Decimal('37.51764900000000'),
#   Decimal('127.10342600000000')),
#  (338,
#   1,
#   '잠실새내역',
#   '송파구',
#   '서울특별시 송파구 올림픽로 96 (잠실동)',
#   Decimal('37.51167900000000'),
#   Decimal('127.08106200000000')),
#  (339,
#   1,
#   '잠실역',
#   '송파구',
#   '서울특별시 송파구 송파대로 562 (신천동, 웰리스타워,삼성웰리스아파트) 1층,2층',
#   Decimal('37.51527200000000'),
#   Decimal('127.09923100000000')),
#  (340,
#   1,
#   '갤러리아팰리스',
#   '송파구',
#   '서울특별시 송파구 올림픽로 212, 갤러리아 팰리스 (잠실동)',
#   Decimal('37.51108365000000'),
#   Decimal('127.09380590000000')),
#  (341,
#   1,
#   '아시아선수촌',
#   '송파구',
#   '서울특별시 송파구 백제고분로 69 (잠실동)',
#   Decimal('37.51059000000000'),
#   Decimal('127.07904700000000')),
#  (342,
#   1,
#   '올림픽아파트',
#   '송파구',
#   '서울특별시 송파구 양재대로 1220 (방이동)',
#   Decimal('37.51531500000000'),
#   Decimal('127.13323700000000')),
#  (343,
#   1,
#   '가락본동',
#   '송파구',
#   '서울특별시 송파구 송파대로30길 13 (가락동)',
#   Decimal('37.49489500000000'),
#   Decimal('127.11878500000000')),
#  (344,
#   1,
#   '석촌역',
#   '송파구',
#   '서울특별시 송파구 백제고분로 358, 1층 (석촌동)',
#   Decimal('37.50426260000000'),
#   Decimal('127.10610769999994')),
#  (345,
#   1,
#   '가락시장역',
#   '송파구',
#   '서울특별시 송파구 중대로 121, 롯데캐슬 파인힐 1층 (가락동)',
#   Decimal('37.49429900000000'),
#   Decimal('127.12135400000000')),
#  (346,
#   1,
#   '가든파이브',
#   '송파구',
#   '서울특별시 송파구 충민로 10 (문정동) 가든파이브툴',
#   Decimal('37.47823160000000'),
#   Decimal('127.11937030000001')),
#  (347,
#   1,
#   '잠실본동',
#   '송파구',
#   '서울특별시 송파구 백제고분로 91 (잠실동), 1층',
#   Decimal('37.50864458854420'),
#   Decimal('127.07949103207000')),
#  (348,
#   1,
#   '송파NC',
#   '송파구',
#   '서울특별시 송파구 충민로 66 (문정동)  가든파이브라이프 패션관1층',
#   Decimal('37.47787610000000'),
#   Decimal('127.12567478000000')),
#  (349,
#   1,
#   '송파거여역',
#   '송파구',
#   '서울특별시 송파구 오금로 493 (거여동)',
#   Decimal('37.49364895715680'),
#   Decimal('127.14369868888800')),
#  (350,
#   1,
#   '몽촌토성역',
#   '송파구',
#   '서울특별시 송파구 위례성대로 6 (방이동)',
#   Decimal('37.51691300000000'),
#   Decimal('127.11312700000000')),
#  (351,
#   1,
#   '송파KT',
#   '송파구',
#   '서울특별시 송파구 잠실로 209 (신천동), 오피스빌딩 1층 2~4호',
#   Decimal('37.51399910000000'),
#   Decimal('127.10630260000000')),
#  (352,
#   1,
#   '문정법조타운 한양타워',
#   '송파구',
#   '서울특별시 송파구 법원로11길 12 (문정동)',
#   Decimal('37.48599091628540'),
#   Decimal('127.11792183157400')),
#  (353,
#   1,
#   '송파마천사거리DT',
#   '송파구',
#   '서울특별시 송파구 거마로 78 (마천동)',
#   Decimal('37.49982900000000'),
#   Decimal('127.14767200000000')),
#  (354,
#   1,
#   '목동파리공원',
#   '양천구',
#   '서울특별시 양천구 목동동로 377 (목동)',
#   Decimal('37.53533600000000'),
#   Decimal('126.87885200000000')),
#  (355,
#   1,
#   '등촌역',
#   '양천구',
#   '서울특별시 양천구 공항대로 566 (목동) 1층 2층',
#   Decimal('37.54888400000000'),
#   Decimal('126.86807000000000')),
#  (356,
#   1,
#   '목동행복한',
#   '양천구',
#   '서울특별시 양천구 목동동로 309 (목동)',
#   Decimal('37.52914700000000'),
#   Decimal('126.87609900000000')),
#  (357,
#   1,
#   '신정DT',
#   '양천구',
#   '서울특별시 양천구 신월로 341 (신정동)',
#   Decimal('37.52199300000000'),
#   Decimal('126.85886500000000')),
#  (358,
#   1,
#   '목동역',
#   '양천구',
#   '서울특별시 양천구 목동로 203 (신정동) 1층일부',
#   Decimal('37.52668400000000'),
#   Decimal('126.86398600000000')),
#  (359,
#   1,
#   '목동오목로',
#   '양천구',
#   '서울특별시 양천구 오목로 279 (목동) 102,103,104,105호',
#   Decimal('37.52592300000000'),
#   Decimal('126.86843800000000')),
#  (360,
#   1,
#   '목동8단지',
#   '양천구',
#   '서울특별시 양천구 목동서로 299 (신정동)',
#   Decimal('37.52051800000000'),
#   Decimal('126.86884100000000')),
#  (361,
#   1,
#   '오목교역',
#   '양천구',
#   '서울특별시 양천구 오목로 354 (목동)',
#   Decimal('37.52358820000000'),
#   Decimal('126.87652120000007')),
#  (362,
#   1,
#   '신월IC DT',
#   '양천구',
#   '서울특별시 양천구 남부순환로 430 (신월동)',
#   Decimal('37.52949840000000'),
#   Decimal('126.83198300000000')),
#  (363,
#   1,
#   '목동7단지',
#   '양천구',
#   '서울특별시 양천구 목동서로 213 (목동) 세신비젼프라자',
#   Decimal('37.52801200000000'),
#   Decimal('126.87053000000000')),
#  (364,
#   1,
#   '목동5단지',
#   '양천구',
#   '서울특별시 양천구 목동동로 411, 1동 116호(목동, 부영그린타운3차)',
#   Decimal('37.53670600000000'),
#   Decimal('126.88212000000000')),
#  (365,
#   1,
#   '목동',
#   '양천구',
#   '서울특별시 양천구 목동서로 67 (목동) 우성에펠타운',
#   Decimal('37.53638383000000'),
#   Decimal('126.87855970000000')),
#  (366,
#   1,
#   '현대목동',
#   '양천구',
#   '서울특별시 양천구 목동동로 257 (목동, 현대하이페리온) 지하2층',
#   Decimal('37.52684800000000'),
# ...
#   Decimal('37.49478620000000'),
#   Decimal('127.01449960000000')),
#  (878,
#   2,
#   '서초역점',
#   '서초구',
#   '서울 서초구 서초동 ',
#   Decimal('37.48838690000000'),
#   Decimal('127.01679540000000')),
#  (879,
#   2,
#   '서초우면중앙점',
#   '서초구',
#   '서울 서초구 양재대로2길 100-11 (우면동, 서초 리슈빌S)',
#   Decimal('37.45620770000000'),
#   Decimal('127.01620330000000')),
#  (880,
#   2,
#   '서초점',
#   '서초구',
#   '서울 서초구 서초대로48길 16 (서초동)',
#   Decimal('37.49205460000000'),
#   Decimal('127.01133480000000')),
#  (881,
#   2,
#   '신사멀버리힐스점',
#   '서초구',
#   '서울 서초구 강남대로 589 (잠원동)',
#   Decimal('37.51438730000000'),
#   Decimal('127.01915000000000')),
#  (882,
#   2,
#   '양재언남점',
#   '서초구',
#   '서울 서초구 동산로 60 (양재동, 화성빌딩)',
#   Decimal('37.46854769999999'),
#   Decimal('127.02780080000000')),
#  (883,
#   2,
#   '양재점',
#   '서초구',
#   '서울 서초구 남부순환로347길 38 (서초동)',
#   Decimal('37.48603920000000'),
#   Decimal('127.03149020000000')),
#  (884,
#   2,
#   '양재중앙점',
#   '서초구',
#   '서울 서초구 강남대로 221 (양재동, 양재역 환승주차장)',
#   Decimal('37.47854670000000'),
#   Decimal('127.04132690000000')),
#  (885,
#   2,
#   '양재하나로마트점',
#   '서초구',
#   '서울 서초구 청계산로 10 (양재동, 농협하나로클럽)',
#   Decimal('37.46279880000000'),
#   Decimal('127.04386750000000')),
#  (886,
#   2,
#   '예술의전당점',
#   '서초구',
#   '서울 서초구 반포대로 32 (서초동, 원일빌딩)',
#   Decimal('37.48337890000000'),
#   Decimal('127.01210740000000')),
#  (887,
#   2,
#   '우면동점',
#   '서초구',
#   '서울 서초구 바우뫼로 20 (우면동, 고호빌딩)',
#   Decimal('37.46996410000000'),
#   Decimal('127.02530100000000')),
#  (888,
#   2,
#   '잠원논현점',
#   '서초구',
#   '서울 서초구 신반포로 333 (잠원동)',
#   Decimal('37.51091800000000'),
#   Decimal('127.02006920000000')),
#  (889,
#   2,
#   '청계산입구역점',
#   '서초구',
#   '서울 서초구 신원동',
#   Decimal('37.44417420000000'),
#   Decimal('127.06214500000000')),
#  (890,
#   2,
#   '포이점',
#   '서초구',
#   '서울 서초구 마방로10길 42 (양재동)',
#   Decimal('37.47565220000000'),
#   Decimal('127.04455970000000')),
#  (891,
#   2,
#   '함지박사거리점',
#   '서초구',
#   '서울 서초구 방배로 234 우신빌딩',
#   Decimal('37.47807380000000'),
#   Decimal('127.00071980000000')),
#  (892,
#   2,
#   '고대개운점',
#   '성북구',
#   '서울 성북구 개운사길 30 (안암동5가)',
#   Decimal('37.58769040000000'),
#   Decimal('127.02943560000000')),
#  (893,
#   2,
#   '고대점',
#   '성북구',
#   '서울 성북구 고려대로24길 35 (안암동5가)',
#   Decimal('37.58468380000000'),
#   Decimal('127.02955620000000')),
#  (894,
#   2,
#   '길음뉴타운점',
#   '성북구',
#   '서울 성북구 길음로 74 (길음동, 길음 에스에이치빌)',
#   Decimal('37.60968510000000'),
#   Decimal('127.02071040000000')),
#  (895,
#   2,
#   '돈암동점',
#   '성북구',
#   '서울 성북구 동소문로 119 (동선동4가)',
#   Decimal('37.59436330000000'),
#   Decimal('127.01853130000000')),
#  (896,
#   2,
#   '돈암아리랑점',
#   '성북구',
#   '서울 성북구 아리랑로 75 (돈암동, 돈암코오롱하늘채)',
#   Decimal('37.59910680000000'),
#   Decimal('127.01379480000000')),
#  (897,
#   2,
#   '돌곶이역점',
#   '성북구',
#   '서울 성북구 돌곶이로22길 3 (석관동)',
#   Decimal('37.61020710000000'),
#   Decimal('127.05810310000000')),
#  (898,
#   2,
#   '동덕여대점',
#   '성북구',
#   '서울 성북구 화랑로 99 (하월곡동)',
#   Decimal('37.60561100000000'),
#   Decimal('127.03801820000000')),
#  (899,
#   2,
#   '동소문동점',
#   '성북구',
#   '서울 성북구 동소문로13길 5 (동소문동4가)',
#   Decimal('37.59204520000000'),
#   Decimal('127.01287510000000')),
#  (900,
#   2,
#   '보문역점',
#   '성북구',
#   '서울 성북구 보문로 111 (보문동2가)',
#   Decimal('37.58488090000001'),
#   Decimal('127.01916830000000')),
#  (901,
#   2,
#   '석계중앙점',
#   '성북구',
#   '서울 성북구 화랑로40길 61 (석관동)',
#   Decimal('37.60737240000000'),
#   Decimal('127.06311940000000')),
#  (902,
#   2,
#   '석관동점',
#   '성북구',
#   '서울 성북구 돌곶이로8길 22 (석관동, 래미안아트리치)',
#   Decimal('37.60610300000000'),
#   Decimal('127.06342290000000')),
#  (903,
#   2,
#   '성신여대역점',
#   '성북구',
#   '서울 성북구 동소문로17길 40 (동소문동6가)',
#   Decimal('37.59394370000000'),
#   Decimal('127.01592840000000')),
#  (904,
#   2,
#   '성신여대점',
#   '성북구',
#   '서울 성북구 보문로34길 100 (동선동2가)',
#   Decimal('37.59120290000000'),
#   Decimal('127.02079090000000')),
#  (905,
#   2,
#   '안암래미안점',
#   '성북구',
#   '서울 성북구 보문로30가길 42 (안암동1가)',
#   Decimal('37.58899940000000'),
#   Decimal('127.02202050000000')),
#  (906,
#   2,
#   '월곡1동점',
#   '성북구',
#   '서울 성북구 오패산로 99 (하월곡동)',
#   Decimal('37.61075770000000'),
#   Decimal('127.03513050000000')),
#  (907,
#   2,
#   '월곡동아점',
#   '성북구',
#   '서울 성북구 장월로1길 47 (상월곡동)',
#   Decimal('37.60619730000000'),
#   Decimal('127.04578430000000')),
#  (908,
#   2,
#   '장위2동점',
#   '성북구',
#   '서울 성북구 화랑로25길 14 (장위동)',
#   Decimal('37.61474040000000'),
#   Decimal('127.06035510000000')),
#  (909,
#   2,
#   '장위뉴타운점',
#   '성북구',
#   '서울 성북구 장월로 144-1 (장위동)',
#   Decimal('37.61765910000000'),
#   Decimal('127.05102320000000')),
#  (910,
#   2,
#   '장위동점',
#   '성북구',
#   '서울 성북구 월계로40길 7 (장위동)',
#   Decimal('37.62293470000000'),
#   Decimal('127.04846060000000')),
#  (911,
#   2,
#   '장위북서울꿈의숲점',
#   '성북구',
#   '서울 성북구 돌곶이로41가길 2 (장위동)',
#   Decimal('37.61864440000000'),
#   Decimal('127.04561080000000')),
#  (912,
#   2,
#   '장위중앙점',
#   '성북구',
#   '서울 성북구 장위로 35 (장위동)',
#   Decimal('37.61446150000000'),
#   Decimal('127.04077820000000')),
#  (913,
#   2,
#   '정릉중앙점',
#   '성북구',
#   '서울 성북구 정릉로 251 (정릉동)',
#   Decimal('37.60471920000000'),
#   Decimal('127.01196500000000')),
#  (914,
#   2,
#   '종암동점',
#   '성북구',
#   '서울 성북구 종암로 105 (종암동)',
#   Decimal('37.59959670000000'),
#   Decimal('127.03391670000000')),
#  (915,
#   2,
#   '하월곡동점',
#   '성북구',
#   '서울 성북구 오패산로 16 (하월곡동)',
#   Decimal('37.60363180000000'),
#   Decimal('127.03759470000000')),
#  (916,
#   2,
#   '한성대역점',
#   '성북구',
#   '서울 성북구 동소문로 19 (동소문동1가)',
#   Decimal('37.58899690000000'),
#   Decimal('127.00638970000000')),
#  (917,
#   2,
#   '한성대점',
#   '성북구',
#   '서울 성북구 삼선교로 10 (삼선동1가)',
#   Decimal('37.58773390000000'),
#   Decimal('127.00690930000000')),
#  (918,
#   2,
#   '가든파이브점',
#   '송파구',
#   '서울 송파구 충민로 10 (문정동, 가든파이브툴)',
#   Decimal('37.47841760000000'),
#   Decimal('127.11888770000000')),
#  (919,
#   2,
#   '가든파이브테크노관점',
#   '송파구',
#   '서울 송파구 충민로 66 (문정동, 가든파이브라이프)',
#   Decimal('37.47748419041258'),
#   Decimal('127.12496889994861')),
#  (920,
#   2,
#   '가락몰점',
#   '송파구',
#   '서울 송파구 양재대로 932 (가락동, 가락몰 판매동)',
#   Decimal('37.49311600000000'),
#   Decimal('127.11645390000000')),
#  (921,
#   2,
#   '가락중앙점',
#   '송파구',
#   '서울 송파구 송이로 87 (가락동)',
#   Decimal('37.49534590000000'),
#   Decimal('127.12384820000000')),
#  (922,
#   2,
#   '개롱역점',
#   '송파구',
#   '서울 송파구 오금로 407 (오금동, 상아아파트)',
#   Decimal('37.49772800000000'),
#   Decimal('127.13583500000000')),
#  (923,
#   2,
#   '거여점',
#   '송파구',
#   '서울 송파구 오금로 497 (거여동)',
#   Decimal('37.48220960000000'),
#   Decimal('127.14302510000000')),
#  (924,
#   2,
#   '문정KDU타워점',
#   '송파구',
#   '서울 송파구 정의로 70 (문정동, 케이디유타워)',
#   Decimal('37.48234360000000'),
#   Decimal('127.11720560000000')),
#  (925,
#   2,
#   '문정문현점',
#   '송파구',
#   '서울 송파구 새말로8길 30 (문정동)',
#   Decimal('37.48014720000000'),
#   Decimal('127.12665190000000')),
#  (926,
#   2,
#   '문정중앙점',
#   '송파구',
#   '서울 송파구 문정로 31-1 (문정동)',
#   Decimal('37.48646620000000'),
#   Decimal('127.12633400000000')),
#  (927,
#   2,
#   '문정테라타워점',
#   '송파구',
#   '서울 송파구 송파대로 167 (문정동, 문정역테라타워)',
#   Decimal('37.49186910000000'),
#   Decimal('127.11915170000000')),
#  (928,
#   2,
#   '방이시장점',
#   '송파구',
#   '서울 송파구 백제고분로48길 3 (방이동)',
#   Decimal('37.51186130000000'),
#   Decimal('127.11375760000000')),
#  (929,
#   2,
#   '방이역점',
#   '송파구',
#   '서울 송파구 위례성대로18길 32 (방이동)',
#   Decimal('37.50957590000000'),
#   Decimal('127.12471890000000')),
#  (930,
#   2,
#   '방이초교점',
#   '송파구',
#   '서울 송파구 가락로 280 (방이동)',
#   Decimal('37.51275620000000'),
#   Decimal('127.12004780000000')),
#  (931,
#   2,
#   '삼전역점',
#   '송파구',
#   '서울 송파구 백제고분로 263 (삼전동)',
#   Decimal('37.50279120000000'),
#   Decimal('127.09580080000000')),
#  (932,
#   2,
#   '삼전중앙점',
#   '송파구',
#   '서울 송파구 백제고분로27길 5 (삼전동)',
#   Decimal('37.50584140000000'),
#   Decimal('127.08979770000000')),
#  (933,
#   2,
#   '서울삼성내과점',
#   '송파구',
#   '서울 송파구 백제고분로 126 (잠실동, 오룡빌딩)',
#   Decimal('37.50615510000000'),
#   Decimal('127.08076680000000')),
#  (934,
#   2,
#   '석촌백제점',
#   '송파구',
#   '서울 송파구 백제고분로39길 15 (석촌동, 삼경빌딩)',
#   Decimal('37.50287330000000'),
#   Decimal('127.09898680000000')),
#  (935,
#   2,
#   '석촌사거리점',
#   '송파구',
#   '서울 송파구 송파대로 409 (석촌동, 범양빌딩)',
#   Decimal('37.50762770000000'),
#   Decimal('127.10815300000000')),
#  (936,
#   2,
#   '석촌역점',
#   '송파구',
#   '서울 송파구 송파대로 456 (송파동, 웅현빌딩)',
#   Decimal('37.50720400000000'),
#   Decimal('127.10584080000000')),
#  (937,
#   2,
#   '송파문정점',
#   '송파구',
#   '서울 송파구 송이로 159 (가락동)',
#   Decimal('37.49295690000000'),
#   Decimal('127.12535260000000')),
#  (938,
#   2,
#   '송파올림픽훼미리타운점',
#   '송파구',
#   '서울 송파구 중대로 24 (문정동, 올림픽훼밀리타운 아카데미 상가)',
#   Decimal('37.48851950000000'),
#   Decimal('127.11437750000000')),
#  (939,
#   2,
#   '송파위례점',
#   '송파구',
#   '서울 송파구 위례광장로 188 (장지동, 아이온스퀘어)',
#   Decimal('37.48116050000000'),
#   Decimal('127.14232920000000')),
#  (940,
#   2,
#   '송파파인타운점',
#   '송파구',
#   '서울 송파구 충민로2길 28 (장지동, 대진플라자2)',
#   Decimal('37.47729840000000'),
#   Decimal('127.12756860000000')),
#  (941,
#   2,
#   '송파풍납점',
#   '송파구',
#   '서울 송파구 강동대로9길 17-1 (풍납동)',
#   Decimal('37.52810059999999'),
#   Decimal('127.11654430000000')),
#  (942,
#   2,
#   '송파하비오점',
#   '송파구',
#   '서울 송파구 송파대로 111 (문정동, 파크하비오)',
#   Decimal('37.48165560000000'),
#   Decimal('127.12345150000000')),
#  (943,
#   2,
#   '송파한양점',
#   '송파구',
#   '서울 송파구 가락로 165 (송파동, 위례캐슬빌)',
#   Decimal('37.50320460000000'),
#   Decimal('127.11784920000000')),
#  (944,
#   2,
#   '오금점',
#   '송파구',
#   '서울 송파구 오금로 306 (가락동, 가락스타클래스)',
#   Decimal('37.50287860000000'),
#   Decimal('127.12612360000000')),
#  (945,
#   2,
#   '오금중앙점 ',
#   '송파구',
#   '서울 송파구 위례성대로22길 18 (오금동, 이시돌빌딩)',
#   Decimal('37.50871130000000'),
#   Decimal('127.13040080000000')),
#  (946,
#   2,
#   '올림픽공원점',
#   '송파구',
#   '서울 송파구 올림픽로 354 (방이동)',
#   Decimal('37.51567460000000'),
#   Decimal('127.12539150000000')),
#  (947,
#   2,
#   '올림픽프라자점',
#   '송파구',
#   '서울 송파구 양재대로 1222 (방이동)',
#   Decimal('37.51582570000000'),
#   Decimal('127.13221820000000')),
#  (948,
#   2,
#   '위례아이파크점',
#   '송파구',
#   '서울 송파구 위례광장로 136 (장지동, 위례아이파크)',
#   Decimal('37.47629600000000'),
#   Decimal('127.14213140000000')),
#  (949,
#   2,
#   '위례포레샤인점',
#   '송파구',
#   '서울 송파구 위례순환로 477 (장지동, 위례포레샤인23단지)',
#   Decimal('37.47628080000000'),
#   Decimal('127.13565490000000')),
#  (950,
#   2,
#   '잠실본동점',
#   '송파구',
#   '서울 송파구 백제고분로 172 (잠실동, 제이케이빌딩)',
#   Decimal('37.51194230000000'),
#   Decimal('127.08702540000000')),
#  (951,
#   2,
#   '잠실역점',
#   '송파구',
#   '서울 송파구 송파대로 567 (잠실동, 잠실주공아파트)',
#   Decimal('37.51432402116925'),
#   Decimal('127.09334786098638')),
#  (952,
#   2,
#   '종합운동장역점',
#   '송파구',
#   '서울 송파구 올림픽로 76 (잠실동, J타워)',
#   Decimal('37.51156630000000'),
#   Decimal('127.07902140000000')),
#  (953,
#   2,
#   '강서초교점',
#   '양천구',
#   '서울 양천구 오목로 48 (신월동)',
#   Decimal('37.52200520000000'),
#   Decimal('126.84294590000000')),
#  (954,
#   2,
#   '남부지방법원점',
#   '양천구',
#   '서울 양천구 은행정로4길 25 (신정동, SM엘루이아파트)',
#   Decimal('37.52153830000000'),
#   Decimal('126.86253760000000')),
#  (955,
#   2,
#   '목3동점',
#   '양천구',
#   '서울 양천구 목동중앙북로 38 (목동, 롯데캐슬위너아파트)',
#   Decimal('37.54688690000000'),
#   Decimal('126.86726110000000')),
#  (956,
#   2,
#   '목4동점',
#   '양천구',
#   '서울 양천구 목동중앙본로7길 46 (목동)',
#   Decimal('37.53949770000000'),
#   Decimal('126.86613100000000')),
#  (957,
#   2,
#   '목동센트럴아이파크위브점',
#   '양천구',
#   '서울 양천구 남부순환로 603 (신월동)',
#   Decimal('37.51521060000000'),
#   Decimal('126.84067040000000')),
#  (958,
#   2,
#   '목동신목점',
#   '양천구',
#   '서울 양천구 목동중앙로 85 (목동, 강산아파트)',
#   Decimal('37.53702030000000'),
#   Decimal('126.87145880000000')),
#  (959,
#   2,
#   '목동신트리점',
#   '양천구',
#   '서울 양천구 신정로 312 (신정동, 뉴프라자)',
#   Decimal('37.51323720000000'),
#   Decimal('126.85553970000000')),
#  (960,
#   2,
#   '목동아델리체점',
#   '양천구',
#   '서울 양천구 중앙로43길 14 (신정동, 래미안 목동아델리체)',
#   Decimal('37.51812730000000'),
#   Decimal('126.85198070000000')),
#  (961,
#   2,
#   '목동역점',
#   '양천구',
#   '서울 양천구 오목로 227 (신정동)',
#   Decimal('37.52607580000000'),
#   Decimal('126.86273430000000')),
#  (962,
#   2,
#   '목동파라곤점',
#   '양천구',
#   '서울 양천구 목동서로 155 (목동)',
#   Decimal('37.52950380000000'),
#   Decimal('126.87516350000000')),
#  (963,
#   2,
#   '목동파리공원점',
#   '양천구',
#   '서울 양천구 목동동로 379 (목동)',
#   Decimal('37.53560480000000'),
#   Decimal('126.87875980000000')),
#  (964,
#   2,
#   '신월5동점',
#   '양천구',
#   '서울 양천구 화곡로 50 (신월동)',
#   Decimal('37.53917180000000'),
#   Decimal('126.82743180000000')),
#  (965,
#   2,
#   '신월7동점',
#   '양천구',
#   '서울 양천구 지양로 79 (신월동)',
#   Decimal('37.52242370000000'),
#   Decimal('126.83296300000000')),
#  (966,
#   2,
#   '신월사거리점',
#   '양천구',
#   '서울 양천구 남부순환로 353 (신월동)',
#   Decimal('37.53568110000000'),
#   Decimal('126.82895290000000')),
#  (967,
#   2,
#   '신정교점',
#   '양천구',
#   '서울 양천구 신목로 36 (신정동)',
#   Decimal('37.51886900000000'),
#   Decimal('126.87382360000000')),
#  (968,
#   2,
#   '신정네거리역점',
#   '양천구',
#   '서울 양천구 중앙로 282 (신정동)',
#   Decimal('37.52158150000000'),
#   Decimal('126.85264660000000')),
#  (969,
#   2,
#   '신정서부점',
#   '양천구',
#   '서울 양천구 신정로11길 50-15 (신정동)',
#   Decimal('37.51221980000000'),
#   Decimal('126.83834770000000')),
#  (970,
#   2,
#   '신정역점',
#   '양천구',
#   '서울 양천구 오목로 155 (신정동)',
#   Decimal('37.52498280000000'),
#   Decimal('126.85465240000000')),
#  (971,
#   2,
#   '양천구청점',
#   '양천구',
#   '서울 양천구 목동동로 63 (신정동)',
#   Decimal('37.51530850000000'),
#   Decimal('126.86231800000000')),
#  (972,
#   2,
#   '오목교대학학원점',
#   '양천구',
#   '서울 양천구 오목로 319 (목동)',
#   Decimal('37.52508050000000'),
#   Decimal('126.87307520000000')),
#  (973,
#   2,
#   'KBS별관점',
#   '영등포구',
#   '서울 영등포구 국제금융로8길 27-9 (여의도동, 동북빌딩)',
#   Decimal('37.51961690000000'),
#   Decimal('126.92895370000000')),
#  (974,
#   2,
#   '국회대로점',
#   '영등포구',
#   '서울 영등포구 국회대로72길 4 (여의도동, 아이비피아빌딩)',
#   Decimal('37.53030550000000'),
#   Decimal('126.91996340000000')),
#  (975,
#   2,
#   '국회의사당역점',
#   '영등포구',
#   '서울 영등포구 의사당대로 22 (여의도동, 이룸센터)',
#   Decimal('37.52682930000000'),
#   Decimal('126.91783000000000')),
#  (976,
#   2,
#   '남부고용센터점',
#   '영등포구',
#   '서울 영등포구 양산로 71 (양평동3가)',
#   Decimal('37.52988780000000'),
#   Decimal('126.89251860000000')),
#  (977,
#   2,
#   '당산버드나루점',
#   '영등포구',
#   '서울 영등포구 버드나루로 87 (영등포동7가)',
#   Decimal('37.52479540000000'),
#   Decimal('126.90731630000000')),
#  (978,
#   2,
#   '당산역점',
#   '영등포구',
#   '서울 영등포구 당산로 222 (당산동5가, 당산디오빌)',
#   Decimal('37.53329740000000'),
#   Decimal('126.90223970000000')),
#  (979,
#   2,
#   '당산중앙점',
#   '영등포구',
#   '서울 영등포구 당산로 159 (당산동4가)',
#   Decimal('37.52905960000000'),
#   Decimal('126.89908220000000')),
#  (980,
#   2,
#   '대림1동점',
#   '영등포구',
#   '서울 영등포구 도림로 198 (대림동)',
#   Decimal('37.49643720000000'),
#   Decimal('126.90284230000000')),
#  (981,
#   2,
#   '대림3동점',
#   '영등포구',
#   '서울 영등포구 대림로 212 (대림동)',
#   Decimal('37.49958420000000'),
#   Decimal('126.89818720000000')),
#  (982,
#   2,
#   '대림역점',
#   '영등포구',
#   '서울 영등포구 도림로31길 2 (대림동)',
#   Decimal('37.49254740000000'),
#   Decimal('126.89592550000000')),
#  (983,
#   2,
#   '도림사거리점',
#   '영등포구',
#   '서울 영등포구 도림로 326 (신길동)',
#   Decimal('37.50658150000000'),
#   Decimal('126.90180010000000')),
#  (984,
#   2,
#   '도림점',
#   '영등포구',
#   '서울 영등포구 도신로15길 40 (도림동, 도림빌딩)',
#   Decimal('37.51059260000000'),
#   Decimal('126.90877370000000')),
#  (985,
#   2,
#   '라이프점',
#   '영등포구',
#   '서울 영등포구 63로 40 (여의도동, 라이프오피스텔)',
#   Decimal('37.51956203765937'),
#   Decimal('126.93913907874030')),
#  (986,
#   2,
#   '보라매역점',
#   '영등포구',
#   '서울 영등포구 여의대방로 141 (신길동)',
#   Decimal('37.50744760000000'),
#   Decimal('126.91679880000000')),
#  (987,
#   2,
#   '서여의도점',
#   '영등포구',
#   '서울 영등포구 국회대로72길 17 (여의도동, KCC파크타운)',
#   Decimal('37.52954760000000'),
#   Decimal('126.92122570000000')),
#  (988,
#   2,
#   '선유도역점',
#   '영등포구',
#   '서울 영등포구 양평로 126 (양평동5가)',
#   Decimal('37.54117230000000'),
#   Decimal('126.89443370000000')),
#  (989,
#   2,
#   '신길성애병원점',
#   '영등포구',
#   '서울 영등포구 여의대방로53길 27 (신길동)',
#   Decimal('37.51778300000000'),
#   Decimal('126.91728360000000')),
#  (990,
#   2,
#   '신길썬프라자점',
#   '영등포구',
#   '서울 영등포구 신길로 42 (신길동)',
#   Decimal('37.49647690000000'),
#   Decimal('126.90862710000000')),
#  (991,
#   2,
#   '신길아이파크점',
#   '영등포구',
#   '서울 영등포구 도림로 280 (신길동)',
#   Decimal('37.50294080000000'),
#   Decimal('126.90421560000000')),
#  (992,
#   2,
#   '신길역점',
#   '영등포구',
#   '서울 영등포구 영등포로 353 (신길동)',
#   Decimal('37.51507080000000'),
#   Decimal('126.91809500000000')),
#  (993,
#   2,
#   '신길중앙점',
#   '영등포구',
#   '서울 영등포구 도신로 229 (신길동)',
#   Decimal('37.51219970000000'),
#   Decimal('126.91650530000000')),
#  (994,
#   2,
#   '신풍역점',
#   '영등포구',
#   '서울 영등포구 신풍로 52-1 (신길동)',
#   Decimal('37.49994590000000'),
#   Decimal('126.91179310000000')),
#  (995,
#   2,
#   '양평동2가점',
#   '영등포구',
#   '서울 영등포구 선유서로25길 19 (양평동2가, 오목교투웨니퍼스트)',
#   Decimal('37.52432510000000'),
#   Decimal('126.88373130000000')),
#  (996,
#   2,
#   '여의나루역점',
#   '영등포구',
#   '서울 영등포구 여의나루로 113 (여의도동)',
#   Decimal('37.52602880000000'),
#   Decimal('126.93075110000000')),
#  (997,
#   2,
#   '여의도농협재단점',
#   '영등포구',
#   '서울 영등포구 국제금융로8길 2 (여의도동, 농협재단빌딩)',
#   Decimal('37.52198380000000'),
#   Decimal('126.93003100000000')),
#  (998,
#   2,
#   '여의도역점',
#   '영등포구',
#   '서울 영등포구 의사당대로 108 (여의도동, 아일렉스)',
#   Decimal('37.52102360000000'),
#   Decimal('126.92401160000000')),
#  (999,
#   2,
#   '영등포knk점',
#   '영등포구',
#   '서울 영등포구 영신로 220 (영등포동8가, KnK디지털타워)',
#   Decimal('37.52655400000000'),
#   Decimal('126.90429900000000')),
#  (1000,
#   2,
#   '영등포구청점',
#   '영등포구',
#   '서울 영등포구 당산로 110 (당산동3가)',
#   Decimal('37.52691890000000'),
#   Decimal('126.89838190000000')),
#  ...]

# %%
cursor.execute("DESC COFFEE_BRAND;")
cursor.fetchall()
# Out:
# [('id', b'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('name', b'varchar(255)', 'YES', '', None, '')]

# %%
cursor.execute("SELECT * FROM COFFEE_BRAND;")
cursor.fetchall()
# Out:
# [(1, 'STARBUCKS'), (2, 'EDIYA')]

# %%
# 스타벅스 매장 주요 분포 지역 (매장수가 많은 상위 5개 구이름, 매장 개수 출력)
cursor.execute("SELECT gu_name, COUNT(*) as store_count FROM COFFEE_STORE WHERE brand=1 GROUP BY gu_name ORDER BY store_count DESC LIMIT 5")
cursor.fetchall()
# Out:
# [('강남구', 89), ('중구', 54), ('서초구', 48), ('영등포구', 42), ('종로구', 40)]

# %%
# 이디야 매장 주요 분포 지역 (매장수가 많은 상위 5개 구이름, 매장 개수 출력)
cursor.execute("SELECT gu_name, COUNT(*) as store_count FROM COFFEE_STORE WHERE brand=2 GROUP BY gu_name ORDER BY store_count DESC LIMIT 5")
cursor.fetchall()
# Out:
# [('영등포구', 40), ('강남구', 39), ('송파구', 35), ('마포구', 31), ('강서구', 31)]

# %%
# 구별 브랜드 각각의 매장 개수 조회 (구이름, 브랜드이름, 매장 개수 출력)
cursor.execute("SELECT s.gu_name, b.name, COUNT(s.brand) FROM COFFEE_BRAND AS b, COFFEE_STORE AS s WHERE b.id=s.brand GROUP BY s.gu_name, b.name ORDER BY s.gu_name, b.name DESC;")
cursor.fetchall()
# Out:
# [('강남구', 'STARBUCKS', 89),
#  ('강남구', 'EDIYA', 39),
#  ('강동구', 'STARBUCKS', 17),
#  ('강동구', 'EDIYA', 23),
#  ('강북구', 'STARBUCKS', 6),
#  ('강북구', 'EDIYA', 12),
#  ('강서구', 'STARBUCKS', 27),
#  ('강서구', 'EDIYA', 31),
#  ('관악구', 'STARBUCKS', 12),
#  ('관악구', 'EDIYA', 24),
#  ('광진구', 'STARBUCKS', 18),
#  ('광진구', 'EDIYA', 20),
#  ('구로구', 'STARBUCKS', 14),
#  ('구로구', 'EDIYA', 24),
#  ('금천구', 'STARBUCKS', 13),
#  ('금천구', 'EDIYA', 19),
#  ('노원구', 'STARBUCKS', 14),
#  ('노원구', 'EDIYA', 20),
#  ('도봉구', 'STARBUCKS', 6),
#  ('도봉구', 'EDIYA', 22),
#  ('동대문구', 'STARBUCKS', 10),
#  ('동대문구', 'EDIYA', 23),
#  ('동작구', 'STARBUCKS', 11),
#  ('동작구', 'EDIYA', 21),
#  ('마포구', 'STARBUCKS', 36),
#  ('마포구', 'EDIYA', 31),
#  ('서대문구', 'STARBUCKS', 22),
#  ('서대문구', 'EDIYA', 16),
#  ('서초구', 'STARBUCKS', 48),
#  ('서초구', 'EDIYA', 29),
#  ('성동구', 'STARBUCKS', 14),
#  ('성동구', 'EDIYA', 19),
#  ('성북구', 'STARBUCKS', 15),
#  ('성북구', 'EDIYA', 26),
#  ('송파구', 'STARBUCKS', 36),
#  ('송파구', 'EDIYA', 35),
#  ('양천구', 'STARBUCKS', 17),
#  ('양천구', 'EDIYA', 20),
#  ('영등포구', 'STARBUCKS', 42),
#  ('영등포구', 'EDIYA', 40),
#  ('용산구', 'STARBUCKS', 25),
#  ('용산구', 'EDIYA', 13),
#  ('은평구', 'STARBUCKS', 13),
#  ('은평구', 'EDIYA', 23),
#  ('종로구', 'STARBUCKS', 40),
#  ('종로구', 'EDIYA', 28),
#  ('중구', 'STARBUCKS', 54),
#  ('중구', 'EDIYA', 29),
#  ('중랑구', 'STARBUCKS', 8),
#  ('중랑구', 'EDIYA', 27)]

# %% [markdown]
# - brand=1 일 때 STARBUCKS / brand=2 일 때 EDIYA
# - group by 는 구 이름과 브랜드별로 묶어주면 됨

# %%
# 구별 브랜드 각각의 매장 개수 조회 (구이름, 스타벅스 매장 개수, 이디야 매장 개수 출력)
cursor.execute("SELECT s.gu_name, s.count, e.count FROM (SELECT gu_name, COUNT(brand) AS count FROM COFFEE_STORE WHERE brand=1 GROUP BY gu_name) AS s, (SELECT gu_name, COUNT(brand) AS count FROM COFFEE_STORE WHERE brand=2 GROUP BY gu_name) AS e WHERE s.gu_name=e.gu_name")
cursor.fetchall()
# Out:
# [('강남구', 89, 39),
#  ('강북구', 6, 12),
#  ('강서구', 27, 31),
#  ('관악구', 12, 24),
#  ('광진구', 18, 20),
#  ('금천구', 13, 19),
#  ('노원구', 14, 20),
#  ('도봉구', 6, 22),
#  ('동작구', 11, 21),
#  ('마포구', 36, 31),
#  ('서대문구', 22, 16),
#  ('서초구', 48, 29),
#  ('성북구', 15, 26),
#  ('송파구', 36, 35),
#  ('양천구', 17, 20),
#  ('영등포구', 42, 40),
#  ('은평구', 13, 23),
#  ('종로구', 40, 28),
#  ('중구', 54, 29),
#  ('강동구', 17, 23),
#  ('구로구', 14, 24),
#  ('동대문구', 10, 23),
#  ('성동구', 14, 19),
#  ('용산구', 25, 13),
#  ('중랑구', 8, 27)]

# %% [markdown]
# Tableau로 시각화를 위하여 쿼리를 통해 csv 파일로 저장하자
#
#
# - 전체 데이터를 가져오는데, 각 스타벅스 매장별로 이디야 전체 매장정보가 매칭되어 있어야 함 (정렬 : s_id, e_id 순)
# - 다음의 형식으로 저장되어야 함 (브랜드 이름, 칼럼 명 주의)
# - 데이터 프레임으로 출력해보자

# %%
import pandas as pd

sql =  "SELECT * FROM (SELECT s.id AS s_id, b.name AS s_brand, s.name AS s_name, s.gu_name AS s_gu, s.address AS s_address, s.lat AS s_lat, s.lng AS s_lng FROM COFFEE_STORE AS s, COFFEE_BRAND AS b WHERE b.id = s.brand AND b.name LIKE 'STARBUCKS') AS st, (SELECT s.id AS e_id, b.name AS e_brand, s.name AS e_name, s.gu_name AS e_gu, s.address AS e_address, s.lat AS e_lat, s.lng AS e_lng from COFFEE_STORE AS s, COFFEE_BRAND AS b WHERE b.id = s.brand AND b.name LIKE 'EDIYA') AS ed ORDER BY st.s_id, ed.e_id"

cursor.execute(sql)
result = cursor.fetchall()
field_names = [i[0] for i in cursor.description]

df = pd.DataFrame(result)
df.columns = field_names

df.to_csv('coffee_output.csv', index = False, encoding = "utf-8")

# %% [markdown]
# ---
